# %%
""" 0. set-up part:  import necessary libraries and set up environment """

import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from collections import Counter, defaultdict
import numpy as np
import math
import copy
import itertools
import matplotlib.pyplot as plt
import matplotlib as mpl

import joblib
from joblib import Parallel, delayed
from threading import Thread

import os
import pickle
import time

import operator
from functools import reduce
import json
import cProfile

# download nltk data once time
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('omw-1.4')
# nltk.download('punkt_tab')
# nltk.download('averaged_perceptron_tagger_eng')

#  chinese character support in matplotlib
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS' 'SimHei' 'DejaVu Sans']  
plt.rcParams['axes.unicode_minus'] = False

# %%
""" 1.1 Data Preprocessing: load data, clean text, lemmatization, remove low-frequency words"""

# Map POS tags to WordNet format， Penn Treebank annotation: fine-grained (45 tags), WordNet annotation: coarse-grained (4 tags: a, v, n, r)
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return 'a'  # 形容词
    elif treebank_tag.startswith('V'):
        return 'v'  # 动词
    elif treebank_tag.startswith('N'):
        return 'n'  # 名词
    elif treebank_tag.startswith('R'):
        return 'r'  # 副词
    else:
        return 'n'  # 默认名词

# Text cleaning and lemmatization preprocessing function
def clean_and_lemmatize(text):
    if pd.isnull(text):
        return []
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # Remove non-alphabetic characters using regex
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    pos_tags = pos_tag(tokens)
    lemmatized = [lemmatizer.lemmatize(w, get_wordnet_pos(pos)) for w, pos in pos_tags]
    return lemmatized  

#-----------------Load data----------------
data = pd.read_excel('./data/raw/papers_CM.xlsx', usecols=['PaperID', 'Abstract', 'Keywords', 'Year'])

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# clean and lemmatize the abstracts
data['Lemmatized_Tokens'] = data['Abstract'].apply(clean_and_lemmatize)

# count word frequencies
all_tokens = [word for tokens in data['Lemmatized_Tokens'] for word in tokens]
word_counts = Counter(all_tokens)

# set a minimum frequency threshold for valid words
min_freq = 10
valid_words = set([word for word, freq in word_counts.items() if freq >= min_freq])

# remove rare words based on frequency threshold
def remove_rare_words(tokens):
    return [word for word in tokens if word in valid_words]

data['Filtered_Tokens'] = data['Lemmatized_Tokens'].apply(remove_rare_words)

# join tokens back into cleaned abstracts
data['Cleaned_Abstract'] = data['Filtered_Tokens'].apply(lambda x: " ".join(x))

# create a cleaned DataFrame with relevant columns
cleaned_data = data[['PaperID', 'Year', 'Cleaned_Abstract']]
cleaned_data = cleaned_data[~(cleaned_data['PaperID'] == 57188)] # this paper has no abstract
cleaned_data = cleaned_data.reset_index(drop=True) 
cleaned_data.insert(0, 'Document_ID', range(len(cleaned_data))) 
abstract_list = cleaned_data['Cleaned_Abstract'].apply(lambda x: x.split()).tolist()

corpus = {doc_id: abstract_list for doc_id, abstract_list in enumerate(abstract_list)}
# cleaned_data.to_csv('./data/processed/cleaned_data.xlsx', index=False, encoding='utf-8-sig')

# %%
""" 1.2 Corpus Analysis: create corpus word frequency table, document-word matrix, and generate corpus statistics """

# Create corpus word frequency table
def create_corpus_word_frequency_table(corpus):
    # count all words in the corpus
    all_words = [word for doc in corpus.values() for word in doc]
    word_freq_counter = Counter(all_words)
    
    # create a DataFrame for word frequencies
    word_freq_df = pd.DataFrame([
        {'Word': word, 'Frequency': freq}
        for word, freq in word_freq_counter.items()
    ]).sort_values('Frequency', ascending=False).reset_index(drop=True)
    
    # add statistics like total words, unique words, and percentages
    total_words = len(all_words)
    unique_words = len(word_freq_counter)
    
    word_freq_df['Percentage'] = (word_freq_df['Frequency'] / total_words * 100).round(4)
    word_freq_df['Cumulative_Percentage'] = word_freq_df['Percentage'].cumsum().round(4)
    
    # add word distribution across documents like document count and percentage
    word_doc_count = {}
    for word in word_freq_counter.keys():
        doc_count = sum(1 for doc in corpus.values() if word in doc)
        word_doc_count[word] = doc_count
    
    word_freq_df['Document_Count'] = word_freq_df['Word'].map(word_doc_count)
    word_freq_df['Document_Percentage'] = (word_freq_df['Document_Count'] / len(corpus) * 100).round(4)
    
    # categorize frequency into High, Medium, Low, Very Low
    def categorize_frequency(freq, total):
        if freq >= total * 0.01:  # >1%
            return 'High'
        elif freq >= total * 0.001:  # 0.1%-1%
            return 'Medium'
        elif freq >= total * 0.0001:  # 0.01%-0.1%
            return 'Low'
        else:
            return 'Very Low'
    
    word_freq_df['Frequency_Category'] = word_freq_df['Frequency'].apply(
        lambda x: categorize_frequency(x, total_words)
    )
    
    # add ranking of words based on frequency
    word_freq_df['Rank'] = range(1, len(word_freq_df) + 1)
    
    # return DataFrame with selected columns in a specific order
    word_freq_df = word_freq_df[[
        'Rank', 'Word', 'Frequency', 'Percentage', 'Cumulative_Percentage',
        'Document_Count', 'Document_Percentage', 'Frequency_Category'
    ]]
    
    return word_freq_df

# Create document-word matrix
def create_document_word_matrix(corpus, cleaned_data=None):
    # get all unique words (sorted by frequency, keeping only the top 1000 most common words)
    all_words = [word for doc in corpus.values() for word in doc]
    word_counter = Counter(all_words)
    top_words = [word for word, _ in word_counter.most_common(1000)]
    
    # create a document-word matrix, where each row corresponds to a document and each column corresponds to a word
    # the value is the frequency of that word in the document
    doc_word_matrix = []
    
    for doc_id, doc in corpus.items():
        doc_counter = Counter(doc)
        row = [doc_counter.get(word, 0) for word in top_words]
        doc_word_matrix.append(row)
    
    # create DataFrame from the document-word matrix
    df = pd.DataFrame(doc_word_matrix, columns=top_words)
    
    # insert Document_ID and other metadata if available
    if cleaned_data is not None and len(cleaned_data) == len(corpus):
        df.insert(0, 'Document_ID', range(len(corpus)))
        df.insert(1, 'PaperID', cleaned_data['PaperID'].values)
        df.insert(2, 'Year', cleaned_data['Year'].values)
    else:
        df.insert(0, 'Document_ID', range(len(corpus)))
    
    return df

# Generate corpus statistics like total documents, total words, unique words, vocabulary richness, average document length, etc.
def generate_corpus_statistics(corpus, cleaned_data=None):

    # word frequency statistics
    total_docs = len(corpus)
    all_words = [word for doc in corpus.values() for word in doc]
    total_words = len(all_words)
    unique_words = len(set(all_words))
    
    # document length statistics
    doc_lengths = [len(doc) for doc in corpus.values()]
    
    # count word frequencies and return statistics
    word_counter = Counter(all_words)
    
    statistics = {
        'basic_stats': {
            'total_documents': total_docs,
            'total_words': total_words,
            'unique_words': unique_words,
            'vocabulary_richness': unique_words / total_words,
            'average_doc_length': np.mean(doc_lengths),
            'median_doc_length': np.median(doc_lengths),
            'min_doc_length': min(doc_lengths),
            'max_doc_length': max(doc_lengths),
            'std_doc_length': np.std(doc_lengths)
        },
        'frequency_distribution': {
            'words_appearing_once': sum(1 for freq in word_counter.values() if freq == 1),
            'words_appearing_2_5_times': sum(1 for freq in word_counter.values() if 2 <= freq <= 5),
            'words_appearing_6_20_times': sum(1 for freq in word_counter.values() if 6 <= freq <= 20),
            'words_appearing_more_than_20': sum(1 for freq in word_counter.values() if freq > 20),
        },
        'top_words': word_counter.most_common(20)
    }
    
    return statistics

#-------------------create word frequency summary-----------------
word_freq_table = create_corpus_word_frequency_table(corpus)

print(f"\n📊 Corpus word frequency information:")
print(f"total words: {word_freq_table['Frequency'].sum():,}")
print(f"num of unique words: {len(word_freq_table):,}")
print(f"average num of words for each doc: {word_freq_table['Frequency'].mean():.2f}")
print(f"standard deviation of word frequency among docs: {word_freq_table['Frequency'].std():.2f}")

print(f"\n🏆 Top 20 High-frequency words:")
print(word_freq_table.head(20).to_string(index=False))

print(f"\n📈 Word Rank Information:")
freq_category_stats = word_freq_table['Frequency_Category'].value_counts()
print(freq_category_stats)

#-------------------create document-word matrix and generate corpus statistics----------------
# create document-word matrix (optional, suitable for smaller datasets)

doc_word_matrix = create_document_word_matrix(corpus, cleaned_data)
print(f"\n📋 create doc-words matrix, shape of matrix is : {doc_word_matrix.shape}")

# generate detailed statistics
corpus_stats = generate_corpus_statistics(corpus, cleaned_data)

print(f"\n📊 Corpus detailed statistics info:")
print("=" * 50)
for category, stats in corpus_stats.items():
    print(f"\n{category.upper()}:")
    if isinstance(stats, dict):
        for key, value in stats.items():
            if isinstance(value, float):
                print(f"  {key}: {value:.4f}")
            else:
                print(f"  {key}: {value}")
    elif isinstance(stats, list):
        print("  Top words:")
        for word, freq in stats:
            print(f"    {word}: {freq}")

# ---------------------save statistics tables-------------------
print(f"\n💾 save statistics tables...")

# word_freq_table.to_csv('corpus_word_frequency_table.csv', index=False, encoding='utf-8')
print("✅ save <- corpus_word_frequency_table.csv")

if 'doc_word_matrix' in locals():
    # doc_word_matrix.to_csv('document_word_matrix.csv', index=False, encoding='utf-8')
    print("✅  save <- document_word_matrix.csv")

# 保存统计摘要
stats_df = pd.DataFrame([
    {'Metric': key, 'Value': value} 
    for category_stats in corpus_stats.values() 
    if isinstance(category_stats, dict)
    for key, value in category_stats.items()
])

# stats_df.to_csv('corpus_statistics_summary.csv', index=False, encoding='utf-8')
print("✅ save <- corpus_statistics_summary.csv")
# Out:
# 📊 Corpus word frequency information:
# total words: 83,202
# num of unique words: 1,490
# average num of words for each doc: 55.84
# standard deviation of word frequency among docs: 104.60
#
# 🏆 Top 20 High-frequency words:
#  Rank          Word  Frequency  Percentage  Cumulative_Percentage  Document_Count  Document_Percentage Frequency_Category
#     1        method       1598      1.9206                 1.9206             654              67.4227               High
#     2         model       1554      1.8677                 3.7883             579              59.6907               High
#     3       element       1112      1.3365                 5.1248             513              52.8866               High
#     4           use        999      1.2007                 6.3255             572              58.9691               High
#     5       propose        823      0.9892                 7.3147             510              52.5773             Medium
#     6     numerical        799      0.9603                 8.2750             535              55.1546             Medium
#     7       problem        774      0.9303                 9.2053             442              45.5670             Medium
#     8        finite        712      0.8557                10.0610             447              46.0825             Medium
#     9      material        695      0.8353                10.8963             339              34.9485             Medium
#    10       present        642      0.7716                11.6679             468              48.2474             Medium
#    11      approach        608      0.7308                12.3987             368              37.9381             Medium
#    12   formulation        575      0.6911                13.0898             305              31.4433             Medium
#    13          base        554      0.6658                13.7556             410              42.2680             Medium
#    14        result        526      0.6322                14.3878             402              41.4433             Medium
#    15 computational        486      0.5841                14.9719             333              34.3299             Medium
#    16      analysis        442      0.5312                15.5031             256              26.3918             Medium
#    17      solution        415      0.4988                16.0019             285              29.3814             Medium
#    18    simulation        405      0.4868                16.4887             261              26.9072             Medium
#    19      equation        404      0.4856                16.9743             251              25.8763             Medium
#    20          mesh        396      0.4760                17.4503             194              20.0000             Medium
#
# 📈 Word Rank Information:
# Frequency_Category
# Low       1264
# Medium     222
# High         4
# Name: count, dtype: int64
#
# 📋 create doc-words matrix, shape of matrix is : (970, 1003)
#
# 📊 Corpus detailed statistics info:
# ==================================================
#
# BASIC_STATS:
#   total_documents: 970
#   total_words: 83202
#   unique_words: 1490
#   vocabulary_richness: 0.0179
#   average_doc_length: 85.7753
#   median_doc_length: 81.0000
#   min_doc_length: 4
#   max_doc_length: 216
#   std_doc_length: 26.3635
#
# FREQUENCY_DISTRIBUTION:
#   words_appearing_once: 0
#   words_appearing_2_5_times: 0
#   words_appearing_6_20_times: 608
#   words_appearing_more_than_20: 882
#
# TOP_WORDS:
#   Top words:
#     method: 1598
#     model: 1554
#     element: 1112
#     use: 999
#     propose: 823
#     numerical: 799
#     problem: 774
#     finite: 712
#     material: 695
#     present: 642
#     approach: 608
#     formulation: 575
#     base: 554
#     result: 526
#     computational: 486
#     analysis: 442
#     solution: 415
#     simulation: 405
#     equation: 404
#     mesh: 396
#
# 💾 save statistics tables...
# ✅ save <- corpus_word_frequency_table.csv
# ✅  save <- document_word_matrix.csv
# ✅ save <- corpus_statistics_summary.csv

# %%
"""2. Core logic function: Chain Rule Process (CRP)"""
class Node:
    """
    Tree node class for hierarchical topic modeling using nested Chinese Restaurant Process (nCRP).
    Each node represents a topic in the hierarchy, with the tree structure representing
    the nested relationship between general and specific topics.
    """
    last_node_id = 0
    total_node = 0
    node_with_id = {}

    def __init__(self, parent=None, layer=0):
        self.node_id = Node.last_node_id # Unique identifier for this node
        Node.last_node_id += 1
        Node.total_node += 1
        self.layer = layer # layer (int): Depth level in the hierarchy (0=root, 1=first level, etc.)
        self.children = [] # children (list): List of child Node objects
        self.parent = parent # parent (Node): Reference to parent node (None for root)
        self.docs_list = [] # record index of documents reaching this node
        Node.node_with_id[self.node_id] = self 

    def add_child(self):
        child = Node(parent=self, layer=self.layer+1)
        self.children.append(child)
        return child
    
    def remove_child(self, child):
        self.children.remove(child)
        Node.node_with_id[child.node_id] = None 
        child.parent = None 
        Node.total_node -= 1

def nCRP(corpus, depth, gamma):
    """
    Nested Chinese Restaurant Process (nCRP) for initializing hierarchical topic structure.
    
    This function implements the generative process for creating a tree structure where:
    1. Each document follows a path from root to a leaf node
    2. At each level, documents choose to either create a new topic or join an existing one
    3. Words in documents are randomly assigned to topics along their path
    """
    # Initialize the root Node class each time nCRP is called
    Node.last_node_id = 0
    Node.total_node = 0
    Node.node_with_id = {}
    
    """
     Args:
        corpus (dict): Document collection {doc_id: [word1, word2, ...]}
        depth (int): Maximum depth of the topic hierarchy (number of levels)
        gamma (float): Concentration parameter controlling topic creation probability
                      Higher gamma -> more likely to create new topics
                      
    Returns: [root_node, path_list, doc_path, doc_word_allocation] where:
        - root_node (Node): Root node of the topic tree
        - path_list (dict): {leaf_node_id: [node0, node1, ...]} - Complete paths from root to each leaf
        - doc_path (dict): {doc_id: leaf_node_id} - Maps each document to its assigned leaf node
        - doc_word_allocation (dict): {doc_id: [layer0, layer1, ...]} - Word-to-layer assignments
    """

    root_node = Node()
    path_list = {} # {leaf_node_id: [node0, node2,...]} - record each path from root to leaf nodes
    doc_word_allocation = {} # {doc_id: {word: layer}} - record word allocation for each document
    doc_path = {} # [leaf_node_id, leaf_node_id, ...] - record only the leaf node id of the path， list indexed by doc_id
    
    for c, doc in corpus.items(): # c is the index, d is the document
        # print(doc)
        # all docs starts from the root node
        path = [root_node]
        root_node.docs_list.append(c)

        for i in range(1, depth):
            # chose node based on CRP
            parent_node = path[i-1]

            CRP_probs = [gamma/(gamma + len(parent_node.docs_list) - 1)] # choose a new node: gamma/(gamma + n - 1)
            for child in parent_node.children:
                CRP_probs.append(len(child.docs_list)/(gamma + len(parent_node.docs_list) - 1))

            chosen_index = np.random.choice(len(CRP_probs), p=CRP_probs) 
            if chosen_index == 0: # create a new node
                current_node = parent_node.add_child()
            else: # chose an existing node
                current_node = parent_node.children[chosen_index - 1]

            path.append(current_node)
            current_node.docs_list.append(c)

        if path[-1].node_id not in path_list.keys():
            path_list[path[-1].node_id] = path
        doc_path[c] = path[-1].node_id

        # assign the words location to the document
        word_allocation = []
        for word in doc:
            allocate_layer = np.random.randint(0,depth) # randomly allocate word to a layer
            word_allocation.append(allocate_layer)

        doc_word_allocation[c] = word_allocation
    return [root_node, path_list, doc_path, doc_word_allocation]

# %%
"""3. Core logic functions: Gibbs sampling, and relevant sub-function: word distribution, likelihood calculation, etc."""
def _create_default_dict_int():
    return defaultdict(int)

def aggregate_words(corpus, doc_word_allocation):
    """ 
    Convert document word-layer assignments into hierarchical node word count.

    Args:
        corpus: {doc_id: [word1, word2, ...]} - Document collection
        doc_word_allocation : {doc_id: [layer0, layer1, ...]} - Word-to-layer assignments
    
    Returns:
        doc_node_allocation: {doc_id: {layer: {word: count}}} - Nested word counts by document and layer
    """
    doc_node_allocation = {}

    for doc_id, doc in corpus.items(): # c is the index, d is the document
        allocation = doc_word_allocation[doc_id]
        
        # Use the named function here
        layer_counts = defaultdict(_create_default_dict_int)
        
        for word, layer in zip(doc, allocation):
            layer_counts[layer][word] += 1

        doc_node_allocation[doc_id] = layer_counts
    return doc_node_allocation

def node_word_distribution(doc_node_allocation, doc_path, path_list, exclude_docs=None):
    """
    Calculate global node-word distribution by aggregating word counts from all documents.
    
    Args:
        doc_node_allocation (dict): {doc_id: {layer: {word: count}}} - Document word counts by layer
        doc_path (dict): {doc_id: leaf_id} - Document to leaf node mapping
        path_list (dict): {leaf_id: [Node1, Node2, ...]} - Complete paths from root to leaf
        exclude_docs (set, optional): Document IDs to exclude from calculation
    
    Returns:
        node_word_dist: {node_id: {word: count}} - Word count distribution for each node
    """
    node_word_dist = defaultdict(lambda: defaultdict(int))
    exclude_docs = set() if exclude_docs is None else set(exclude_docs)
    
    for doc_id, leaf_id in doc_path.items():
        if doc_id in exclude_docs:
            continue
            
        path = path_list[leaf_id]
        
        doc_allocation = doc_node_allocation[doc_id]
        
        for node in path:
            node_layer = node.layer
            if node_layer in doc_allocation:
                for word, count in doc_allocation[node_layer].items():
                    node_word_dist[node.node_id][word] += count
    
    return node_word_dist

def calc_node_likelihood(compare_dist, target_dist, eta, len_W):
    """
    Calculate likelihood of generating target word distribution from comparison node 
    to any tree node using Dirichlet-multinomial model, providing a probability estimate to choose the best path.
   
    Args:
        compare_dist: {word: count} - Current word distribution of the comparison node
        target_dist: {word: count} - Target word distribution to be generated  
        eta (int): Dirichlet prior parameter (smoothing parameter)
        len_W (int): Vocabulary size
    
    Returns:
        float: Likelihood probability (or -inf for numerical overflow)
    """
    sum_A = sum(compare_dist.values()) + eta * len_W
    sum_B = sum(compare_dist.values()) + sum(target_dist.values()) + eta * len_W
    
    lgamma_sum_A = math.lgamma(sum_A)
    lgamma_sum_B = math.lgamma(sum_B)
    
    lgamma_prod_A = 0.0
    lgamma_prod_B = 0.0
    
    for word, count in target_dist.items():
        comp_val = compare_dist.get(word, 0)
        A = comp_val + eta
        B = comp_val + count + eta
        
        lgamma_prod_A += math.lgamma(A)
        lgamma_prod_B += math.lgamma(B)

    try:
        log_likelihood = (lgamma_sum_A - lgamma_prod_A) + (lgamma_prod_B - lgamma_sum_B)
        return math.exp(log_likelihood)
    except (OverflowError, ValueError):
        return float('-inf')  # 返回负无穷表示极小概率    

def create_new_path(base_node, doc_id, depth):
    new_path = []
    current = base_node
    while current:
        new_path.insert(0, current)
        current = current.parent
    
    current = base_node
    for _ in range(base_node.layer, depth-1):
        new_node = current.add_child()
        new_path.append(new_node)
        current = new_node
        
    return current.node_id, new_path

def exclude_doc_from_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id):
    doc_path_lst = path_list[doc_path[doc_id]]
    for node in doc_path_lst:
        if node.node_id in global_node_word_dist:
            for word, count in doc_node_allocation[doc_id].get(node.layer, {}).items():
                global_node_word_dist[node.node_id][word] -= count
                if global_node_word_dist[node.node_id][word] <= 0:
                    del global_node_word_dist[node.node_id][word]
    return global_node_word_dist

def add_doc_to_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id):
    """将文档的词分布添加到全局词分布中"""
    doc_path_lst = path_list[doc_path[doc_id]]
    for node in doc_path_lst:
        node_layer = node.layer
        if node_layer in doc_node_allocation[doc_id]:
            for word, count in doc_node_allocation[doc_id][node_layer].items():
                if node.node_id not in global_node_word_dist:
                    global_node_word_dist[node.node_id] = defaultdict(int)
                global_node_word_dist[node.node_id][word] += count
    return global_node_word_dist

def Gibbs_sampling(corpus, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
                   gamma, eta, alpha, depth, iteration, iter_start=None, iter_end=None):
    W = set(itertools.chain.from_iterable(corpus.values()))

    for doc_id, doc in corpus.items():
        # print('doc_id', doc_id)
        current_path = path_list[doc_path[doc_id]]
        current_node_allocation = doc_node_allocation[doc_id]
        node_word_dist = exclude_doc_from_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id)
        # print('g2',global_node_word_dist[0])

        # isolate doc_c from current situation
        nodes_to_remove = []
        for node in current_path[::-1]:
            node.docs_list.remove(doc_id)
            if len(node.docs_list) == 0 and node != root_node:
                nodes_to_remove.append(node)
        
        if nodes_to_remove:
            del path_list[doc_path[doc_id]]
            for node in nodes_to_remove:
                if node.parent:  # 再次检查以确保安全
                    node.parent.remove_child(node)

        # sample path
        path_prior_lst = {}
        path_likelihood_lst = {}

        target_prior = {}
        target_likelihood = {}
        for path_id, path in path_list.items():
            node_prior_lst = [1.0]
            node_likelihood_lst = []
            
            for node in path:
                if node.parent:
                    prior = (len(node.docs_list)) / (gamma + len(node.parent.docs_list)) 
                    node_prior_lst.append(prior)
                
                if node.layer in current_node_allocation:
                    likelihood = calc_node_likelihood(node_word_dist[node.node_id], current_node_allocation[node.layer], eta, len(W))
                    node_likelihood_lst.append(likelihood)
                else:
                    node_likelihood_lst.append(0)

            target_prior[path_id] = node_prior_lst
            target_likelihood[path_id] = node_likelihood_lst

            path_prior = reduce(operator.mul, (x for x in node_prior_lst if x != 0), 1)
            path_likelihood = reduce(operator.mul, (x for x in node_likelihood_lst if x != 0), 1)
            path_prior_lst[path_id] = path_prior
            path_likelihood_lst[path_id] = path_likelihood

        multiplied_path_dict = {key: path_prior_lst[key] * path_likelihood_lst[key] for key in path_likelihood_lst}
        
        # create new path,
        new_path_prior_lst = {}
        new_path_likelihood_lst = {}

        new_target_prior = {}
        new_target_likelihood = {}

        for node_id, node in Node.node_with_id.items():
            if node != None and node.layer < depth-1:
                new_node_prior_lst = [gamma / (gamma + len(node.docs_list))]
                
                if 0 in current_node_allocation:
                    new_node_likelihood_lst = [calc_node_likelihood(node_word_dist[0], current_node_allocation[0], eta, len(W))]
                else:
                    new_node_likelihood_lst = [0]
                
                temp_node = node
                while temp_node.parent:
                    new_node_prior_lst.insert(0, (len(temp_node.docs_list)) / (gamma + len(temp_node.parent.docs_list)))             
                
                    if temp_node.layer in current_node_allocation:
                        new_node_likelihood_lst.insert(1, calc_node_likelihood(node_word_dist[temp_node.node_id], current_node_allocation[temp_node.layer], eta, len(W)))
                    else:
                        new_node_likelihood_lst.insert(1, 0)

                    temp_node = temp_node.parent

                for layer in range(node.layer+1, depth):
                    if layer in current_node_allocation:
                        new_node_likelihood_lst.append(calc_node_likelihood({}, current_node_allocation[layer], eta, len(W)))

                new_target_prior[node_id] = new_node_prior_lst
                new_target_likelihood[node_id] = new_node_likelihood_lst
                new_path_prior = reduce(operator.mul, (x for x in new_node_prior_lst if x != 0), 1)
                new_path_likelihood = reduce(operator.mul, (x for x in new_node_likelihood_lst if x != 0), 1)
                new_path_prior_lst[node_id] = new_path_prior
                new_path_likelihood_lst[node_id] = new_path_likelihood
        
        multiplied_new_path_dict = {f'create{key}': new_path_prior_lst[key] * new_path_likelihood_lst[key] for key in new_path_likelihood_lst}
        all_probs = {**multiplied_path_dict, **multiplied_new_path_dict}

        total_prob = sum(v for v in all_probs.values())
        if total_prob > 0:
            normalized_probs = {k: v/total_prob for k, v in all_probs.items()}
        else:
            normalized_probs = {k: 1.0/len(all_probs) for k in all_probs}
        # print(normalized_probs)
        
        chosen_path = np.random.choice(list(normalized_probs.keys()),p=list(normalized_probs.values()))
        if chosen_path.startswith('create'):
            base_node = Node.node_with_id[int(chosen_path[6:])]
            leaf_id, added_path = create_new_path(base_node, doc_id, depth)
            path_list.update({leaf_id:added_path})
            doc_path[doc_id] = leaf_id
        else:
            leaf_id = int(chosen_path)
            added_path = path_list[int(chosen_path)]
            doc_path[doc_id] = int(chosen_path)
        
        for node in added_path:
            node.docs_list.append(doc_id)
        
        """sample topic"""
        # node_word_dist_update = node_word_distribution(doc_node_allocation, doc_path, path_list, exclude_docs=None)
        node_word_dist_update = add_doc_to_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id)
        # print('g3',global_node_word_dist[0])
        
        doc_word2node = doc_word_allocation[doc_id]
        current_path = path_list[doc_path[doc_id]]
        update_doc_word2node = []
        for word, old_layer in zip(doc, doc_word2node):
            doc_node_allocation[doc_id][old_layer][word] -= 1
            node_word_dist_update[current_path[old_layer].node_id][word] -= 1
            topic_probs = {}

            for layer, topic in enumerate(current_path):
                word_in_topic = node_word_dist_update[topic.node_id].get(word,0)
                topic_in_doc = sum(doc_node_allocation[doc_id].get(layer,{}).values())

                word_prop = (word_in_topic+eta)/(sum(node_word_dist_update[topic.node_id].values())+len(W)*eta)
                topic_prop = (topic_in_doc+alpha)/(len(doc)+depth*alpha)
                topic_probs[layer] = word_prop*topic_prop
            
            total_topic_prob = sum(v for v in topic_probs.values() if v > 0)
            if total_topic_prob > 0:
                normalized_topic_probs = {k: v/total_topic_prob for k, v in topic_probs.items()}
            else:
                normalized_topic_probs = {k: 1.0/len(topic_probs) for k in topic_probs}

            chosen_layer = np.random.choice(list(normalized_topic_probs.keys()),p=list(normalized_topic_probs.values()))
            update_doc_word2node.append(chosen_layer)
            doc_node_allocation[doc_id][chosen_layer][word] += 1
            node_word_dist_update[current_path[chosen_layer].node_id][word] += 1

        doc_word_allocation[doc_id] = update_doc_word2node
        # print('g4',global_node_word_dist[0])

# %%
class Recorder:
    """Gibbs采样迭代记录器"""
    
    def __init__(self, corpus, depth, eta, alpha):
        self.corpus = corpus
        self.depth = depth
        self.eta = eta
        self.alpha = alpha
        self.iteration_records = []
        self.vocab = set(itertools.chain.from_iterable(corpus.values()))
        
    def record_iteration(self, iteration_num, root_node, path_list, doc_path, 
                        doc_word_allocation, doc_node_allocation, global_node_word_dist,
                        newly_created_paths=None, iter_start_for_detailed_log=float('inf')): # 添加新参数并设默认值
        """记录单次迭代的所有信息"""
        
        should_record_word_node_details_to_file = (iteration_num >= iter_start_for_detailed_log)

        # 计算改变路径的文档数
        changed_docs_count = 0
        if iteration_num > 0:  # 对第一轮之后的迭代进行统计
            previous_doc_paths = {doc['document_id']: doc['leaf_node_id'] 
                                for doc in self.iteration_records[-1]['doc_path_assignments']}
            changed_docs_count = sum(1 for doc_id, leaf_id in doc_path.items() 
                                if doc_id in previous_doc_paths and previous_doc_paths[doc_id] != leaf_id)
        
        # 1. 记录文档路径分配
        # file_name: gibbs_iteration_records_document_paths - 
        doc_path_records = []
        for doc_id, leaf_id in doc_path.items():
            doc_path_records.append({
                'iteration': iteration_num,
                'document_id': doc_id,
                'leaf_node_id': leaf_id,
                'path_created_this_iteration': leaf_id in (newly_created_paths or [])
            })
        
        # 2. 记录路径/树结构 
        # path_list: {leaf_id: [Node1, Node2, ...]}
        # doc_path: {doc_id: leaf_id}
        # file_name:gibbs_iteration_records_path_structures - 
        path_structure_records = []
        for leaf_id, path_nodes in path_list.items():
            node_ids = [node.node_id for node in path_nodes]
            
            docs_in_this_path = [doc_id for doc_id, assigned_leaf_id in doc_path.items()
                                if assigned_leaf_id == leaf_id]
            
            path_record = {
                'iteration': iteration_num,
                'leaf_node_id': leaf_id,
                'document_count': len(docs_in_this_path),
                'documents_in_path': docs_in_this_path,
                'path_created_this_iteration': leaf_id in (newly_created_paths or [])
            }

            for i in range(self.depth):
                layer_key = f'layer_{i}_node_id'
                if i < len(node_ids):
                    path_record[layer_key] = node_ids[i]
                else:
                    path_record[layer_key] = None 
            
            path_structure_records.append(path_record),
        
        # 3. 记录词语分配 (仅在详细记录窗口内填充)
        # file_name: gibbs_iteration_records_word_allocations - 
        # doc_word_allocation: {doc_id: [layer_for_word1, layer_for_word2,...]}
        word_allocation_records = []
        # attention: should_record_word_node_details_to_file = (iteration_num >= iter_start_for_detailed_log)
        if should_record_word_node_details_to_file:
            for doc_id, word_assignments in doc_word_allocation.items():
                doc_words = self.corpus[doc_id]
                for word_idx, (word, layer) in enumerate(zip(doc_words, word_assignments)):
                    word_allocation_records.append({
                        'iteration': iteration_num,
                        'document_id': doc_id,
                        'word_index': word_idx,
                        'word': word,
                        'assigned_layer': layer,
                        'leaf_node_id': doc_path[doc_id],
                        'assigned_node_id': path_list[doc_path[doc_id]][layer].node_id
                    })
        
        # 4. 计算节点词分布 (始终需要为log-likelihood计算)
        # file_name: gibbs_iteration_records_node_word_distributions - 
        # doc_node_allocation: ?
        # node_word_dist = self._calculate_node_word_distribution(
        #     doc_node_allocation, doc_path, path_list
        # )
        # node_word_dist: # {node_id: {word: count}}
        #   记录节点词分布 (仅在详细记录窗口内填充)
        node_word_records = []
        # attention: should_record_word_node_details_to_file = (iteration_num >= iter_start_for_detailed_log)
        if should_record_word_node_details_to_file:
            for node_id, current_word_dist in global_node_word_dist.items(): # 使用计算得到的 node_word_dist
                for word, count in current_word_dist.items():
                    node_word_records.append({
                        'iteration': iteration_num,
                        'node_id': node_id,
                        'word': word,
                        'count': count
                    })
        
        # 5. 计算生成概率/log-likelihood (始终使用计算出的 node_word_dist)
        # file_name: gibbs_iteration_records_iteration_summaries - 
        log_likelihood = self._calculate_log_likelihood(
            doc_path, path_list, doc_word_allocation, global_node_word_dist
        )
        
        # 6. 记录整体统计信息,
        # file_name: gibbs_iteration_records_iteration_summaries -
        iteration_summary = {
            'iteration': iteration_num,
            'total_paths': len(path_list),
            'total_documents': len(doc_path),
            'log_likelihood': log_likelihood,
            'changed_docs_count': changed_docs_count, 
            'newly_created_paths': len(newly_created_paths or []),
            'avg_path_size': np.mean([len([doc_id for doc_id, assigned_leaf_id in doc_path.items() 
                                            if assigned_leaf_id == leaf_id]) for leaf_id in path_list.keys()]) if path_list else 0,
            'max_path_size': max([len([doc_id for doc_id, assigned_leaf_id in doc_path.items() 
                                        if assigned_leaf_id == leaf_id]) for leaf_id in path_list.keys()]) if path_list else 0,
            'min_path_size': min([len([doc_id for doc_id, assigned_leaf_id in doc_path.items() 
                                        if assigned_leaf_id == leaf_id]) for leaf_id in path_list.keys()]) if path_list else 0,
        #     'doc_path': doc_path,
        #     'doc_node_allocation':doc_node_allocation
        }
            
        self.iteration_records.append({
            'iteration': iteration_num,
            'doc_path_assignments': doc_path_records,
            'path_structures': path_structure_records,
            'word_allocations': word_allocation_records, # 如果不满足条件，则为空列表
            'node_word_distributions': node_word_records, # 如果不满足条件，则为空列表
            'iteration_summary': iteration_summary
        })
        
        return iteration_summary
    
    # def _calculate_node_word_distribution(self, doc_node_allocation, doc_path, path_list):
    #     """计算节点词分布"""
    #     node_word_dist = defaultdict(lambda: defaultdict(int))
        
    #     for doc_id, leaf_id in doc_path.items():
    #         path = path_list[leaf_id]
    #         doc_allocation = doc_node_allocation[doc_id]
            
    #         for node in path:
    #             node_layer = node.layer
    #             if node_layer in doc_allocation:
    #                 for word, count in doc_allocation[node_layer].items():
    #                     node_word_dist[node.node_id][word] += count
        
    #     return node_word_dist

    def _calculate_log_likelihood(self, doc_path, path_list, 
                                    doc_word_allocation, # {doc_id: [layer_for_word1, layer_for_word2,...]}
                                    node_word_dist):     # {node_id: {word: count}}
        """
        计算在当前文档词语层级分配和路径下，重新生成所有文档词语的对数概率。
        log P(Words | WordLayerAssignments, Paths, eta)
        """
        total_log_likelihood = 0.0
        vocab_size = len(self.vocab)
        
        # 预计算每个节点的总词数
        node_total_words_map = defaultdict(int)
        for node_id, dist in node_word_dist.items():
            node_total_words_map[node_id] = sum(dist.values())

        for doc_id, words_in_doc in self.corpus.items():
            if not words_in_doc:
                continue

            current_doc_word_layer_assignments = doc_word_allocation[doc_id]
            current_doc_path_nodes = path_list[doc_path[doc_id]] # List of Node objects

            for i, word in enumerate(words_in_doc):
                assigned_layer = current_doc_word_layer_assignments[i]

                # P(word | assigned_node, eta)
                # = (count_of_this_word_in_node + eta) / (total_words_in_node + vocab_size * eta)
                if assigned_layer >= len(current_doc_path_nodes):
                    # print(f\Warning: Likelihood calc - doc_id {doc_id}, word '{word}' assigned_layer {assigned_layer} out of bounds for path length {len(current_doc_path_nodes)}.\)
                    total_log_likelihood += -float('inf') # Penalize for inconsistent assignment
                    continue

                assigned_node_object = current_doc_path_nodes[assigned_layer]
                assigned_node_id = assigned_node_object.node_id
                
                count_word_in_assigned_node = node_word_dist.get(assigned_node_id, {}).get(word, 0)
                total_words_in_assigned_node = node_total_words_map.get(assigned_node_id, 0)

                denominator_val = total_words_in_assigned_node + vocab_size * self.eta
                if denominator_val <= 0: 
                    log_prob_word_generation = -float('inf') 
                else:
                    numerator_val = count_word_in_assigned_node + self.eta
                    if numerator_val <=0: # Should not happen if eta > 0
                        log_prob_word_generation = -float('inf')
                    else:
                        log_prob_word_generation = math.log(numerator_val) - math.log(denominator_val)
                
                total_log_likelihood += log_prob_word_generation
                
        return total_log_likelihood
    
    def save_to_files(self, base_filename="iteration", last_n_iterations=20):
        """保存所有记录到CSV文件"""
        
        if not self.iteration_records:
            print("No iteration records to save.")
            return
        
        # 1. 保存文档路径分配记录 (保持不变)
        all_doc_paths = []
        for record in self.iteration_records:
            all_doc_paths.extend(record['doc_path_assignments'])
        
        doc_path_df = pd.DataFrame(all_doc_paths)
        doc_path_df.to_csv(f'{base_filename}_document_paths.csv', index=False, encoding='utf-8')
        print(f"✅ doc-path allocation is saved : {base_filename}_document_paths.csv")
    
        # 2. 保存路径结构记录 - 处理列表字段
        # 假设 path_record (来自 record['path_structures']) 已经包含了 layer_X_node_id 列
        all_path_structures = []
        for record in self.iteration_records:
            for path_record_item in record['path_structures']: # path_record_item 是包含分层信息的字典
                path_record_copy = path_record_item.copy()
                all_path_structures.append(path_record_copy)
        
        path_structure_df = pd.DataFrame(all_path_structures)
        path_structure_df.to_csv(f'{base_filename}_path_structures.csv', index=False, encoding='utf-8')
        print(f"✅ structure of tree path is saved: {base_filename}_path_structures.csv")
        
        # 5. 保存迭代摘要 (保持不变)
        iteration_summaries = [record['iteration_summary'] for record in self.iteration_records]
        summary_df = pd.DataFrame(iteration_summaries)
        summary_df.to_csv(f'{base_filename}_iteration_summaries.csv', index=False, encoding='utf-8')
        print(f"✅ info recoreded in iteration is saved: {base_filename}_iteration_summaries.csv")
        
        # 6. 额外保存一个详细的路径-文档映射表 - 修改此处以适应分层结构   
        path_document_mapping = []
        for record in self.iteration_records:
            for path_record_item in record['path_structures']: # path_record_item 是包含分层信息的字典
                iteration_num = path_record_item['iteration']
                leaf_id = path_record_item['leaf_node_id']

                for doc_id_in_path in path_record_item['documents_in_path']:
                    mapping_entry = {
                        'iteration': iteration_num,
                        'leaf_node_id': leaf_id,
                        'document_id': doc_id_in_path,
                    }
                    # 添加分层节点ID，直到模型定义的深度 self.depth
                    # 确保 self.depth 在 __init__ 中被设置
                    if hasattr(self, 'depth'):
                        for i in range(self.depth):
                            layer_key = f'layer_{i}_node_id'
                            mapping_entry[layer_key] = path_record_item.get(layer_key) # 从 path_record_item 获取
                    else:
                        # 如果 self.depth 不可用，可以尝试从 path_record_item 的键推断，但这不太理想
                        # 或者只记录实际存在的层级
                        pass # 根据实际情况处理 self.depth 不可用的情况
                    
                    path_document_mapping.append(mapping_entry)
        
        path_doc_mapping_df = pd.DataFrame(path_document_mapping)
        path_doc_mapping_df.to_csv(f'{base_filename}_path_document_mapping.csv', index=False, encoding='utf-8')
        print(f"✅ doc-path mapping is saved: {base_filename}_path_document_mapping.csv")
        
        filtered_records_for_detail = self.iteration_records[-last_n_iterations:]
        
        # 3. 保存词语分配记录 (保持不变)
        all_word_allocations = []
        for record in filtered_records_for_detail:
            all_word_allocations.extend(record['word_allocations'])
        
        word_allocation_df = pd.DataFrame(all_word_allocations)
        word_allocation_df.to_csv(f'{base_filename}_word_allocations.csv', index=False, encoding='utf-8')
        print(f"✅ doc's words allocation to node is saved: {base_filename}_word_allocations.csv")
        
        # 4. 保存节点词分布记录 (保持不变)
        all_node_words = []
        for record in filtered_records_for_detail:
            all_node_words.extend(record['node_word_distributions'])
        
        node_word_df = pd.DataFrame(all_node_words)
        node_word_df.to_csv(f'{base_filename}_node_word_distributions.csv', index=False, encoding='utf-8')
        print(f"✅ node word distribution is saved: {base_filename}_node_word_distributions.csv")
        
        return {
            'doc_path_df': doc_path_df,
            'path_structure_df': path_structure_df,
            'word_allocation_df': word_allocation_df,
            'node_word_df': node_word_df,
            'summary_df': summary_df,
            'path_doc_mapping_df': path_doc_mapping_df
        }

    def get_iteration_summary(self):
        """获取迭代过程摘要"""
        if not self.iteration_records:
            return None
        
        summaries = [record['iteration_summary'] for record in self.iteration_records]
        return pd.DataFrame(summaries)

# %%
import pickle
import os

def save_gibbs_checkpoint(filename, recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, iteration):
    """保存Gibbs采样的断点（所有关键变量）"""
    checkpoint = {
        'recorder': recorder,
        'root_node': root_node,
        'path_list': path_list,
        'doc_path': doc_path,
        'doc_word_allocation': doc_word_allocation,
        'doc_node_allocation': doc_node_allocation,
        'iteration': iteration
    }
    with open(filename, 'wb') as f:
        pickle.dump(checkpoint, f)
    print(f"✅ checkpoint is saved to: {filename}（迭代 {iteration}）")

# %%
def load_gibbs_checkpoint(filename):
    """从断点文件恢复Gibbs采样的所有关键变量"""
    with open(filename, 'rb') as f:
        checkpoint = pickle.load(f)
    print(f"✅ from checkpoint file {filename} recover to iteration {checkpoint['iteration']}"),
    return (checkpoint['recorder'], checkpoint['root_node'], checkpoint['path_list'],
            checkpoint['doc_path'], checkpoint['doc_word_allocation'],
            checkpoint['doc_node_allocation'], checkpoint['iteration'])

# %%
# actually, this function is designed to be used after all iterations are done, to get stable documents across the last `window` iterations
# but we also can use it in a sliding window manner during iterations, if we input the windowed portion of doc_path_lst
def get_stable_docs_sliding_window(doc_path_lst_portion, back_window=5): # 迭代完成后计算
    """
    返回每一轮（从window轮开始）连续window轮路径都没变的文档ID集合
    返回格式：{迭代号: set(稳定文档ID)}
    """
    iter_portion = sorted(doc_path_lst_portion.keys())

    doc_ids = sorted(doc_path_lst_portion[iter_portion[-1]].keys())
    doc_idx_map = {doc_id: idx for idx, doc_id in enumerate(doc_ids)} # 这个是担心doc_ids不连续
    n_docs = len(doc_ids)
    n_iters = len(iter_portion) # 15
    # 构造完整路径矩阵 shape=(n_iters, n_docs)
    path_matrix = np.full((n_iters, n_docs), -1, dtype=np.int32)
    for i, iter_num in enumerate(iter_portion):
        for doc_id, leaf_id in doc_path_lst_portion[iter_num].items():
            path_matrix[i, doc_idx_map[doc_id]] = leaf_id
    # 滑动窗口统计
    stable_dict = {}
    # sliding window from 4 and review back from [0,5] to find stable docs
    for i in range(back_window-1, n_iters): # range from 4, and review back, is okay
        window_matrix = path_matrix[i-back_window+1:i+1, :]  # [0,5] rows # shape=(window, n_docs)
        first_row = window_matrix[0]
        stable_mask = np.all(window_matrix == first_row, axis=0) & (first_row != -1)
        stable_doc_ids = {doc_ids[j] for j in np.where(stable_mask)[0]}
        stable_dict[iter_portion[i]] = stable_doc_ids # 从第四个开始算稳定文档
    return stable_dict
## now, it can be used for check_inner_convergence

def get_jaccard_list_from_stable_dict(stable_dict, doc_node_allocation_lst_portion, back_window=5, depth=3):
    """
    返回每一轮与前一轮稳定文档集合的Jaccard相似度列表
    并统计窗口内每层每词最小词频值出现次数所占比例（最小值稳定性）
    """
    iters = sorted(stable_dict.keys()) # 从4开始
    jaccard_list = []
    stable_word_ratio_list = []
    for i in range(1, len(iters)):
        set1 = stable_dict[iters[i-1]]
        set2 = stable_dict[iters[i]]
        intersection = len(set1 & set2)
        union = len(set1 | set2)
        jaccard_index = intersection / union if union != 0 else 0
        jaccard_list.append(jaccard_index)

    for i in range(len(iters)):
        if doc_node_allocation_lst_portion is not None and iters[0] >= back_window-1: # 确保有足够的迭代次数
            stable_docs = stable_dict[iters[i]]
            min_freq_sum = 0
            total_freq_sum = 0
            for doc_id in stable_docs:
                window_allocs = [doc_node_allocation_lst_portion[j].get(doc_id, {}) for j in range(iters[i]-back_window+1, iters[i]+1)] # 窗口内的分配
                # print(f"window_allocs: {window_allocs}")
                for layer in range(depth): 
                    # 合并窗口内所有词
                    words = set()
                    for alloc in window_allocs:
                        words.update(alloc.get(layer, {}).keys())
                    for word in words:
                        freq_list = [alloc.get(layer, {}).get(word, 0) for alloc in window_allocs]
                        min_freq = min(freq_list)
                        min_freq_sum += min_freq
                        total_freq_sum += sum(freq_list)
            ratio = min_freq_sum / total_freq_sum if total_freq_sum > 0 else 0
            stable_word_ratio_list.append(ratio)
            # print(f"iter={iters[i]}, min_freq_sum={min_freq_sum}, total_freq_sum={total_freq_sum}, ratio={ratio}")
        else:
            print("⚠️ unable to calculate word ratio stability, missing doc_node_allocation_lst or not enough iterations")
            exit()
    return jaccard_list, stable_word_ratio_list

def calculate_gelman_rubin(chain_values, use_differences=False):
    """
    计算 Gelman-Rubin 统计量 (R-hat)
    
    Args:
        chain_values: 字典，键为链ID，值为该链的jaccard list
        warmup: 预热期比例，丢弃每条链前 warmup% 的样本
        
    Returns:
        float: Gelman-Rubin 统计量
    """
     # 处理原始数据
    if use_differences:
        # 计算差值（当前轮次减去前一轮次）
        diff_chains = {}
        for chain_id, values in chain_values.items():
            diff_values = [abs(values[i] - values[i-1]) for i in range(1, len(values))]
            diff_chains[chain_id] = diff_values
        chain_values = diff_chains

    chains = [chain for chain in chain_values.values()]
    
    n_chains = len(chains)
    n_samples = len(chains[0])
    
    # 计算链内均值
    chain_means = [np.mean(chain) for chain in chains]
    
    # 计算全局均值
    global_mean = np.mean(chain_means)
    
    # 计算链间方差 B
    between_chain_var = n_samples * np.sum([(mean - global_mean)**2 for mean in chain_means]) / (n_chains - 1)
    
    # 计算链内方差 W
    within_chain_var = np.mean([np.var(chain, ddof=1) for chain in chains])
    
    # 计算方差估计
    var_estimate = ((n_samples - 1) / n_samples) * within_chain_var + (1 / n_samples) * between_chain_var
    
    # 计算 R-hat
    r_hat = np.sqrt(var_estimate / within_chain_var)
    
    return r_hat

def check_convergence_with_gelman_rubin(chain_len_docs, mean_jaccard, mean_ratio, iteration, r_hat_threshold=1.1):
    """
    路径选择和稳定词分配ratio都要R-hat收敛才认为整体收敛
    """
    print(f"check_dual_convergence_with_gelman_rubin: chain_len_docs:{chain_len_docs}, mean_jaccard:{mean_jaccard}, mean_ratio:{mean_ratio}")
    r_hat_len_docs = calculate_gelman_rubin(chain_len_docs, use_differences=False)
    is_converged = (r_hat_len_docs < r_hat_threshold)
    
    convergence_info = {
        "iteration": iteration,
        "r_hat_len_docs": r_hat_len_docs,
        "mean_jaccard": mean_jaccard,
        "mean_ratio": mean_ratio,
        "threshold": r_hat_threshold,
        "converged": is_converged,
    }
    print(f"🥰 Convergence status: {'✅ Converged!' if is_converged else '❌ Not converged...'}")
    print(f"🥰  R-hat info: {r_hat_len_docs:.4f}，mean_jaccard:{mean_jaccard}, mean_ratio:{mean_ratio}")
    return is_converged, convergence_info

# %%
class SharedState:
    """多进程间共享状态管理类，支持Jaccard和ratio历史的存储与读取"""
    def __init__(self, base_dir):
        self.base_dir = base_dir
        self.state_file = os.path.join(base_dir, "shared_state.json")
        self.ensure_dir()
        self.init_state()

    def ensure_dir(self):
        os.makedirs(self.base_dir, exist_ok=True)

    def init_state(self):
        state = {
            "chains": {},
            "last_update": time.time(),
            "rhat_history": [],
            "convergence": False
        }
        self.save_state(state)

    def save_state(self, state):
        import json
        def convert_numpy_types(obj):
            if isinstance(obj, np.integer):
                return int(obj)
            elif isinstance(obj, np.floating):
                return float(obj)
            elif isinstance(obj, np.ndarray):
                return obj.tolist()
            elif isinstance(obj, np.bool_):
                return bool(obj)
            elif isinstance(obj, dict):
                return {k: convert_numpy_types(v) for k, v in obj.items()}
            elif isinstance(obj, list):
                return [convert_numpy_types(i) for i in obj]
            return obj
        converted_state = convert_numpy_types(state)
        with open(self.state_file, "w") as f:
            json.dump(converted_state, f)

    def load_state(self):
        import json
        try:
            with open(self.state_file, "r") as f:
                return json.load(f)
        except (FileNotFoundError, json.JSONDecodeError):
            self.init_state()
            return self.load_state()

    def update_chain_data(self, chain_id, len_stable_docs, jaccard_list, ratio_list, iteration, record_time): # update a single chain's data
        """
        更新某条链的数据（Jaccard和ratio历史）
        """
        state = self.load_state()
        if str(chain_id) not in state["chains"]:
            state["chains"][str(chain_id)] = {
                "len_stable_docs":{},
                "jaccard": {},
                "ratio": {},
                "record_time": -1,
                "converged": False
            }
        chain_data = state["chains"][str(chain_id)]
        
        # 感觉如果是稳定路径数的话，倒也不用用till now的mean和std，因为数量比较好衡量是不是？
        chain_data["len_stable_docs"][str(record_time)] = len_stable_docs
        chain_data["jaccard"][str(record_time)] = jaccard_list
        chain_data["ratio"][str(record_time)] = ratio_list
        chain_data["record_time"] = record_time
        state["last_update"] = time.time()
        self.save_state(state)

    def update_rhat(self, rhat_info, iteration, converged=False):
        state = self.load_state()
        state["rhat_history"].append({
            "rhat_len_docs": rhat_info.get("r_hat_len_docs"),
            "mean_jaccard": rhat_info.get("mean_jaccard"),
            "mean_ratio": rhat_info.get("mean_ratio"),
            "rhat_threshold": rhat_info.get("r_hat_threshold"),
            "converged": converged,
            "iteration": iteration,
            "timestamp": time.time()
        })
        state["convergence"] = converged
        self.save_state(state)

    def update_convergence_status(self, converged):
        state = self.load_state()
        state["convergence"] = converged
        self.save_state(state)

    def get_chain_data_histories(self, record_time, max_retry=5, wait_sec=2):
        for _ in range(max_retry):
            state = self.load_state()
            len_stable_docs = {}
            jaccard_lists = {}
            ratio_lists = {}

            for chain_id, data in state["chains"].items():
                # 只取当前record_time对应的数据
                len_stable_docs[str(chain_id)] = data["len_stable_docs"][str(record_time)]
                jaccard_lists[str(chain_id)] = data["jaccard"][str(record_time)]
                ratio_lists[str(chain_id)] = data["ratio"][str(record_time)]

        return len_stable_docs, jaccard_lists, ratio_lists
    
    def get_latest_completed_record(self, n_chains): # find the min last_iteration across all chains
        state = self.load_state() # state is a dict from JSON file
        """
        state = {
        "chains": {},
        "last_update": time.time(),
        "rhat_history": [],
        "convergence": False
        }
        """
        if len(state["chains"]) < n_chains: # must have all chains
            return -1
        chain_record = []
        for data in state["chains"].values():
            chain_record.append(data.get("record_time", -1))
        return min(chain_record)

    def get_convergence_status(self):
        state = self.load_state()
        return state["convergence"]

    def all_chains_finished(self, n_chains):
        state = self.load_state()
        if len(state["chains"]) < n_chains:
            return False
        return all(data.get("converged", False) for data in state["chains"].values())

# %%
def rhat_monitor_process(shared_state, n_chains, max_iterations, burn_in, check_interval, back_window, r_hat_threshold=1.1):
    """
    监控Jaccard和ratio的R-hat，及时判断多链收敛
    shared_state: SharedState实例
    n_chains: 链数量
    max_iterations: 最大迭代次数
    r_hat_threshold: R-hat收敛阈值
    该进程持续运行，直到检测到收敛或所有链完成
    """
    print("🔍 Initialize R-hat independent monitor thread (stable docs & Jaccard & Ratio)")
    convergence_detected = False
    record_time = 0

    while True:
        # 其实这里就不需要了，因为_checkpoint已经做出判断了，而且很危险的是，如果monitor晚点检查就会被替代，所以要把update函数改为append
        current_record_time = shared_state.get_latest_completed_record(n_chains=n_chains)
        # last replaced lsts, iteration是向前回溯的
        
        if not current_record_time >= record_time:
            time.sleep(5)
            continue
        
        chain_len_docs, chain_jaccard_lists, chain_ratio_lists = shared_state.get_chain_data_histories(record_time = record_time)
        # print(f"chain_len_docs:{chain_len_docs}, chain_ratio_lists: {chain_ratio_lists}, chain_jaccard_lists: {chain_jaccard_lists}")
        
        mean_jaccard = [np.mean(jaccard_lst) for jaccard_lst in chain_jaccard_lists.values()]
        mean_ratio = [np.mean(ratio_lst) for ratio_lst in chain_ratio_lists.values()]
        # print(mean_jaccard, mean_ratio)                   
        
        current_last_iteration = min(burn_in+back_window+current_record_time*check_interval, max_iterations)
        is_converged, convergence_info = check_convergence_with_gelman_rubin(chain_len_docs=chain_len_docs, mean_jaccard=mean_jaccard, mean_ratio=mean_ratio, iteration=current_last_iteration, r_hat_threshold=r_hat_threshold)

        
        # print(f"chain_len_docs:{chain_len_docs}, chain_ratio_lists: {chain_ratio_lists}, chain_jaccard_lists: {chain_jaccard_lists}")
 
        """
        convergence_info = {
        "iteration": iteration,
        "r_hat_len_docs": r_hat_len_docs,
        "mean_jaccard": mean_jaccard,
        "mean_ratio": mean_ratio,
        "threshold": r_hat_threshold,
        "converged": is_converged,
    }
        """

        # 记录R-hat值
        shared_state.update_rhat(convergence_info, current_last_iteration, converged=is_converged)

        if is_converged:
            print(f"✅ r-hat of multi-chains is detected to convergence {burn_in+back_window+record_time*check_interval} in iteration:{current_last_iteration}, R-hat={convergence_info['r_hat_len_docs']:.4f}, Jaccard平均值={convergence_info['mean_jaccard']}, Ratio平均值={convergence_info['mean_ratio']}")
            convergence_detected = True
            shared_state.update_convergence_status(True)

        record_time += 1

        # 检查是否所有链都已完成
        if shared_state.all_chains_finished(n_chains) or current_last_iteration >= max_iterations:
            print("✊ All chains finished or max iterations reached, exiting r-hat monitor process.")
            break

        if convergence_detected:
            print("✅ R-hat convergence is detected, waiting for all chains to finish.")

        time.sleep(2)
    print("✅ R-hat monitor process finished.")

# %%
def run_gibbs_with_checkpoint(
    corpus, depth=3, gamma=None, eta=None, alpha=None,
    max_iterations=200, save_every_n_iter=10, checkpoint_dir='gibbs_checkpoints',
    check_interval=10, resume_from_checkpoint=None, base_dir=None,
    shared_state=None, chain_id=None, back_window=5, burn_in = 50):
    """
    支持断点保存与恢复的Gibbs采样主循环
    - resume_from_checkpoint: 断点文件路径（如需恢复则填写，否则从头开始)
    
     result = run_gibbs_with_checkpoint(
        corpus=corpus,
        depth=depth,
        gamma=gamma,
        eta=eta,
        alpha=alpha,
        max_iterations=max_iterations,
        checkpoint_dir=os.path.join(chain_dir, "checkpoints"),
        base_dir=chain_dir,
        chain_id=chain_id,
        shared_state=shared_state,
        back_window=back_window,
        burn_in=burn_in,  # 设置burn-in期为50轮
        check_interval=check_interval  # 设置滑动窗口大小
    """
    os.makedirs(checkpoint_dir, exist_ok=True)
    if resume_from_checkpoint is not None and os.path.exists(resume_from_checkpoint):
        # 从断点恢复
        (recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, start_iter) = load_gibbs_checkpoint(resume_from_checkpoint)
        print(f"Resume from checkpoint and continue sampling (from iteration {start_iter+1})")
    else:
        # 全新开始,
        print("📊 Initialize nCRP Process...")
        [root_node, path_list, doc_path, doc_word_allocation] = nCRP(
            corpus=corpus, depth=depth, gamma=gamma,
        )
        # path_list: {leaf_id: [Node1, Node2, ...]}
        # doc_path: {doc_id: leaf_id}
        # doc_word_allocation: {doc_id: [layer_for_word1, layer_for_word2,...]}
        
        recorder = Recorder(corpus, depth, eta, alpha) # for Recorder self._init_ setting
        doc_node_allocation = aggregate_words(corpus, doc_word_allocation)
        # doc_node_allocation: {doc_id: {layer: {word: count}}}
        
        global_node_word_dist = node_word_distribution(doc_node_allocation, doc_path, path_list, exclude_docs=None)
        # global_node_word_dist[node_id]: {layer: {word: count}}
        
        # 定义详细记录开始的迭代（与Gibbs采样中的iter_start一致）
        iter_start_for_log = burn_in + back_window

        initial_summary = recorder.record_iteration(
            0, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation,global_node_word_dist,
            iter_start_for_detailed_log=iter_start_for_log # 传递给初始记录
        ) # record the initial state
        """
        recorder_iteration return: some basic infomation
        iteration_summary = {
                    'iteration': iteration_num,
                    'total_paths': len(path_list),
                    'total_documents': len(doc_path),
                    'log_likelihood': log_likelihood,
                    'changed_docs_count': changed_docs_count, 
                    'newly_created_paths': len(newly_created_paths or []),
                    'avg_path_size',
                    'max_path_size',
                    'min_path_size'}
        """
        print(f"📝 Chain {chain_id} initial state after nCRP is recorded: {initial_summary['total_paths']} path, ", 
                f"Log-likelihood: {initial_summary['log_likelihood']:.2f}")
        start_iter = 1

    previous_log_likelihood = recorder.iteration_records[-1]['iteration_summary']['log_likelihood']
    loglikelihood_list = [previous_log_likelihood]
    change_docs_list = []

    doc_path_lst = {0:doc_path.copy()}# 用于存储每条链的jaccard历史记录
    doc_node_allocation_lst = {0:doc_node_allocation.copy()} # 用于存储每条链的doc_node_allocation历史记录

    record_time = 0
    start_window = burn_in + back_window 
    
    for iteration in range(start_iter, max_iterations + 1): # start_iter=1
        old_paths = set(path_list.keys())
        doc_path_lst[iteration] = doc_path.copy()
        
        # 定义详细记录开始的迭代（与Gibbs采样中的iter_start一致）
        # 也用于控制Recorder的详细日志记录           
        current_iter_start_for_detailed_log = burn_in + back_window

        Gibbs_sampling(
            corpus, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
            gamma, eta, alpha, depth, iteration, 
            iter_start=current_iter_start_for_detailed_log, # Gibbs采样内部使用
            iter_end=max_iterations
        )
        """
        detail_record.items() = {
            'iteration': iteration,
            'doc_id': doc_id,
            'deleted_path_list': {leaf_id: [node.node_id for node in path_nodes] for leaf_id, path_nodes in path_list.items()}, # 注意深拷贝的性能影响
            'doc_path': {k:v for k, v in doc_path.items()},
            'doc_word_allocation': list(doc_word_allocation[doc_id]),
            'doc_node_allocation': {layer: {word: count for word, count in word_counts.items()} 
                                    for layer, word_counts in doc_node_allocation[doc_id].items()}
        }

        jump_record.items() = {
            'iteration': iteration,
            'doc_id': doc_id,
            'old_leaf_id': current_path[-1].node_id,
            'old_path': [n.node_id for n in current_path],
            'new_leaf_id': added_path[-1].node_id,
            'new_path': [n.node_id for n in added_path],
            'origal_probs':all_probs,
            'normalized_probs': normalized_probs,
            'chosen_path_prob': chosen_path_prob,
            'rank': f'{rank} out of {len(values)}',
            'create_path': True
        }
        """

        doc_path_lst[iteration] = doc_path.copy() # 记录当前迭代的doc_path，用于后续计算jaccard
        doc_node_allocation_lst[iteration] = doc_node_allocation.copy() # 记录当前迭代的doc_node_allocation

        new_paths = set(path_list.keys()) - old_paths
        iteration_summary = recorder.record_iteration(
            iteration, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
            new_paths, iter_start_for_detailed_log=current_iter_start_for_detailed_log # 传递给Recorder
        )
        print(f"🔄 Chain {chain_id} in iteration {iteration}/{max_iterations},\n",
                f"📊 path: {iteration_summary['total_paths']}, ",
                f"new path: {iteration_summary['newly_created_paths']}, ",
                f"docs changed path: {iteration_summary['changed_docs_count']}, ",
                f"Log-likelihood: {iteration_summary['log_likelihood']:.2f}")
        
        # 断点保存
        # if (iteration % save_every_n_iter == 0) or (iteration == max_iterations):
        #     checkpoint_path = os.path.join(checkpoint_dir, f'gibbs_checkpoint_iter{iteration}.pkl')
        #     save_gibbs_checkpoint(
        #         checkpoint_path, recorder, root_node, path_list, doc_path,
        #         doc_word_allocation, doc_node_allocation, iteration,
        #     )

        # 检查收敛
        change_docs_list.append(iteration_summary['changed_docs_count'])
        loglikelihood_list.append(iteration_summary['log_likelihood'])
        
        # iteration starts from 1, burn_in + back_window + check_interval 
        # print((iteration - start_window) / check_interval)
        if (iteration - start_window) / check_interval == 1 or  (iteration == max_iterations): # iteration starts from 1
            # 每次迭代开始时检查是否已收敛（快速检查，无需重新计算）
            convergence_status = shared_state.get_convergence_status() if shared_state else False
            if convergence_status:
                final_iteration = iteration
                print(f"🎉 Chain {chain_id} is detected to convergence in iteration {iteration}, sampling ends prematurely.")
                break
                
            """    
            check_interval=5,
            back_window=3,
            burn_in=2,
            """
            window_keys = list(range(iteration-check_interval-back_window+1, iteration+1))
            # print(f"window_keys:{window_keys}")
            
            doc_path_window = {k: doc_path_lst[k] for k in window_keys} # 6-20
            
            stable_docs = get_stable_docs_sliding_window(doc_path_window, back_window=back_window) # interval+1轮的stable docs
            chain_len_docs = [len(doc_list) for iterd, doc_list in stable_docs.items()]
            
            doc_node_allocation_window = {k: doc_node_allocation_lst[k] for k in window_keys}
            
            jaccard_lst, ratio_lst = get_jaccard_list_from_stable_dict(stable_docs, doc_node_allocation_window, back_window=back_window, depth=depth)
            
            shared_state.update_chain_data(chain_id, chain_len_docs, jaccard_lst, ratio_lst, iteration, record_time)
            start_window = iteration
            record_time += 1
            
            # print(f"stable_docs:{stable_docs},jaccard_lst{jaccard_lst}, ratio_lst{ratio_lst}")
            
            """ def update_chain_data(self, chain_id, len_stable_docs, jaccard_list, ratio_list, iteration, record_time): # update a single chain's data"""
    
    print(f"🎯 Chain {chain_id} finish Gibbs Sampling.")
    print("💾 Save iterations info...")
    saved_files = recorder.save_to_files(base_filename=os.path.join(base_dir, "iteration") if base_dir else "iteration")
    return recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, saved_files, change_docs_list, loglikelihood_list, doc_path_lst, doc_node_allocation_lst

# %%
def calculate_renyi_entropy(prob_dist, q=2.0):
    total = sum(prob_dist.values())
    if total <= 0:
        return 0.0
    moment_q = 0.0
    for v in prob_dist.values():
        p = v / total
        if p > 0:
            moment_q += p ** q
    if moment_q <= 0:
        return float('inf')
    return (1.0 / (1.0 - q)) * math.log(moment_q)  # 自然对数

def jensen_shannon_divergence(dist1, dist2):
    # 统一词表并归一化
    keys = set(dist1.keys()) | set(dist2.keys())
    s1 = float(sum(dist1.get(k, 0.0) for k in keys))
    s2 = float(sum(dist2.get(k, 0.0) for k in keys))
    if s1 == 0 or s2 == 0:
        return 1.0
    p = {k: dist1.get(k, 0.0) / s1 for k in keys}
    q = {k: dist2.get(k, 0.0) / s2 for k in keys}
    m = {k: 0.5 * (p[k] + q[k]) for k in keys}

    def _kl(a, b):
        val = 0.0
        for k in keys:
            ak = a[k]
            bk = b[k]
            if ak > 0 and bk > 0:
                val += ak * math.log(ak / bk)
        return val

    return 0.5 * _kl(p, m) + 0.5 * _kl(q, m)

def evaluate_tree_structure_with_nodes(root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation):
    """
    返回：
      - node_records: 每节点一行（layer/node_id/parent_id/entropy/doc_count/path）
      - layer_entropy_wavg: {layer: 文档数加权的Rényi熵}
      - layer_distinctiveness_wavg: {layer: 文档数加权JSD(主题异质性)}
      - nodes_per_layer: {layer: 节点数}
    说明：
      - 节点文档数：统计落在该节点（该层）上的去重文档数
      - 加权平均：用成对权重 m_i*m_j（异质性）与节点权重 m_i（熵）
    """
    # 词频与文档集合
    layer_word_dist = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))  # layer -> node_id -> word -> cnt
    node_doc_sets = defaultdict(set)  # node_id -> {doc_ids}

    # 若 root_node 是 dict[node_id]->obj 且含 parent_id，用它；否则 parent_id 置 None
    get_parent_id = (lambda nid: getattr(root_node.get(nid), 'parent_id', None)) if isinstance(root_node, dict) else (lambda nid: None)

    # 累积每节点的词频与文档集合
    for doc_id, leaf_id in doc_path.items():
        path_nodes = path_list[leaf_id]  # [Node1, Node2, ...]
        per_doc_alloc = doc_node_allocation.get(doc_id, {})
        for node in path_nodes:
            lyr = node.layer
            if lyr in per_doc_alloc:
                # 记录词频
                for w, c in per_doc_alloc[lyr].items():
                    layer_word_dist[lyr][node.node_id][w] += c
                # 记录文档
                node_doc_sets[node.node_id].add(doc_id)

#     # 汇总逐节点
#     node_records = []
#     for layer, nodes_dist in layer_word_dist.items():
#         for nid, wdist in nodes_dist.items():
#             entropy = calculate_renyi_entropy(wdist, q=2.0)
#             doc_count = len(node_doc_sets[nid])
#             node_records.append({
#                 "layer": layer,
#                 "node_id": nid,
#                 "parent_id": get_parent_id(nid),
#                 "entropy": entropy,
#                 "doc_count": doc_count,
#                 # 可选：保存路径字符串（如需要，你可以在外部预先构造 node_id->path_str 的映射传入）
#                 "path": None
#             })
            
    # 在 evaluate_tree_structure 函数中添加调试信息
    node_records = []
    for layer, nodes_dist in layer_word_dist.items():
        for nid, wdist in nodes_dist.items():
            entropy = calculate_renyi_entropy(wdist, q=2.0)
            doc_count = len(node_doc_sets[nid]) if nid in node_doc_sets else 0

            # 添加调试信息
            if entropy == 0:
                print(f"⚠️ Node {nid} (Layer {layer}) has entropy=0:")
                print(f"   Word distribution: {dict(wdist)}")
                print(f"   Number of unique words: {len(wdist)}")
                print(f"   Total word count: {sum(wdist.values())}")
                print(f"   Document count: {doc_count}")
                print()

            node_records.append({
                "layer": layer,
                "node_id": nid,
                "parent_id": get_parent_id(nid),
                "entropy": entropy,
                "doc_count": doc_count,
                "unique_words": len(wdist),
                "total_words": sum(wdist.values()),
                "path": None
            })
        
    # 层级文档加权熵
    layer_entropy_wavg = {}
    nodes_per_layer = {}
    for layer, nodes_dist in layer_word_dist.items():
        nodes = list(nodes_dist.keys())
        nodes_per_layer[layer] = len(nodes)
        total_docs = sum(len(node_doc_sets[nid]) for nid in nodes)
        if total_docs == 0:
            layer_entropy_wavg[layer] = 0.0
            continue
        wsum = 0.0
        for nid in nodes:
            H = calculate_renyi_entropy(nodes_dist[nid], q=2.0)
            w = len(node_doc_sets[nid])
            wsum += H * w
        layer_entropy_wavg[layer] = wsum / total_docs

    # 层级文档加权主题异质性（加权JSD）
    layer_distinctiveness_wavg = {}
    for layer, nodes_dist in layer_word_dist.items():
        nids = list(nodes_dist.keys())
        if len(nids) < 2:
            layer_distinctiveness_wavg[layer] = 0.0
            continue
        wsum_jsd = 0.0
        wsum = 0.0
        for i in range(len(nids)):
            for j in range(i+1, len(nids)):
                ni, nj = nids[i], nids[j]
                mi, mj = len(node_doc_sets[ni]), len(node_doc_sets[nj])
                if mi == 0 or mj == 0:
                    continue
                jsd = jensen_shannon_divergence(nodes_dist[ni], nodes_dist[nj])
                w = mi * mj
                wsum_jsd += jsd * w
                wsum += w
        layer_distinctiveness_wavg[layer] = (wsum_jsd / wsum) if wsum > 0 else 0.0

    return {
        "node_records": node_records,
        "layer_entropy_wavg": layer_entropy_wavg,
        "layer_distinctiveness_wavg": layer_distinctiveness_wavg,
        "nodes_per_layer": nodes_per_layer
    }

# %%
def _run_single_chain(args):
    """
    运行单条 hLDA 链的函数（用于 joblib 并行）
    
    Args:
        args: 元组 (chain_id, corpus, depth, gamma, eta, alpha, max_iterations, general_dir, seed)
        
    Returns:
        dict: 包含链结果的字典
    """
    (chain_id, corpus, depth, gamma, eta, alpha, max_iterations, general_dir, seed, shared_state, back_window, check_interval, burn_in) = args

    print(f"⛓️ Chain {chain_id} starts（PID: {os.getpid()}）")
    
    # 设置随机种子
    np.random.seed(seed)
    
    # 为链创建目录
    chain_dir = os.path.join(general_dir, f"depth_{depth}_gamma_{gamma}_run_{chain_id}")
    os.makedirs(chain_dir, exist_ok=True)
    
    # 运行Gibbs采样
    """
    def run_gibbs_with_checkpoint(
    corpus, depth=3, gamma=None, eta=None, alpha=None,
    max_iterations=200, save_every_n_iter=10, checkpoint_dir='gibbs_checkpoints',
    check_interval=10, resume_from_checkpoint=None, base_dir=None,
    shared_state=None, chain_id=None, back_window=5, burn_in = 50):
    """
    result = run_gibbs_with_checkpoint(
        corpus=corpus,
        depth=depth,
        gamma=gamma,
        eta=eta,
        alpha=alpha,
        max_iterations=max_iterations,
        checkpoint_dir=os.path.join(chain_dir, "checkpoints"),
        base_dir=chain_dir,
        chain_id=chain_id,
        shared_state=shared_state,
        back_window=back_window,
        burn_in=burn_in,  # 设置burn-in期为50轮
        check_interval=check_interval  # 设置滑动窗口大小
    )
    # 1. converged: return recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, saved_files
    # 2. not converged: return recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, saved_files, change_docs_list, loglikelihood_list, converge_or_not, doc_path_lst, doc_node_allocation_lst
    
    # 提取结果
    recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, saved_files, change_docs_list, loglikelihood_list, doc_path_lst, doc_node_allocation_lst = result
    
    # 保存轻量级结果到磁盘以便主进程读取
    result_file = os.path.join(chain_dir, "final_checkpoint.pkl")
    with open(result_file, 'wb') as f:
        chain_result = {
            'chain_id': chain_id,
            'loglikelihood_history': loglikelihood_list,
            'changed_docs_history': change_docs_list
            # 不保存太大的对象
        }
        pickle.dump(chain_result, f)
    
    print(f"✅ Chain {chain_id} Finished !")
    
    # 1. 按层保存
    
    res = evaluate_tree_structure_with_nodes(root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation)
    
    layers = sorted(res["layer_entropy_wavg"].keys())
    layer_rows = []
    for L in layers:
        layer_rows.append({
            "depth": depth,
            "gamma": gamma,
            "eta": eta,
            "alpha": alpha,
            "layer": L,
            "entropy_wavg": res["layer_entropy_wavg"].get(L, 0.0),
            "distinctiveness_wavg_jsd": res["layer_distinctiveness_wavg"].get(L, 0.0),
            "nodes_in_layer": res["nodes_per_layer"].get(L, 0)
        })
    df_layers = pd.DataFrame(layer_rows)
    layers_csv = os.path.join(chain_dir, "result_layers.csv")
    os.makedirs(chain_dir, exist_ok=True)
    if not os.path.exists(layers_csv):
        df_layers.to_csv(layers_csv, index=False, mode='w', header=True)
    else:
        df_layers.to_csv(layers_csv, index=False, mode='a', header=False)

    # 2. 按节点保存
    df_nodes = pd.DataFrame(res["node_records"])
    if not df_nodes.empty:
        df_nodes.insert(0, "depth", depth)
        df_nodes.insert(1, "gamma", gamma)
        df_nodes.insert(2, "eta", eta)
        df_nodes.insert(3, "alpha", alpha)
        nodes_csv = os.path.join(chain_dir, "result_nodes.csv")
        if not os.path.exists(nodes_csv):
            df_nodes.to_csv(nodes_csv, index=False, mode='w', header=True)
        else:
            df_nodes.to_csv(nodes_csv, index=False, mode='a', header=False)

    # 3. 单行摘要（原来的 result_metrics.csv ）
    summary = {
        "depth": depth,
        "gamma": gamma,
        "eta": eta,
        "alpha": alpha,
        "avg_entropy_wavg_over_layers": float(np.mean([res["layer_entropy_wavg"][L] for L in layers])) if layers else 0.0,
        "avg_distinctiveness_wavg_over_layers": float(np.mean([res["layer_distinctiveness_wavg"][L] for L in layers])) if layers else 0.0,
        "total_layers": len(layers),
        "total_nodes": int(sum(res["nodes_per_layer"].values())) if layers else 0
    }
    df_metrics = pd.DataFrame([summary])
    metrics_csv = os.path.join(chain_dir, "result_metrics.csv")
    if not os.path.exists(metrics_csv):
        df_metrics.to_csv(metrics_csv, index=False, mode='w', header=True)
    else:
        df_metrics.to_csv(metrics_csv, index=False, mode='a', header=False)

#     # 计算指标并保存
#     metrics = evaluate_tree_structure(root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation)

#     metrics.update({
#         'gamma': gamma,
#         'eta': eta,
#         'depth': depth,
#         'alpha': alpha,
#     })     
    
#     metrics_df = pd.DataFrame([metrics])  # 将字典转换为DataFrame
#     metrics_df.to_csv(os.path.join(chain_dir, "result_metrics.csv"), index=False)
    
    # 返回轻量级结果
    return {
        'chain_id': chain_id,
        'loglikelihood_history': loglikelihood_list,
        'result_file': result_file,
        'changed_docs_history': change_docs_list,
        'doc_path_lst': doc_path_lst,
        'doc_node_allocation_lst': doc_node_allocation_lst
    }

# %%
from threading import Thread
import json

def run_multi_chain_hlda(
    corpus, depth=3, gamma=0.01, eta=0.01, alpha=0.1,
    n_chains=3, max_iterations=20, r_hat_threshold=1.1,
    general_dir="multi_chain_hlda_results",
    back_window=5, check_interval=10, burn_in=50
):
    """
    并行运行多条 hLDA 链，收敛检查由 monitor 线程实时完成。
    运行结束后自动保存所有收敛检查历史数据为 CSV。
    
    result = run_multi_chain_hlda(
    corpus=corpus,
    depth=depth,
    gamma=gamma,
    eta=eta,
    alpha=alpha,
    n_chains=n_chains,
    max_iterations=30,
    check_interval=5,
    back_window=3,
    burn_in=2,
    r_hat_threshold=1.1,
    general_dir="0809_multi_len_docs")
    """

    os.makedirs(general_dir, exist_ok=True)

    # 启动共享状态和监控线程
    shared_state = SharedState(general_dir)
    monitor = Thread(
        target=rhat_monitor_process,
        args=(shared_state, n_chains, max_iterations, burn_in, check_interval, back_window, r_hat_threshold)
    )
    #  # args=(shared_state, n_chains, max_iterations, burn_in, r_hat_threshold, check_interval)
    
    monitor.daemon = False
    monitor.start()
    print("🚀 Start R-hat monitor process")

    # 构造每条链的参数
    args_list = []
    for i in range(1, n_chains + 1):
        seed = i * 1000 + int(time.time()) % 1000
        args_list.append((
            i, corpus, depth, gamma, eta, alpha,
            max_iterations, general_dir, seed,
            shared_state, back_window, check_interval, burn_in
        ))
        
    """
    (chain_id, corpus, depth, gamma, eta, alpha, max_iterations, general_dir, seed, shared_state, back_window, check_interval, burn_in) = args
    """

    print(f"🚀 Start {n_chains} hLDA chain，each chain could have {max_iterations} max iterations...")

    # 并行运行所有链
    chain_results = Parallel(n_jobs=n_chains, backend='multiprocessing', verbose=10)(
        delayed(_run_single_chain)(args) for args in args_list
    )

    print("✅ All chains finish sampling and waiting for monitor process finish...")

    # 等待监控线程结束（即所有链都收敛或达到最大迭代）
    monitor.join(timeout=60)
    print("✅ R-hat monitor process finished !")

    # 收集每条链的结果
    full_results = {}
    for result in chain_results:
        with open(result['result_file'], 'rb') as f:
            full_results[result['chain_id']] = pickle.load(f)

    # 保存收敛检查历史数据
    rhat_file = os.path.join(general_dir, "shared_state.json")
    if os.path.exists(rhat_file):
        with open(rhat_file, "r") as f:
            shared_state_data = json.load(f)
        
        # 1. 保存总体R-hat收敛历史到general_dir
        rhat_history = shared_state_data.get("rhat_history", [])
        if rhat_history:
            convergence_df = pd.DataFrame(rhat_history)
            convergence_csv = os.path.join(general_dir, "convergence_info.csv")
            convergence_df.to_csv(convergence_csv, index=False, encoding='utf-8')
            print(f"✅ Overall convergence history is saved to CSV: {convergence_csv}")
        else:
            print("⚠️ Does not find any convergence history in shared_state.json.")
        
        # 2. 为每个链单独保存其收敛信息到各自的chain_dir
        for result in chain_results:
            chain_id = result['chain_id']
            chain_dir = os.path.join(general_dir, f"depth_{depth}_gamma_{gamma}_run_{chain_id}")
            
            # 提取该链特定的数据
            chain_data = shared_state_data.get("chains", {}).get(str(chain_id), {})
            if chain_data:
                # 转换为DataFrame格式方便分析
                chain_records = []
                for record_time, len_docs in chain_data.get('len_stable_docs', {}).items():
                    jaccard_list = chain_data.get('jaccard', {}).get(record_time, [])
                    ratio_list = chain_data.get('ratio', {}).get(record_time, [])
                    
                    chain_records.append({
                        'record_time': int(record_time),
                        'len_stable_docs': len_docs,
                        'jaccard_mean': np.mean(jaccard_list) if jaccard_list else 0,
                        'jaccard_std': np.std(jaccard_list) if jaccard_list else 0,
                        'ratio_mean': np.mean(ratio_list) if ratio_list else 0,
                        'ratio_std': np.std(ratio_list) if ratio_list else 0,
                        'jaccard_list': jaccard_list,
                        'ratio_list': ratio_list
                    })
                
                if chain_records:
                    chain_df = pd.DataFrame(chain_records)
                    chain_convergence_csv = os.path.join(chain_dir, "chain_convergence_info.csv")
                    chain_df.to_csv(chain_convergence_csv, index=False, encoding='utf-8')
                    print(f"✅ Chain {chain_id} convergence info saved to: {chain_convergence_csv}")
                else:
                    print(f"⚠️ No convergence data found for chain {chain_id}")
            else:
                print(f"⚠️ No chain data found for chain {chain_id}")
    else:
        print("⚠️ Does not find shared_state.json, no convergence history saved.")

    return full_results

# %%
import cProfile
# 设置参数（使用小写变量名）
depth = 3
gamma = 0.05
eta = 0.05
alpha = 0.05
n_chains = 3  # 3条链并行运行

# 使用 joblib 运行多链
result = run_multi_chain_hlda(
    corpus=corpus,
    depth=depth,
    gamma=gamma,
    eta=eta,
    alpha=alpha,
    n_chains=n_chains,
    max_iterations=300,
    check_interval=20,
    back_window=5,
    burn_in=100,
    r_hat_threshold=1.1,
    general_dir="step3_d3_g005_e005_a005_第二次")
# Out:
# 🔍 Initialize R-hat independent monitor thread (stable docs & Jaccard & Ratio)
# 🚀 Start R-hat monitor process
# 🚀 Start 3 hLDA chain，each chain could have 300 max iterations...
# ⛓️ Chain 1 starts（PID: 48592）
# 📊 Initialize nCRP Process...
# ⛓️ Chain 2 starts（PID: 48593）
# 📊 Initialize nCRP Process...
# ⛓️ Chain 3 starts（PID: 48594）
# 📊 Initialize nCRP Process...
# [Parallel(n_jobs=3)]: Using backend MultiprocessingBackend with 3 concurrent workers.
# 📝 Chain 1 initial state after nCRP is recorded: 2 path,  Log-likelihood: -544300.72
# 📝 Chain 2 initial state after nCRP is recorded: 2 path,  Log-likelihood: -545657.84
# 📝 Chain 3 initial state after nCRP is recorded: 2 path,  Log-likelihood: -545083.03
# 🔄 Chain 1 in iteration 1/300,
#  📊 path: 71,  new path: 69,  docs changed path: 250,  Log-likelihood: -513498.85
# 🔄 Chain 2 in iteration 1/300,
#  📊 path: 61,  new path: 59,  docs changed path: 171,  Log-likelihood: -516137.62
# 🔄 Chain 3 in iteration 1/300,
#  📊 path: 77,  new path: 75,  docs changed path: 197,  Log-likelihood: -511861.75
# 🔄 Chain 1 in iteration 2/300,
#  📊 path: 117,  new path: 68,  docs changed path: 199,  Log-likelihood: -501092.84
# 🔄 Chain 2 in iteration 2/300,
#  📊 path: 112,  new path: 70,  docs changed path: 190,  Log-likelihood: -503720.65
# 🔄 Chain 3 in iteration 2/300,
#  📊 path: 125,  new path: 73,  docs changed path: 199,  Log-likelihood: -500811.97
# 🔄 Chain 2 in iteration 3/300,
#  📊 path: 121,  new path: 64,  docs changed path: 187,  Log-likelihood: -496757.40
# 🔄 Chain 1 in iteration 3/300,
#  📊 path: 131,  new path: 76,  docs changed path: 203,  Log-likelihood: -494390.70
# 🔄 Chain 3 in iteration 3/300,
#  📊 path: 129,  new path: 69,  docs changed path: 187,  Log-likelihood: -495077.56
# 🔄 Chain 2 in iteration 4/300,
#  📊 path: 135,  new path: 73,  docs changed path: 196,  Log-likelihood: -492500.99
# 🔄 Chain 1 in iteration 4/300,
#  📊 path: 143,  new path: 77,  docs changed path: 196,  Log-likelihood: -490481.25
# 🔄 Chain 3 in iteration 4/300,
#  📊 path: 135,  new path: 60,  docs changed path: 176,  Log-likelihood: -489351.98
# 🔄 Chain 2 in iteration 5/300,
#  📊 path: 142,  new path: 63,  docs changed path: 198,  Log-likelihood: -488536.56
# 🔄 Chain 1 in iteration 5/300,
#  📊 path: 143,  new path: 70,  docs changed path: 187,  Log-likelihood: -487588.91
# 🔄 Chain 3 in iteration 5/300,
#  📊 path: 143,  new path: 67,  docs changed path: 178,  Log-likelihood: -485895.09
# 🔄 Chain 1 in iteration 6/300,
#  📊 path: 151,  new path: 66,  docs changed path: 193,  Log-likelihood: -485459.73
# 🔄 Chain 2 in iteration 6/300,
#  📊 path: 152,  new path: 75,  docs changed path: 200,  Log-likelihood: -486030.43
# 🔄 Chain 3 in iteration 6/300,
#  📊 path: 153,  new path: 72,  docs changed path: 180,  Log-likelihood: -481786.49
# 🔄 Chain 1 in iteration 7/300,
#  📊 path: 141,  new path: 58,  docs changed path: 191,  Log-likelihood: -482432.92
# 🔄 Chain 2 in iteration 7/300,
#  📊 path: 142,  new path: 66,  docs changed path: 204,  Log-likelihood: -484173.57
# 🔄 Chain 3 in iteration 7/300,
#  📊 path: 150,  new path: 61,  docs changed path: 199,  Log-likelihood: -480928.57
# 🔄 Chain 1 in iteration 8/300,
#  📊 path: 151,  new path: 59,  docs changed path: 199,  Log-likelihood: -481718.38
# 🔄 Chain 2 in iteration 8/300,
#  📊 path: 150,  new path: 70,  docs changed path: 220,  Log-likelihood: -481989.90
# 🔄 Chain 3 in iteration 8/300,
#  📊 path: 148,  new path: 60,  docs changed path: 206,  Log-likelihood: -477395.25
# 🔄 Chain 1 in iteration 9/300,
#  📊 path: 148,  new path: 62,  docs changed path: 208,  Log-likelihood: -479682.94
# 🔄 Chain 2 in iteration 9/300,
#  📊 path: 143,  new path: 55,  docs changed path: 233,  Log-likelihood: -480361.05
# 🔄 Chain 3 in iteration 9/300,
#  📊 path: 151,  new path: 51,  docs changed path: 205,  Log-likelihood: -476589.37
# 🔄 Chain 1 in iteration 10/300,
#  📊 path: 147,  new path: 51,  docs changed path: 200,  Log-likelihood: -478003.64
# 🔄 Chain 2 in iteration 10/300,
#  📊 path: 152,  new path: 56,  docs changed path: 234,  Log-likelihood: -476503.02
# 🔄 Chain 3 in iteration 10/300,
#  📊 path: 143,  new path: 57,  docs changed path: 214,  Log-likelihood: -476816.72
# 🔄 Chain 1 in iteration 11/300,
#  📊 path: 148,  new path: 58,  docs changed path: 196,  Log-likelihood: -476793.44
# 🔄 Chain 2 in iteration 11/300,
#  📊 path: 156,  new path: 58,  docs changed path: 228,  Log-likelihood: -474233.16
# 🔄 Chain 3 in iteration 11/300,
#  📊 path: 147,  new path: 52,  docs changed path: 216,  Log-likelihood: -475462.85
# 🔄 Chain 1 in iteration 12/300,
#  📊 path: 154,  new path: 59,  docs changed path: 215,  Log-likelihood: -475869.80
# 🔄 Chain 2 in iteration 12/300,
#  📊 path: 169,  new path: 58,  docs changed path: 229,  Log-likelihood: -472273.42
# 🔄 Chain 3 in iteration 12/300,
#  📊 path: 144,  new path: 46,  docs changed path: 221,  Log-likelihood: -474197.98
# 🔄 Chain 1 in iteration 13/300,
#  📊 path: 156,  new path: 51,  docs changed path: 219,  Log-likelihood: -474529.10
# 🔄 Chain 2 in iteration 13/300,
#  📊 path: 158,  new path: 54,  docs changed path: 246,  Log-likelihood: -473301.67
# 🔄 Chain 3 in iteration 13/300,
#  📊 path: 150,  new path: 54,  docs changed path: 216,  Log-likelihood: -473253.45
# 🔄 Chain 1 in iteration 14/300,
#  📊 path: 158,  new path: 45,  docs changed path: 215,  Log-likelihood: -471912.04
# 🔄 Chain 3 in iteration 14/300,
#  📊 path: 151,  new path: 46,  docs changed path: 225,  Log-likelihood: -470451.09
# 🔄 Chain 2 in iteration 14/300,
#  📊 path: 165,  new path: 46,  docs changed path: 243,  Log-likelihood: -469861.72
# 🔄 Chain 1 in iteration 15/300,
#  📊 path: 156,  new path: 57,  docs changed path: 234,  Log-likelihood: -472353.94
# 🔄 Chain 3 in iteration 15/300,
#  📊 path: 162,  new path: 53,  docs changed path: 222,  Log-likelihood: -470191.19
# 🔄 Chain 2 in iteration 15/300,
#  📊 path: 161,  new path: 47,  docs changed path: 260,  Log-likelihood: -468527.75
# 🔄 Chain 1 in iteration 16/300,
#  📊 path: 163,  new path: 54,  docs changed path: 241,  Log-likelihood: -470232.62
# 🔄 Chain 2 in iteration 16/300,
#  📊 path: 157,  new path: 37,  docs changed path: 237,  Log-likelihood: -469155.13
# 🔄 Chain 3 in iteration 16/300,
#  📊 path: 168,  new path: 53,  docs changed path: 216,  Log-likelihood: -470105.51
# 🔄 Chain 1 in iteration 17/300,
#  📊 path: 168,  new path: 62,  docs changed path: 243,  Log-likelihood: -469819.14
# 🔄 Chain 2 in iteration 17/300,
#  📊 path: 170,  new path: 51,  docs changed path: 256,  Log-likelihood: -465627.25
# 🔄 Chain 3 in iteration 17/300,
#  📊 path: 166,  new path: 49,  docs changed path: 232,  Log-likelihood: -469234.99
# 🔄 Chain 1 in iteration 18/300,
#  📊 path: 156,  new path: 45,  docs changed path: 240,  Log-likelihood: -470000.90
# 🔄 Chain 2 in iteration 18/300,
#  📊 path: 179,  new path: 54,  docs changed path: 257,  Log-likelihood: -464858.26
# 🔄 Chain 3 in iteration 18/300,
#  📊 path: 159,  new path: 46,  docs changed path: 242,  Log-likelihood: -468941.86
# 🔄 Chain 1 in iteration 19/300,
#  📊 path: 161,  new path: 51,  docs changed path: 238,  Log-likelihood: -467761.31
# 🔄 Chain 2 in iteration 19/300,
#  📊 path: 180,  new path: 52,  docs changed path: 245,  Log-likelihood: -462720.01
# 🔄 Chain 3 in iteration 19/300,
#  📊 path: 173,  new path: 57,  docs changed path: 263,  Log-likelihood: -465947.36
# 🔄 Chain 1 in iteration 20/300,
#  📊 path: 173,  new path: 56,  docs changed path: 247,  Log-likelihood: -467494.88
# 🔄 Chain 2 in iteration 20/300,
#  📊 path: 176,  new path: 43,  docs changed path: 263,  Log-likelihood: -462428.35
# 🔄 Chain 3 in iteration 20/300,
#  📊 path: 178,  new path: 54,  docs changed path: 276,  Log-likelihood: -465391.24
# 🔄 Chain 1 in iteration 21/300,
#  📊 path: 178,  new path: 60,  docs changed path: 257,  Log-likelihood: -468031.14
# 🔄 Chain 2 in iteration 21/300,
#  📊 path: 187,  new path: 54,  docs changed path: 256,  Log-likelihood: -461458.93
# 🔄 Chain 3 in iteration 21/300,
#  📊 path: 168,  new path: 38,  docs changed path: 262,  Log-likelihood: -464469.93
# 🔄 Chain 1 in iteration 22/300,
#  📊 path: 171,  new path: 44,  docs changed path: 248,  Log-likelihood: -466915.57
# 🔄 Chain 2 in iteration 22/300,
#  📊 path: 181,  new path: 41,  docs changed path: 261,  Log-likelihood: -461140.69
# 🔄 Chain 3 in iteration 22/300,
#  📊 path: 177,  new path: 53,  docs changed path: 283,  Log-likelihood: -461994.95
# 🔄 Chain 1 in iteration 23/300,
#  📊 path: 175,  new path: 48,  docs changed path: 257,  Log-likelihood: -464308.90
# 🔄 Chain 2 in iteration 23/300,
#  📊 path: 187,  new path: 47,  docs changed path: 267,  Log-likelihood: -459330.69
# 🔄 Chain 3 in iteration 23/300,
#  📊 path: 176,  new path: 45,  docs changed path: 291,  Log-likelihood: -462154.52
# 🔄 Chain 1 in iteration 24/300,
#  📊 path: 175,  new path: 49,  docs changed path: 257,  Log-likelihood: -464716.42
# 🔄 Chain 2 in iteration 24/300,
#  📊 path: 184,  new path: 44,  docs changed path: 251,  Log-likelihood: -459042.14
# 🔄 Chain 3 in iteration 24/300,
#  📊 path: 175,  new path: 47,  docs changed path: 279,  Log-likelihood: -461838.54
# 🔄 Chain 1 in iteration 25/300,
#  📊 path: 180,  new path: 56,  docs changed path: 253,  Log-likelihood: -464280.21
# 🔄 Chain 2 in iteration 25/300,
#  📊 path: 180,  new path: 46,  docs changed path: 242,  Log-likelihood: -458812.68
# 🔄 Chain 3 in iteration 25/300,
#  📊 path: 182,  new path: 50,  docs changed path: 283,  Log-likelihood: -460778.73
# 🔄 Chain 1 in iteration 26/300,
#  📊 path: 176,  new path: 46,  docs changed path: 246,  Log-likelihood: -463528.88
# 🔄 Chain 2 in iteration 26/300,
#  📊 path: 182,  new path: 45,  docs changed path: 262,  Log-likelihood: -458047.51
# 🔄 Chain 3 in iteration 26/300,
#  📊 path: 182,  new path: 40,  docs changed path: 273,  Log-likelihood: -459718.94
# 🔄 Chain 1 in iteration 27/300,
#  📊 path: 177,  new path: 48,  docs changed path: 262,  Log-likelihood: -463219.35
# 🔄 Chain 2 in iteration 27/300,
#  📊 path: 191,  new path: 49,  docs changed path: 256,  Log-likelihood: -457250.01
# 🔄 Chain 3 in iteration 27/300,
#  📊 path: 183,  new path: 53,  docs changed path: 300,  Log-likelihood: -459628.82
# 🔄 Chain 1 in iteration 28/300,
#  📊 path: 178,  new path: 48,  docs changed path: 253,  Log-likelihood: -462512.47
# 🔄 Chain 2 in iteration 28/300,
#  📊 path: 190,  new path: 49,  docs changed path: 271,  Log-likelihood: -456701.46
# 🔄 Chain 3 in iteration 28/300,
#  📊 path: 188,  new path: 44,  docs changed path: 302,  Log-likelihood: -457463.22
# 🔄 Chain 1 in iteration 29/300,
#  📊 path: 179,  new path: 48,  docs changed path: 244,  Log-likelihood: -461513.15
# 🔄 Chain 2 in iteration 29/300,
#  📊 path: 197,  new path: 49,  docs changed path: 268,  Log-likelihood: -455890.97
# 🔄 Chain 3 in iteration 29/300,
#  📊 path: 192,  new path: 45,  docs changed path: 303,  Log-likelihood: -457008.11
# 🔄 Chain 1 in iteration 30/300,
#  📊 path: 177,  new path: 54,  docs changed path: 249,  Log-likelihood: -462670.70
# 🔄 Chain 3 in iteration 30/300,
#  📊 path: 188,  new path: 50,  docs changed path: 316,  Log-likelihood: -456517.67
# 🔄 Chain 2 in iteration 30/300,
#  📊 path: 192,  new path: 50,  docs changed path: 266,  Log-likelihood: -456160.31
# 🔄 Chain 1 in iteration 31/300,
#  📊 path: 182,  new path: 49,  docs changed path: 268,  Log-likelihood: -461006.69
# 🔄 Chain 3 in iteration 31/300,
#  📊 path: 187,  🔄 Chain 2 in iteration 31/300,
# new path: 49,   📊 path: 194, docs changed path: 305,   new path: 55, Log-likelihood: -456658.86
# docs changed path: 275,  Log-likelihood: -456659.33
# 🔄 Chain 1 in iteration 32/300,
#  📊 path: 177,  new path: 45,  docs changed path: 272,  Log-likelihood: -460760.58
# 🔄 Chain 3 in iteration 32/300,
#  📊 path: 184,  new path: 38,  docs changed path: 297,  Log-likelihood: -455811.00
# 🔄 Chain 2 in iteration 32/300,
#  📊 path: 191,  new path: 49,  docs changed path: 271,  Log-likelihood: -455529.81
# 🔄 Chain 1 in iteration 33/300,
#  📊 path: 176,  new path: 44,  docs changed path: 249,  Log-likelihood: -460059.48
# 🔄 Chain 3 in iteration 33/300,
#  📊 path: 189,  new path: 49,  docs changed path: 331,  Log-likelihood: -455267.80
# 🔄 Chain 2 in iteration 33/300,
#  📊 path: 196,  new path: 48,  docs changed path: 256,  Log-likelihood: -454910.68
# 🔄 Chain 1 in iteration 34/300,
#  📊 path: 181,  new path: 54,  docs changed path: 249,  Log-likelihood: -459541.11
# 🔄 Chain 3 in iteration 34/300,
#  📊 path: 187,  new path: 44,  docs changed path: 309,  Log-likelihood: -454546.13
# 🔄 Chain 2 in iteration 34/300,
#  📊 path: 192,  new path: 45,  docs changed path: 267,  Log-likelihood: -454844.75
# 🔄 Chain 1 in iteration 35/300,
#  📊 path: 184,  new path: 40,  docs changed path: 242,  Log-likelihood: -459617.66
# 🔄 Chain 3 in iteration 35/300,
#  📊 path: 193,  new path: 41,  docs changed path: 295,  Log-likelihood: -453553.84
# 🔄 Chain 2 in iteration 35/300,
#  📊 path: 193,  new path: 50,  docs changed path: 268,  Log-likelihood: -454140.94
# 🔄 Chain 1 in iteration 36/300,
#  📊 path: 188,  new path: 42,  docs changed path: 267,  Log-likelihood: -458853.84
# 🔄 Chain 3 in iteration 36/300,
#  📊 path: 181,  new path: 37,  docs changed path: 300,  Log-likelihood: -454240.69
# 🔄 Chain 2 in iteration 36/300,
#  📊 path: 197,  new path: 52,  docs changed path: 267,  Log-likelihood: -454322.61
# 🔄 Chain 1 in iteration 37/300,
#  📊 path: 179,  new path: 45,  docs changed path: 264,  Log-likelihood: -458517.28
# 🔄 Chain 3 in iteration 37/300,
#  📊 path: 183,  new path: 44,  docs changed path: 300,  Log-likelihood: -454327.29
# 🔄 Chain 2 in iteration 37/300,
#  📊 path: 191,  new path: 38,  docs changed path: 256,  Log-likelihood: -453417.08
# 🔄 Chain 1 in iteration 38/300,
#  📊 path: 183,  new path: 47,  docs changed path: 268,  Log-likelihood: -457688.55
# 🔄 Chain 3 in iteration 38/300,
#  📊 path: 194,  new path: 43,  docs changed path: 303,  Log-likelihood: -453579.12
# 🔄 Chain 2 in iteration 38/300,
#  📊 path: 195,  new path: 42,  docs changed path: 262,  Log-likelihood: -453015.91
# 🔄 Chain 1 in iteration 39/300,
#  📊 path: 184,  new path: 54,  docs changed path: 265,  Log-likelihood: -458299.36
# 🔄 Chain 3 in iteration 39/300,
#  📊 path: 197,  new path: 40,  docs changed path: 296,  Log-likelihood: -452284.22
# 🔄 Chain 2 in iteration 39/300,
#  📊 path: 196,  new path: 58,  docs changed path: 258,  Log-likelihood: -452707.12
# 🔄 Chain 1 in iteration 40/300,
#  📊 path: 191,  new path: 53,  docs changed path: 281,  Log-likelihood: -457633.96
# 🔄 Chain 3 in iteration 40/300,
#  📊 path: 200,  new path: 50,  docs changed path: 312,  Log-likelihood: -452482.31
# 🔄 Chain 2 in iteration 40/300,
#  📊 path: 196,  new path: 43,  docs changed path: 253,  Log-likelihood: -452520.21
# 🔄 Chain 1 in iteration 41/300,
#  📊 path: 197,  new path: 60,  docs changed path: 281,  Log-likelihood: -456501.59
# 🔄 Chain 3 in iteration 41/300,
#  📊 path: 194,  new path: 40,  docs changed path: 288,  Log-likelihood: -452232.00
# 🔄 Chain 1 in iteration 42/300,
#  📊 path: 184,  new path: 46,  docs changed path: 275,  Log-likelihood: -458864.69
# 🔄 Chain 2 in iteration 41/300,
#  📊 path: 205,  new path: 50,  docs changed path: 263,  Log-likelihood: -450728.81
# 🔄 Chain 1 in iteration 43/300,
#  📊 path: 187,  new path: 48,  docs changed path: 251,  Log-likelihood: -455943.16
# 🔄 Chain 3 in iteration 42/300,
#  📊 path: 198,  new path: 47,  docs changed path: 295,  Log-likelihood: -451746.80
# 🔄 Chain 2 in iteration 42/300,
#  📊 path: 194,  new path: 43,  docs changed path: 262,  Log-likelihood: -452292.43
# 🔄 Chain 1 in iteration 44/300,
#  📊 path: 185,  new path: 54,  docs changed path: 257,  Log-likelihood: -456359.17
# 🔄 Chain 3 in iteration 43/300,
#  📊 path: 207,  new path: 52,  docs changed path: 308,  Log-likelihood: -450650.54
# 🔄 Chain 2 in iteration 43/300,
#  📊 path: 196,  new path: 42,  docs changed path: 270,  Log-likelihood: -450266.92
# 🔄 Chain 1 in iteration 45/300,
#  📊 path: 189,  new path: 49,  docs changed path: 272,  Log-likelihood: -455735.46
# 🔄 Chain 2 in iteration 44/300,
#  📊 path: 199,  new path: 48,  docs changed path: 263,  Log-likelihood: -451244.77
# 🔄 Chain 3 in iteration 44/300,
#  📊 path: 205,  new path: 48,  docs changed path: 317,  Log-likelihood: -451886.21
# 🔄 Chain 1 in iteration 46/300,
#  📊 path: 188,  new path: 40,  docs changed path: 254,  Log-likelihood: -455022.89
# 🔄 Chain 2 in iteration 45/300,
#  📊 path: 194,  new path: 35,  docs changed path: 256,  Log-likelihood: -451210.86
# 🔄 Chain 3 in iteration 45/300,
#  📊 path: 199,  new path: 45,  docs changed path: 306,  Log-likelihood: -450540.46
# 🔄 Chain 1 in iteration 47/300,
#  📊 path: 186,  new path: 45,  docs changed path: 266,  Log-likelihood: -456598.62
# 🔄 Chain 2 in iteration 46/300,
#  📊 path: 205,  new path: 48,  docs changed path: 271,  Log-likelihood: -450854.67
# 🔄 Chain 3 in iteration 46/300,
#  📊 path: 208,  new path: 51,  docs changed path: 319,  Log-likelihood: -450398.44
# 🔄 Chain 1 in iteration 48/300,
#  📊 path: 187,  new path: 44,  docs changed path: 279,  Log-likelihood: -456325.28
# 🔄 Chain 2 in iteration 47/300,
#  📊 path: 207,  new path: 55,  docs changed path: 279,  Log-likelihood: -450264.92
# 🔄 Chain 3 in iteration 47/300,
#  📊 path: 207,  new path: 56,  docs changed path: 327,  Log-likelihood: -449019.66
# 🔄 Chain 1 in iteration 49/300,
#  📊 path: 195,  new path: 51,  docs changed path: 276,  Log-likelihood: -455081.58
# 🔄 Chain 2 in iteration 48/300,
#  📊 path: 200,  new path: 40,  docs changed path: 254,  Log-likelihood: -450104.01
# 🔄 Chain 3 in iteration 48/300,
#  📊 path: 206,  new path: 50,  docs changed path: 301,  Log-likelihood: -448800.02
# 🔄 Chain 1 in iteration 50/300,
#  📊 path: 196,  new path: 50,  docs changed path: 273,  Log-likelihood: -455181.93
# 🔄 Chain 2 in iteration 49/300,
#  📊 path: 198,  new path: 42,  docs changed path: 269,  Log-likelihood: -449731.40
# 🔄 Chain 3 in iteration 49/300,
#  📊 path: 205,  new path: 44,  docs changed path: 313,  Log-likelihood: -448709.52
# 🔄 Chain 1 in iteration 51/300,
#  📊 path: 204,  new path: 54,  docs changed path: 280,  Log-likelihood: -453863.12
# 🔄 Chain 2 in iteration 50/300,
#  📊 path: 204,  new path: 46,  docs changed path: 265,  Log-likelihood: -448775.57
# 🔄 Chain 3 in iteration 50/300,
#  📊 path: 201,  new path: 40,  docs changed path: 299,  Log-likelihood: -448837.90
# 🔄 Chain 1 in iteration 52/300,
#  📊 path: 191,  new path: 46,  docs changed path: 254,  Log-likelihood: -453631.30
# 🔄 Chain 2 in iteration 51/300,
#  📊 path: 199,  new path: 45,  docs changed path: 246,  Log-likelihood: -449637.86
# 🔄 Chain 3 in iteration 51/300,
#  📊 path: 207,  new path: 52,  docs changed path: 315,  Log-likelihood: -448111.83
# 🔄 Chain 1 in iteration 53/300,
#  📊 path: 194,  new path: 42,  docs changed path: 254,  Log-likelihood: -454131.72
# 🔄 Chain 2 in iteration 52/300,
#  📊 path: 204,  new path: 50,  docs changed path: 261,  Log-likelihood: -447401.53
# 🔄 Chain 3 in iteration 52/300,
#  📊 path: 211,  new path: 52,  docs changed path: 307,  Log-likelihood: -448219.69
# 🔄 Chain 1 in iteration 54/300,
#  📊 path: 200,  new path: 49,  docs changed path: 261,  Log-likelihood: -452288.30
# 🔄 Chain 2 in iteration 53/300,
#  📊 path: 206,  new path: 50,  docs changed path: 251,  Log-likelihood: -447887.42
# 🔄 Chain 3 in iteration 53/300,
#  📊 path: 206,  new path: 41,  docs changed path: 317,  Log-likelihood: -448404.84
# 🔄 Chain 1 in iteration 55/300,
#  📊 path: 191,  new path: 43,  docs changed path: 275,  Log-likelihood: -454266.22
# 🔄 Chain 2 in iteration 54/300,
#  📊 path: 196,  new path: 45,  docs changed path: 250,  Log-likelihood: -448459.82
# 🔄 Chain 3 in iteration 54/300,
#  📊 path: 201,  new path: 38,  docs changed path: 299,  Log-likelihood: -448453.97
# 🔄 Chain 1 in iteration 56/300,
#  📊 path: 197,  new path: 49,  docs changed path: 286,  Log-likelihood: -454386.25
# 🔄 Chain 2 in iteration 55/300,
#  📊 path: 208,  new path: 50,  docs changed path: 255,  Log-likelihood: -446973.09
# 🔄 Chain 3 in iteration 55/300,
#  📊 path: 220,  new path: 63,  docs changed path: 320,  Log-likelihood: -446272.83
# 🔄 Chain 1 in iteration 57/300,
#  📊 path: 196,  new path: 51,  docs changed path: 276,  Log-likelihood: -453356.62
# 🔄 Chain 2 in iteration 56/300,
#  📊 path: 201,  new path: 40,  docs changed path: 249,  Log-likelihood: -446827.52
# 🔄 Chain 3 in iteration 56/300,
#  📊 path: 215,  new path: 45,  docs changed path: 307,  Log-likelihood: -445938.04
# 🔄 Chain 1 in iteration 58/300,
#  📊 path: 198,  new path: 43,  docs changed path: 273,  Log-likelihood: -452412.77
# 🔄 Chain 2 in iteration 57/300,
#  📊 path: 201,  new path: 41,  docs changed path: 248,  Log-likelihood: -448338.65
# 🔄 Chain 1 in iteration 59/300,
#  📊 path: 196,  new path: 42,  docs changed path: 265,  Log-likelihood: -453195.03
# 🔄 Chain 3 in iteration 57/300,
#  📊 path: 214,  new path: 39,  docs changed path: 293,  Log-likelihood: -446560.77
# 🔄 Chain 2 in iteration 58/300,
#  📊 path: 207,  new path: 45,  docs changed path: 261,  Log-likelihood: -447242.25
# 🔄 Chain 1 in iteration 60/300,
#  📊 path: 195,  new path: 49,  docs changed path: 258,  Log-likelihood: -452682.65
# 🔄 Chain 3 in iteration 58/300,
#  📊 path: 211,  new path: 44,  docs changed path: 310,  Log-likelihood: -446587.24
# 🔄 Chain 2 in iteration 59/300,
#  📊 path: 202,  new path: 52,  docs changed path: 262,  Log-likelihood: -448000.95
# 🔄 Chain 1 in iteration 61/300,
#  📊 path: 189,  new path: 42,  docs changed path: 262,  Log-likelihood: -451867.85
# 🔄 Chain 3 in iteration 59/300,
#  📊 path: 215,  new path: 48,  docs changed path: 308,  Log-likelihood: -445702.09
# 🔄 Chain 2 in iteration 60/300,
#  📊 path: 206,  new path: 55,  docs changed path: 260,  Log-likelihood: -446324.68
# 🔄 Chain 1 in iteration 62/300,
#  📊 path: 196,  new path: 43,  docs changed path: 271,  Log-likelihood: -453231.63
# 🔄 Chain 3 in iteration 60/300,
#  📊 path: 204,  new path: 35,  docs changed path: 309,  Log-likelihood: -447222.48
# 🔄 Chain 2 in iteration 61/300,
#  📊 path: 209,  new path: 46,  docs changed path: 267,  Log-likelihood: -446896.86
# 🔄 Chain 1 in iteration 63/300,
#  📊 path: 185,  new path: 41,  docs changed path: 266,  Log-likelihood: -453499.87
# 🔄 Chain 3 in iteration 61/300,
#  📊 path: 205,  new path: 41,  docs changed path: 302,  Log-likelihood: -445879.98
# 🔄 Chain 2 in iteration 62/300,
#  📊 path: 206,  new path: 51,  docs changed path: 268,  Log-likelihood: -445853.92
# 🔄 Chain 1 in iteration 64/300,
#  📊 path: 194,  new path: 50,  docs changed path: 281,  Log-likelihood: -453377.53
# 🔄 Chain 3 in iteration 62/300,
#  📊 path: 212,  new path: 47,  docs changed path: 298,  Log-likelihood: -444955.05
# 🔄 Chain 2 in iteration 63/300,
#  📊 path: 208,  new path: 44,  docs changed path: 259,  Log-likelihood: -445938.97
# 🔄 Chain 1 in iteration 65/300,
#  📊 path: 189,  new path: 43,  docs changed path: 265,  Log-likelihood: -454096.87
# 🔄 Chain 3 in iteration 63/300,
#  📊 path: 225,  new path: 59,  docs changed path: 297,  Log-likelihood: -443191.32
# 🔄 Chain 2 in iteration 64/300,
#  📊 path: 203,  new path: 51,  docs changed path: 275,  Log-likelihood: -445914.86
# 🔄 Chain 1 in iteration 66/300,
#  📊 path: 203,  new path: 53,  docs changed path: 277,  Log-likelihood: -452084.71
# 🔄 Chain 3 in iteration 64/300,
#  📊 path: 212,  new path: 41,  docs changed path: 294,  Log-likelihood: -444494.83
# 🔄 Chain 2 in iteration 65/300,
#  📊 path: 209,  new path: 54,  docs changed path: 272,  Log-likelihood: -445982.11
# 🔄 Chain 1 in iteration 67/300,
#  📊 path: 193,  new path: 42,  docs changed path: 267,  Log-likelihood: -452480.84
# 🔄 Chain 3 in iteration 65/300,
#  📊 path: 223,  new path: 56,  docs changed path: 316,  Log-likelihood: -441065.35
# 🔄 Chain 2 in iteration 66/300,
#  📊 path: 211,  new path: 47,  docs changed path: 271,  Log-likelihood: -446119.93
# 🔄 Chain 1 in iteration 68/300,
#  📊 path: 196,  new path: 52,  docs changed path: 255,  Log-likelihood: -452164.64
# 🔄 Chain 3 in iteration 66/300,
#  📊 path: 222,  new path: 46,  docs changed path: 323,  Log-likelihood: -442354.47
# 🔄 Chain 1 in iteration 69/300,
#  📊 path: 198,  new path: 48,  docs changed path: 265,  Log-likelihood: -453127.26
# 🔄 Chain 2 in iteration 67/300,
#  📊 path: 206,  new path: 41,  docs changed path: 265,  Log-likelihood: -445672.90
# 🔄 Chain 3 in iteration 67/300,
#  📊 path: 222,  new path: 48,  docs changed path: 314,  Log-likelihood: -443701.28
# 🔄 Chain 1 in iteration 70/300,
#  📊 path: 204,  new path: 49,  docs changed path: 267,  Log-likelihood: -453566.56
# 🔄 Chain 2 in iteration 68/300,
#  📊 path: 210,  new path: 44,  docs changed path: 266,  Log-likelihood: -444755.27
# 🔄 Chain 1 in iteration 71/300,
#  📊 path: 190,  new path: 37,  docs changed path: 257,  Log-likelihood: -452728.92
# 🔄 Chain 3 in iteration 68/300,
#  📊 path: 212,  new path: 41,  docs changed path: 296,  Log-likelihood: -442881.15
# 🔄 Chain 2 in iteration 69/300,
#  📊 path: 213,  new path: 44,  docs changed path: 258,  Log-likelihood: -445328.26
# 🔄 Chain 1 in iteration 72/300,
#  📊 path: 195,  new path: 48,  docs changed path: 270,  Log-likelihood: -453079.04
# 🔄 Chain 3 in iteration 69/300,
#  📊 path: 208,  new path: 41,  docs changed path: 303,  Log-likelihood: -442909.16
# 🔄 Chain 2 in iteration 70/300,
#  📊 path: 214,  new path: 46,  docs changed path: 262,  Log-likelihood: -445076.32
# 🔄 Chain 1 in iteration 73/300,
#  📊 path: 203,  new path: 53,  docs changed path: 280,  Log-likelihood: -452693.70
# 🔄 Chain 3 in iteration 70/300,
#  📊 path: 207,  new path: 38,  docs changed path: 277,  Log-likelihood: -442008.19
# 🔄 Chain 2 in iteration 71/300,
#  📊 path: 211,  new path: 52,  docs changed path: 277,  Log-likelihood: -444711.83
# 🔄 Chain 1 in iteration 74/300,
#  📊 path: 192,  new path: 45,  docs changed path: 275,  Log-likelihood: -452681.36
# 🔄 Chain 3 in iteration 71/300,
#  📊 path: 206,  new path: 32,  docs changed path: 292,  Log-likelihood: -442278.86
# 🔄 Chain 2 in iteration 72/300,
#  📊 path: 219,  new path: 54,  docs changed path: 272,  Log-likelihood: -444331.35
# 🔄 Chain 1 in iteration 75/300,
#  📊 path: 189,  new path: 47,  docs changed path: 272,  Log-likelihood: -451840.13
# 🔄 Chain 3 in iteration 72/300,
#  📊 path: 215,  new path: 43,  docs changed path: 278,  Log-likelihood: -441193.63
# 🔄 Chain 2 in iteration 73/300,
#  📊 path: 221,  new path: 50,  docs changed path: 266,  Log-likelihood: -444748.61
# 🔄 Chain 1 in iteration 76/300,
#  📊 path: 203,  new path: 58,  docs changed path: 265,  Log-likelihood: -449605.88
# 🔄 Chain 2 in iteration 74/300,
#  📊 path: 211,  new path: 44,  docs changed path: 269,  Log-likelihood: -445496.66
# 🔄 Chain 3 in iteration 73/300,
#  📊 path: 216,  new path: 42,  docs changed path: 285,  Log-likelihood: -440868.97
# 🔄 Chain 1 in iteration 77/300,
#  📊 path: 194,  new path: 43,  docs changed path: 266,  Log-likelihood: -452956.85
# 🔄 Chain 2 in iteration 75/300,
#  📊 path: 208,  new path: 52,  docs changed path: 287,  Log-likelihood: -445544.08
# 🔄 Chain 3 in iteration 74/300,
#  📊 path: 217,  new path: 48,  docs changed path: 296,  Log-likelihood: -441005.07
# 🔄 Chain 1 in iteration 78/300,
#  📊 path: 204,  new path: 48,  docs changed path: 260,  Log-likelihood: -451172.64
# 🔄 Chain 2 in iteration 76/300,
#  📊 path: 215,  new path: 47,  docs changed path: 259,  Log-likelihood: -442949.18
# 🔄 Chain 3 in iteration 75/300,
#  📊 path: 224,  new path: 49,  docs changed path: 288,  Log-likelihood: -439795.56
# 🔄 Chain 1 in iteration 79/300,
#  📊 path: 212,  new path: 51,  docs changed path: 279,  Log-likelihood: -449723.00
# 🔄 Chain 2 in iteration 77/300,
#  📊 path: 219,  new path: 52,  docs changed path: 283,  Log-likelihood: -443336.22
# 🔄 Chain 3 in iteration 76/300,
#  📊 path: 227,  new path: 41,  docs changed path: 289,  Log-likelihood: -440269.91
# 🔄 Chain 1 in iteration 80/300,
#  📊 path: 203,  new path: 45,  docs changed path: 290,  Log-likelihood: -450466.39
# 🔄 Chain 2 in iteration 78/300,
#  📊 path: 212,  new path: 36,  docs changed path: 267,  Log-likelihood: -444931.55
# 🔄 Chain 3 in iteration 77/300,
#  📊 path: 215,  new path: 39,  docs changed path: 293,  Log-likelihood: -440620.20
# 🔄 Chain 1 in iteration 81/300,
#  📊 path: 203,  new path: 45,  docs changed path: 262,  Log-likelihood: -449292.85
# 🔄 Chain 2 in iteration 79/300,
#  📊 path: 214,  new path: 47,  docs changed path: 261,  Log-likelihood: -444183.31
# 🔄 Chain 3 in iteration 78/300,
#  📊 path: 237,  new path: 55,  docs changed path: 302,  Log-likelihood: -439305.16
# 🔄 Chain 1 in iteration 82/300,
#  📊 path: 196,  new path: 48,  docs changed path: 263,  Log-likelihood: -449791.47
# 🔄 Chain 2 in iteration 80/300,
#  📊 path: 206,  new path: 44,  docs changed path: 255,  Log-likelihood: -443524.85
# 🔄 Chain 1 in iteration 83/300,
#  📊 path: 202,  new path: 44,  docs changed path: 261,  Log-likelihood: -449376.44
# 🔄 Chain 3 in iteration 79/300,
#  📊 path: 227,  new path: 34,  docs changed path: 286,  Log-likelihood: -439356.47
# 🔄 Chain 2 in iteration 81/300,
#  📊 path: 214,  new path: 52,  docs changed path: 272,  Log-likelihood: -442743.14
# 🔄 Chain 1 in iteration 84/300,
#  📊 path: 212,  new path: 56,  docs changed path: 293,  Log-likelihood: -448199.93
# 🔄 Chain 3 in iteration 80/300,
#  📊 path: 230,  new path: 40,  docs changed path: 298,  Log-likelihood: -439681.54
# 🔄 Chain 2 in iteration 82/300,
#  📊 path: 208,  new path: 45,  docs changed path: 255,  Log-likelihood: -444503.31
# 🔄 Chain 1 in iteration 85/300,
#  📊 path: 201,  new path: 40,  docs changed path: 270,  Log-likelihood: -448068.88
# 🔄 Chain 3 in iteration 81/300,
#  📊 path: 228,  new path: 49,  docs changed path: 289,  Log-likelihood: -438006.18
# 🔄 Chain 2 in iteration 83/300,
#  📊 path: 214,  new path: 50,  docs changed path: 247,  Log-likelihood: -443471.25
# 🔄 Chain 1 in iteration 86/300,
#  📊 path: 210,  new path: 54,  docs changed path: 291,  Log-likelihood: -448162.78
# 🔄 Chain 3 in iteration 82/300,
#  📊 path: 217,  new path: 44,  docs changed path: 269,  Log-likelihood: -439753.25
# 🔄 Chain 2 in iteration 84/300,
#  📊 path: 213,  new path: 53,  docs changed path: 260,  Log-likelihood: -441266.23
# 🔄 Chain 1 in iteration 87/300,
#  📊 path: 214,  new path: 54,  docs changed path: 269,  Log-likelihood: -448089.71
# 🔄 Chain 3 in iteration 83/300,
#  📊 path: 226,  new path: 44,  docs changed path: 265,  Log-likelihood: -438235.58
# 🔄 Chain 2 in iteration 85/300,
#  📊 path: 222,  new path: 58,  docs changed path: 269,  Log-likelihood: -442269.57
# 🔄 Chain 1 in iteration 88/300,
#  📊 path: 212,  new path: 50,  docs changed path: 266,  Log-likelihood: -448386.70
# 🔄 Chain 3 in iteration 84/300,
#  📊 path: 233,  new path: 46,  docs changed path: 276,  Log-likelihood: -437480.01
# 🔄 Chain 2 in iteration 86/300,
#  📊 path: 208,  new path: 46,  docs changed path: 260,  Log-likelihood: -441885.10
# 🔄 Chain 1 in iteration 89/300,
#  📊 path: 220,  new path: 52,  docs changed path: 284,  Log-likelihood: -447167.09
# 🔄 Chain 3 in iteration 85/300,
#  📊 path: 231,  new path: 50,  docs changed path: 287,  Log-likelihood: -437790.44
# 🔄 Chain 2 in iteration 87/300,
#  📊 path: 217,  new path: 50,  docs changed path: 264,  Log-likelihood: -440827.59
# 🔄 Chain 1 in iteration 90/300,
#  📊 path: 210,  new path: 39,  docs changed path: 267,  Log-likelihood: -447117.08
# 🔄 Chain 3 in iteration 86/300,
#  📊 path: 233,  new path: 46,  docs changed path: 303,  Log-likelihood: -437623.97
# 🔄 Chain 2 in iteration 88/300,
#  📊 path: 222,  new path: 59,  docs changed path: 262,  Log-likelihood: -441914.86
# 🔄 Chain 1 in iteration 91/300,
#  📊 path: 212,  new path: 53,  docs changed path: 263,  Log-likelihood: -446830.02
# 🔄 Chain 3 in iteration 87/300,
#  📊 path: 225,  new path: 42,  docs changed path: 276,  Log-likelihood: -437342.76
# 🔄 Chain 2 in iteration 89/300,
#  📊 path: 224,  new path: 60,  docs changed path: 276,  Log-likelihood: -441273.51
# 🔄 Chain 1 in iteration 92/300,
#  📊 path: 210,  new path: 57,  docs changed path: 287,  Log-likelihood: -446710.19
# 🔄 Chain 3 in iteration 88/300,
#  📊 path: 230,  new path: 52,  docs changed path: 279,  Log-likelihood: -436755.17
# 🔄 Chain 2 in iteration 90/300,
#  📊 path: 215,  new path: 40,  docs changed path: 252,  Log-likelihood: -441603.31
# 🔄 Chain 1 in iteration 93/300,
#  📊 path: 219,  new path: 52,  docs changed path: 280,  Log-likelihood: -446871.12
# 🔄 Chain 2 in iteration 91/300,
#  📊 path: 213,  new path: 50,  docs changed path: 259,  Log-likelihood: -440502.63
# 🔄 Chain 3 in iteration 89/300,
#  📊 path: 230,  new path: 42,  docs changed path: 281,  Log-likelihood: -437411.96
# 🔄 Chain 1 in iteration 94/300,
#  📊 path: 213,  new path: 43,  docs changed path: 278,  Log-likelihood: -445731.76
# 🔄 Chain 2 in iteration 92/300,
#  📊 path: 219,  new path: 45,  docs changed path: 271,  Log-likelihood: -440465.42
# 🔄 Chain 3 in iteration 90/300,
#  📊 path: 224,  new path: 41,  docs changed path: 281,  Log-likelihood: -436971.89
# 🔄 Chain 1 in iteration 95/300,
#  📊 path: 217,  new path: 62,  docs changed path: 289,  Log-likelihood: -446001.93
# 🔄 Chain 2 in iteration 93/300,
#  📊 path: 226,  new path: 47,  docs changed path: 245,  Log-likelihood: -440792.42
# 🔄 Chain 3 in iteration 91/300,
#  📊 path: 232,  new path: 53,  docs changed path: 273,  Log-likelihood: -435547.22
# 🔄 Chain 1 in iteration 96/300,
#  📊 path: 214,  new path: 56,  docs changed path: 273,  Log-likelihood: -447920.76
# 🔄 Chain 2 in iteration 94/300,
#  📊 path: 227,  new path: 47,  docs changed path: 264,  Log-likelihood: -439415.09
# 🔄 Chain 3 in iteration 92/300,
#  📊 path: 227,  new path: 45,  docs changed path: 289,  Log-likelihood: -436644.12
# 🔄 Chain 1 in iteration 97/300,
#  📊 path: 217,  new path: 50,  docs changed path: 274,  Log-likelihood: -447089.73
# 🔄 Chain 2 in iteration 95/300,
#  📊 path: 223,  new path: 41,  docs changed path: 255,  Log-likelihood: -440327.37
# 🔄 Chain 1 in iteration 98/300,
#  📊 path: 216,  new path: 50,  docs changed path: 270,  Log-likelihood: -447480.72
# 🔄 Chain 3 in iteration 93/300,
#  📊 path: 221,  new path: 45,  docs changed path: 283,  Log-likelihood: -437719.90
# 🔄 Chain 2 in iteration 96/300,
#  📊 path: 223,  new path: 53,  docs changed path: 265,  Log-likelihood: -440070.89
# 🔄 Chain 1 in iteration 99/300,
#  📊 path: 216,  new path: 56,  docs changed path: 287,  Log-likelihood: -447357.68
# 🔄 Chain 3 in iteration 94/300,
#  📊 path: 222,  new path: 42,  docs changed path: 257,  Log-likelihood: -437535.57
# 🔄 Chain 2 in iteration 97/300,
#  📊 path: 222,  new path: 48,  docs changed path: 254,  Log-likelihood: -440711.56
# 🔄 Chain 1 in iteration 100/300,
#  📊 path: 212,  new path: 52,   docs changed path: 272, Log-likelihood: -447190.31
# 🔄 Chain 3 in iteration 95/300,
#  📊 path: 232,  new path: 55,  docs changed path: 281,  Log-likelihood: -436111.04
# 🔄 Chain 2 in iteration 98/300,
#  📊 path: 227,  new path: 52,  docs changed path: 258,  Log-likelihood: -438898.11
# 🔄 Chain 1 in iteration 101/300,
#  📊 path: 208,  new path: 46,  docs changed path: 263,  Log-likelihood: -446587.98
# 🔄 Chain 3 in iteration 96/300,
#  📊 path: 227,  new path: 47,  docs changed path: 266,  Log-likelihood: -436797.29
# 🔄 Chain 2 in iteration 99/300,
#  📊 path: 227,  new path: 51,  docs changed path: 267,  Log-likelihood: -439763.58
# 🔄 Chain 1 in iteration 102/300,
#  📊 path: 221,  new path: 58,  docs changed path: 272,  Log-likelihood: -446763.25
# 🔄 Chain 3 in iteration 97/300,
#  📊 path: 236,  new path: 55,  docs changed path: 275,  Log-likelihood: -436345.70
# 🔄 Chain 2 in iteration 100/300,
#  📊 path: 215,  new path: 43,  docs changed path: 262,  Log-likelihood: -439411.14
# 🔄 Chain 1 in iteration 103/300,
#  📊 path: 217,  new path: 44,  docs changed path: 276,  Log-likelihood: -447074.19
# 🔄 Chain 3 in iteration 98/300,
#  📊 path: 238,  new path: 43,  docs changed path: 294,  Log-likelihood: -435277.02
# 🔄 Chain 2 in iteration 101/300,
#  📊 path: 216,  new path: 43,  docs changed path: 263,  Log-likelihood: -439817.82
# 🔄 Chain 1 in iteration 104/300,
#  📊 path: 213,  new path: 45,  docs changed path: 267,  Log-likelihood: -446932.10
# 🔄 Chain 3 in iteration 99/300,
#  📊 path: 229,  new path: 50,  docs changed path: 294,  Log-likelihood: -436707.07
# 🔄 Chain 2 in iteration 102/300,
#  📊 path: 225,  new path: 48,  docs changed path: 245,  Log-likelihood: -438366.88
# 🔄 Chain 1 in iteration 105/300,
#  📊 path: 205,  new path: 44,  docs changed path: 269,  Log-likelihood: -447283.22
# 🔄 Chain 3 in iteration 100/300,
#  📊 path: 223,  new path: 40,  docs changed path: 271,  Log-likelihood: -437262.23
# 🔄 Chain 2 in iteration 103/300,
#  📊 path: 225,  new path: 54,  docs changed path: 260,  Log-likelihood: -438437.23
# 🔄 Chain 1 in iteration 106/300,
#  📊 path: 206,  new path: 50,  docs changed path: 266,  Log-likelihood: -446341.60
# 🔄 Chain 3 in iteration 101/300,
#  📊 path: 226,  new path: 44,  docs changed path: 288,  Log-likelihood: -435647.50
# 🔄 Chain 1 in iteration 107/300,
#  📊 path: 215,  new path: 53,  docs changed path: 260,  Log-likelihood: -446285.49
# 🔄 Chain 2 in iteration 104/300,
#  📊 path: 233,  new path: 57,  docs changed path: 257,  Log-likelihood: -437939.86
# 🔄 Chain 3 in iteration 102/300,
#  📊 path: 226,  new path: 47,  docs changed path: 281,  Log-likelihood: -435727.87
# 🔄 Chain 1 in iteration 108/300,
#  📊 path: 212,  new path: 49,  docs changed path: 265,  Log-likelihood: -444627.76
# 🔄 Chain 2 in iteration 105/300,
#  📊 path: 223,  new path: 39,  docs changed path: 262,  Log-likelihood: -437806.21
# 🔄 Chain 3 in iteration 103/300,
#  📊 path: 237,  new path: 56,  docs changed path: 265,  Log-likelihood: -435020.54
# 🔄 Chain 1 in iteration 109/300,
#  📊 path: 207,  new path: 48,  docs changed path: 256,  Log-likelihood: -447461.23
# 🔄 Chain 2 in iteration 106/300,
#  📊 path: 225,  new path: 50,  docs changed path: 272,  Log-likelihood: -436970.37
# 🔄 Chain 3 in iteration 104/300,
#  📊 path: 239,  new path: 55,  docs changed path: 280,  Log-likelihood: -434680.37
# 🔄 Chain 1 in iteration 110/300,
#  📊 path: 211,  new path: 51,  docs changed path: 257,  Log-likelihood: -446133.03
# 🔄 Chain 2 in iteration 107/300,
#  📊 path: 223,  new path: 45,  docs changed path: 254,  Log-likelihood: -438188.83
# 🔄 Chain 1 in iteration 111/300,
#  📊 path: 208,  new path: 46,  docs changed path: 261,  Log-likelihood: -445481.96
# 🔄 Chain 3 in iteration 105/300,
#  📊 path: 245,  new path: 50,  docs changed path: 273,  Log-likelihood: -434188.79
# 🔄 Chain 2 in iteration 108/300,
#  📊 path: 221,  new path: 44,  docs changed path: 263,  Log-likelihood: -437361.91
# 🔄 Chain 1 in iteration 112/300,
#  📊 path: 211,  new path: 49,  docs changed path: 256,  Log-likelihood: -445469.06
# 🔄 Chain 3 in iteration 106/300,
#  📊 path: 234,  new path: 41,  docs changed path: 251,  Log-likelihood: -434045.54
# 🔄 Chain 2 in iteration 109/300,
#  📊 path: 228,  new path: 51,  docs changed path: 251,  Log-likelihood: -436915.80
# 🔄 Chain 1 in iteration 113/300,
#  📊 path: 208,  new path: 46,  docs changed path: 264,  Log-likelihood: -446743.39
# 🔄 Chain 3 in iteration 107/300,
#  📊 path: 237,  new path: 46,  docs changed path: 256,  Log-likelihood: -434663.83
# 🔄 Chain 2 in iteration 110/300,
#  📊 path: 224,  new path: 49,  docs changed path: 250,  Log-likelihood: -437379.95
# 🔄 Chain 1 in iteration 114/300,
#  📊 path: 213,  new path: 55,  docs changed path: 244,  Log-likelihood: -445760.45
# 🔄 Chain 2 in iteration 111/300,
#  📊 path: 226,  new path: 49,  docs changed path: 247,  Log-likelihood: -436807.65
# 🔄 Chain 3 in iteration 108/300,
#  📊 path: 229,  new path: 45,  docs changed path: 274,  Log-likelihood: -434311.99
# 🔄 Chain 1 in iteration 115/300,
#  📊 path: 207,  new path: 53,  docs changed path: 277,  Log-likelihood: -446858.56
# 🔄 Chain 2 in iteration 112/300,
#  📊 path: 232,  new path: 55,  docs changed path: 260,  Log-likelihood: -437603.10
# 🔄 Chain 3 in iteration 109/300,
#  📊 path: 237,  new path: 49,  docs changed path: 268,  Log-likelihood: -434088.66
# 🔄 Chain 1 in iteration 116/300,
#  📊 path: 213,  new path: 57,  docs changed path: 276,  Log-likelihood: -445362.75
# 🔄 Chain 2 in iteration 113/300,
#  📊 path: 226,  new path: 46,  docs changed path: 262,  Log-likelihood: -437247.91
# 🔄 Chain 3 in iteration 110/300,
#  📊 path: 242,  new path: 56,  docs changed path: 274,  Log-likelihood: -434109.35
# 🔄 Chain 1 in iteration 117/300,
#  📊 path: 209,  new path: 53,  docs changed path: 279,  Log-likelihood: -446803.41
# 🔄 Chain 2 in iteration 114/300,
#  📊 path: 227,  new path: 49,  docs changed path: 237,  Log-likelihood: -436616.34
# 🔄 Chain 3 in iteration 111/300,
#  📊 path: 239,  new path: 48,  docs changed path: 280,  Log-likelihood: -434594.34
# 🔄 Chain 1 in iteration 118/300,
#  📊 path: 216,  new path: 55,  docs changed path: 284,  Log-likelihood: -443862.55
# 🔄 Chain 2 in iteration 115/300,
#  📊 path: 222,  new path: 46,  docs changed path: 255,  Log-likelihood: -436327.12
# 🔄 Chain 3 in iteration 112/300,
#  📊 path: 245,  new path: 51,  docs changed path: 279,  Log-likelihood: -433139.61
# 🔄 Chain 1 in iteration 119/300,
#  📊 path: 216,  new path: 55,  docs changed path: 260,  Log-likelihood: -444994.90
# 🔄 Chain 2 in iteration 116/300,
#  📊 path: 230,  new path: 50,  docs changed path: 244,  Log-likelihood: -435847.28
# 🔄 Chain 3 in iteration 113/300,
#  📊 path: 239,  new path: 47,  docs changed path: 278,  Log-likelihood: -432875.52
# 🔄 Chain 1 in iteration 120/300,
#  📊 path: 218,  new path: 53,  docs changed path: 267,  Log-likelihood: -444793.60
# 🔄 Chain 2 in iteration 117/300,
#  📊 path: 231,  new path: 53,  docs changed path: 254,  Log-likelihood: -435517.02
# 🔄 Chain 3 in iteration 114/300,
#  📊 path: 239,  new path: 57,  docs changed path: 271,  Log-likelihood: -432272.90
# 🔄 Chain 1 in iteration 121/300,
#  📊 path: 215,  new path: 56,  docs changed path: 267,  Log-likelihood: -444584.55
# 🔄 Chain 2 in iteration 118/300,
#  📊 path: 233,  new path: 57,  docs changed path: 250,  Log-likelihood: -435033.72
# 🔄 Chain 1 in iteration 122/300,
#  📊 path: 217,  new path: 54,  docs changed path: 255,  Log-likelihood: -444562.72
# 🔄 Chain 3 in iteration 115/300,
#  📊 path: 240,  new path: 55,  docs changed path: 257,  Log-likelihood: -433973.07
# 🔄 Chain 2 in iteration 119/300,
#  📊 path: 235,  new path: 56,  docs changed path: 233,  Log-likelihood: -434317.53
# 🔄 Chain 1 in iteration 123/300,
#  📊 path: 205,  new path: 44,  docs changed path: 247,  Log-likelihood: -445003.60
# 🔄 Chain 3 in iteration 116/300,
#  📊 path: 243,  new path: 47,  docs changed path: 276,  Log-likelihood: -433283.49
# 🔄 Chain 2 in iteration 120/300,
#  📊 path: 236,  new path: 53,  docs changed path: 246,  Log-likelihood: -435841.89
# 🔄 Chain 1 in iteration 124/300,
#  📊 path: 211,  new path: 55,  docs changed path: 265,  Log-likelihood: -445208.09
# 🔄 Chain 3 in iteration 117/300,
#  📊 path: 249,  new path: 51,  docs changed path: 261,  Log-likelihood: -432216.76
# 🔄 Chain 2 in iteration 121/300,
#  📊 path: 236,  new path: 54,  docs changed path: 259,  Log-likelihood: -435917.97
# 🔄 Chain 1 in iteration 125/300,
#  📊 path: 208,  new path: 53,  docs changed path: 262,  Log-likelihood: -445244.23
# 🔄 Chain 3 in iteration 118/300,
#  📊 path: 235,  new path: 42,  docs changed path: 259,  Log-likelihood: -433319.18
# 🔄 Chain 2 in iteration 122/300,
#  📊 path: 231,  new path: 44,  docs changed path: 254,  Log-likelihood: -434957.08
# 🔄 Chain 1 in iteration 126/300,
#  📊 path: 217,  new path: 52,  docs changed path: 263,  Log-likelihood: -444085.72
# 🔄 Chain 3 in iteration 119/300,
#  📊 path: 242,  new path: 49,  docs changed path: 247,  Log-likelihood: -432933.14
# 🔄 Chain 1 in iteration 127/300,
#  📊 path: 207,  new path: 49,  docs changed path: 258,  Log-likelihood: -445090.73
# 🔄 Chain 2 in iteration 123/300,
#  📊 path: 230,  new path: 49,  docs changed path: 240,  Log-likelihood: -435786.15
# 🔄 Chain 3 in iteration 120/300,
#  📊 path: 243,  new path: 48,  docs changed path: 253,  Log-likelihood: -432436.76
# 🔄 Chain 1 in iteration 128/300,
#  📊 path: 217,  new path: 54,  docs changed path: 267,  Log-likelihood: -444513.23
# 🔄 Chain 2 in iteration 124/300,
#  📊 path: 234,  new path: 47,  docs changed path: 243,  Log-likelihood: -435139.85
# 🔄 Chain 3 in iteration 121/300,
#  📊 path: 250,  new path: 50,  docs changed path: 262,  Log-likelihood: -432465.23
# 🔄 Chain 1 in iteration 129/300,
#  📊 path: 214,  new path: 52,  docs changed path: 256,  Log-likelihood: -443866.05
# 🔄 Chain 2 in iteration 125/300,
#  📊 path: 230,  new path: 49,  docs changed path: 253,  Log-likelihood: -435167.91
# 🔄 Chain 3 in iteration 122/300,
#  📊 path: 242,  new path: 43,  docs changed path: 275,  Log-likelihood: -432489.00
# 🔄 Chain 1 in iteration 130/300,
#  📊 path: 221,  new path: 61,  docs changed path: 268,  Log-likelihood: -443334.55
# 🔄 Chain 2 in iteration 126/300,
#  📊 path: 247,  new path: 60,  docs changed path: 274,  Log-likelihood: -434242.09
# 🔄 Chain 3 in iteration 123/300,
#  📊 path: 231,  new path: 37,  docs changed path: 269,  Log-likelihood: -433852.92
# 🔄 Chain 1 in iteration 131/300,
#  📊 path: 211,  new path: 38,  docs changed path: 262,  Log-likelihood: -443716.98
# 🔄 Chain 2 in iteration 127/300,
#  📊 path: 237,  new path: 44,  docs changed path: 263,  Log-likelihood: -433933.22
# 🔄 Chain 3 in iteration 124/300,
#  📊 path: 240,  new path: 43,  docs changed path: 257,  Log-likelihood: -432723.56
# 🔄 Chain 1 in iteration 132/300,
#  📊 path: 218,  new path: 55,  docs changed path: 278,  Log-likelihood: -443400.21
# 🔄 Chain 2 in iteration 128/300,
#  📊 path: 232,  new path: 42,  docs changed path: 238,  Log-likelihood: -436031.36
# 🔄 Chain 1 in iteration 133/300,
#  📊 path: 216,  new path: 54,  docs changed path: 267,  Log-likelihood: -444265.23
# 🔄 Chain 3 in iteration 125/300,
#  📊 path: 237,  new path: 39,  docs changed path: 279,  Log-likelihood: -432592.96
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'1': [584, 591, 595, 597, 597, 601, 601, 606, 608, 608, 600, 601, 601, 589, 592, 599, 597, 608, 608, 607, 613], '2': [603, 589, 603, 595, 600, 607, 604, 610, 615, 612, 603, 604, 611, 605, 620, 615, 609, 610, 610, 609, 603], '3': [562, 579, 574, 581, 582, 571, 570, 571, 573, 567, 576, 579, 570, 584, 577, 583, 587, 582, 576, 576, 575]}, mean_jaccard:[0.9434380931081213, 0.9370127640814949, 0.9224174709243312], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.5457，mean_jaccard:[0.9434380931081213, 0.9370127640814949, 0.9224174709243312], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 2 in iteration 129/300,
#  📊 path: 238,  new path: 51,  docs changed path: 240,  Log-likelihood: -434214.96
# 🔄 Chain 1 in iteration 134/300,
#  📊 path: 207,  new path: 45,  docs changed path: 269,  Log-likelihood: -445142.54
# 🔄 Chain 3 in iteration 126/300,
#  📊 path: 244,  new path: 46,  docs changed path: 273,  Log-likelihood: -431820.50
# 🔄 Chain 2 in iteration 130/300,
#  📊 path: 232,  new path: 49,  docs changed path: 244,  Log-likelihood: -434121.56
# 🔄 Chain 1 in iteration 135/300,
#  📊 path: 224,  new path: 61,  docs changed path: 261,  Log-likelihood: -443649.58
# 🔄 Chain 3 in iteration 127/300,
#  📊 path: 247,  new path: 46,  docs changed path: 277,  Log-likelihood: -431618.30
# 🔄 Chain 2 in iteration 131/300,
#  📊 path: 240,  new path: 50,  docs changed path: 246,  Log-likelihood: -433780.64
# 🔄 Chain 1 in iteration 136/300,
#  📊 path: 215,  new path: 50,  docs changed path: 255,  Log-likelihood: -443830.36
# 🔄 Chain 3 in iteration 128/300,
#  📊 path: 238,  new path: 41,  docs changed path: 271,  Log-likelihood: -432330.82
# 🔄 Chain 2 in iteration 132/300,
#  📊 path: 234,  new path: 40,  docs changed path: 238,  Log-likelihood: -435614.32
# 🔄 Chain 1 in iteration 137/300,
#  📊 path: 224,  new path: 56,  docs changed path: 269,  Log-likelihood: -444247.99
# 🔄 Chain 3 in iteration 129/300,
#  📊 path: 230,  new path: 44,  docs changed path: 253,  Log-likelihood: -432635.51
# 🔄 Chain 2 in iteration 133/300,
#  📊 path: 241,  new path: 50,  docs changed path: 243,  Log-likelihood: -433383.01
# 🔄 Chain 1 in iteration 138/300,
#  📊 path: 219,  new path: 54,  docs changed path: 262,  Log-likelihood: -443682.81
# 🔄 Chain 3 in iteration 130/300,
#  📊 path: 238,  new path: 42,  docs changed path: 248,  Log-likelihood: -431423.14
# 🔄 Chain 2 in iteration 134/300,
#  📊 path: 237,  new path: 38,  docs changed path: 238,  Log-likelihood: -434371.36
# 🔄 Chain 1 in iteration 139/300,
#  📊 path: 215,  new path: 53,  docs changed path: 239,  Log-likelihood: -443329.87
# 🔄 Chain 3 in iteration 131/300,
#  📊 path: 242,  new path: 44,  docs changed path: 268,  Log-likelihood: -432653.64
# 🔄 Chain 2 in iteration 135/300,
#  📊 path: 237,  new path: 46,  docs changed path: 233,  Log-likelihood: -434193.32
# 🔄 Chain 1 in iteration 140/300,
#  📊 path: 216,  new path: 49,  docs changed path: 262,  Log-likelihood: -443194.89
# 🔄 Chain 3 in iteration 132/300,
#  📊 path: 236,  new path: 40,  docs changed path: 265,  Log-likelihood: -432035.24
# 🔄 Chain 2 in iteration 136/300,
#  📊 path: 243,  new path: 60,  docs changed path: 247,  Log-likelihood: -433517.98
# 🔄 Chain 1 in iteration 141/300,
#  📊 path: 211,  new path: 48,  docs changed path: 272,  Log-likelihood: -443975.02
# 🔄 Chain 3 in iteration 133/300,
#  📊 path: 246,  new path: 50,  docs changed path: 259,  Log-likelihood: -431695.34
# 🔄 Chain 2 in iteration 137/300,
#  📊 path: 242,  new path: 52,  docs changed path: 264,  Log-likelihood: -433291.80
# ...
#    Number of unique words: 98
#    Total word count: 1
#    Document count: 1
#
# ⚠️ Node 15323 (Layer 1) has entropy=0:
#    Word distribution: {'paper': 0, 'propose': 0, 'calculate': 0, 'particle': 0, 'rigid': 0, 'assume': 0, 'force': 0, 'normal': 0, 'property': 0, 'orientation': 0, 'unknown': 0, 'perform': 0, 'finite': 0, 'element': 0, 'model': 0, 'different': 0, 'impact': 0, 'velocity': 0, 'result': 0, 'fe': 0, 'agreement': 0, 'deformation': 0, 'elastic': 0, 'material': 0, 'parameter': 0, 'remain': 0, 'coefficient': 0, 'calibrate': 0, 'maximum': 0, 'size': 0, 'ratio': 0, 'angle': 0, 'good': 0, 'dimensional': 0, 'wall': 0, 'small': 0, 'hybrid': 0, 'independent': 0}
#    Number of unique words: 38
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 15244 (Layer 2) has entropy=0:
#    Word distribution: {'paper': 0, 'model': 0, 'fsi': 0, 'air': 0, 'aim': 0, 'develop': 0, 'robust': 0, 'practical': 0, 'dynamic': 0, 'structure': 0, 'response': 0, 'involve': 0, 'large': 0, 'approach': 0, 'adopt': 0, 'contact': 0, 'solid': 0, 'object': 0, 'core': 0, 'present': 0, 'test': 0, 'use': 0, 'finite': 0, 'particular': 0, 'couple': 0, 'iga': 0, 'method': 0, 'interest': 0, 'due': 0, 'higherorder': 0, 'accuracy': 0, 'discretizations': 0, 'simplicity': 0, 'handle': 0, 'example': 0, 'illustrate': 0, 'propose': 0, 'twopart': 0, 'phenomena': 0, 'latter': 0, 'inelastic': 0, 'monolithic': 0, 'intrinsic': 0, 'without': 0, 'methodology': 0, 'variety': 0, 'isogeometric': 0, 'nonuniform': 0, 'bsplines': 0, 'rkpm': 0, 'technique': 0, 'particularly': 0, 'attractive': 0, 'problem': 0, 'framework': 0, 'capable': 0, 'immerse': 0, 'standard': 0, 'relative': 0, 'scenario': 0, 'good': 0, 'performance': 0, 'particle': 0, 'begin': 0, 'meshfree': 0, 'deformation': 0, 'focus': 0, 'combination': 0, 'class': 0, 'accurate': 0, 'rational': 0, 'interaction': 0, 'new': 0, 'motion': 0, 'computational': 0, 'ii': 0, 'detection': 0, 'suitable': 0, 'numerical': 0, 'development': 0, 'fluidstructure': 0, 'analysis': 0, 'restriction': 0, 'lead': 0, 'formulation': 0, 'part': 0, 'base': 0}
#    Number of unique words: 87
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 15267 (Layer 2) has entropy=0:
#    Word distribution: {'technique': 0, 'fracture': 0, 'material': 0, 'numerical': 0, 'limitation': 0, 'crack': 0, 'either': 0, 'discretized': 0, 'aim': 0, 'track': 0, 'start': 0, 'one': 0, 'two': 0, 'orientation': 0, 'structural': 0, 'propose': 0, 'validate': 0, 'simulation': 0, 'experimentally': 0, 'test': 0, 'inplane': 0, 'computational': 0, 'algorithm': 0, 'efficient': 0, 'represent': 0, 'currently': 0, 'available': 0, 'propagate': 0, 'paper': 0, 'mesh': 0, 'enhancement': 0, 'multiple': 0, 'approach': 0, 'example': 0, 'load': 0, 'algorithms': 0, 'boundary': 0, 'domain': 0, 'mechanism': 0, 'discuss': 0, 'constitute': 0, 'benchmark': 0, 'solution': 0, 'cost': 0, 'predict': 0, 'localized': 0, 'novel': 0, 'model': 0, 'important': 0, 'element': 0, 'point': 0, 'along': 0, 'frame': 0, 'simulate': 0, 'without': 0, 'directional': 0, 'circumvent': 0, 'allows': 0}
#    Number of unique words: 58
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 15166 (Layer 2) has entropy=0:
#    Word distribution: {'give': 0, 'mechanical': 0, 'characteristic': 0, 'via': 0, 'droplet': 0, 'ordinary': 0, 'process': 0, 'high': 0, 'fidelity': 0, 'example': 0, 'evaluation': 0, 'build': 0, 'show': 0, 'physic': 0, 'optimal': 0, 'present': 0, 'several': 0, 'take': 0, 'partial': 0, 'differential': 0, 'appropriate': 0, 'numerical': 0, 'scheme': 0, 'environment': 0, 'well': 0, 'recent': 0, 'solve': 0, 'describe': 0, 'transmission': 0, 'equation': 0}
#    Number of unique words: 30
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 14605 (Layer 2) has entropy=0:
#    Word distribution: {'artificial': 0, 'widely': 0, 'material': 0, 'behavior': 0, 'simple': 0, 'base': 0, 'large': 0, 'size': 0, 'phase': 0, 'create': 0, 'realistic': 0, 'software': 0, 'deformation': 0, 'process': 0, 'individual': 0, 'design': 0, 'use': 0, 'limit': 0, 'experimental': 0, 'application': 0, 'model': 0, 'present': 0, 'ii': 0, 'usually': 0, 'field': 0, 'work': 0, 'method': 0, 'cover': 0, 'case': 0, 'microstructural': 0, 'directly': 0, 'deep': 0, 'concern': 0, 'part': 0, 'distribution': 0, 'detail': 0, 'feature': 0, 'achieve': 0, 'commercial': 0, 'necessary': 0, 'requirement': 0, 'due': 0, 'example': 0, 'investigation': 0, 'structure': 0, 'homogeneous': 0, 'free': 0, 'give': 0, 'ie': 0, 'microstructures': 0, 'relative': 0, 'generate': 0, 'study': 0, 'however': 0, 'describe': 0, 'hierarchical': 0, 'four': 0, 'fe': 0, 'numerical': 0, 'another': 0, 'result': 0, 'data': 0, 'poisson': 0, 'concept': 0}
#    Number of unique words: 64
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 15264 (Layer 2) has entropy=0:
#    Word distribution: {'finite': 0, 'ie': 0, 'use': 0, 'microstructural': 0, 'dislocation': 0, 'interface': 0, 'effect': 0, 'response': 0, 'cohesive': 0, 'strength': 0, 'diffusion': 0, 'additional': 0, 'degree': 0, 'freedom': 0, 'consequently': 0, 'equation': 0, 'potential': 0, 'requirement': 0, 'linear': 0, 'compare': 0, 'require': 0, 'consistent': 0, 'achieve': 0, 'numerical': 0, 'result': 0, 'formulation': 0, 'constitutive': 0, 'problem': 0, 'present': 0, 'impact': 0, 'accumulation': 0, 'etc': 0, 'plastic': 0, 'rather': 0, 'zero': 0, 'adopt': 0, 'straightforward': 0, 'physical': 0, 'initially': 0, 'behaviour': 0, 'thus': 0, 'c': 0, 'term': 0, 'across': 0, 'discontinuous': 0, 'express': 0, 'condition': 0, 'propose': 0, 'discuss': 0, 'incorporate': 0, 'various': 0, 'function': 0, 'explore': 0}
#    Number of unique words: 53
#    Total word count: 0
#    Document count: 1
#
# 🔄 Chain 3 in iteration 295/300,
#  📊 path: 247,  new path: 46,  docs changed path: 250,  Log-likelihood: -425602.92
# 🔄 Chain 3 in iteration 296/300,
#  📊 path: 251,  new path: 53,  docs changed path: 273,  Log-likelihood: -425128.61
# 🔄 Chain 3 in iteration 297/300,
#  📊 path: 257,  new path: 52,  docs changed path: 257,  Log-likelihood: -425774.56
# 🔄 Chain 3 in iteration 298/300,
#  📊 path: 272,  new path: 63,  docs changed path: 262,  Log-likelihood: -424956.71
# 🔄 Chain 3 in iteration 299/300,
#  📊 path: 255,  new path: 40,  docs changed path: 261,  Log-likelihood: -425049.15
# 🔄 Chain 3 in iteration 300/300,
#  📊 path: 255,  new path: 42,  docs changed path: 238,  Log-likelihood: -425920.41
# 🎯 Chain 3 finish Gibbs Sampling.
# 💾 Save iterations info...
# ✅ doc-path allocation is saved : step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_document_paths.csv
# ✅ structure of tree path is saved: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_path_structures.csv
# ✅ info recoreded in iteration is saved: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_iteration_summaries.csv
# ✅ doc-path mapping is saved: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_path_document_mapping.csv
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'1': [561, 563, 576, 576, 579, 577, 574, 564, 562, 555, 562, 568, 573, 565, 544, 547, 546, 549, 556, 569, 548], '2': [629, 617, 614, 621, 619, 630, 615, 606, 607, 597, 602, 600, 593, 593, 588, 589, 595, 608, 600, 602, 603], '3': [594, 601, 607, 597, 593, 598, 601, 601, 606, 604, 601, 598, 593, 594, 588, 581, 564, 572, 568, 571, 583]}, mean_jaccard:[0.9275616708212061, 0.9294434493511006, 0.9248421514151415], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.0567，mean_jaccard:[0.9275616708212061, 0.9294434493511006, 0.9248421514151415], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# ✅ doc's words allocation to node is saved: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_word_allocations.csv
# ✅ node word distribution is saved: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_node_word_distributions.csv
# ✅ Chain 3 Finished !
# ⚠️ Node 14453 (Layer 1) has entropy=0:
#    Word distribution: {'vibration': 0, 'nonlinear': 0, 'system': 0, 'complexity': 0, 'number': 0, 'model': 0, 'demand': 0, 'efficient': 0, 'approach': 0, 'hybrid': 0, 'base': 0, 'degree': 0, 'freedom': 0, 'new': 0, 'approximate': 0, 'solution': 0, 'difference': 0, 'treat': 0, 'balance': 0, 'chain': 0, 'oscillation': 0, 'propose': 0, 'harmonic': 0, 'efficiency': 0, 'dynamical': 0, 'increasingly': 0, 'important': 0, 'industry': 0, 'method': 0, 'combine': 0, 'literature': 0, 'directly': 0, 'nonlinearities': 0, 'motion': 0, 'use': 0, 'approximation': 0, 'within': 0, 'advantage': 0, 'finite': 0, 'however': 0, 'steadystate': 0, 'one': 0, 'scheme': 0, 'standard': 0, 'contribution': 0, 'performance': 0, 'pure': 0, 'quality': 0, 'description': 0, 'dynamic': 0, 'periodic': 0, 'show': 0, 'demonstrate': 0, 'framework': 0, 'comparison': 0, 'part': 0, 'common': 0, 'application': 0, 'problem': 0, 'linear': 0, 'keep': 0, 'industrial': 0, 'large': 0, 'become': 0, 'excellent': 0, 'socalled': 0, 'affect': 0, 'possible': 0, 'constitutive': 0, 'relation': 0, 'rate': 0, 'take': 0, 'besides': 0, 'introduce': 0, 'stress': 0, 'order': 0, 'creep': 0, 'early': 0, 'another': 0, 'hand': 0, 'strain': 0, 'herein': 0, 'instability': 0, 'print': 0, 'predict': 0, 'incremental': 0, 'boundary': 0, 'kinematics': 0, 'multiplicative': 0, 'know': 0, 'time': 0, 'relative': 0, 'deformation': 0, 'respect': 0, 'formulation': 0, 'configuration': 0, 'prior': 0, 'generalize': 0, 'latter': 0, 'example': 0, 'concrete': 0, 'view': 0, 'decomposition': 0, 'equation': 0, 'simulation': 0, 'due': 0, 'process': 0, 'viscoelasticity': 0, 'structural': 0, 'regard': 0, 'describe': 0, 'point': 0, 'elasticity': 0, 'assume': 0, 'work': 0, 'motivate': 0, 'relaxation': 0, 'adapt': 0, 'lagrangian': 0, 'intermediate': 0, 'transport': 0, 'therefore': 0, 'variable': 0, 'actual': 0, 'back': 0, 'well': 0, 'define': 0, 'range': 0, 'gradient': 0, 'moreover': 0, 'set': 0, 'must': 0, 'internal': 0, 'restriction': 0, 'nature': 0, 'numerical': 0, 'particular': 0, 'form': 0, 'account': 0, 'illustrate': 0, 'reference': 0, 'evolution': 0}
#    Number of unique words: 142
#    Total word count: 0
#    Document count: 2
#
# ⚠️ Node 14421 (Layer 2) has entropy=0:
#    Word distribution: {'focus': 0, 'particular': 0, 'emphasis': 0, 'provide': 0, 'behavior': 0, 'new': 0, 'shape': 0, 'complementary': 0, 'approach': 0, 'model': 0, 'therefore': 0, 'space': 0, 'time': 0, 'thickness': 0, 'cell': 0, 'order': 0, 'particle': 0, 'porous': 0, 'turn': 0, 'interface': 0, 'layer': 0, 'methodology': 0, 'simulation': 0, 'different': 0, 'transition': 0, 'strategy': 0, 'recent': 0, 'energy': 0, 'storage': 0, 'theoretical': 0, 'analysis': 0, 'good': 0, 'actual': 0, 'tailor': 0, 'experimental': 0, 'role': 0, 'material': 0, 'multiscale': 0, 'characteristic': 0, 'length': 0, 'single': 0, 'large': 0, 'form': 0, 'concept': 0, 'scale': 0, 'finally': 0, 'next': 0, 'understand': 0, 'way': 0, 'play': 0, 'prediction': 0, 'device': 0, 'magnitude': 0, 'microstructure': 0, 'propose': 0, 'literature': 0, 'occur': 0, 'well': 0, 'computational': 0, 'condition': 0, 'design': 0, 'discuss': 0, 'instance': 0, 'challenge': 0, 'generation': 0, 'multiphysics': 0, 'may': 0, 'highlight': 0, 'address': 0, 'deposition': 0, 'conduct': 0, 'th': 0, 'air': 0, 'directly': 0, 'case': 0, 'rate': 0, 'implement': 0, 'resolve': 0, 'turbulent': 0, 'flow': 0, 'effect': 0, 'insight': 0, 'base': 0, 'relation': 0, 'relate': 0, 'mechanical': 0, 'size': 0, 'develop': 0, 'droplet': 0, 'contribution': 0, 'branch': 0, 'group': 0, 'thus': 0, 'strong': 0, 'region': 0, 'due': 0, 'reduce': 0, 'pandemic': 0, 'recently': 0, 'unlike': 0, 'transport': 0, 'human': 0, 'view': 0, 'track': 0, 'navierstokes': 0, 'enable': 0, 'select': 0, 'finding': 0, 'possible': 0, 'individual': 0, 'fluid': 0, 'severe': 0, 'identify': 0, 'deal': 0, 'study': 0, 'among': 0, 'covid': 0, 'lagrangian': 0, 'term': 0, 'reduction': 0, 'within': 0, 'low': 0, 'allow': 0, 'impact': 0, 'transmission': 0, 'work': 0, 'one': 0, 'increase': 0, 'investigate': 0, 'load': 0, 'local': 0, 'include': 0, 'framework': 0}
#    Number of unique words: 133
#    Total word count: 0
#    Document count: 2
#
# ⚠️ Node 14345 (Layer 2) has entropy=0:
#    Word distribution: {'tensor': 0, 'stretch': 0, 'formulate': 0, 'hyperelastic': 0, 'model': 0, 'strain': 0, 'rubber': 0, 'similar': 0, 'material': 0, 'may': 0, 'finite': 0, 'element': 0, 'software': 0, 'subroutine': 0, 'robust': 0, 'input': 0, 'multiple': 0, 'product': 0, 'principal': 0, 'stable': 0, 'implementation': 0, 'validate': 0, 'validation': 0, 'method': 0, 'demonstrate': 0, 'low': 0, 'computational': 0, 'constitutive': 0, 'measure': 0, 'know': 0, 'accurately': 0, 'response': 0, 'propose': 0, 'straightforward': 0, 'definition': 0, 'development': 0, 'accurate': 0, 'algorithm': 0, 'equal': 0, 'develop': 0, 'require': 0, 'effort': 0, 'compare': 0, 'alternative': 0, 'wellknown': 0, 'elasticity': 0, 'define': 0, 'numerical': 0, 'present': 0, 'configuration': 0, 'novel': 0, 'include': 0, 'efficient': 0, 'coefficient': 0, 'direction': 0, 'isotropic': 0, 'analysis': 0, 'provide': 0, 'unique': 0, 'stress': 0, 'feature': 0, 'available': 0}
#    Number of unique words: 62
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 14263 (Layer 2) has entropy=0:
#    Word distribution: {'efficient': 0, 'propagation': 0, 'material': 0, 'challenge': 0, 'task': 0, 'spectral': 0, 'method': 0, 'combination': 0, 'fictitious': 0, 'domain': 0, 'concept': 0, 'complicate': 0, 'microstructure': 0, 'paper': 0, 'implementation': 0, 'however': 0, 'framework': 0, 'core': 0, 'result': 0, 'cpu': 0, 'code': 0, 'achieve': 0, 'simulation': 0, 'wave': 0, 'still': 0, 'cell': 0, 'represent': 0, 'approach': 0, 'detail': 0, 'parallel': 0, 'element': 0, 'develop': 0, 'kernel': 0, 'employ': 0, 'well': 0, 'single': 0, 'operation': 0, 'proven': 0, 'version': 0, 'heterogeneous': 0, 'report': 0, 'use': 0, 'show': 0}
#    Number of unique words: 43
#    Total word count: 0
#    Document count: 1
#
# ⚠️ Node 14304 (Layer 2) has entropy=0:
#    Word distribution: {'behavior': 0, 'include': 0, 'theory': 0, 'combine': 0, 'particular': 0, 'material': 0, 'fracture': 0, 'whereas': 0, 'brittle': 0, 'eg': 0, 'reinforce': 0, 'hybrid': 0, 'develop': 0, 'void': 0, 'mechanical': 0, 'arise': 0, 'microstructure': 0, 'give': 0, 'higherorder': 0, 'term': 0, 'represent': 0, 'homogenize': 0, 'conduct': 0, 'multifield': 0, 'investigate': 0, 'kind': 0, 'sequence': 0, 'fiber': 0, 'analyze': 0, 'within': 0, 'failure': 0, 'present': 0, 'therefore': 0, 'phasefield': 0, 'method': 0, 'assume': 0, 'matrix': 0, 'ductile': 0, 'undergo': 0, 'apply': 0, 'along': 0, 'plasticity': 0, 'response': 0, 'additional': 0, 'test': 0, 'formulation': 0, 'long': 0, 'polymer': 0, 'inelastic': 0, 'regime': 0, 'final': 0, 'embed': 0, 'approach': 0, 'growth': 0, 'microscale': 0, 'contribution': 0, 'novel': 0, 'typical': 0, 'model': 0, 'series': 0, 'numerical': 0, 'account': 0, 'different': 0, 'composite': 0, 'comprehensive': 0}
#    Number of unique words: 65
#    Total word count: 0
#    Document count: 1
#
# ✅ All chains finish sampling and waiting for monitor process finish...
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed: 170.9min finished
# ✅ R-hat monitor process finished !
# ✅ Overall convergence history is saved to CSV: step3_d3_g005_e005_a005_第二次/convergence_info.csv
# ✅ Chain 1 convergence info saved to: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1/chain_convergence_info.csv
# ✅ Chain 2 convergence info saved to: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2/chain_convergence_info.csv
# ✅ Chain 3 convergence info saved to: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/chain_convergence_info.csv

# %%
def restore_from_csv_files(chain_dir, corpus, depth):
    """
    从CSV文件恢复单条链的所有变量
    """
    import os
    
    # 检查必要文件是否存在
    path_struct_file = os.path.join(chain_dir, 'iteration_path_structures.csv')
    word_alloc_file = os.path.join(chain_dir, 'iteration_word_allocations.csv')
    
    if not os.path.exists(path_struct_file):
        raise FileNotFoundError(f"Path structure file not found: {path_struct_file}")
    if not os.path.exists(word_alloc_file):
        raise FileNotFoundError(f"Word allocation file not found: {word_alloc_file}")
    
    print(f"📄 Reading files from {chain_dir}")
    print(f"   - Path structure: {path_struct_file}")
    print(f"   - Word allocation: {word_alloc_file}")
    
    # 读取路径结构CSV
    path_struct_df = pd.read_csv(path_struct_file)
    max_iter = path_struct_df['iteration'].max()
    df_path = path_struct_df[path_struct_df['iteration'] == max_iter]
    print(f"📊 Using iteration {max_iter} from path structure file")

    # 收集所有节点ID及其层级信息
    node_info = {}
    for _, row in df_path.iterrows():
        for layer in range(depth):
            node_id = row[f'layer_{layer}_node_id']
            if pd.notna(node_id) and node_id not in node_info:
                node_info[node_id] = {
                    'layer': layer,
                    'parent_id': row[f'layer_{layer-1}_node_id'] if layer > 0 else None,
                    'children': set(),
                    'docs_list': []
                }

    # 建立父子关系
    for _, row in df_path.iterrows():
        for layer in range(1, depth):
            parent_id = row[f'layer_{layer-1}_node_id']
            child_id = row[f'layer_{layer}_node_id']
            if (pd.notna(parent_id) and pd.notna(child_id) and 
                parent_id in node_info and child_id in node_info):
                node_info[parent_id]['children'].add(child_id)
                node_info[child_id]['parent_id'] = parent_id

    # 重置Node类的静态变量并重建所有Node对象
    Node.last_node_id = max(node_info.keys()) + 1 if node_info else 0
    Node.total_node = len(node_info)
    Node.node_with_id = {}

    node_dict = {}
    for node_id, info in node_info.items():
        node = Node.__new__(Node)
        node.node_id = node_id
        node.layer = info['layer']
        node.parent = None
        node.children = []
        node.docs_list = []
        Node.node_with_id[node_id] = node
        node_dict[node_id] = node

    # 建立Node对象之间的父子关系
    for node_id, info in node_info.items():
        node = node_dict[node_id]
        if info['parent_id'] is not None and info['parent_id'] in node_dict:
            node.parent = node_dict[info['parent_id']]
        node.children = [node_dict[child_id] for child_id in info['children'] if child_id in node_dict]

    # 找到根节点
    root_node = None
    for node in node_dict.values():
        if node.layer == 0 and node.parent is None:
            root_node = node
            break

    if root_node is None:
        raise ValueError("No root node found in the restored tree")

    # 重建path_list
    path_list = {}
    for _, row in df_path.iterrows():
        leaf_id = row['leaf_node_id']
        node_ids = [row[f'layer_{i}_node_id'] for i in range(depth)]
        if all(pd.notna(nid) and nid in node_dict for nid in node_ids):
            path_list[leaf_id] = [node_dict[nid] for nid in node_ids]

    # 读取词语分配数据
    word_alloc_df = pd.read_csv(word_alloc_file)
    max_iter_word = word_alloc_df['iteration'].max()
    df_word = word_alloc_df[word_alloc_df['iteration'] == max_iter_word]
    print(f"📊 Using iteration {max_iter_word} from word allocation file")

    # 还原doc_word_allocation：按word_index从小到大排序，取assigned_layer
    doc_word_allocation = {}
    for doc_id, group in df_word.groupby('document_id'):
        sorted_group = group.sort_values('word_index')
        doc_word_allocation[doc_id] = list(sorted_group['assigned_layer'])

    # 还原doc_path：取document_id和leaf_node_id的映射
    doc_path = {}
    for _, row in df_word.drop_duplicates('document_id').iterrows():
        doc_path[row['document_id']] = row['leaf_node_id']

    # 重建doc_node_allocation
    doc_node_allocation = aggregate_words(corpus, doc_word_allocation)

    # 根据doc_path重新构建每个节点的docs_list
    for doc_id, leaf_id in doc_path.items():
        if leaf_id in path_list:
            path_nodes = path_list[leaf_id]
            for node in path_nodes:
                if doc_id not in node.docs_list:
                    node.docs_list.append(doc_id)

    print(f"✅ Successfully restored from {chain_dir}")
    print(f"   - Nodes: {len(node_dict)}")
    print(f"   - Paths: {len(path_list)}")
    print(f"   - Documents: {len(doc_path)}")
    
    return root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation

def Gibbs_sampling_simple(corpus, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
                   gamma, eta, alpha, depth, iteration, iter_start=None, iter_end=None):
    """
    简化版本的Gibbs采样函数，去除jump和detail记录
    """
    W = set(itertools.chain.from_iterable(corpus.values()))

    for doc_id, doc in corpus.items():
        current_path = path_list[doc_path[doc_id]]
        current_node_allocation = doc_node_allocation[doc_id]
        
        # 从全局分布中排除当前文档
        node_word_dist = exclude_doc_from_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id)

        # 从当前路径移除文档
        nodes_to_remove = []
        for node in current_path[::-1]:
            if doc_id in node.docs_list:
                node.docs_list.remove(doc_id)
            if len(node.docs_list) == 0 and node != root_node:
                nodes_to_remove.append(node)
        
        if nodes_to_remove:
            del path_list[doc_path[doc_id]]
            for node in nodes_to_remove:
                if node.parent:
                    node.parent.remove_child(node)

        # 计算现有路径的概率
        path_prior_lst = {}
        path_likelihood_lst = {}

        for path_id, path in path_list.items():
            node_prior_lst = [1.0]
            node_likelihood_lst = []
            
            for node in path:
                if node.parent:
                    prior = (len(node.docs_list)) / (gamma + len(node.parent.docs_list)) 
                    node_prior_lst.append(prior)
                
                if node.layer in current_node_allocation:
                    likelihood = calc_node_likelihood(node_word_dist[node.node_id], current_node_allocation[node.layer], eta, len(W))
                    node_likelihood_lst.append(likelihood)
                else:
                    node_likelihood_lst.append(0)

            path_prior = reduce(operator.mul, (x for x in node_prior_lst if x != 0), 1)
            path_likelihood = reduce(operator.mul, (x for x in node_likelihood_lst if x != 0), 1)
            path_prior_lst[path_id] = path_prior
            path_likelihood_lst[path_id] = path_likelihood

        multiplied_path_dict = {key: path_prior_lst[key] * path_likelihood_lst[key] for key in path_likelihood_lst}
        
        # 计算新路径的概率
        new_path_prior_lst = {}
        new_path_likelihood_lst = {}

        for node_id, node in Node.node_with_id.items():
            if node != None and node.layer < depth-1:
                new_node_prior_lst = [gamma / (gamma + len(node.docs_list))]
                
                if 0 in current_node_allocation:
                    new_node_likelihood_lst = [calc_node_likelihood(node_word_dist[0], current_node_allocation[0], eta, len(W))]
                else:
                    new_node_likelihood_lst = [0]
                
                temp_node = node
                while temp_node.parent:
                    new_node_prior_lst.insert(0, (len(temp_node.docs_list)) / (gamma + len(temp_node.parent.docs_list)))             
                
                    if temp_node.layer in current_node_allocation:
                        new_node_likelihood_lst.insert(1, calc_node_likelihood(node_word_dist[temp_node.node_id], current_node_allocation[temp_node.layer], eta, len(W)))
                    else:
                        new_node_likelihood_lst.insert(1, 0)

                    temp_node = temp_node.parent

                for layer in range(node.layer+1, depth):
                    if layer in current_node_allocation:
                        new_node_likelihood_lst.append(calc_node_likelihood({}, current_node_allocation[layer], eta, len(W)))

                new_path_prior = reduce(operator.mul, (x for x in new_node_prior_lst if x != 0), 1)
                new_path_likelihood = reduce(operator.mul, (x for x in new_node_likelihood_lst if x != 0), 1)
                new_path_prior_lst[node_id] = new_path_prior
                new_path_likelihood_lst[node_id] = new_path_likelihood
        
        multiplied_new_path_dict = {f'create{key}': new_path_prior_lst[key] * new_path_likelihood_lst[key] for key in new_path_likelihood_lst}
        all_probs = {**multiplied_path_dict, **multiplied_new_path_dict}

        total_prob = sum(v for v in all_probs.values())
        if total_prob > 0:
            normalized_probs = {k: v/total_prob for k, v in all_probs.items()}
        else:
            normalized_probs = {k: 1.0/len(all_probs) for k in all_probs}
        
        chosen_path = np.random.choice(list(normalized_probs.keys()),p=list(normalized_probs.values()))
        if chosen_path.startswith('create'):
            base_node = Node.node_with_id[int(chosen_path[6:])]
            leaf_id, added_path = create_new_path(base_node, doc_id, depth)
            path_list.update({leaf_id:added_path})
            doc_path[doc_id] = leaf_id
        else:
            leaf_id = int(chosen_path)
            added_path = path_list[int(chosen_path)]
            doc_path[doc_id] = int(chosen_path)
        
        # 将文档添加到新路径
        for node in added_path:
            node.docs_list.append(doc_id)
        
        # 更新全局词分布
        node_word_dist_update = add_doc_to_node_dist(global_node_word_dist, doc_node_allocation, doc_path, path_list, doc_id)
        
        # 词语主题采样
        doc_word2node = doc_word_allocation[doc_id]
        current_path = path_list[doc_path[doc_id]]
        update_doc_word2node = []
        
        for word, old_layer in zip(doc, doc_word2node):
            doc_node_allocation[doc_id][old_layer][word] -= 1
            node_word_dist_update[current_path[old_layer].node_id][word] -= 1
            topic_probs = {}

            for layer, topic in enumerate(current_path):
                word_in_topic = node_word_dist_update[topic.node_id].get(word,0)
                topic_in_doc = sum(doc_node_allocation[doc_id].get(layer,{}).values())

                word_prop = (word_in_topic+eta)/(sum(node_word_dist_update[topic.node_id].values())+len(W)*eta)
                topic_prop = (topic_in_doc+alpha)/(len(doc)+depth*alpha)
                topic_probs[layer] = word_prop*topic_prop
            
            total_topic_prob = sum(v for v in topic_probs.values() if v > 0)
            if total_topic_prob > 0:
                normalized_topic_probs = {k: v/total_topic_prob for k, v in topic_probs.items()}
            else:
                normalized_topic_probs = {k: 1.0/len(topic_probs) for k in topic_probs}

            chosen_layer = np.random.choice(list(normalized_topic_probs.keys()),p=list(normalized_topic_probs.values()))
            update_doc_word2node.append(chosen_layer)
            doc_node_allocation[doc_id][chosen_layer][word] += 1
            node_word_dist_update[current_path[chosen_layer].node_id][word] += 1

        doc_word_allocation[doc_id] = update_doc_word2node

def run_gibbs_with_checkpoint_restore(
    corpus, depth=3, gamma=None, eta=None, alpha=None,
    max_iterations=200, checkpoint_dir='gibbs_checkpoints',
    check_interval=10, base_dir=None,
    shared_state=None, chain_id=None, back_window=5, burn_in=50,
    restored_state=None
):
    """
    专门用于恢复模式的Gibbs采样主循环（跳过nCRP初始化）
    """
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    if restored_state is None:
        raise ValueError("restored_state is required for restore mode")
    
    # 从恢复状态开始
    root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation = restored_state
    
    # 创建新的recorder
    recorder = Recorder(corpus, depth, eta, alpha)
    
    # 计算全局节点词分布
    global_node_word_dist = node_word_distribution(doc_node_allocation, doc_path, path_list, exclude_docs=None)
    
    # 记录恢复后的初始状态
    iter_start_for_log = burn_in + back_window
    initial_summary = recorder.record_iteration(
        0, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
        iter_start_for_detailed_log=iter_start_for_log
    )
    
    print(f"📝 Chain {chain_id} restored state recorded: {initial_summary['total_paths']} paths, ", 
          f"Log-likelihood: {initial_summary['log_likelihood']:.2f}")
    
    start_iter = 1
    previous_log_likelihood = recorder.iteration_records[-1]['iteration_summary']['log_likelihood']
    loglikelihood_list = [previous_log_likelihood]
    change_docs_list = []

    doc_path_lst = {0: doc_path.copy()}
    doc_node_allocation_lst = {0: doc_node_allocation.copy()}

    record_time = 0
    start_window = burn_in + back_window 
    
    for iteration in range(start_iter, max_iterations + 1):
        old_paths = set(path_list.keys())
        doc_path_lst[iteration] = doc_path.copy()
        
        current_iter_start_for_detailed_log = burn_in + back_window

        try:
            # 使用简化版本的Gibbs采样（去除jump和detail记录）
            Gibbs_sampling_simple(
                corpus, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
                gamma, eta, alpha, depth, iteration, 
                iter_start=current_iter_start_for_detailed_log,
                iter_end=max_iterations
            )
            
        except Exception as e:
            print(f"❌ Error in Gibbs sampling at iteration {iteration}: {e}")
            break

        doc_path_lst[iteration] = doc_path.copy()
        doc_node_allocation_lst[iteration] = doc_node_allocation.copy()

        new_paths = set(path_list.keys()) - old_paths
        iteration_summary = recorder.record_iteration(
            iteration, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, global_node_word_dist,
            new_paths, iter_start_for_detailed_log=current_iter_start_for_detailed_log
        )
        print(f"🔄 Chain {chain_id} in iteration {iteration}/{max_iterations}, \n",
              f"path: {iteration_summary['total_paths']}, ",
              f"new path: {iteration_summary['newly_created_paths']}, ",
              f"docs changed path: {iteration_summary['changed_docs_count']}, ",
              f"Log-likelihood: {iteration_summary['log_likelihood']:.2f}")
        
        # 检查收敛
        change_docs_list.append(iteration_summary['changed_docs_count'])
        loglikelihood_list.append(iteration_summary['log_likelihood'])
        
        if (iteration - start_window) / check_interval == 1 or (iteration == max_iterations):
            convergence_status = shared_state.get_convergence_status() if shared_state else False
            if convergence_status:
                final_iteration = iteration
                print(f"🎉 Chain {chain_id} is detected to convergence in iteration {iteration}, sampling ends prematurely.")
                break
                
            window_keys = list(range(iteration-check_interval-back_window+1, iteration+1))
            doc_path_window = {k: doc_path_lst[k] for k in window_keys}
            
            stable_docs = get_stable_docs_sliding_window(doc_path_window, back_window=back_window)
            chain_len_docs = [len(doc_list) for iterd, doc_list in stable_docs.items()]
            
            doc_node_allocation_window = {k: doc_node_allocation_lst[k] for k in window_keys}
            
            jaccard_lst, ratio_lst = get_jaccard_list_from_stable_dict(stable_docs, doc_node_allocation_window, back_window=back_window, depth=depth)
            
            if shared_state:
                shared_state.update_chain_data(chain_id, chain_len_docs, jaccard_lst, ratio_lst, iteration, record_time)
            start_window = iteration
            record_time += 1
    
    print(f"🎯 Chain {chain_id} finish Gibbs Sampling.")
    print("💾 Save iterations info...")
    saved_files = recorder.save_to_files(base_filename=os.path.join(base_dir, "iteration") if base_dir else "iteration")
    return recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation, saved_files, change_docs_list, loglikelihood_list, doc_path_lst, doc_node_allocation_lst

def _run_single_chain_with_restore(args):
    """
    运行单条链，支持从CSV文件恢复
    """
    (chain_id, corpus, depth, gamma, eta, alpha, max_iterations, general_dir, seed, 
     shared_state, back_window, check_interval, burn_in, restore_from_existing, source_dir) = args

    # 如果不需要恢复，直接返回
    if not restore_from_existing:
        return {
            'chain_id': chain_id,
            'status': 'stopped',
            'message': 'restore_from_existing=False, execution stopped'
        }

    print(f"⛓️ Chain {chain_id} starts (PID: {os.getpid()})")
    
    # 设置随机种子
    np.random.seed(seed)
    
    # 为新运行创建目录
    chain_dir = os.path.join(general_dir, f"depth_{depth}_gamma_{gamma}_run_{chain_id}")
    os.makedirs(chain_dir, exist_ok=True)
    
    # 尝试从现有数据恢复
    try:
        # 构造源目录中对应链的路径
        source_chain_dir = os.path.join(source_dir, f"depth_{depth}_gamma_{gamma}_run_{chain_id}")
        
        if not os.path.exists(source_chain_dir):
            raise FileNotFoundError(f"Source chain directory not found: {source_chain_dir}")
        
        print(f"🔄 Attempting to restore Chain {chain_id} from {source_chain_dir}...")
        restored_state = restore_from_csv_files(source_chain_dir, corpus, depth)
        
        print(f"✅ Chain {chain_id} restored successfully from {source_chain_dir}")
        
        # 使用恢复的状态继续运行Gibbs采样
        result = run_gibbs_with_checkpoint_restore(
            corpus=corpus,
            depth=depth,
            gamma=gamma,
            eta=eta,
            alpha=alpha,
            max_iterations=max_iterations,
            checkpoint_dir=os.path.join(chain_dir, "checkpoints"),
            base_dir=chain_dir,
            chain_id=chain_id,
            shared_state=shared_state,
            back_window=back_window,
            burn_in=burn_in,
            check_interval=check_interval,
            restored_state=restored_state
        )
        
    except Exception as e:
        print(f"❌ Failed to restore Chain {chain_id}: {e}")
        import traceback
        print(f"📋 Full traceback: {traceback.format_exc()}")
        return {
            'chain_id': chain_id,
            'status': 'failed',
            'message': f'Failed to restore: {e}'
        }
    
    # 提取结果
    recorder, root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation = result[:6]
    
    # 计算指标并保存
    res = evaluate_tree_structure_with_nodes(root_node, path_list, doc_path, doc_word_allocation, doc_node_allocation)
    
    # 保存结果文件
    layers = sorted(res["layer_entropy_wavg"].keys())
    layer_rows = []
    for L in layers:
        layer_rows.append({
            "depth": depth,
            "gamma": gamma,
            "eta": eta,
            "alpha": alpha,
            "layer": L,
            "entropy_wavg": res["layer_entropy_wavg"].get(L, 0.0),
            "distinctiveness_wavg_jsd": res["layer_distinctiveness_wavg"].get(L, 0.0),
            "nodes_in_layer": res["nodes_per_layer"].get(L, 0)
        })
    
    df_layers = pd.DataFrame(layer_rows)
    layers_csv = os.path.join(chain_dir, "result_layers.csv")
    df_layers.to_csv(layers_csv, index=False)
    
    # 保存节点详细信息
    df_nodes = pd.DataFrame(res["node_records"])
    if not df_nodes.empty:
        df_nodes.insert(0, "depth", depth)
        df_nodes.insert(1, "gamma", gamma)
        df_nodes.insert(2, "eta", eta)
        df_nodes.insert(3, "alpha", alpha)
        nodes_csv = os.path.join(chain_dir, "result_nodes.csv")
        df_nodes.to_csv(nodes_csv, index=False)
    
    # 保存摘要指标
    summary = {
        "depth": depth,
        "gamma": gamma,
        "eta": eta,
        "alpha": alpha,
        "avg_entropy_wavg_over_layers": float(np.mean([res["layer_entropy_wavg"][L] for L in layers])) if layers else 0.0,
        "avg_distinctiveness_wavg_over_layers": float(np.mean([res["layer_distinctiveness_wavg"][L] for L in layers])) if layers else 0.0,
        "total_layers": len(layers),
        "total_nodes": int(sum(res["nodes_per_layer"].values())) if layers else 0
    }
    df_metrics = pd.DataFrame([summary])
    metrics_csv = os.path.join(chain_dir, "result_metrics.csv")
    df_metrics.to_csv(metrics_csv, index=False)
    
    print(f"✅ Chain {chain_id} Finished and results saved to {chain_dir}")
    
    return {
        'chain_id': chain_id,
        'chain_dir': chain_dir,
        'metrics': res,
        'status': 'completed'
    }

def run_multi_chain_hlda_with_restore(
    corpus, depth=3, gamma=0.01, eta=0.01, alpha=0.1,
    n_chains=3, max_iterations=20, r_hat_threshold=1.1,
    general_dir="multi_chain_hlda_results",
    back_window=5, check_interval=10, burn_in=50,
    restore_from_existing=True,
    source_dir=None
):
    """
    并行运行多条 hLDA 链，支持从现有CSV文件恢复
    """
    # 如果不需要恢复，直接返回
    if not restore_from_existing:
        print("❌ restore_from_existing=False, stopping execution")
        return None
    
    os.makedirs(general_dir, exist_ok=True)
    
    # 如果没有指定源目录，使用默认规则推断
    if restore_from_existing and source_dir is None:
        # 根据参数自动生成源目录名称
        gamma_str = str(gamma).replace('0.', '').replace('0', '0')
        source_dir = f"d{depth}_g{gamma_str}_收敛"
        print(f"⚠️ No source_dir specified, using inferred path: {source_dir}")

    if not os.path.exists(source_dir):
        print(f"❌ Source directory does not exist: {source_dir}")
        return None

    # 启动共享状态和监控线程
    shared_state = SharedState(general_dir)
    monitor = Thread(
        target=rhat_monitor_process,
        args=(shared_state, n_chains, max_iterations, burn_in, check_interval, back_window, r_hat_threshold)
    )
    monitor.daemon = False
    monitor.start()
    print("🚀 Start R-hat monitor process")

    # 构造每条链的参数
    args_list = []
    for i in range(1, n_chains + 1):
        seed = i * 1000 + int(time.time()) % 1000
        args_list.append((
            i, corpus, depth, gamma, eta, alpha,
            max_iterations, general_dir, seed,
            shared_state, back_window, check_interval, burn_in,
            restore_from_existing, source_dir
        ))

    print(f"🚀 Start {n_chains} hLDA chains with restore from {source_dir}")
    print(f"   New results will be saved to: {general_dir}")

    # 并行运行所有链
    chain_results = Parallel(n_jobs=n_chains, backend='multiprocessing', verbose=10)(
        delayed(_run_single_chain_with_restore)(args) for args in args_list
    )

    # 检查是否有链因为问题而停止
    stopped_chains = [result for result in chain_results if result.get('status') in ['stopped', 'failed']]
    if stopped_chains:
        print(f"⚠️ {len(stopped_chains)} chains were stopped or failed:")
        for result in stopped_chains:
            print(f"   Chain {result['chain_id']}: {result['message']}")

    print("✅ All chains finish sampling and waiting for monitor process finish...")

    # 等待监控线程结束
    monitor.join(timeout=60)
    print("✅ R-hat monitor process finished !")

    # 保存收敛检查历史数据
    rhat_file = os.path.join(general_dir, "shared_state.json")
    if os.path.exists(rhat_file):
        with open(rhat_file, "r") as f:
            shared_state_data = json.load(f)
        
        # 保存总体R-hat收敛历史
        rhat_history = shared_state_data.get("rhat_history", [])
        if rhat_history:
            convergence_df = pd.DataFrame(rhat_history)
            convergence_csv = os.path.join(general_dir, "convergence_info.csv")
            convergence_df.to_csv(convergence_csv, index=False, encoding='utf-8')
            print(f"✅ Overall convergence history saved to: {convergence_csv}")

        # 为每个链保存收敛信息
        for result in chain_results:
            if result.get('status') == 'completed':
                chain_id = result['chain_id']
                chain_dir = result['chain_dir']
                
                chain_data = shared_state_data.get("chains", {}).get(str(chain_id), {})
                if chain_data:
                    chain_records = []
                    for record_time, len_docs in chain_data.get('len_stable_docs', {}).items():
                        jaccard_list = chain_data.get('jaccard', {}).get(record_time, [])
                        ratio_list = chain_data.get('ratio', {}).get(record_time, [])
                        
                        chain_records.append({
                            'record_time': int(record_time),
                            'len_stable_docs': len_docs,
                            'jaccard_mean': np.mean(jaccard_list) if jaccard_list else 0,
                            'jaccard_std': np.std(jaccard_list) if jaccard_list else 0,
                            'ratio_mean': np.mean(ratio_list) if ratio_list else 0,
                            'ratio_std': np.std(ratio_list) if ratio_list else 0,
                            'jaccard_list': jaccard_list,
                            'ratio_list': ratio_list
                        })
                    
                    if chain_records:
                        chain_df = pd.DataFrame(chain_records)
                        chain_convergence_csv = os.path.join(chain_dir, "chain_convergence_info.csv")
                        chain_df.to_csv(chain_convergence_csv, index=False, encoding='utf-8')
                        print(f"✅ Chain {chain_id} convergence info saved to: {chain_convergence_csv}")

    return chain_results

# %%
# 从现有结果恢复并继续运行
results = run_multi_chain_hlda_with_restore(
    corpus=corpus,
    depth=3,
    gamma=0.05,
    eta=0.05,
    alpha=0.05,
    n_chains=3,
    max_iterations=200,  # 继续运行的迭代次数
    general_dir="step3_d3_g005_e005_a005_第二次_恢复01",  # 新的输出目录
    source_dir="step3_d3_g005_e005_a005_第二次",  # 包含原始链结果的目录
    restore_from_existing=True,  # 启用恢复模式
    back_window=5,
    check_interval=20,
    burn_in=5,
    r_hat_threshold=1.1
)

print("✅ All chains restored and continued running!")
# Out:
# 🔍 Initialize R-hat independent monitor thread (stable docs & Jaccard & Ratio)
# 🚀 Start R-hat monitor process
# 🚀 Start 3 hLDA chains with restore from step3_d3_g005_e005_a005_第二次
#    New results will be saved to: step3_d3_g005_e005_a005_第二次_恢复01
# ⛓️ Chain 1 starts (PID: 102427)
# 🔄 Attempting to restore Chain 1 from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1...
# 📄 Reading files from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1
#    - Path structure: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1/iteration_path_structures.csv
#    - Word allocation: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1/iteration_word_allocations.csv
# ⛓️ Chain 2 starts (PID: 102428)
# 🔄 Attempting to restore Chain 2 from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2...
# 📄 Reading files from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2
#    - Path structure: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2/iteration_path_structures.csv
#    - Word allocation: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2/iteration_word_allocations.csv
# ⛓️ Chain 3 starts (PID: 102429)
# 🔄 Attempting to restore Chain 3 from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3...
# 📄 Reading files from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3
#    - Path structure: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_path_structures.csv
#    - Word allocation: step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3/iteration_word_allocations.csv
# 📊 Using iteration 300 from path structure file
# 📊 Using iteration 300 from path structure file
# [Parallel(n_jobs=3)]: Using backend MultiprocessingBackend with 3 concurrent workers.
# 📊 Using iteration 300 from path structure file
# 📊 Using iteration 300 from word allocation file
# 📊 Using iteration 300 from word allocation file
# 📊 Using iteration 300 from word allocation file
# ✅ Successfully restored from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1
#    - Nodes: 310
#    - Paths: 244
#    - Documents: 970
# ✅ Chain 1 restored successfully from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_1
# ✅ Successfully restored from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2
#    - Nodes: 311
#    - Paths: 254
#    - Documents: 970
# ✅ Chain 2 restored successfully from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_2
# ✅ Successfully restored from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3
#    - Nodes: 313
#    - Paths: 255
#    - Documents: 970
# ✅ Chain 3 restored successfully from step3_d3_g005_e005_a005_第二次/depth_3_gamma_0.05_run_3
# 📝 Chain 1 restored state recorded: 244 paths,  Log-likelihood: -431661.10
# 📝 Chain 2 restored state recorded: 254 paths,  Log-likelihood: -427259.00
# 📝 Chain 3 restored state recorded: 255 paths,  Log-likelihood: -425920.41
# 🔄 Chain 2 in iteration 1/200,
#  path: 246,  new path: 43,  docs changed path: 256,  Log-likelihood: -427048.91
# 🔄 Chain 3 in iteration 1/200,
#  path: 246,  new path: 37,  docs changed path: 256,  Log-likelihood: -426600.70
# 🔄 Chain 1 in iteration 1/200,
#  path: 242,  new path: 54,  docs changed path: 283,  Log-likelihood: -431849.67
# 🔄 Chain 2 in iteration 2/200,
#  path: 245,  new path: 47,  docs changed path: 248,  Log-likelihood: -427587.98
# 🔄 Chain 3 in iteration 2/200,
#  path: 257,  new path: 56,  docs changed path: 255,  Log-likelihood: -424557.60
# 🔄 Chain 1 in iteration 2/200,
#  path: 244,  new path: 56,  docs changed path: 293,  Log-likelihood: -431757.35
# 🔄 Chain 2 in iteration 3/200,
#  path: 257,  new path: 57,  docs changed path: 247,  Log-likelihood: -426209.40
# 🔄 Chain 3 in iteration 3/200,
#  path: 257,  new path: 49,  docs changed path: 262,  Log-likelihood: -425010.33
# 🔄 Chain 1 in iteration 3/200,
#  path: 253,  new path: 58,  docs changed path: 306,  Log-likelihood: -431551.09
# 🔄 Chain 2 in iteration 4/200,
#  path: 253,  new path: 49,  docs changed path: 257,  Log-likelihood: -427214.01
# 🔄 Chain 3 in iteration 4/200,
#  path: 256,  new path: 50,  docs changed path: 263,  Log-likelihood: -425071.18
# 🔄 Chain 1 in iteration 4/200,
#  path: 245,  new path: 49,  docs changed path: 296,  Log-likelihood: -431758.96
# 🔄 Chain 2 in iteration 5/200,
#  path: 258,  new path: 49,  docs changed path: 249,  Log-likelihood: -426379.24
# 🔄 Chain 1 in iteration 5/200,
#  path: 245,  new path: 53,  docs changed path: 290,  Log-likelihood: -431346.45
# 🔄 Chain 3 in iteration 5/200,
#  path: 258,  new path: 48,  docs changed path: 249,  Log-likelihood: -424848.63
# 🔄 Chain 2 in iteration 6/200,
#  path: 265,  new path: 56,  docs changed path: 241,  Log-likelihood: -426048.58
# 🔄 Chain 1 in iteration 6/200,
#  path: 242,  new path: 55,  docs changed path: 302,  Log-likelihood: -430925.45
# 🔄 Chain 3 in iteration 6/200,
#  path: 257,  new path: 49,  docs changed path: 262,  Log-likelihood: -425498.76
# 🔄 Chain 2 in iteration 7/200,
#  path: 266,  new path: 61,  docs changed path: 285,  Log-likelihood: -426415.29
# 🔄 Chain 1 in iteration 7/200,
#  path: 257,  new path: 65,  docs changed path: 309,  Log-likelihood: -431208.97
# 🔄 Chain 3 in iteration 7/200,
#  path: 263,  new path: 59,  docs changed path: 258,  Log-likelihood: -424962.34
# 🔄 Chain 2 in iteration 8/200,
#  path: 270,  new path: 64,  docs changed path: 279,  Log-likelihood: -426508.91
# 🔄 Chain 1 in iteration 8/200,
#  path: 252,  new path: 58,  docs changed path: 304,  Log-likelihood: -430369.20
# 🔄 Chain 3 in iteration 8/200,
#  path: 257,  new path: 45,  docs changed path: 250,  Log-likelihood: -424830.92
# 🔄 Chain 2 in iteration 9/200,
#  path: 260,  new path: 53,  docs changed path: 266,  Log-likelihood: -427465.34
# 🔄 Chain 1 in iteration 9/200,
#  path: 239,  new path: 49,  docs changed path: 297,  Log-likelihood: -432055.17
# 🔄 Chain 3 in iteration 9/200,
#  path: 266,  new path: 53,  docs changed path: 260,  Log-likelihood: -424247.34
# 🔄 Chain 2 in iteration 10/200,
#  path: 254,  new path: 55,  docs changed path: 267,  Log-likelihood: -427618.55
# 🔄 Chain 1 in iteration 10/200,
#  path: 249,  new path: 57,  docs changed path: 299,  Log-likelihood: -431666.69
# 🔄 Chain 3 in iteration 10/200,
#  path: 261,  new path: 51,  docs changed path: 291,  Log-likelihood: -424896.52
# 🔄 Chain 2 in iteration 11/200,
#  path: 249,  new path: 51,  docs changed path: 260,  Log-likelihood: -427761.38
# 🔄 Chain 1 in iteration 11/200,
#  path: 253,  new path: 60,  docs changed path: 296,  Log-likelihood: -431714.62
# 🔄 Chain 3 in iteration 11/200,
#  path: 263,  new path: 52,  docs changed path: 273,  Log-likelihood: -424474.05
# 🔄 Chain 2 in iteration 12/200,
#  path: 256,  new path: 56,  docs changed path: 246,  Log-likelihood: -426745.19
# 🔄 Chain 1 in iteration 12/200,
#  path: 252,  new path: 55,  docs changed path: 300,  Log-likelihood: -430893.83
# 🔄 Chain 3 in iteration 12/200,
#  path: 270,  new path: 61,  docs changed path: 271,  Log-likelihood: -424282.65
# 🔄 Chain 2 in iteration 13/200,
#  path: 255,  new path: 54,  docs changed path: 267,  Log-likelihood: -427274.68
# 🔄 Chain 1 in iteration 13/200,
#  path: 258,  new path: 52,  docs changed path: 295,  Log-likelihood: -430768.64
# 🔄 Chain 3 in iteration 13/200,
#  path: 263,  new path: 51,  docs changed path: 267,  Log-likelihood: -425109.25
# 🔄 Chain 2 in iteration 19/200,
#  path: 254,  new path: 49,  docs changed path: 256,  Log-likelihood: -427173.97
# 🔄 Chain 1 in iteration 19/200,
#  path: 240,  new path: 50,  docs changed path: 273,  Log-likelihood: -429703.28
# 🔄 Chain 3 in iteration 19/200,
#  path: 251,  new path: 50,  docs changed path: 258,  Log-likelihood: -424526.34
# 🔄 Chain 2 in iteration 20/200,
#  path: 257,  new path: 54,  docs changed path: 235,  Log-likelihood: -426766.36
# 🔄 Chain 1 in iteration 20/200,
#  path: 239,  new path: 42,  docs changed path: 285,  Log-likelihood: -430443.15
# 🔄 Chain 3 in iteration 20/200,
#  path: 263,  new path: 52,  docs changed path: 256,  Log-likelihood: -424409.35
# 🔄 Chain 2 in iteration 21/200,
#  path: 241,  new path: 42,  docs changed path: 254,  Log-likelihood: -428373.63
# 🔄 Chain 1 in iteration 21/200,
#  path: 246,  new path: 51,  docs changed path: 304,  Log-likelihood: -430653.14
# 🔄 Chain 3 in iteration 21/200,
#  path: 267,  new path: 54,  docs changed path: 255,  Log-likelihood: -424035.23
# 🔄 Chain 2 in iteration 22/200,
#  path: 242,  new path: 41,  docs changed path: 248,  Log-likelihood: -428239.01
# 🔄 Chain 1 in iteration 22/200,
#  path: 252,  new path: 59,  docs changed path: 294,  Log-likelihood: -429755.17
# 🔄 Chain 3 in iteration 22/200,
#  path: 260,  new path: 49,  docs changed path: 264,  Log-likelihood: -425047.40
# 🔄 Chain 2 in iteration 23/200,
#  path: 254,  new path: 40,  docs changed path: 253,  Log-likelihood: -427705.20
# 🔄 Chain 1 in iteration 23/200,
#  path: 252,  new path: 48,  docs changed path: 281,  Log-likelihood: -428843.44
# 🔄 Chain 3 in iteration 23/200,
#  path: 259,  new path: 51,  docs changed path: 262,  Log-likelihood: -424220.60
# 🔄 Chain 2 in iteration 24/200,
#  path: 250,  new path: 41,  docs changed path: 257,  Log-likelihood: -427206.60
# 🔄 Chain 1 in iteration 24/200,
#  path: 245,  new path: 53,  docs changed path: 302,  Log-likelihood: -429585.77
# 🔄 Chain 3 in iteration 24/200,
#  path: 263,  new path: 53,  docs changed path: 262,  Log-likelihood: -424450.76
# 🔄 Chain 2 in iteration 25/200,
#  path: 253,  new path: 45,  docs changed path: 251,  Log-likelihood: -428078.76
# 🔄 Chain 1 in iteration 25/200,
#  path: 248,  new path: 47,  docs changed path: 276,  Log-likelihood: -429988.06
# 🔄 Chain 3 in iteration 25/200,
#  path: 259,  new path: 42,  docs changed path: 251,  Log-likelihood: -424271.81
# 🔄 Chain 2 in iteration 26/200,
#  path: 259,  new path: 58,  docs changed path: 269,  Log-likelihood: -427390.13
# 🔄 Chain 1 in iteration 26/200,
#  path: 254,  new path: 51,  docs changed path: 316,  Log-likelihood: -429327.64
# 🔄 Chain 3 in iteration 26/200,
#  path: 258,  new path: 43,  docs changed path: 267,  Log-likelihood: -424469.61
# 🔄 Chain 2 in iteration 27/200,
#  path: 253,  new path: 45,  docs changed path: 264,  Log-likelihood: -428694.45
# 🔄 Chain 1 in iteration 27/200,
#  path: 254,  new path: 55,  docs changed path: 298,  Log-likelihood: -428917.85
# 🔄 Chain 2 in iteration 32/200,
#  path: 258,  new path: 53,  docs changed path: 269,  Log-likelihood: -427594.32
# 🔄 Chain 1 in iteration 32/200,
#  path: 259,  new path: 57,  docs changed path: 291,  Log-likelihood: -428285.96
# 🔄 Chain 3 in iteration 32/200,
#  path: 252,  new path: 42,  docs changed path: 249,  Log-likelihood: -424321.11
# 🔄 Chain 2 in iteration 33/200,
#  path: 252,  new path: 48,  docs changed path: 264,  Log-likelihood: -428171.87
# 🔄 Chain 1 in iteration 33/200,
#  path: 246,  new path: 49,  docs changed path: 292,  Log-likelihood: -428841.27
# 🔄 Chain 3 in iteration 33/200,
#  path: 257,  new path: 53,  docs changed path: 269,  Log-likelihood: -424636.58
# 🔄 Chain 2 in iteration 34/200,
#  path: 256,  new path: 52,  docs changed path: 277,  Log-likelihood: -427371.30
# 🔄 Chain 1 in iteration 34/200,
#  path: 245,  new path: 46,  docs changed path: 269,  Log-likelihood: -429428.36
# 🔄 Chain 3 in iteration 34/200,
#  path: 249,  new path: 45,  docs changed path: 271,  Log-likelihood: -425286.59
# 🔄 Chain 2 in iteration 35/200,
#  path: 260,  new path: 53,  docs changed path: 257,  Log-likelihood: -426398.80
# 🔄 Chain 1 in iteration 35/200,
#  path: 256,  new path: 51,  docs changed path: 277,  Log-likelihood: -428330.58
# 🔄 Chain 3 in iteration 35/200,
#  path: 258,  new path: 53,  docs changed path: 268,  Log-likelihood: -424878.98
# 🔄 Chain 2 in iteration 36/200,
#  path: 269,  new path: 59,  docs changed path: 255,  Log-likelihood: -425409.69
# 🔄 Chain 1 in iteration 36/200,
#  path: 253,  new path: 51,  docs changed path: 277,  Log-likelihood: -428944.43
# 🔄 Chain 3 in iteration 36/200,
#  path: 254,  new path: 42,  docs changed path: 266,  Log-likelihood: -424373.78
# 🔄 Chain 2 in iteration 37/200,
#  path: 256,  new path: 44,  docs changed path: 254,  Log-likelihood: -426923.98
# 🔄 Chain 1 in iteration 37/200,
#  path: 253,  new path: 67,  docs changed path: 295,  Log-likelihood: -428481.33
# 🔄 Chain 3 in iteration 37/200,
#  path: 263,  new path: 62,  docs changed path: 274,  Log-likelihood: -424472.90
# 🔄 Chain 2 in iteration 38/200,
#  path: 262,  new path: 54,  docs changed path: 260,  Log-likelihood: -426000.97
# 🔄 Chain 1 in iteration 38/200,
#  path: 256,  new path: 59,  docs changed path: 287,  Log-likelihood: -429221.59
# 🔄 Chain 3 in iteration 38/200,
#  path: 269,  new path: 59,  docs changed path: 273,  Log-likelihood: -424753.65
# 🔄 Chain 2 in iteration 39/200,
#  path: 265,  new path: 52,  docs changed path: 254,  Log-likelihood: -425627.86
# 🔄 Chain 1 in iteration 39/200,
#  path: 257,  new path: 65,  docs changed path: 313,  Log-likelihood: -428179.57
# 🔄 Chain 3 in iteration 39/200,
#  path: 268,  new path: 48,  docs changed path: 273,  Log-likelihood: -425062.35
# 🔄 Chain 2 in iteration 40/200,
#  path: 261,  new path: 50,  docs changed path: 253,  Log-likelihood: -426587.94
# 🔄 Chain 2 in iteration 45/200,
#  path: 257,  new path: 57,  docs changed path: 275,  Log-likelihood: -426003.07
# 🔄 Chain 3 in iteration 44/200,
#  path: 258,  new path: 44,  docs changed path: 259,  Log-likelihood: -424279.30
# 🔄 Chain 1 in iteration 45/200,
#  path: 249,  new path: 56,  docs changed path: 295,  Log-likelihood: -429200.20
# 🔄 Chain 2 in iteration 46/200,
#  path: 260,  new path: 51,  docs changed path: 245,  Log-likelihood: -425932.71
# 🔄 Chain 1 in iteration 46/200,
#  path: 242,  new path: 52,  docs changed path: 293,  Log-likelihood: -428424.88
# 🔄 Chain 3 in iteration 45/200,
#  path: 258,  new path: 46,  docs changed path: 266,  Log-likelihood: -424235.90
# 🔄 Chain 2 in iteration 47/200,
#  path: 253,  new path: 44,  docs changed path: 255,  Log-likelihood: -426279.50
# 🔄 Chain 1 in iteration 47/200,
#  path: 258,  new path: 67,  docs changed path: 291,  Log-likelihood: -427885.64
# 🔄 Chain 3 in iteration 46/200,
#  path: 261,  new path: 45,  docs changed path: 258,  Log-likelihood: -424563.05
# 🔄 Chain 2 in iteration 48/200,
#  path: 251,  new path: 55,  docs changed path: 266,  Log-likelihood: -426677.97
# 🔄 Chain 1 in iteration 48/200,
#  path: 254,  new path: 53,  docs changed path: 292,  Log-likelihood: -427667.08
# 🔄 Chain 3 in iteration 47/200,
#  path: 269,  new path: 54,  docs changed path: 272,  Log-likelihood: -424162.98
# 🔄 Chain 2 in iteration 49/200,
#  path: 255,  new path: 50,  docs changed path: 263,  Log-likelihood: -425686.08
# 🔄 Chain 1 in iteration 49/200,
#  path: 252,  new path: 55,  docs changed path: 297,  Log-likelihood: -428199.00
# 🔄 Chain 3 in iteration 48/200,
#  path: 259,  new path: 46,  docs changed path: 249,  Log-likelihood: -424747.58
# 🔄 Chain 2 in iteration 50/200,
#  path: 263,  new path: 55,  docs changed path: 240,  Log-likelihood: -425816.44
# 🔄 Chain 1 in iteration 50/200,
#  path: 254,  new path: 60,  docs changed path: 296,  Log-likelihood: -427432.51
# 🔄 Chain 3 in iteration 49/200,
#  path: 251,  new path: 43,  docs changed path: 259,  Log-likelihood: -424691.50
# 🔄 Chain 2 in iteration 51/200,
#  path: 268,  new path: 54,  docs changed path: 265,  Log-likelihood: -425375.42
# 🔄 Chain 1 in iteration 51/200,
#  path: 247,  new path: 52,  docs changed path: 297,  Log-likelihood: -427425.63
# 🔄 Chain 3 in iteration 50/200,
#  path: 250,  new path: 41,  docs changed path: 248,  Log-likelihood: -424495.17
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [573, 581, 581, 586, 578, 584, 582, 581, 590, 595, 594, 599, 599, 600, 597, 590, 587, 595, 597, 598, 603], '1': [542, 545, 549, 554, 551, 560, 567, 576, 558, 541, 545, 540, 549, 555, 558, 562, 562, 558, 553, 554, 557], '3': [585, 586, 575, 566, 560, 557, 561, 566, 563, 553, 559, 555, 553, 563, 578, 573, 576, 566, 571, 576, 565]}, mean_jaccard:[0.9326272042266532, 0.9269880924291221, 0.9207666288444752], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.2232，mean_jaccard:[0.9326272042266532, 0.9269880924291221, 0.9207666288444752], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 2 in iteration 52/200,
#  path: 260,  new path: 49,  docs changed path: 263,  Log-likelihood: -426112.95
# 🔄 Chain 1 in iteration 52/200,
#  path: 254,  new path: 61,  docs changed path: 294,  Log-likelihood: -427734.18
# 🔄 Chain 2 in iteration 56/200,
#  path: 267,  new path: 56,  docs changed path: 272,  Log-likelihood: -426136.73
# 🔄 Chain 1 in iteration 56/200,
#  path: 251,  new path: 57,  docs changed path: 293,  Log-likelihood: -427277.87
# 🔄 Chain 3 in iteration 55/200,
#  path: 249,  new path: 47,  docs changed path: 247,  Log-likelihood: -425232.26
# 🔄 Chain 2 in iteration 57/200,
#  path: 255,  new path: 44,  docs changed path: 275,  Log-likelihood: -426739.22
# 🔄 Chain 1 in iteration 57/200,
#  path: 249,  new path: 45,  docs changed path: 291,  Log-likelihood: -428205.69
# 🔄 Chain 3 in iteration 56/200,
#  path: 256,  new path: 49,  docs changed path: 266,  Log-likelihood: -425299.52
# 🔄 Chain 2 in iteration 58/200,
#  path: 251,  new path: 41,  docs changed path: 261,  Log-likelihood: -426512.84
# 🔄 Chain 1 in iteration 58/200,
#  path: 250,  new path: 53,  docs changed path: 283,  Log-likelihood: -428208.49
# 🔄 Chain 3 in iteration 57/200,
#  path: 264,  new path: 43,  docs changed path: 279,  Log-likelihood: -424827.58
# 🔄 Chain 2 in iteration 59/200,
#  path: 255,  new path: 51,  docs changed path: 245,  Log-likelihood: -426255.81
# 🔄 Chain 1 in iteration 59/200,
#  path: 247,  new path: 51,  docs changed path: 285,  Log-likelihood: -427277.27
# 🔄 Chain 3 in iteration 58/200,
#  path: 258,  new path: 44,  docs changed path: 261,  Log-likelihood: -425523.82
# 🔄 Chain 1 in iteration 60/200,
#  path: 248,  new path: 49,  docs changed path: 274,  Log-likelihood: -427265.75
# 🔄 Chain 2 in iteration 60/200,
#  path: 252,  new path: 45,  docs changed path: 262,  Log-likelihood: -426463.97
# 🔄 Chain 3 in iteration 59/200,
#  path: 266,  new path: 52,  docs changed path: 276,  Log-likelihood: -424436.14
# 🔄 Chain 1 in iteration 61/200,
#  path: 253,  new path: 61,  docs changed path: 277,  Log-likelihood: -426612.01
# 🔄 Chain 2 in iteration 61/200,
#  path: 259,  new path: 58,  docs changed path: 267,  Log-likelihood: -426445.29
# 🔄 Chain 3 in iteration 60/200,
#  path: 263,  new path: 50,  docs changed path: 272,  Log-likelihood: -425182.89
# 🔄 Chain 1 in iteration 62/200,
#  path: 248,  new path: 49,  docs changed path: 304,  Log-likelihood: -427734.13
# 🔄 Chain 2 in iteration 62/200,
#  path: 250,  new path: 54,  docs changed path: 261,  Log-likelihood: -427004.13
# 🔄 Chain 3 in iteration 61/200,
#  path: 275,  new path: 63,  docs changed path: 284,  Log-likelihood: -424203.24
# 🔄 Chain 1 in iteration 63/200,
#  path: 247,  new path: 52,  docs changed path: 276,  Log-likelihood: -427405.43
# 🔄 Chain 2 in iteration 63/200,
#  path: 258,  new path: 47,  docs changed path: 248,  Log-likelihood: -426115.93
# 🔄 Chain 3 in iteration 66/200,
#  path: 269,  new path: 59,  docs changed path: 280,  Log-likelihood: -423877.39
# 🔄 Chain 1 in iteration 68/200,
#  path: 241,  new path: 41,  docs changed path: 273,  Log-likelihood: -428678.31
# 🔄 Chain 2 in iteration 68/200,
#  path: 257,  new path: 53,  docs changed path: 241,  Log-likelihood: -426001.35
# 🔄 Chain 3 in iteration 67/200,
#  path: 264,  new path: 56,  docs changed path: 267,  Log-likelihood: -424079.13
# 🔄 Chain 1 in iteration 69/200,
#  path: 241,  new path: 43,  docs changed path: 263,  Log-likelihood: -428001.78
# 🔄 Chain 2 in iteration 69/200,
#  path: 262,  new path: 50,  docs changed path: 238,  Log-likelihood: -426040.35
# 🔄 Chain 3 in iteration 68/200,
#  path: 259,  new path: 51,  docs changed path: 258,  Log-likelihood: -424977.83
# 🔄 Chain 1 in iteration 70/200,
#  path: 245,  new path: 43,  docs changed path: 276,  Log-likelihood: -427819.27
# 🔄 Chain 2 in iteration 70/200,
#  path: 258,  new path: 52,  docs changed path: 250,  Log-likelihood: -425780.12
# 🔄 Chain 3 in iteration 69/200,
#  path: 265,  new path: 57,  docs changed path: 285,  Log-likelihood: -424395.59
# 🔄 Chain 1 in iteration 71/200,
#  path: 243,  new path: 45,  docs changed path: 272,  Log-likelihood: -427898.83
# 🔄 Chain 2 in iteration 71/200,
#  path: 262,  new path: 59,  docs changed path: 277,  Log-likelihood: -425405.86
# 🔄 Chain 1 in iteration 72/200,
#  path: 245,  new path: 50,  docs changed path: 265,  Log-likelihood: -428406.35
# 🔄 Chain 3 in iteration 70/200,
#  path: 265,  new path: 46,  docs changed path: 270,  Log-likelihood: -424864.53
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [603, 589, 591, 584, 570, 568, 569, 567, 563, 566, 576, 583, 588, 584, 583, 589, 589, 593, 601, 606, 612], '1': [557, 545, 530, 539, 556, 557, 557, 555, 551, 550, 561, 565, 561, 555, 550, 540, 558, 567, 568, 589, 584], '3': [565, 572, 574, 575, 581, 582, 571, 559, 557, 548, 551, 541, 531, 542, 556, 561, 565, 563, 552, 553, 556]}, mean_jaccard:[0.9229758513302503, 0.9248484390028505, 0.9120572579769488], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 1.4775，mean_jaccard:[0.9229758513302503, 0.9248484390028505, 0.9120572579769488], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 2 in iteration 72/200,
#  path: 266,  new path: 60,  docs changed path: 248,  Log-likelihood: -424725.11
# 🔄 Chain 1 in iteration 73/200,
#  path: 244,  new path: 51,  docs changed path: 265,  Log-likelihood: -428550.97
# 🔄 Chain 3 in iteration 71/200,
#  path: 261,  new path: 43,  docs changed path: 298,  Log-likelihood: -424770.87
# 🔄 Chain 2 in iteration 73/200,
#  path: 269,  new path: 63,  docs changed path: 236,  Log-likelihood: -425008.03
# 🔄 Chain 1 in iteration 74/200,
#  path: 249,  new path: 43,  docs changed path: 257,  Log-likelihood: -427462.12
# 🔄 Chain 3 in iteration 72/200,
#  path: 258,  new path: 49,  docs changed path: 278,  Log-likelihood: -424784.28
# 🔄 Chain 2 in iteration 74/200,
#  path: 259,  new path: 46,  docs changed path: 235,  Log-likelihood: -425990.93
# 🔄 Chain 3 in iteration 75/200,
#  path: 258,  new path: 46,  docs changed path: 259,  Log-likelihood: -423784.28
# 🔄 Chain 3 in iteration 78/200,
#  path: 264,  new path: 59,  docs changed path: 292,  Log-likelihood: -423649.17
# 🔄 Chain 2 in iteration 80/200,
#  path: 251,  new path: 43,  docs changed path: 248,  Log-likelihood: -425062.79
# 🔄 Chain 1 in iteration 81/200,
#  path: 250,  new path: 56,  docs changed path: 254,  Log-likelihood: -426298.66
# 🔄 Chain 3 in iteration 79/200,
#  path: 262,  new path: 49,  docs changed path: 245,  Log-likelihood: -423212.77
# 🔄 Chain 2 in iteration 81/200,
#  path: 254,  new path: 38,  docs changed path: 227,  Log-likelihood: -425321.63
# 🔄 Chain 1 in iteration 82/200,
#  path: 247,  new path: 44,  docs changed path: 278,  Log-likelihood: -426872.38
# 🔄 Chain 3 in iteration 80/200,
#  path: 259,  new path: 46,  docs changed path: 260,  Log-likelihood: -423936.86
# 🔄 Chain 2 in iteration 82/200,
#  path: 255,  new path: 44,  docs changed path: 245,  Log-likelihood: -425769.69
# 🔄 Chain 1 in iteration 83/200,
#  path: 255,  new path: 49,  docs changed path: 270,  Log-likelihood: -426923.36
# 🔄 Chain 3 in iteration 81/200,
#  path: 272,  new path: 59,  docs changed path: 257,  Log-likelihood: -422759.40
# 🔄 Chain 1 in iteration 84/200,
#  path: 250,  new path: 54,  docs changed path: 272,  Log-likelihood: -426373.18
# 🔄 Chain 2 in iteration 83/200,
#  path: 263,  new path: 59,  docs changed path: 258,  Log-likelihood: -425911.16
# 🔄 Chain 3 in iteration 82/200,
#  path: 256,  new path: 44,  docs changed path: 270,  Log-likelihood: -425586.43
# 🔄 Chain 1 in iteration 85/200,
#  path: 263,  new path: 54,  docs changed path: 255,  Log-likelihood: -425056.97
# 🔄 Chain 2 in iteration 84/200,
#  path: 257,  new path: 46,  docs changed path: 248,  Log-likelihood: -425413.81
# 🔄 Chain 3 in iteration 83/200,
#  path: 266,  new path: 52,  docs changed path: 280,  Log-likelihood: -424566.91
# 🔄 Chain 1 in iteration 86/200,
#  path: 262,  new path: 57,  docs changed path: 287,  Log-likelihood: -425150.10
# 🔄 Chain 2 in iteration 85/200,
#  path: 259,  new path: 53,  docs changed path: 251,  Log-likelihood: -424852.39
# 🔄 Chain 3 in iteration 84/200,
#  path: 258,  new path: 45,  docs changed path: 273,  Log-likelihood: -424422.29
# 🔄 Chain 1 in iteration 87/200,
#  path: 254,  new path: 51,  docs changed path: 275,  Log-likelihood: -425876.90
# 🔄 Chain 2 in iteration 86/200,
#  path: 253,  new path: 43,  docs changed path: 253,  Log-likelihood: -425425.87
# 🔄 Chain 3 in iteration 85/200,
#  path: 254,  new path: 51,  docs changed path: 271,  Log-likelihood: -423962.88
# 🔄 Chain 1 in iteration 88/200,
#  path: 259,  new path: 57,  docs changed path: 287,  Log-likelihood: -425003.02
# 🔄 Chain 2 in iteration 87/200,
#  path: 262,  new path: 57,  docs changed path: 225,  Log-likelihood: -425293.98
# 🔄 Chain 3 in iteration 86/200,
#  path: 252,  new path: 50,  docs changed path: 252,  Log-likelihood: -423853.62
# 🔄 Chain 1 in iteration 89/200,
#  path: 257,  new path: 53,  docs changed path: 283,  Log-likelihood: -425434.79
# 🔄 Chain 2 in iteration 88/200,
#  path: 265,  new path: 57,  docs changed path: 245,  Log-likelihood: -425403.51
# 🔄 Chain 3 in iteration 87/200,
#  path: 261,  new path: 54,  docs changed path: 271,  Log-likelihood: -423654.07
# 🔄 Chain 1 in iteration 90/200,
#  path: 246,  new path: 48,  docs changed path: 263,  Log-likelihood: -425813.91
# 🔄 Chain 2 in iteration 89/200,
#  path: 258,  new path: 58,  docs changed path: 241,  Log-likelihood: -424920.13
# 🔄 Chain 3 in iteration 88/200,
#  path: 254,  new path: 41,  docs changed path: 261,  Log-likelihood: -423325.78
# 🔄 Chain 1 in iteration 91/200,
#  path: 251,  new path: 51,  docs changed path: 266,  Log-likelihood: -425363.31
# 🔄 Chain 2 in iteration 90/200,
#  path: 260,  new path: 50,  docs changed path: 248,  Log-likelihood: -425118.46
# 🔄 Chain 3 in iteration 89/200,
#  path: 250,  new path: 42,  docs changed path: 243,  Log-likelihood: -424678.85
# 🔄 Chain 1 in iteration 92/200,
#  path: 250,  new path: 44,  docs changed path: 254,  Log-likelihood: -425758.96
# 🔄 Chain 2 in iteration 91/200,
#  path: 260,  new path: 53,  docs changed path: 248,  Log-likelihood: -424700.21
# 🔄 Chain 3 in iteration 90/200,
#  path: 252,  new path: 41,  docs changed path: 266,  Log-likelihood: -424945.43
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [612, 597, 599, 597, 599, 614, 607, 606, 604, 600, 584, 585, 586, 580, 599, 600, 601, 620, 617, 626, 620], '1': [584, 572, 575, 582, 596, 581, 568, 575, 576, 571, 572, 570, 561, 567, 564, 575, 581, 582, 587, 568, 564], '3': [556, 538, 538, 544, 538, 550, 561, 565, 551, 569, 577, 575, 587, 573, 565, 554, 561, 561, 566, 568, 556]}, mean_jaccard:[0.9256422937924009, 0.9253682647167534, 0.9195437770915287], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.0930，mean_jaccard:[0.9256422937924009, 0.9253682647167534, 0.9195437770915287], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 1 in iteration 93/200,
#  path: 255,  new path: 53,  docs changed path: 263,  Log-likelihood: -425044.37
# 🔄 Chain 2 in iteration 92/200,
#  path: 252,  new path: 47,  docs changed path: 254,  Log-likelihood: -425660.13
# 🔄 Chain 3 in iteration 91/200,
#  path: 254,  new path: 48,  docs changed path: 263,  Log-likelihood: -424616.33
# 🔄 Chain 1 in iteration 94/200,
#  path: 258,  new path: 57,  docs changed path: 273,  Log-likelihood: -424941.48
# 🔄 Chain 2 in iteration 93/200,
#  path: 254,  new path: 52,  docs changed path: 249,  Log-likelihood: -425416.76
# 🔄 Chain 3 in iteration 92/200,
#  path: 270,  new path: 60,  docs changed path: 269,  Log-likelihood: -424199.21
# 🔄 Chain 1 in iteration 95/200,
#  path: 270,  new path: 60,  docs changed path: 277,  Log-likelihood: -424201.04
# 🔄 Chain 2 in iteration 94/200,
#  path: 257,  new path: 48,  docs changed path: 249,  Log-likelihood: -424793.63
# 🔄 Chain 3 in iteration 93/200,
#  path: 264,  new path: 38,  docs changed path: 259,  Log-likelihood: -423661.12
# 🔄 Chain 1 in iteration 96/200,
#  path: 253,  new path: 46,  docs changed path: 291,  Log-likelihood: -425753.48
# 🔄 Chain 2 in iteration 95/200,
#  path: 255,  new path: 57,  docs changed path: 241,  Log-likelihood: -425563.11
# 🔄 Chain 3 in iteration 94/200,
#  path: 261,  new path: 39,  docs changed path: 239,  Log-likelihood: -424447.26
# 🔄 Chain 1 in iteration 97/200,
#  path: 260,  new path: 54,  docs changed path: 269,  Log-likelihood: -425543.15
# 🔄 Chain 2 in iteration 96/200,
#  path: 246,  new path: 47,  docs changed path: 238,  Log-likelihood: -425753.68
# 🔄 Chain 3 in iteration 95/200,
#  path: 260,  new path: 53,  docs changed path: 252,  Log-likelihood: -424352.56
# 🔄 Chain 2 in iteration 97/200,
#  path: 252,  new path: 52,  docs changed path: 257,  Log-likelihood: -425853.64
# 🔄 Chain 1 in iteration 98/200,
#  path: 250,  new path: 51,  docs changed path: 260,  Log-likelihood: -425442.61
# 🔄 Chain 2 in iteration 98/200,
#  path: 255,  new path: 47,  docs changed path: 232,  Log-likelihood: -425508.46
# 🔄 Chain 3 in iteration 96/200,
#  path: 260,  new path: 50,  docs changed path: 265,  Log-likelihood: -423975.54
# 🔄 Chain 1 in iteration 99/200,
#  path: 253,  new path: 55,  docs changed path: 273,  Log-likelihood: -425023.78
# 🔄 Chain 2 in iteration 99/200,
#  path: 260,  new path: 52,  docs changed path: 245,  Log-likelihood: -424886.66
# 🔄 Chain 3 in iteration 97/200,
#  path: 251,  new path: 44,  docs changed path: 248,  Log-likelihood: -423880.71
# 🔄 Chain 1 in iteration 100/200,
#  path: 254,  new path: 57,  docs changed path: 264,  Log-likelihood: -424948.02
# 🔄 Chain 2 in iteration 100/200,
#  path: 258,  new path: 52,  docs changed path: 256,  Log-likelihood: -425510.62
# 🔄 Chain 1 in iteration 101/200,
#  path: 257,  new path: 50,  docs changed path: 271,  Log-likelihood: -425280.00
# 🔄 Chain 3 in iteration 98/200,
#  path: 259,  new path: 45,  docs changed path: 247,  Log-likelihood: -423980.99
# 🔄 Chain 1 in iteration 102/200,
#  path: 251,  new path: 52,  docs changed path: 264,  Log-likelihood: -424782.64
# 🔄 Chain 2 in iteration 101/200,
#  path: 261,  new path: 65,  docs changed path: 255,  Log-likelihood: -425378.22
# 🔄 Chain 3 in iteration 99/200,
#  path: 254,  new path: 45,  docs changed path: 261,  Log-likelihood: -424528.83
# 🔄 Chain 1 in iteration 103/200,
#  path: 252,  new path: 45,  docs changed path: 271,  Log-likelihood: -426301.00
# 🔄 Chain 2 in iteration 102/200,
#  path: 258,  new path: 52,  docs changed path: 242,  Log-likelihood: -424792.29
# 🔄 Chain 3 in iteration 100/200,
#  path: 252,  new path: 38,  docs changed path: 239,  Log-likelihood: -424561.30
# 🔄 Chain 1 in iteration 104/200,
#  path: 254,  new path: 57,  docs changed path: 274,  Log-likelihood: -424707.68
# 🔄 Chain 2 in iteration 103/200,
#  path: 258,  new path: 50,  docs changed path: 243,  Log-likelihood: -426634.30
# 🔄 Chain 3 in iteration 101/200,
#  path: 258,  new path: 42,  docs changed path: 244,  Log-likelihood: -423997.93
# 🔄 Chain 1 in iteration 105/200,
#  path: 264,  new path: 59,  docs changed path: 269,  Log-likelihood: -424579.50
# 🔄 Chain 2 in iteration 104/200,
#  path: 262,  new path: 50,  docs changed path: 250,  Log-likelihood: -426202.84
# 🔄 Chain 3 in iteration 102/200,
#  path: 255,  new path: 44,  docs changed path: 255,  Log-likelihood: -424026.85
# 🔄 Chain 1 in iteration 106/200,
#  path: 253,  new path: 47,  docs changed path: 277,  Log-likelihood: -425154.76
# 🔄 Chain 2 in iteration 105/200,
#  path: 260,  new path: 52,  docs changed path: 261,  Log-likelihood: -425548.65
# 🔄 Chain 3 in iteration 103/200,
#  path: 257,  new path: 42,  docs changed path: 262,  Log-likelihood: -424660.61
# 🔄 Chain 1 in iteration 107/200,
#  path: 262,  new path: 60,  docs changed path: 293,  Log-likelihood: -424781.02
# 🔄 Chain 2 in iteration 106/200,
#  path: 256,  new path: 57,  docs changed path: 249,  Log-likelihood: -424706.39
# 🔄 Chain 3 in iteration 104/200,
#  path: 258,  new path: 46,  docs changed path: 268,  Log-likelihood: -424421.42
# 🔄 Chain 1 in iteration 108/200,
#  path: 254,  new path: 50,  docs changed path: 272,  Log-likelihood: -424515.79
# 🔄 Chain 2 in iteration 107/200,
#  path: 256,  new path: 52,  docs changed path: 250,  Log-likelihood: -425362.52
# 🔄 Chain 3 in iteration 105/200,
#  path: 252,  new path: 44,  docs changed path: 261,  Log-likelihood: -425533.53
# 🔄 Chain 1 in iteration 109/200,
#  path: 256,  new path: 51,  docs changed path: 278,  Log-likelihood: -424559.99
# 🔄 Chain 2 in iteration 108/200,
#  path: 263,  new path: 51,  docs changed path: 259,  Log-likelihood: -425486.30
# 🔄 Chain 3 in iteration 106/200,
#  path: 262,  new path: 56,  docs changed path: 251,  Log-likelihood: -424548.32
# 🔄 Chain 2 in iteration 109/200,
#  path: 251,  new path: 42,  docs changed path: 252,  Log-likelihood: -426304.70
# 🔄 Chain 1 in iteration 110/200,
#  path: 257,  new path: 54,  docs changed path: 280,  Log-likelihood: -424829.77
# 🔄 Chain 3 in iteration 107/200,
#  path: 263,  new path: 52,  docs changed path: 262,  Log-likelihood: -423862.80
# 🔄 Chain 2 in iteration 110/200,
#  path: 257,  new path: 54,  docs changed path: 253,  Log-likelihood: -425228.26
# 🔄 Chain 1 in iteration 111/200,
#  path: 253,  new path: 45,  docs changed path: 258,  Log-likelihood: -424334.11
# 🔄 Chain 3 in iteration 108/200,
#  path: 260,  new path: 50,  docs changed path: 244,  Log-likelihood: -424149.36
# 🔄 Chain 1 in iteration 112/200,
#  path: 252,  new path: 50,  docs changed path: 256,  Log-likelihood: -424876.40
# 🔄 Chain 2 in iteration 111/200,
#  path: 261,  new path: 50,  docs changed path: 257,  Log-likelihood: -425095.15
# 🔄 Chain 3 in iteration 109/200,
#  path: 264,  new path: 53,  docs changed path: 250,  Log-likelihood: -424342.23
# 🔄 Chain 1 in iteration 113/200,
#  path: 264,  new path: 56,  docs changed path: 274,  Log-likelihood: -424691.18
# 🔄 Chain 2 in iteration 112/200,
#  path: 257,  new path: 49,  docs changed path: 258,  Log-likelihood: -425546.53
# 🔄 Chain 3 in iteration 110/200,
#  path: 268,  new path: 49,  docs changed path: 285,  Log-likelihood: -422964.62
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [620, 611, 602, 603, 593, 585, 582, 583, 601, 607, 611, 610, 602, 596, 594, 595, 590, 589, 592, 604, 602], '1': [564, 560, 571, 580, 577, 583, 569, 572, 574, 577, 585, 577, 570, 567, 566, 569, 556, 547, 551, 553, 547], '3': [556, 563, 573, 577, 580, 591, 576, 592, 584, 585, 595, 593, 596, 608, 586, 563, 552, 550, 569, 564, 563]}, mean_jaccard:[0.9293681743912465, 0.9216440780359143, 0.9189753667968794], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 1.5900，mean_jaccard:[0.9293681743912465, 0.9216440780359143, 0.9189753667968794], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 1 in iteration 114/200,
#  path: 262,  new path: 44,  docs changed path: 285,  Log-likelihood: -424879.57
# 🔄 Chain 2 in iteration 113/200,
#  path: 248,  new path: 40,  docs changed path: 232,  Log-likelihood: -425716.07
# 🔄 Chain 3 in iteration 111/200,
#  path: 269,  new path: 55,  docs changed path: 266,  Log-likelihood: -422928.63
# 🔄 Chain 2 in iteration 114/200,
#  path: 246,  new path: 41,  docs changed path: 241,  Log-likelihood: -425056.52
# 🔄 Chain 1 in iteration 115/200,
#  path: 253,  new path: 53,  docs changed path: 283,  Log-likelihood: -425391.49
# 🔄 Chain 3 in iteration 112/200,
#  path: 265,  new path: 54,  docs changed path: 271,  Log-likelihood: -423662.17
# 🔄 Chain 2 in iteration 115/200,
#  path: 255,  new path: 56,  docs changed path: 237,  Log-likelihood: -424432.66
# 🔄 Chain 1 in iteration 116/200,
#  path: 260,  new path: 57,  docs changed path: 280,  Log-likelihood: -424792.04
# 🔄 Chain 3 in iteration 113/200,
#  path: 262,  new path: 46,  docs changed path: 265,  Log-likelihood: -423410.96
# 🔄 Chain 2 in iteration 116/200,
#  path: 254,  new path: 52,  docs changed path: 231,  Log-likelihood: -425337.39
# 🔄 Chain 1 in iteration 117/200,
#  path: 254,  new path: 43,  docs changed path: 275,  Log-likelihood: -425286.47
# 🔄 Chain 3 in iteration 114/200,
#  path: 255,  new path: 41,  docs changed path: 256,  Log-likelihood: -423965.12
# 🔄 Chain 2 in iteration 117/200,
#  path: 250,  new path: 49,  docs changed path: 242,  Log-likelihood: -425041.79
# 🔄 Chain 1 in iteration 118/200,
#  path: 252,  new path: 55,  docs changed path: 277,  Log-likelihood: -425285.87
# 🔄 Chain 3 in iteration 115/200,
#  path: 261,  new path: 57,  docs changed path: 255,  Log-likelihood: -424732.26
# 🔄 Chain 2 in iteration 118/200,
#  path: 257,  new path: 47,  docs changed path: 238,  Log-likelihood: -425080.27
# 🔄 Chain 1 in iteration 119/200,
#  path: 260,  new path: 60,  docs changed path: 281,  Log-likelihood: -425705.09
# 🔄 Chain 3 in iteration 116/200,
#  path: 266,  new path: 52,  docs changed path: 265,  Log-likelihood: -423420.10
# 🔄 Chain 2 in iteration 119/200,
#  path: 259,  new path: 50,  docs changed path: 248,  Log-likelihood: -424962.79
# 🔄 Chain 1 in iteration 120/200,
#  path: 256,  new path: 56,  docs changed path: 287,  Log-likelihood: -424755.96
# 🔄 Chain 3 in iteration 117/200,
#  path: 264,  new path: 46,  docs changed path: 266,  Log-likelihood: -423982.89
# 🔄 Chain 2 in iteration 120/200,
#  path: 253,  new path: 48,  docs changed path: 257,  Log-likelihood: -425705.07
# 🔄 Chain 1 in iteration 121/200,
#  path: 258,  new path: 51,  docs changed path: 276,  Log-likelihood: -424195.01
# 🔄 Chain 3 in iteration 118/200,
#  path: 261,  new path: 54,  docs changed path: 266,  Log-likelihood: -424041.16
# 🔄 Chain 2 in iteration 121/200,
#  path: 248,  new path: 51,  docs changed path: 232,  Log-likelihood: -426372.13
# 🔄 Chain 1 in iteration 122/200,
#  path: 265,  new path: 56,  docs changed path: 276,  Log-likelihood: -422575.93
# 🔄 Chain 3 in iteration 119/200,
#  path: 255,  new path: 49,  docs changed path: 257,  Log-likelihood: -424600.46
# 🔄 Chain 2 in iteration 122/200,
#  path: 258,  new path: 58,  docs changed path: 236,  Log-likelihood: -425000.44
# 🔄 Chain 1 in iteration 123/200,
#  path: 268,  new path: 58,  docs changed path: 289,  Log-likelihood: -424135.99
# 🔄 Chain 3 in iteration 120/200,
#  path: 249,  new path: 43,  docs changed path: 250,  Log-likelihood: -425261.98
# 🔄 Chain 2 in iteration 123/200,
#  path: 256,  new path: 43,  docs changed path: 238,  Log-likelihood: -424453.89
# 🔄 Chain 1 in iteration 124/200,
#  path: 260,  new path: 46,  docs changed path: 284,  Log-likelihood: -424328.44
# 🔄 Chain 3 in iteration 121/200,
#  path: 261,  new path: 51,  docs changed path: 258,  Log-likelihood: -424413.60
# 🔄 Chain 2 in iteration 124/200,
#  path: 259,  new path: 47,  docs changed path: 228,  Log-likelihood: -424082.21
# 🔄 Chain 1 in iteration 125/200,
#  path: 256,  new path: 51,  docs changed path: 279,  Log-likelihood: -425106.67
# 🔄 Chain 3 in iteration 122/200,
#  path: 265,  new path: 49,  docs changed path: 266,  Log-likelihood: -423809.91
# 🔄 Chain 2 in iteration 125/200,
#  path: 251,  new path: 40,  docs changed path: 224,  Log-likelihood: -424609.99
# 🔄 Chain 1 in iteration 126/200,
#  path: 259,  new path: 54,  docs changed path: 277,  Log-likelihood: -424435.94
# 🔄 Chain 3 in iteration 123/200,
#  path: 260,  new path: 42,  docs changed path: 272,  Log-likelihood: -424242.62
# 🔄 Chain 2 in iteration 126/200,
#  path: 253,  new path: 48,  docs changed path: 230,  Log-likelihood: -425129.34
# 🔄 Chain 1 in iteration 127/200,
#  path: 260,  new path: 54,  docs changed path: 287,  Log-likelihood: -425364.13
# 🔄 Chain 3 in iteration 124/200,
#  path: 264,  new path: 44,  docs changed path: 260,  Log-likelihood: -424509.10
# 🔄 Chain 2 in iteration 127/200,
#  path: 262,  new path: 54,  docs changed path: 236,  Log-likelihood: -424230.34
# 🔄 Chain 1 in iteration 128/200,
#  path: 257,  new path: 46,  docs changed path: 264,  Log-likelihood: -425165.74
# 🔄 Chain 3 in iteration 125/200,
#  path: 271,  new path: 56,  docs changed path: 287,  Log-likelihood: -424379.84
# 🔄 Chain 2 in iteration 128/200,
#  path: 249,  new path: 44,  docs changed path: 224,  Log-likelihood: -425075.90
# 🔄 Chain 1 in iteration 129/200,
#  path: 253,  new path: 51,  docs changed path: 267,  Log-likelihood: -424296.39
# 🔄 Chain 3 in iteration 126/200,
#  path: 266,  new path: 52,  docs changed path: 288,  Log-likelihood: -423341.59
# 🔄 Chain 2 in iteration 129/200,
#  path: 264,  new path: 59,  docs changed path: 227,  Log-likelihood: -424083.48
# 🔄 Chain 1 in iteration 130/200,
#  path: 257,  new path: 61,  docs changed path: 274,  Log-likelihood: -424424.93
# 🔄 Chain 3 in iteration 127/200,
#  path: 274,  new path: 55,  docs changed path: 272,  Log-likelihood: -423177.54
# 🔄 Chain 2 in iteration 130/200,
#  path: 255,  new path: 48,  docs changed path: 239,  Log-likelihood: -425253.21
# 🔄 Chain 1 in iteration 131/200,
#  path: 264,  new path: 54,  docs changed path: 295,  Log-likelihood: -424065.29
# 🔄 Chain 3 in iteration 128/200,
#  path: 276,  new path: 56,  docs changed path: 285,  Log-likelihood: -422730.82
# 🔄 Chain 2 in iteration 131/200,
#  path: 252,  new path: 48,  docs changed path: 238,  Log-likelihood: -425489.66
# 🔄 Chain 1 in iteration 132/200,
#  path: 263,  new path: 47,  docs changed path: 278,  Log-likelihood: -424545.87
# 🔄 Chain 3 in iteration 129/200,
#  path: 263,  new path: 48,  docs changed path: 268,  Log-likelihood: -422998.00
# 🔄 Chain 2 in iteration 132/200,
#  path: 253,  new path: 50,  docs changed path: 238,  Log-likelihood: -424715.78
# 🔄 Chain 1 in iteration 133/200,
#  path: 257,  new path: 55,  docs changed path: 290,  Log-likelihood: -424814.72
# 🔄 Chain 2 in iteration 133/200,
#  path: 246,  new path: 46,  docs changed path: 239,  Log-likelihood: -425174.36
# 🔄 Chain 3 in iteration 130/200,
#  path: 266,  new path: 46,  docs changed path: 263,  Log-likelihood: -423457.49
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [602, 595, 590, 595, 603, 608, 607, 611, 618, 611, 610, 614, 612, 611, 613, 609, 618, 621, 631, 628, 626], '1': [547, 562, 578, 583, 584, 574, 565, 571, 575, 569, 552, 554, 553, 553, 552, 559, 556, 553, 565, 571, 569], '3': [563, 567, 564, 563, 568, 571, 572, 579, 572, 562, 571, 579, 570, 567, 569, 567, 560, 559, 550, 566, 583]}, mean_jaccard:[0.9314149142466228, 0.9258512734101249, 0.9250885400908888], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.8321，mean_jaccard:[0.9314149142466228, 0.9258512734101249, 0.9250885400908888], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 1 in iteration 134/200,
#  path: 251,  new path: 51,  docs changed path: 272,  Log-likelihood: -425129.44
# 🔄 Chain 2 in iteration 134/200,
#  path: 250,  new path: 47,  docs changed path: 241,  Log-likelihood: -425876.55
# 🔄 Chain 3 in iteration 131/200,
#  path: 254,  new path: 40,  docs changed path: 260,  Log-likelihood: -424367.12
# 🔄 Chain 1 in iteration 135/200,
#  path: 260,  new path: 54,  docs changed path: 286,  Log-likelihood: -424536.46
# 🔄 Chain 2 in iteration 135/200,
#  path: 253,  new path: 53,  docs changed path: 247,  Log-likelihood: -425455.22
# 🔄 Chain 3 in iteration 132/200,
#  path: 252,  new path: 36,  docs changed path: 255,  Log-likelihood: -423304.24
# 🔄 Chain 1 in iteration 136/200,
#  path: 265,  new path: 55,  docs changed path: 265,  Log-likelihood: -424151.26
# 🔄 Chain 2 in iteration 136/200,
#  path: 251,  new path: 48,  docs changed path: 230,  Log-likelihood: -424344.18
# 🔄 Chain 3 in iteration 133/200,
#  path: 253,  new path: 38,  docs changed path: 238,  Log-likelihood: -423367.38
# 🔄 Chain 1 in iteration 137/200,
#  path: 268,  new path: 66,  docs changed path: 288,  Log-likelihood: -422747.58
# 🔄 Chain 2 in iteration 137/200,
#  path: 257,  new path: 53,  docs changed path: 220,  Log-likelihood: -424986.19
# 🔄 Chain 3 in iteration 134/200,
#  path: 252,  new path: 44,  docs changed path: 247,  Log-likelihood: -424635.78
# 🔄 Chain 1 in iteration 138/200,
#  path: 258,  new path: 53,  docs changed path: 292,  Log-likelihood: -425222.54
# 🔄 Chain 2 in iteration 138/200,
#  path: 256,  new path: 53,  docs changed path: 231,  Log-likelihood: -424821.93
# 🔄 Chain 3 in iteration 135/200,
#  path: 252,  new path: 42,  docs changed path: 257,  Log-likelihood: -424241.35
# 🔄 Chain 1 in iteration 139/200,
#  path: 258,  new path: 44,  docs changed path: 279,  Log-likelihood: -424059.64
# 🔄 Chain 2 in iteration 139/200,
#  path: 255,  new path: 48,  docs changed path: 232,  Log-likelihood: -423917.38
# 🔄 Chain 3 in iteration 136/200,
#  path: 255,  new path: 45,  docs changed path: 247,  Log-likelihood: -424108.41
# 🔄 Chain 1 in iteration 140/200,
#  path: 268,  new path: 61,  docs changed path: 287,  Log-likelihood: -423334.03
# 🔄 Chain 2 in iteration 140/200,
#  path: 260,  new path: 52,  docs changed path: 234,  Log-likelihood: -424339.89
# 🔄 Chain 3 in iteration 137/200,
#  path: 271,  new path: 63,  docs changed path: 281,  Log-likelihood: -422991.20
# 🔄 Chain 1 in iteration 141/200,
#  path: 262,  new path: 55,  docs changed path: 296,  Log-likelihood: -423285.33
# 🔄 Chain 2 in iteration 141/200,
#  path: 261,  new path: 52,  docs changed path: 248,  Log-likelihood: -423823.63
# 🔄 Chain 3 in iteration 138/200,
#  path: 267,  new path: 49,  docs changed path: 278,  Log-likelihood: -423524.78
# 🔄 Chain 1 in iteration 142/200,
#  path: 263,  new path: 57,  docs changed path: 278,  Log-likelihood: -423132.09
# 🔄 Chain 2 in iteration 142/200,
#  path: 254,  new path: 42,  docs changed path: 243,  Log-likelihood: -424551.83
# 🔄 Chain 3 in iteration 139/200,
#  path: 265,  new path: 55,  docs changed path: 295,  Log-likelihood: -423314.29
# 🔄 Chain 1 in iteration 143/200,
#  path: 255,  new path: 49,  docs changed path: 291,  Log-likelihood: -423823.38
# 🔄 Chain 2 in iteration 143/200,
#  path: 257,  new path: 51,  docs changed path: 257,  Log-likelihood: -425029.45
# 🔄 Chain 3 in iteration 140/200,
#  path: 271,  new path: 58,  docs changed path: 287,  Log-likelihood: -423813.58
# 🔄 Chain 1 in iteration 144/200,
#  path: 253,  new path: 42,  docs changed path: 274,  Log-likelihood: -423537.38
# 🔄 Chain 2 in iteration 144/200,
#  path: 255,  new path: 48,  docs changed path: 239,  Log-likelihood: -424473.67
# 🔄 Chain 3 in iteration 141/200,
#  path: 264,  new path: 49,  docs changed path: 284,  Log-likelihood: -423809.90
# 🔄 Chain 1 in iteration 145/200,
#  path: 260,  new path: 56,  docs changed path: 277,  Log-likelihood: -424021.71
# 🔄 Chain 2 in iteration 145/200,
#  path: 259,  new path: 45,  docs changed path: 224,  Log-likelihood: -424517.51
# 🔄 Chain 3 in iteration 142/200,
#  path: 257,  new path: 47,  docs changed path: 258,  Log-likelihood: -423347.60
# 🔄 Chain 1 in iteration 146/200,
#  path: 268,  new path: 63,  docs changed path: 280,  Log-likelihood: -423092.59
# 🔄 Chain 2 in iteration 146/200,
#  path: 252,  new path: 46,  docs changed path: 233,  Log-likelihood: -425484.42
# 🔄 Chain 3 in iteration 143/200,
#  path: 266,  new path: 53,  docs changed path: 279,  Log-likelihood: -423597.46
# 🔄 Chain 1 in iteration 147/200,
#  path: 263,  new path: 54,  docs changed path: 252,  Log-likelihood: -424033.57
# 🔄 Chain 2 in iteration 147/200,
#  path: 252,  new path: 46,  docs changed path: 230,  Log-likelihood: -425017.74
# 🔄 Chain 3 in iteration 144/200,
#  path: 260,  new path: 46,  docs changed path: 281,  Log-likelihood: -423409.78
# 🔄 Chain 1 in iteration 148/200,
#  path: 253,  new path: 49,  docs changed path: 270,  Log-likelihood: -423912.99
# 🔄 Chain 2 in iteration 148/200,
#  path: 250,  new path: 52,  docs changed path: 238,  Log-likelihood: -426142.14
# 🔄 Chain 3 in iteration 145/200,
#  path: 262,  new path: 53,  docs changed path: 268,  Log-likelihood: -423463.33
# 🔄 Chain 1 in iteration 149/200,
#  path: 252,  new path: 50,  docs changed path: 275,  Log-likelihood: -424626.94
# 🔄 Chain 2 in iteration 149/200,
#  path: 254,  new path: 47,  docs changed path: 253,  Log-likelihood: -426076.87
# 🔄 Chain 3 in iteration 146/200,
#  path: 259,  new path: 49,  docs changed path: 272,  Log-likelihood: -423836.67
# 🔄 Chain 1 in iteration 150/200,
#  path: 251,  new path: 53,  docs changed path: 275,  Log-likelihood: -423722.87
# 🔄 Chain 2 in iteration 150/200,
#  path: 251,  new path: 44,  docs changed path: 249,  Log-likelihood: -425917.48
# 🔄 Chain 3 in iteration 147/200,
#  path: 261,  new path: 51,  docs changed path: 260,  Log-likelihood: -423562.58
# 🔄 Chain 1 in iteration 151/200,
#  path: 264,  new path: 61,  docs changed path: 271,  Log-likelihood: -424400.53
# 🔄 Chain 2 in iteration 151/200,
#  path: 251,  new path: 50,  docs changed path: 236,  Log-likelihood: -425897.48
# 🔄 Chain 3 in iteration 148/200,
#  path: 261,  new path: 52,  docs changed path: 269,  Log-likelihood: -423518.05
# 🔄 Chain 1 in iteration 152/200,
#  path: 252,  new path: 48,  docs changed path: 276,  Log-likelihood: -424231.13
# 🔄 Chain 2 in iteration 152/200,
#  path: 256,  new path: 49,  docs changed path: 237,  Log-likelihood: -425934.07
# 🔄 Chain 1 in iteration 153/200,
#  path: 266,  new path: 64,  docs changed path: 294,  Log-likelihood: -423653.42
# 🔄 Chain 3 in iteration 149/200,
#  path: 258,  new path: 61,  docs changed path: 271,  Log-likelihood: -423995.62
# 🔄 Chain 2 in iteration 153/200,
#  path: 259,  new path: 55,  docs changed path: 242,  Log-likelihood: -425289.90
# 🔄 Chain 1 in iteration 154/200,
#  path: 265,  new path: 58,  docs changed path: 273,  Log-likelihood: -423369.58
# 🔄 Chain 3 in iteration 150/200,
#  path: 261,  new path: 57,  docs changed path: 284,  Log-likelihood: -423683.76
# check_dual_convergence_with_gelman_rubin: chain_len_docs:{'2': [626, 633, 625, 614, 612, 613, 610, 618, 626, 623, 630, 618, 610, 598, 592, 595, 593, 609, 616, 615, 610], '1': [569, 561, 561, 533, 542, 540, 546, 557, 558, 560, 560, 553, 554, 550, 544, 548, 550, 559, 565, 572, 573], '3': [583, 586, 587, 591, 588, 579, 585, 564, 564, 564, 549, 557, 553, 549, 536, 545, 551, 563, 581, 571, 562]}, mean_jaccard:[0.9316579064961298, 0.9155096375997298, 0.9154323277599191], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🥰 Convergence status: ❌ Not converged...
# 🥰  R-hat info: 2.5425，mean_jaccard:[0.9316579064961298, 0.9155096375997298, 0.9154323277599191], mean_ratio:[0.20000000000000004, 0.20000000000000004, 0.20000000000000004]
# 🔄 Chain 2 in iteration 154/200,
#  path: 252,  new path: 47,  docs changed path: 245,  Log-likelihood: -425159.81
# 🔄 Chain 1 in iteration 155/200,
#  path: 255,  new path: 46,  docs changed path: 293,  Log-likelihood: -424809.24
# 🔄 Chain 3 in iteration 151/200,
#  path: 262,  new path: 50,  docs changed path: 277,  Log-likelihood: -423005.12
# 🔄 Chain 2 in iteration 155/200,
#  path: 262,  new path: 62,  docs changed path: 250,  Log-likelihood: -424795.06
# 🔄 Chain 1 in iteration 156/200,
#  path: 256,  new path: 46,  docs changed path: 276,  Log-likelihood: -424419.28
# 🔄 Chain 3 in iteration 152/200,
#  path: 256,  new path: 36,  docs changed path: 265,  Log-likelihood: -423451.60

# %%
# # 从现有结果恢复并继续运行
# results = run_multi_chain_hlda_with_restore(
#     corpus=corpus,
#     depth=3,
#     gamma=0.05,
#     eta=0.005,
#     alpha=0.1,
#     n_chains=2,
#     max_iterations=200,  # 继续运行的迭代次数
#     general_dir="step2_d3_g005_e0005_恢复02",  # 新的输出目录
#     source_dir="step2_d3_g005_e0005_恢复01",  # 包含原始链结果的目录
#     restore_from_existing=True,  # 启用恢复模式
#     back_window=5,
#     check_interval=20,
#     burn_in=5,
#     r_hat_threshold=1.1
# )

# print("✅ All chains restored and continued running!")

# %%
# # 从现有结果恢复并继续运行
# results = run_multi_chain_hlda_with_restore(
#     corpus=corpus,
#     depth=3,
#     gamma=0.05,
#     eta=0.005,
#     alpha=0.1,
#     n_chains=2,
#     max_iterations=200,  # 继续运行的迭代次数
#     general_dir="step2_d3_g005_e0005_恢复03",  # 新的输出目录
#     source_dir="step2_d3_g005_e0005_恢复02",  # 包含原始链结果的目录
#     restore_from_existing=True,  # 启用恢复模式
#     back_window=5,
#     check_interval=20,
#     burn_in=5,
#     r_hat_threshold=1.1
# )

# print("✅ All chains restored and continued running!")
