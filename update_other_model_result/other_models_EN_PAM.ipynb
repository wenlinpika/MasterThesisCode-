# %%
""" 0. set-up part:  import necessary libraries and set up environment """

import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from collections import Counter, defaultdict
import numpy as np
import math
import copy
import itertools
import matplotlib.pyplot as plt
import matplotlib as mpl

import joblib
from joblib import Parallel, delayed
from threading import Thread

import os
import pickle
import time

import operator
from functools import reduce
import json
import cProfile

import gensim
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary

import tomotopy as tp

# download nltk data once time
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('omw-1.4')
# nltk.download('punkt_tab')
# nltk.download('averaged_perceptron_tagger_eng')

#  chinese character support in matplotlib
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS' 'SimHei' 'DejaVu Sans']  
plt.rcParams['axes.unicode_minus'] = False

# %%
""" 1.1 Data Preprocessing: load data, clean text, lemmatization, remove low-frequency words"""

# Map POS tags to WordNet format， Penn Treebank annotation: fine-grained (45 tags), WordNet annotation: coarse-grained (4 tags: a, v, n, r)
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return 'a'  # 形容词
    elif treebank_tag.startswith('V'):
        return 'v'  # 动词
    elif treebank_tag.startswith('N'):
        return 'n'  # 名词
    elif treebank_tag.startswith('R'):
        return 'r'  # 副词
    else:
        return 'n'  # 默认名词

# Text cleaning and lemmatization preprocessing function
def clean_and_lemmatize(text):
    if pd.isnull(text):
        return []
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # Remove non-alphabetic characters using regex
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    pos_tags = pos_tag(tokens)
    lemmatized = [lemmatizer.lemmatize(w, get_wordnet_pos(pos)) for w, pos in pos_tags]
    return lemmatized  

#-----------------Load data----------------
data = pd.read_excel('./data/raw/papers_CM.xlsx', usecols=['PaperID', 'Abstract', 'Keywords', 'Year'])

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# clean and lemmatize the abstracts
data['Lemmatized_Tokens'] = data['Abstract'].apply(clean_and_lemmatize)

# count word frequencies
all_tokens = [word for tokens in data['Lemmatized_Tokens'] for word in tokens]
word_counts = Counter(all_tokens)

# set a minimum frequency threshold for valid words
min_freq = 10
valid_words = set([word for word, freq in word_counts.items() if freq >= min_freq])

# remove rare words based on frequency threshold
def remove_rare_words(tokens):
    return [word for word in tokens if word in valid_words]

data['Filtered_Tokens'] = data['Lemmatized_Tokens'].apply(remove_rare_words)

# join tokens back into cleaned abstracts
data['Cleaned_Abstract'] = data['Filtered_Tokens'].apply(lambda x: " ".join(x))

# create a cleaned DataFrame with relevant columns
cleaned_data = data[['PaperID', 'Year', 'Cleaned_Abstract']]
cleaned_data = cleaned_data[~(cleaned_data['PaperID'] == 57188)] # this paper has no abstract
cleaned_data = cleaned_data.reset_index(drop=True) 
cleaned_data.insert(0, 'Document_ID', range(len(cleaned_data))) 
abstract_list = cleaned_data['Cleaned_Abstract'].apply(lambda x: x.split()).tolist()

corpus = {doc_id: abstract_list for doc_id, abstract_list in enumerate(abstract_list)}
# cleaned_data.to_csv('./data/processed/cleaned_data.xlsx', index=False, encoding='utf-8-sig')

# %%
# ===== Enhanced Coherence Calculation Function (Supports Multiple Metrics Including NPMI) =====
def calculate_multiple_coherence_metrics(mdl, corpus_docs, metrics=['c_v', 'c_npmi'], fast_mode=True, top_n=5):
    """
    Enhanced coherence calculation function - supports multiple coherence metrics including NPMI
    
    Supported coherence metrics:
    - c_v: Vector space-based coherence (default)
    - c_npmi: Normalized Pointwise Mutual Information (NPMI)
    
    Supported model types:
    - Single-layer models: LDA, CTM
    - Hierarchical models: hLDA, PAM, hPAM
    - Non-parametric models: HDP
    
    Returns: dict containing various coherence metrics
    """
    try:
        docs = list(corpus_docs)
        dictionary = Dictionary(docs)
        
        # Check if it is a hierarchical model
        model_type_str = str(type(mdl))
        is_hierarchical = hasattr(mdl, 'depth') or 'HLDA' in model_type_str or 'PAM' in model_type_str
        
        if is_hierarchical:
            # Hierarchical model: calculate coherence by level, weighted average
            metrics_results = {metric: [] for metric in metrics}
            layer_weights = []
            
            try:
                for level in range(getattr(mdl, 'depth', 3)):
                    level_topics = []
                    level_doc_count = 0
                    
                    # Iterate through all nodes of this level
                    for k in range(getattr(mdl, 'k', 100)):
                        try:
                            topic_words = mdl.get_topic_words(k, top_n=top_n)
                            if topic_words:
                                words = [word for word, prob in topic_words]
                                level_topics.append(words)
                                level_doc_count += 1
                        except:
                            continue
                    
                    if level_topics:
                        # Calculate coherence for each metric
                        for metric in metrics:
                            try:
                                cm = CoherenceModel(
                                    topics=level_topics,
                                    texts=docs,
                                    dictionary=dictionary,
                                    coherence=metric,
                                    processes=1
                                )
                                score = cm.get_coherence()
                                if score and not math.isnan(score):
                                    metrics_results[metric].append(score)
                                else:
                                    metrics_results[metric].append(0.1)
                            except Exception as e:
                                print(f"Hierarchical model {metric} calculation warning: {e}")
                                metrics_results[metric].append(0.1)
                        
                        layer_weights.append(level_doc_count)
            except:
                pass
            
            # Calculate weighted average
            final_results = {}
            for metric in metrics:
                if metrics_results[metric] and layer_weights:
                    total_weight = sum(layer_weights)
                    if total_weight > 0:
                        weighted_avg = sum(score * w for score, w in zip(metrics_results[metric], layer_weights)) / total_weight
                        final_results[metric] = weighted_avg
                    else:
                        final_results[metric] = 0.1
                else:
                    final_results[metric] = 0.1
            
            return final_results
        
        # Single-layer model: calculate coherence for all topics
        num_topics = getattr(mdl, 'k', None) or getattr(mdl, 'num_topics', None) or 100
        topics = []
        
        for k in range(num_topics):
            try:
                topic_words = mdl.get_topic_words(k, top_n=top_n)
                if topic_words:
                    words = [word for word, prob in topic_words]
                    topics.append(words)
            except:
                continue
        
        if not topics:
            return {metric: 0.1 for metric in metrics}
        
        # Calculate coherence for each metric
        final_results = {}
        for metric in metrics:
            try:
                cm = CoherenceModel(
                    topics=topics,
                    texts=docs,
                    dictionary=dictionary,
                    coherence=metric,
                    processes=1
                )
                score = cm.get_coherence()
                final_results[metric] = score if score and not math.isnan(score) else 0.1
            except Exception as e:
                print(f"Single-layer model {metric} calculation warning: {e}")
                final_results[metric] = 0.1
        
        return final_results
        
    except Exception as e:
        print(f"Coherence calculation error: {e}")
        return {metric: 0.1 for metric in metrics}

# %%
def calculate_renyi_entropy_unweighted(model, alpha=2):
    """
    Calculate the Renyi entropy for all topics (unweighted version, direct average)
    - model: topic model object (e.g., tomotopy LDA/CTM/PAM/hLDA)
    - alpha: order of Renyi entropy (commonly 2)
    Returns: the average of Renyi entropies for all topics
    """
    # ...existing code...
    import numpy as np
    entropies = []
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    for k in range(num_topics):
        try:
            topic_probs = np.array([prob for word, prob in model.get_topic_words(k, top_n=-1)])
            topic_probs = topic_probs / topic_probs.sum()
            if len(topic_probs) > 0:
                renyi = (1/(1-alpha)) * np.log(np.sum(topic_probs**alpha))
                entropies.append(renyi)
            else:
                entropies.append(0)
        except:
            entropies.append(0)
    if entropies:
        return float(np.mean(entropies))
    else:
        return 0.0

# %%
# ===== 加权Renyi熵计算函数 (Weighted Renyi Entropy) =====
def get_topic_doc_counts(model, threshold=0.01):
    """
    获取每个主题覆盖的文档数（即每个主题出现在了多少个文档中）
    """
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    topic_doc_counts = [0] * num_topics
    for doc in model.docs:
        try:
            topic_dist = doc.get_topic_dist()
        except:
            continue
        for k, prob in enumerate(topic_dist):
            if prob > threshold:
                topic_doc_counts[k] += 1
    return topic_doc_counts

def calculate_weighted_renyi_entropy(model, alpha=2):
    """
    按主题覆盖的文档数加权的Renyi熵
    """
    entropies = []
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    for k in range(num_topics):
        try:
            topic_probs = np.array([prob for word, prob in model.get_topic_words(k, top_n=-1)])
            if topic_probs.sum() > 0:
                topic_probs = topic_probs / topic_probs.sum()
                renyi = (1/(1-alpha)) * np.log(np.sum(topic_probs**alpha))
                entropies.append(renyi)
            else:
                entropies.append(0)
        except:
            entropies.append(0)
    
    # 按主题的文档覆盖数进行加权
    topic_doc_counts = get_topic_doc_counts(model)
    total_docs_covered = sum(topic_doc_counts)
    
    if total_docs_covered > 0 and len(entropies) == len(topic_doc_counts):
        return np.average(entropies, weights=topic_doc_counts)
    elif entropies:
        return np.mean(entropies) # 如果加权失败，则返回普通平均值
    else:
        return 0.0

# %%
from scipy.spatial.distance import jensenshannon
import numpy as np

def calculate_topic_diversity_jsd(model, top_n=25):
    """
    计算所有主题对之间的平均JSD（Jensen-Shannon Divergence），以衡量主题多样性。
    JSD值域为[0, 1]，值越高代表主题间差异越大，多样性越好。

    - model: 训练好的tomotopy模型。
    - top_n: 用于计算JSD的每个主题的top N个词。
    """
    try:
        num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
        if num_topics < 2:
            return 0.0

        # 1. 收集所有主题的top N词和概率，并建立一个共享词汇表
        topic_word_probs = []
        vocab = set()
        for k in range(num_topics):
            try:
                words = model.get_topic_words(k, top_n=top_n)
                if not words: continue
                topic_word_probs.append(dict(words))
                vocab.update([word for word, prob in words])
            except:
                continue
        
        if len(topic_word_probs) < 2:
            return 0.0

        vocab_list = sorted(list(vocab))
        vocab_map = {word: i for i, word in enumerate(vocab_list)}
        
        # 2. 将每个主题的词分布转换为对齐的概率向量
        aligned_probs = []
        for topic_dict in topic_word_probs:
            prob_vector = np.zeros(len(vocab_list))
            for word, prob in topic_dict.items():
                if word in vocab_map:
                    prob_vector[vocab_map[word]] = prob
            
            # 归一化，使其成为有效的概率分布
            if prob_vector.sum() > 1e-9:
                prob_vector /= prob_vector.sum()
            else:
                continue # 跳过无效的空主题
            aligned_probs.append(prob_vector)

        if len(aligned_probs) < 2:
            return 0.0

        # 3. 计算所有主题对之间的JSD
        jsd_values = []
        for i in range(len(aligned_probs)):
            for j in range(i + 1, len(aligned_probs)):
                p = aligned_probs[i]
                q = aligned_probs[j]
                jsd = jensenshannon(p, q, base=2)
                if not np.isnan(jsd):
                    jsd_values.append(jsd**2) # JSD距离通常使用JSD值的平方

        if not jsd_values:
            return 0.0
        
        return float(np.mean(jsd_values))

    except Exception as e:
        # print(f"Error calculating JSD: {e}")
        return 0.0

# %%
# ===== General Topic Analysis Function =====
def analyze_model_topics(model, model_name="Model", top_words=5, min_prob=0.01, max_display=10):
    """
    General topic analysis function - applicable to all topic models
    
    Functionality:
    - Extracts active topics
    - Displays topic words and weights
    - Calculates topic activity rate
    """
    print(f"\n🔍 {model_name} Topic Analysis (showing top {top_words} words):")
    print("=" * 80)
    
    active_topics = 0
    topic_info = []
    
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    
    for k in range(num_topics):
        try:
            topic_words = model.get_topic_words(k, top_n=top_words)
            if topic_words and topic_words[0][1] > min_prob:
                active_topics += 1
                words_str = ", ".join([f"{word}({prob:.3f})" for word, prob in topic_words[:5]])
                topic_info.append((k, topic_words[0][1], words_str))
                
                if active_topics <= max_display:
                    print(f"Topic {k:3d} (weight:{topic_words[0][1]:.3f}): {words_str}")
        except:
            continue
    
    if active_topics > max_display:
        print(f"... (and {active_topics - max_display} more active topics)")
    
    print(f"\n📊 {model_name} Topic Statistics:")
    print(f"   - Active topics: {active_topics}/{num_topics}")
    print(f"   - Topic activity rate: {active_topics/num_topics*100:.1f}%")
    
    return topic_info

# %%
def calculate_r_hat(chains_history):
    """
    根据多个MCMC链的后半部分历史记录计算R-hat（Gelman-Rubin诊断）值。
    
    参数:
    - chains_history (np.ndarray): 一个2D numpy数组，形状为 (M, N)，
      其中 M 是链的数量（运行次数），N 是每个链记录的迭代次数。
      数组中的值是对数似然（log-likelihood）。

    返回:
    - float: R-hat值。如果无法计算，则返回 np.nan。
    """
    # 仅使用后半部分的样本进行计算，这是标准做法
    num_iterations = chains_history.shape[1]
    start_index = num_iterations // 2
    
    if chains_history.shape[0] < 2 or (num_iterations - start_index) < 2:
        return np.nan

    chains_history = chains_history[:, start_index:]
    num_chains, num_used_iterations = chains_history.shape
    
    # 1. 计算每个链的均值
    chain_means = np.mean(chains_history, axis=1)
    
    # 2. 计算每个链的方差
    chain_variances = np.var(chains_history, axis=1, ddof=1)
    
    # 3. 计算链内方差的均值 (W)
    W = np.mean(chain_variances)
    
    # 4. 计算链间方差 (B)
    overall_mean = np.mean(chain_means)
    B = num_used_iterations / (num_chains - 1) * np.sum((chain_means - overall_mean)**2)
    
    # 5. 估计目标分布的方差 (Var_hat)
    var_hat = (1 - 1 / num_used_iterations) * W + (1 / num_used_iterations) * B
    
    if W == 0:
        return np.nan
        
    # 6. 计算R-hat
    r_hat = np.sqrt(var_hat / W)
    
    return r_hat

# %%
def calculate_weighted_coherence(model, corpus_docs, metrics=['c_v', 'c_npmi'], top_n=10, threshold=0.01):
    """
    计算按主题的文档覆盖率加权的 coherence 分数 (NPMI, C_v)。
    
    Args:
        model: 训练好的 tomotopy 模型。
        corpus_docs: 用于计算 coherence 的原始文档列表。
        metrics: 要计算的指标列表。
        top_n: 用于定义主题的 top N 个词。
        threshold: 判断一个主题在文档中是否“显著”的概率阈值。

    Returns:
        一个包含加权和未加权 coherence 分数的字典。
    """
    try:
        docs = list(corpus_docs)
        dictionary = Dictionary(docs)
        num_topics = getattr(model, 'k', 0) or getattr(model, 'num_topics', 0)
        
        if num_topics == 0:
            return {}

        # 1. 提取所有主题的 top words
        topics = []
        for k in range(num_topics):
            topic_words = [word for word, prob in model.get_topic_words(k, top_n=top_n)]
            if topic_words:
                topics.append(topic_words)
        
        if not topics:
            return {}

        # 2. 获取每个主题的权重 (文档覆盖数)
        topic_doc_counts = np.zeros(num_topics)
        for doc in model.docs:
            topic_dist = doc.get_topic_dist()
            for k, prob in enumerate(topic_dist):
                if prob > threshold:
                    topic_doc_counts[k] += 1
        
        total_docs_covered = np.sum(topic_doc_counts)
        
        results = {}
        for metric in metrics:
            cm = CoherenceModel(
                topics=topics,
                texts=docs,
                dictionary=dictionary,
                coherence=metric,
                processes=1
            )
            
            # 获取每个主题的分数
            per_topic_scores = cm.get_coherence_per_topic()
            
            # 计算简单平均值 (未加权)
            unweighted_avg = np.mean(per_topic_scores)
            results[f'unweighted_{metric}'] = unweighted_avg
            
            # 计算加权平均值
            if total_docs_covered > 0:
                weighted_avg = np.average(per_topic_scores, weights=topic_doc_counts)
                results[f'weighted_{metric}'] = weighted_avg
            else:
                results[f'weighted_{metric}'] = unweighted_avg # 如果没有权重，则退回到简单平均

        return results

    except Exception as e:
        print(f"计算加权Coherence时出错: {e}")
        return {}

# --- 如何使用 ---
# 假设 best_lda_model 是你训练好的模型
# weighted_scores = calculate_weighted_coherence(best_lda_model, abstract_list)
# print(weighted_scores)
# 输出可能像这样:
# {'unweighted_c_v': 0.45, 'weighted_c_v': 0.48, 'unweighted_c_npmi': 0.05, 'weighted_c_npmi': 0.06}

# %%
def evaluate_pam_sub_topics(model, corpus_docs, top_n=10):
    """
    修复并优化的PAM子主题评估函数。
    它通过分析所有文档的子主题分布来推断子主题词汇，而不是调用不存在的方法。
    """
    if not isinstance(model, tp.PAModel):
        print("❌错误: 此函数仅适用于 tomotopy.PAModel。")
        return {}

    # print(f"\n🔬 开始评估 {model.k2} 个子主题 (修复版)...")
    
    sub_topics = []
    sub_topic_word_probs = [] # 用于计算Renyi和JSD

    try:
        # 1. 为每个子主题初始化一个词汇计数器
        sub_topic_word_counts = [defaultdict(float) for _ in range(model.k2)]
        
        # 2. 遍历所有文档，根据子主题分布累加词汇权重
        num_valid_docs = 0
        for doc_idx, doc in enumerate(model.docs):
            if hasattr(doc, 'get_sub_topic_dist'):
                sub_dist = doc.get_sub_topic_dist()
                if sum(sub_dist) < 0.1: continue # 跳过无效分布的文档
                
                num_valid_docs += 1
                original_doc_words = corpus_docs[doc_idx]
                
                for k in range(model.k2):
                    weight = sub_dist[k]
                    if weight > 0.01: # 只考虑有一定权重的
                        for word in original_doc_words:
                            sub_topic_word_counts[k][word] += weight
        
        # print(f"   分析了 {num_valid_docs} 个文档的子主题分布。")

        # 3. 从累加的权重中提取每个子主题的 Top N 词汇
        for k in range(model.k2):
            if not sub_topic_word_counts[k]:
                continue

            # 归一化得到概率分布，用于计算Renyi和JSD
            total_weight = sum(sub_topic_word_counts[k].values())
            if total_weight > 0:
                word_probs = {word: count / total_weight for word, count in sub_topic_word_counts[k].items()}
                sub_topic_word_probs.append(word_probs)

            # 提取top N词用于计算Coherence
            sorted_words = sorted(sub_topic_word_counts[k].items(), key=lambda item: item[1], reverse=True)
            top_words = [word for word, weight in sorted_words[:top_n]]
            
            if len(top_words) >= 2: # 至少需要2个词才能计算coherence
                sub_topics.append(top_words)

    except Exception as e:
        # print(f"   ❌ 推断子主题时发生严重错误: {e}")
        pass

    # --- 后续计算部分 ---
    if not sub_topics:
        # print("❌ 未能提取任何有效子主题！")
        return {
            'sub_topics_npmi': 0.0, 'sub_topics_c_v': 0.0, 
            'sub_topics_renyi_entropy': 0.0, 'sub_topics_jsd_diversity': 0.0
        }
    
    results = {}
    # 1. 计算Coherence
    try:
        dictionary = Dictionary(corpus_docs)
        cm_npmi = CoherenceModel(topics=sub_topics, texts=corpus_docs, dictionary=dictionary, coherence='c_npmi', processes=1)
        npmi_score = cm_npmi.get_coherence()
        results['sub_topics_npmi'] = npmi_score if not np.isnan(npmi_score) else 0.0
        
        cm_cv = CoherenceModel(topics=sub_topics, texts=corpus_docs, dictionary=dictionary, coherence='c_v', processes=1)
        cv_score = cm_cv.get_coherence()
        results['sub_topics_c_v'] = cv_score if not np.isnan(cv_score) else 0.0
    except Exception:
        results['sub_topics_npmi'] = 0.0
        results['sub_topics_c_v'] = 0.0

    # 2. 计算Renyi熵和JSD多样性
    try:
        # 模拟一个模型对象，使其能被现有函数使用
        class SubTopicProvider:
            def __init__(self, inferred_topics):
                self.inferred_topics = inferred_topics
                self.k = len(inferred_topics)
            def get_topic_words(self, k, top_n=-1):
                # 将字典转换为 (word, prob) 格式
                topic_dist = self.inferred_topics[k]
                sorted_words = sorted(topic_dist.items(), key=lambda item: item[1], reverse=True)
                if top_n == -1:
                    return sorted_words
                return sorted_words[:top_n]

        if sub_topic_word_probs:
            sub_topic_provider = SubTopicProvider(sub_topic_word_probs)
            # Renyi熵 (这里用父主题的函数，因为它只依赖get_topic_words)
            # 注意：calculate_weighted_renyi_entropy无法使用，因为它依赖doc.get_topic_dist()
            # 我们用一个简化的非加权版本
            entropies = []
            for k in range(sub_topic_provider.k):
                topic_probs = np.array([prob for word, prob in sub_topic_provider.get_topic_words(k, top_n=-1)])
                if len(topic_probs) > 0:
                    renyi = (1/(1-2)) * np.log(np.sum(topic_probs**2))
                    entropies.append(renyi)
            results['sub_topics_renyi_entropy'] = np.mean(entropies) if entropies else 0.0
            
            # JSD多样性
            results['sub_topics_jsd_diversity'] = calculate_topic_diversity_jsd(sub_topic_provider, top_n=25)
        else:
            results['sub_topics_renyi_entropy'] = 0.0
            results['sub_topics_jsd_diversity'] = 0.0
    except Exception:
        results['sub_topics_renyi_entropy'] = 0.0
        results['sub_topics_jsd_diversity'] = 0.0

    return results

# %%
def tune_pam_model(
    docs, 
    k_combinations, 
    alpha_range, 
    sub_alpha_range,
    eta_range, 
    num_runs=3, 
    seed=42, 
    max_iters=1000,
    burn_in=100,
    convergence_patience=5,
    convergence_tolerance=1e-2,
    parent_top_n=10,  # <--- 新增：父主题的 top_n
    sub_top_n=5      # <--- 新增：子主题的 top_n
):
    """
    对PAM模型执行全面的网格搜索（最终版）。

    - 遍历所有 k1, k2, alpha, sub_alpha, eta 的组合。
    - 包含一个独立的 burn-in 阶段。
    - 使用对数似然（LL）的变化判断收敛。
    - 为每个组合运行多次以获得稳健的结果。
    - 收集父主题和子主题的详细指标：LL/word, PPL, Coherence, Renyi熵, JSD多样性。
    """
    all_run_results = []
    best_single_run_npmi = -1
    best_params = {}
    best_model = None

    param_grid = list(itertools.product(k_combinations, alpha_range, sub_alpha_range, eta_range))
    total_combinations = len(param_grid)
    
    print(f"🚀 开始 PAM 模型全面网格搜索，共 {total_combinations} 种组合，每种运行 {num_runs} 次...")
    print(f"   (收敛判断: LL 在 {convergence_patience} 次连续检查中的波动 < {convergence_tolerance})")

    for i, (k_list, alpha, subalpha_val, eta) in enumerate(param_grid, 1):
        if len(k_list) != 2:
            print(f"\n--- 跳过组合 {i}/{total_combinations}: K={k_list} 不是有效的PAM模型两层结构。 ---")
            continue
        
        k1, k2 = k_list[0], k_list[1]
        print(f"\n--- 组合 {i}/{total_combinations}: 测试 K1={k1}, K2={k2}, Alpha={alpha}, Subalpha={subalpha_val}, Eta={eta} ---")
        
        for run_idx in range(num_runs):
            start_time = time.time()
            current_seed = seed + run_idx
            print(f"  - 运行 {run_idx + 1}/{num_runs} (seed={current_seed})...")
            
            try:
                model = tp.PAModel(k1=k1, k2=k2, alpha=alpha, subalpha=subalpha_val, eta=eta, seed=current_seed)
                for doc in docs:
                    model.add_doc(doc)
                
                if burn_in > 0:
                    model.train(burn_in)

                ll_history = []
                converged = False
                final_iter = max_iters
                for step in range(0, max_iters, 10):
                    model.train(10, 1)
                    ll_history.append(model.ll_per_word)
                    if len(ll_history) > convergence_patience:
                        recent_ll = ll_history[-convergence_patience:]
                        if (np.max(recent_ll) - np.min(recent_ll)) < convergence_tolerance:
                            final_iter = step + 10
                            converged = True
                            break
                if not converged: final_iter = max_iters

                # --- 评估指标 ---
                ll_per_word = model.ll_per_word
                perplexity = math.exp(-ll_per_word) if ll_per_word is not None else float('inf')
                
                # [修改] 使用 parent_top_n
                parent_coherence = calculate_weighted_coherence(model, docs, metrics=['c_v', 'c_npmi'], top_n=parent_top_n)
                parent_renyi = calculate_weighted_renyi_entropy(model)
                parent_jsd = calculate_topic_diversity_jsd(model)
                
                # [修改] 使用 sub_top_n
                sub_topic_metrics = evaluate_pam_sub_topics(model, docs, top_n=sub_top_n)

                w_npmi = parent_coherence.get('weighted_c_npmi', 0)
                converged_str = "Yes" if converged else "No"
                print(f"    => 结果: LL/word={ll_per_word:.4f}, PPL={perplexity:.2f}, Parent_W_NPMI={w_npmi:.4f}, Sub_NPMI={sub_topic_metrics.get('sub_topics_npmi', 0):.4f}, Converged={converged_str}")

                run_result = {
                    'K1': k1, 'K2': k2, 'Alpha': alpha, 'Subalpha': subalpha_val, 'Eta': eta,
                    'Run_Index': run_idx + 1,
                    'LL_per_word': ll_per_word,
                    'Perplexity': perplexity,
                    
                    'Parent_Weighted_NPMI': parent_coherence.get('weighted_c_npmi', 0),
                    'Parent_Weighted_Cv': parent_coherence.get('weighted_c_v', 0),
                    'Parent_Unweighted_NPMI': parent_coherence.get('unweighted_c_npmi', 0),
                    'Parent_Unweighted_Cv': parent_coherence.get('unweighted_c_v', 0),
                    'Parent_Renyi_Entropy': parent_renyi,
                    'Parent_JSD_Diversity': parent_jsd,

                    'Sub_NPMI': sub_topic_metrics.get('sub_topics_npmi', 0),
                    'Sub_Cv': sub_topic_metrics.get('sub_topics_c_v', 0),
                    'Sub_Renyi_Entropy': sub_topic_metrics.get('sub_topics_renyi_entropy', 0),
                    'Sub_JSD_Diversity': sub_topic_metrics.get('sub_topics_jsd_diversity', 0),

                    'Iterations': final_iter + burn_in,
                    'Converged': converged_str,
                    'Time_sec': time.time() - start_time
                }
                all_run_results.append(run_result)
                
                if w_npmi > best_single_run_npmi:
                    best_single_run_npmi = w_npmi
                    best_params = {'K': k_list, 'Alpha': alpha, 'Subalpha': subalpha_val, 'Eta': eta}
                    best_model = model

            except Exception as e:
                print(f"    ❌ 运行 {run_idx + 1} 失败: {e}")

    results_df = pd.DataFrame(all_run_results)
    print("\n\n✅ PAM 全面网格搜索完成!")
    
    if best_params:
        print(f"\n🏆 所有运行中 Parent_Weighted_NPMI 最高的一次参数: K={best_params.get('K')}, Alpha={best_params.get('Alpha')}, Subalpha={best_params.get('Subalpha')}, Eta={best_params.get('Eta')} (NPMI: {best_single_run_npmi:.4f})")
    else:
        print("\n❌ 未能成功完成任何运行。")

    return results_df, best_model, best_params

# %%
print("\n🎯 开始为 PAM 模型进行全面网格搜索...")
print("=" * 60)

# 1. 定义需要测试的超参数范围
k_combinations_to_test = [
    [10,60],
    [10,80],
]
alpha_range_to_test = [0.1, 0.5, 1]
sub_alpha_range_to_test = [0.1, 0.5,1]
eta_range_to_test = [0.01, 0.1, 1]

# [新增] 定义父主题和子主题的 top_n
PARENT_TOP_N = 10
SUB_TOP_N = 5

# 2. 确保您的预处理文档已准备就绪
pam_docs = abstract_list

# 3. 运行网格搜索函数
pam_results_df, best_pam_model, best_pam_params = tune_pam_model(
    docs=pam_docs,
    k_combinations=k_combinations_to_test,
    alpha_range=alpha_range_to_test,
    sub_alpha_range=sub_alpha_range_to_test,
    eta_range=eta_range_to_test,
    num_runs=5, # 为了演示，减少运行次数
    max_iters=1000, # 为了演示，减少迭代次数
    burn_in=200,
    parent_top_n=PARENT_TOP_N, # <--- 传入父主题 top_n
    sub_top_n=SUB_TOP_N       # <--- 传入子主题 top_n
)

# 4. 打印找到的最佳模型信息
print("\n\n🎉 PAM 网格搜索完成！")
if best_pam_params:
    print(f"🏆 找到的最佳超参数 (基于全局单次运行最高 Parent_Weighted_NPMI): "
          f"K={best_pam_params.get('K')}, "
          f"Alpha={best_pam_params.get('Alpha')}, "
          f"Subalpha={best_pam_params.get('Subalpha')}, "
          f"Eta={best_pam_params.get('Eta')}")
    
    # 分别分析父主题和子主题
    print("\n🔍 对最佳PAM模型的【父主题】进行分析:")
    analyze_model_topics(best_pam_model, model_name="Best PAM (Super-Topics)", top_words=PARENT_TOP_N)
    
    print("\n🔬 对最佳PAM模型的【子主题】进行评估:")
    # [修改] 在最终评估时也使用 SUB_TOP_N 保持一致
    evaluate_pam_sub_topics(best_pam_model, pam_docs, top_n=SUB_TOP_N)

else:
    print("❌ 未能找到最佳模型。")

# 5. 显示并保存详细的、每一次运行的调优结果表格
if pam_results_df is not None and not pam_results_df.empty:
    print("\n--- PAM 最终全部运行调优结果 ---")
    # 调整列顺序以获得更好的可读性
    cols = [
        'K1', 'K2', 'Alpha', 'Subalpha', 'Eta', 'Run_Index',
        'Parent_Weighted_NPMI', 'Sub_NPMI', 'Perplexity',
        'Parent_Weighted_Cv', 'Sub_Cv',
        'Parent_Renyi_Entropy', 'Sub_Renyi_Entropy',
        'Parent_JSD_Diversity', 'Sub_JSD_Diversity',
        'LL_per_word', 'Converged', 'Iterations', 'Time_sec'
    ]
    display_df = pam_results_df.reindex(columns=[c for c in cols if c in pam_results_df.columns])
    print(display_df.to_string())
    
    # 保存结果
    output_path = './data/model_result/pam_full_grid_search_results.csv'
    pam_results_df.to_csv(output_path, index=False, encoding='utf-8-sig')
    print(f"\n✅ 结果已保存到: {output_path}")
# Out:
# 🎯 开始为 PAM 模型进行全面网格搜索...
# ============================================================
# 🚀 开始 PAM 模型全面网格搜索，共 54 种组合，每种运行 5 次...
#    (收敛判断: LL 在 5 次连续检查中的波动 < 0.01)
#
# --- 组合 1/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
# /tmp/ipykernel_1719/1911189480.py:55: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   model.train(burn_in)
#     => 结果: LL/word=-8.5325, PPL=5076.99, Parent_W_NPMI=0.0926, Sub_NPMI=0.0243, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.2832, PPL=3956.74, Parent_W_NPMI=0.0364, Sub_NPMI=0.0240, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.4084, PPL=4484.52, Parent_W_NPMI=0.0117, Sub_NPMI=0.0208, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.3613, PPL=4278.45, Parent_W_NPMI=0.0321, Sub_NPMI=0.0235, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4778, PPL=4806.79, Parent_W_NPMI=0.0604, Sub_NPMI=0.0241, Converged=Yes
#
# --- 组合 2/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.4503, PPL=12712.18, Parent_W_NPMI=0.0361, Sub_NPMI=0.0275, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3992, PPL=12078.51, Parent_W_NPMI=0.0633, Sub_NPMI=0.0295, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3292, PPL=11262.21, Parent_W_NPMI=0.0682, Sub_NPMI=0.0353, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3379, PPL=11360.62, Parent_W_NPMI=0.0498, Sub_NPMI=0.0304, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4054, PPL=12153.32, Parent_W_NPMI=0.1016, Sub_NPMI=0.0432, Converged=Yes
#
# --- 组合 3/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.1214, PPL=9149.44, Parent_W_NPMI=-0.4304, Sub_NPMI=0.0366, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0135, PPL=8213.24, Parent_W_NPMI=-0.3762, Sub_NPMI=0.0328, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0233, PPL=8293.94, Parent_W_NPMI=-0.2568, Sub_NPMI=0.0395, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1224, PPL=9157.82, Parent_W_NPMI=-0.4455, Sub_NPMI=0.0317, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0512, PPL=8529.00, Parent_W_NPMI=-0.4653, Sub_NPMI=0.0483, Converged=Yes
#
# --- 组合 4/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.3689, PPL=4310.92, Parent_W_NPMI=0.0506, Sub_NPMI=0.0180, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.2995, PPL=4022.00, Parent_W_NPMI=0.0256, Sub_NPMI=0.0188, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.5797, PPL=5322.55, Parent_W_NPMI=0.0510, Sub_NPMI=0.0215, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.2835, PPL=3958.21, Parent_W_NPMI=-0.0079, Sub_NPMI=0.0245, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.2552, PPL=3847.61, Parent_W_NPMI=0.0807, Sub_NPMI=0.0188, Converged=No
#
# --- 组合 5/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3304, PPL=11275.90, Parent_W_NPMI=0.0393, Sub_NPMI=0.0383, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4817, PPL=13118.06, Parent_W_NPMI=0.0458, Sub_NPMI=0.0291, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5119, PPL=13520.09, Parent_W_NPMI=0.0699, Sub_NPMI=0.0292, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3567, PPL=11576.27, Parent_W_NPMI=0.0321, Sub_NPMI=0.0346, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4853, PPL=13164.15, Parent_W_NPMI=0.0166, Sub_NPMI=0.0363, Converged=Yes
#
# --- 组合 6/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7930, PPL=6587.89, Parent_W_NPMI=-0.2665, Sub_NPMI=0.0707, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9311, PPL=7563.58, Parent_W_NPMI=-0.3641, Sub_NPMI=0.0505, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.7356, PPL=6220.52, Parent_W_NPMI=-0.4625, Sub_NPMI=0.0409, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9344, PPL=7588.83, Parent_W_NPMI=-0.4440, Sub_NPMI=0.0381, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.5433, PPL=5132.18, Parent_W_NPMI=-0.3518, Sub_NPMI=0.0660, Converged=No
#
# --- 组合 7/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4687, PPL=4763.48, Parent_W_NPMI=0.0137, Sub_NPMI=0.0182, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.3557, PPL=4254.33, Parent_W_NPMI=0.1034, Sub_NPMI=0.0317, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.6019, PPL=5441.73, Parent_W_NPMI=0.0449, Sub_NPMI=0.0138, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.3072, PPL=4053.11, Parent_W_NPMI=0.0187, Sub_NPMI=0.0260, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.3350, PPL=4167.32, Parent_W_NPMI=0.0492, Sub_NPMI=0.0271, Converged=Yes
#
# --- 组合 8/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.4423, PPL=12610.98, Parent_W_NPMI=0.0293, Sub_NPMI=0.0258, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4700, PPL=12964.63, Parent_W_NPMI=0.0331, Sub_NPMI=0.0310, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3694, PPL=11723.97, Parent_W_NPMI=0.0541, Sub_NPMI=0.0410, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4852, PPL=13163.53, Parent_W_NPMI=0.0757, Sub_NPMI=0.0269, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4729, PPL=13002.28, Parent_W_NPMI=0.0739, Sub_NPMI=0.0355, Converged=Yes
#
# --- 组合 9/54: 测试 K1=10, K2=60, Alpha=0.1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.8317, PPL=6848.00, Parent_W_NPMI=-0.3190, Sub_NPMI=0.0633, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.7010, PPL=6009.04, Parent_W_NPMI=-0.4638, Sub_NPMI=0.0259, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.5026, PPL=4927.71, Parent_W_NPMI=-0.2969, Sub_NPMI=0.0367, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.3730, PPL=4328.64, Parent_W_NPMI=-0.2919, Sub_NPMI=0.0441, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.5542, PPL=5188.37, Parent_W_NPMI=-0.3281, Sub_NPMI=0.0291, Converged=Yes
#
# --- 组合 10/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.0984, PPL=8940.96, Parent_W_NPMI=0.0404, Sub_NPMI=0.0217, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0610, PPL=8613.11, Parent_W_NPMI=0.0774, Sub_NPMI=0.0259, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3472, PPL=11466.24, Parent_W_NPMI=0.0565, Sub_NPMI=0.0243, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0752, PPL=8735.91, Parent_W_NPMI=0.0598, Sub_NPMI=0.0204, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0015, PPL=8114.92, Parent_W_NPMI=0.0341, Sub_NPMI=0.0188, Converged=Yes
#
# --- 组合 11/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0409, PPL=22945.29, Parent_W_NPMI=0.0539, Sub_NPMI=0.0327, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.2162, PPL=27342.97, Parent_W_NPMI=0.0515, Sub_NPMI=0.0328, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9626, PPL=21217.70, Parent_W_NPMI=0.0097, Sub_NPMI=0.0319, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.1720, PPL=26160.76, Parent_W_NPMI=0.0672, Sub_NPMI=0.0263, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9121, PPL=20172.93, Parent_W_NPMI=0.0278, Sub_NPMI=0.0316, Converged=No
#
# --- 组合 12/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2310, PPL=10208.41, Parent_W_NPMI=-0.3202, Sub_NPMI=0.0568, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.1231, PPL=9164.62, Parent_W_NPMI=-0.2659, Sub_NPMI=0.0495, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4537, PPL=12755.05, Parent_W_NPMI=-0.3371, Sub_NPMI=0.0585, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3891, PPL=11957.07, Parent_W_NPMI=-0.2662, Sub_NPMI=0.0337, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.6521, PPL=15554.55, Parent_W_NPMI=-0.0896, Sub_NPMI=0.0611, Converged=Yes
#
# --- 组合 13/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.9033, PPL=7356.41, Parent_W_NPMI=0.0511, Sub_NPMI=0.0155, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9960, PPL=8070.57, Parent_W_NPMI=0.0567, Sub_NPMI=0.0198, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0113, PPL=8195.55, Parent_W_NPMI=0.0198, Sub_NPMI=0.0296, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0814, PPL=8790.59, Parent_W_NPMI=0.0344, Sub_NPMI=0.0188, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2481, PPL=10384.37, Parent_W_NPMI=0.0374, Sub_NPMI=0.0148, Converged=Yes
#
# --- 组合 14/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0121, PPL=22295.52, Parent_W_NPMI=0.0478, Sub_NPMI=0.0275, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9679, PPL=21331.23, Parent_W_NPMI=0.0658, Sub_NPMI=0.0254, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.0571, PPL=23320.15, Parent_W_NPMI=0.0276, Sub_NPMI=0.0252, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9050, PPL=20030.14, Parent_W_NPMI=0.1038, Sub_NPMI=0.0322, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.0469, PPL=23083.62, Parent_W_NPMI=0.0488, Sub_NPMI=0.0271, Converged=Yes
#
# --- 组合 15/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.0361, PPL=8401.04, Parent_W_NPMI=-0.3207, Sub_NPMI=0.0404, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9232, PPL=7503.79, Parent_W_NPMI=-0.3387, Sub_NPMI=0.0416, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3048, PPL=10990.76, Parent_W_NPMI=-0.2429, Sub_NPMI=0.0568, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0899, PPL=8864.98, Parent_W_NPMI=-0.3411, Sub_NPMI=0.0388, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1851, PPL=9750.61, Parent_W_NPMI=-0.3886, Sub_NPMI=0.0332, Converged=Yes
#
# --- 组合 16/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3560, PPL=11567.99, Parent_W_NPMI=0.0389, Sub_NPMI=0.0183, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8539, PPL=7001.48, Parent_W_NPMI=0.0660, Sub_NPMI=0.0222, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0283, PPL=8335.92, Parent_W_NPMI=0.0614, Sub_NPMI=0.0211, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1558, PPL=9469.39, Parent_W_NPMI=0.0674, Sub_NPMI=0.0221, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9564, PPL=7757.55, Parent_W_NPMI=0.0502, Sub_NPMI=0.0284, Converged=No
#
# --- 组合 17/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.9769, PPL=21524.29, Parent_W_NPMI=0.0475, Sub_NPMI=0.0250, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0679, PPL=23573.88, Parent_W_NPMI=0.0793, Sub_NPMI=0.0311, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.0910, PPL=24124.74, Parent_W_NPMI=0.0332, Sub_NPMI=0.0261, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.1889, PPL=26605.56, Parent_W_NPMI=0.0603, Sub_NPMI=0.0245, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.0723, PPL=23677.00, Parent_W_NPMI=0.0275, Sub_NPMI=0.0337, Converged=Yes
#
# --- 组合 18/54: 测试 K1=10, K2=60, Alpha=0.5, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7938, PPL=6593.02, Parent_W_NPMI=-0.3053, Sub_NPMI=0.0536, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8686, PPL=7105.44, Parent_W_NPMI=-0.4022, Sub_NPMI=0.0334, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.6320, PPL=5608.33, Parent_W_NPMI=-0.4338, Sub_NPMI=0.0497, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.6325, PPL=5611.20, Parent_W_NPMI=-0.3124, Sub_NPMI=0.0426, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.8245, PPL=6798.82, Parent_W_NPMI=-0.2424, Sub_NPMI=0.0382, Converged=Yes
#
# --- 组合 19/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3531, PPL=11534.35, Parent_W_NPMI=0.0329, Sub_NPMI=0.0230, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2432, PPL=10333.67, Parent_W_NPMI=-0.0135, Sub_NPMI=0.0275, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.2552, PPL=10459.20, Parent_W_NPMI=0.0828, Sub_NPMI=0.0287, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1933, PPL=9831.09, Parent_W_NPMI=0.0326, Sub_NPMI=0.0246, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3059, PPL=11002.35, Parent_W_NPMI=0.0805, Sub_NPMI=0.0233, Converged=Yes
#
# --- 组合 20/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.7164, PPL=16588.25, Parent_W_NPMI=0.0371, Sub_NPMI=0.0382, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.3722, PPL=31958.00, Parent_W_NPMI=0.0298, Sub_NPMI=0.0198, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8764, PPL=19464.81, Parent_W_NPMI=0.0521, Sub_NPMI=0.0336, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.3734, PPL=31998.62, Parent_W_NPMI=0.0920, Sub_NPMI=0.0216, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.8821, PPL=19577.08, Parent_W_NPMI=0.0547, Sub_NPMI=0.0380, Converged=Yes
#
# --- 组合 21/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.8146, PPL=18298.25, Parent_W_NPMI=-0.3947, Sub_NPMI=0.0269, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4352, PPL=12521.73, Parent_W_NPMI=-0.4358, Sub_NPMI=0.0177, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.6211, PPL=15079.49, Parent_W_NPMI=-0.3194, Sub_NPMI=0.0294, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.2209, PPL=10106.52, Parent_W_NPMI=-0.3943, Sub_NPMI=0.0118, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.7501, PPL=17156.12, Parent_W_NPMI=-0.2721, Sub_NPMI=0.0415, Converged=Yes
#
# --- 组合 22/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2322, PPL=10220.63, Parent_W_NPMI=0.0619, Sub_NPMI=0.0222, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.1442, PPL=9359.99, Parent_W_NPMI=0.0291, Sub_NPMI=0.0292, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0703, PPL=8692.90, Parent_W_NPMI=0.0605, Sub_NPMI=0.0229, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4493, PPL=12699.26, Parent_W_NPMI=0.0553, Sub_NPMI=0.0196, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1874, PPL=9773.00, Parent_W_NPMI=0.0186, Sub_NPMI=0.0218, Converged=No
#
# --- 组合 23/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.8134, PPL=18276.37, Parent_W_NPMI=0.0316, Sub_NPMI=0.0349, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9013, PPL=19955.44, Parent_W_NPMI=0.0498, Sub_NPMI=0.0329, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9332, PPL=20602.52, Parent_W_NPMI=0.0934, Sub_NPMI=0.0316, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.7230, PPL=16697.20, Parent_W_NPMI=0.0359, Sub_NPMI=0.0397, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9734, PPL=21448.93, Parent_W_NPMI=0.0542, Sub_NPMI=0.0350, Converged=No
#
# --- 组合 24/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2742, PPL=10658.91, Parent_W_NPMI=-0.3395, Sub_NPMI=0.0317, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.1609, PPL=9517.46, Parent_W_NPMI=-0.2946, Sub_NPMI=0.0390, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0322, PPL=8368.23, Parent_W_NPMI=-0.3462, Sub_NPMI=0.0449, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0971, PPL=8929.09, Parent_W_NPMI=-0.3073, Sub_NPMI=0.0353, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1253, PPL=9185.08, Parent_W_NPMI=-0.2800, Sub_NPMI=0.0321, Converged=Yes
#
# --- 组合 25/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2992, PPL=10928.87, Parent_W_NPMI=0.0296, Sub_NPMI=0.0168, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2027, PPL=9924.28, Parent_W_NPMI=0.0971, Sub_NPMI=0.0270, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.2947, PPL=10880.52, Parent_W_NPMI=0.0381, Sub_NPMI=0.0175, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3193, PPL=11151.48, Parent_W_NPMI=0.0318, Sub_NPMI=0.0281, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0372, PPL=8410.52, Parent_W_NPMI=0.0375, Sub_NPMI=0.0204, Converged=No
#
# --- 组合 26/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.6294, PPL=15205.62, Parent_W_NPMI=0.0464, Sub_NPMI=0.0252, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9018, PPL=19967.11, Parent_W_NPMI=0.0338, Sub_NPMI=0.0305, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9529, PPL=21013.82, Parent_W_NPMI=0.0492, Sub_NPMI=0.0338, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9553, PPL=21062.59, Parent_W_NPMI=0.0333, Sub_NPMI=0.0277, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.6596, PPL=15670.75, Parent_W_NPMI=0.0500, Sub_NPMI=0.0364, Converged=No
#
# --- 组合 27/54: 测试 K1=10, K2=60, Alpha=1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7888, PPL=6560.22, Parent_W_NPMI=-0.2306, Sub_NPMI=0.0662, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9384, PPL=7619.00, Parent_W_NPMI=-0.3064, Sub_NPMI=0.0442, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.7623, PPL=6388.85, Parent_W_NPMI=-0.3547, Sub_NPMI=0.0446, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.8040, PPL=6660.90, Parent_W_NPMI=-0.1527, Sub_NPMI=0.0330, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9808, PPL=7949.39, Parent_W_NPMI=-0.3113, Sub_NPMI=0.0258, Converged=Yes
#
# --- 组合 28/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.3834, PPL=4373.98, Parent_W_NPMI=0.0092, Sub_NPMI=0.0318, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8704, PPL=7117.87, Parent_W_NPMI=0.0247, Sub_NPMI=0.0239, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.6881, PPL=5932.02, Parent_W_NPMI=0.1069, Sub_NPMI=0.0293, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.4909, PPL=4870.42, Parent_W_NPMI=0.0330, Sub_NPMI=0.0256, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.7412, PPL=6255.23, Parent_W_NPMI=0.0335, Sub_NPMI=0.0266, Converged=Yes
#
# --- 组合 29/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.4393, PPL=12573.05, Parent_W_NPMI=0.0076, Sub_NPMI=0.0409, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4319, PPL=12479.71, Parent_W_NPMI=0.0234, Sub_NPMI=0.0359, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5095, PPL=13486.73, Parent_W_NPMI=0.0146, Sub_NPMI=0.0422, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5131, PPL=13536.12, Parent_W_NPMI=0.0074, Sub_NPMI=0.0435, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3950, PPL=12027.71, Parent_W_NPMI=0.0223, Sub_NPMI=0.0394, Converged=No
#
# --- 组合 30/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7337, PPL=6208.66, Parent_W_NPMI=-0.2659, Sub_NPMI=0.0367, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.1149, PPL=9089.58, Parent_W_NPMI=-0.3341, Sub_NPMI=0.0416, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0828, PPL=8802.35, Parent_W_NPMI=-0.3295, Sub_NPMI=0.0273, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9805, PPL=7946.59, Parent_W_NPMI=-0.4436, Sub_NPMI=0.0495, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.7852, PPL=6536.54, Parent_W_NPMI=-0.3238, Sub_NPMI=0.0306, Converged=No
#
# --- 组合 31/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.6186, PPL=5533.47, Parent_W_NPMI=0.0769, Sub_NPMI=0.0242, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.4367, PPL=4613.24, Parent_W_NPMI=0.0092, Sub_NPMI=0.0223, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.4530, PPL=4688.95, Parent_W_NPMI=0.0533, Sub_NPMI=0.0218, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.5665, PPL=5252.91, Parent_W_NPMI=0.0455, Sub_NPMI=0.0257, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.5954, PPL=5406.64, Parent_W_NPMI=0.0534, Sub_NPMI=0.0278, Converged=Yes
#
# --- 组合 32/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3078, PPL=11024.07, Parent_W_NPMI=0.0112, Sub_NPMI=0.0428, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4505, PPL=12714.92, Parent_W_NPMI=0.0463, Sub_NPMI=0.0424, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5542, PPL=14104.44, Parent_W_NPMI=0.0184, Sub_NPMI=0.0388, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3820, PPL=11872.42, Parent_W_NPMI=-0.0452, Sub_NPMI=0.0358, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.5147, PPL=13557.00, Parent_W_NPMI=0.0183, Sub_NPMI=0.0413, Converged=Yes
#
# --- 组合 33/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7432, PPL=6267.64, Parent_W_NPMI=-0.3848, Sub_NPMI=0.0405, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.7442, PPL=6273.91, Parent_W_NPMI=-0.4080, Sub_NPMI=0.0452, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.3544, PPL=4248.87, Parent_W_NPMI=-0.3475, Sub_NPMI=0.0353, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.5635, PPL=5236.75, Parent_W_NPMI=-0.4834, Sub_NPMI=0.0405, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4057, PPL=4472.57, Parent_W_NPMI=-0.3272, Sub_NPMI=0.0312, Converged=Yes
#
# --- 组合 34/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.5402, PPL=5116.62, Parent_W_NPMI=0.0241, Sub_NPMI=0.0266, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.5809, PPL=5328.79, Parent_W_NPMI=0.0919, Sub_NPMI=0.0297, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.3934, PPL=4417.92, Parent_W_NPMI=0.0427, Sub_NPMI=0.0195, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.5962, PPL=5410.89, Parent_W_NPMI=0.0321, Sub_NPMI=0.0248, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.3677, PPL=4305.66, Parent_W_NPMI=0.0556, Sub_NPMI=0.0163, Converged=No
#
# --- 组合 35/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.5205, PPL=13636.66, Parent_W_NPMI=0.0050, Sub_NPMI=0.0314, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3921, PPL=11993.60, Parent_W_NPMI=0.0285, Sub_NPMI=0.0403, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5270, PPL=13725.22, Parent_W_NPMI=0.0336, Sub_NPMI=0.0383, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5409, PPL=13917.55, Parent_W_NPMI=0.0450, Sub_NPMI=0.0358, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3348, PPL=11325.35, Parent_W_NPMI=0.0332, Sub_NPMI=0.0320, Converged=No
#
# --- 组合 36/54: 测试 K1=10, K2=80, Alpha=0.1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4066, PPL=4476.55, Parent_W_NPMI=-0.4249, Sub_NPMI=0.0437, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.1774, PPL=3559.75, Parent_W_NPMI=-0.3994, Sub_NPMI=0.0491, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.2760, PPL=3928.59, Parent_W_NPMI=-0.3052, Sub_NPMI=0.0617, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.2878, PPL=3975.05, Parent_W_NPMI=-0.2856, Sub_NPMI=0.0513, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.5433, PPL=5132.00, Parent_W_NPMI=-0.4121, Sub_NPMI=0.0315, Converged=Yes
#
# --- 组合 37/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.1253, PPL=9184.96, Parent_W_NPMI=0.0576, Sub_NPMI=0.0278, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3318, PPL=11291.05, Parent_W_NPMI=0.0318, Sub_NPMI=0.0254, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.2037, PPL=9933.59, Parent_W_NPMI=0.0131, Sub_NPMI=0.0289, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9427, PPL=7651.67, Parent_W_NPMI=0.0440, Sub_NPMI=0.0226, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0945, PPL=8906.03, Parent_W_NPMI=0.0248, Sub_NPMI=0.0216, Converged=Yes
#
# --- 组合 38/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0509, PPL=23176.28, Parent_W_NPMI=0.0951, Sub_NPMI=0.0305, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0560, PPL=23295.20, Parent_W_NPMI=0.0417, Sub_NPMI=0.0366, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9350, PPL=20641.18, Parent_W_NPMI=0.0281, Sub_NPMI=0.0399, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0440, PPL=23018.40, Parent_W_NPMI=0.0321, Sub_NPMI=0.0403, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.0683, PPL=23583.97, Parent_W_NPMI=0.0476, Sub_NPMI=0.0346, Converged=Yes
#
# --- 组合 39/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2207, PPL=10104.49, Parent_W_NPMI=-0.2297, Sub_NPMI=0.0542, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3623, PPL=11641.66, Parent_W_NPMI=-0.3049, Sub_NPMI=0.0322, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1238, PPL=9171.32, Parent_W_NPMI=-0.3736, Sub_NPMI=0.0436, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4571, PPL=12799.22, Parent_W_NPMI=-0.3824, Sub_NPMI=0.0434, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3525, PPL=11528.11, Parent_W_NPMI=-0.3384, Sub_NPMI=0.0301, Converged=Yes
#
# --- 组合 40/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.0809, PPL=8785.51, Parent_W_NPMI=0.0577, Sub_NPMI=0.0256, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0943, PPL=8904.61, Parent_W_NPMI=0.0393, Sub_NPMI=0.0295, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1466, PPL=9382.70, Parent_W_NPMI=0.0281, Sub_NPMI=0.0295, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0574, PPL=8581.71, Parent_W_NPMI=-0.0137, Sub_NPMI=0.0294, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0511, PPL=8528.28, Parent_W_NPMI=-0.0021, Sub_NPMI=0.0292, Converged=Yes
#
# --- 组合 41/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0651, PPL=23508.74, Parent_W_NPMI=0.0303, Sub_NPMI=0.0343, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.1260, PPL=24985.28, Parent_W_NPMI=-0.0046, Sub_NPMI=0.0319, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9720, PPL=21418.12, Parent_W_NPMI=0.0614, Sub_NPMI=0.0428, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0002, PPL=22031.05, Parent_W_NPMI=0.0090, Sub_NPMI=0.0301, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9767, PPL=21519.98, Parent_W_NPMI=0.0111, Sub_NPMI=0.0338, Converged=No
#
# --- 组合 42/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.5615, PPL=5226.39, Parent_W_NPMI=-0.4511, Sub_NPMI=0.0350, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.7344, PPL=6213.03, Parent_W_NPMI=-0.3411, Sub_NPMI=0.0524, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0283, PPL=8335.67, Parent_W_NPMI=-0.4180, Sub_NPMI=0.0360, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.6128, PPL=5501.38, Parent_W_NPMI=-0.3729, Sub_NPMI=0.0330, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.8079, PPL=6686.83, Parent_W_NPMI=-0.4279, Sub_NPMI=0.0318, Converged=Yes
#
# --- 组合 43/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.9676, PPL=7844.72, Parent_W_NPMI=0.0984, Sub_NPMI=0.0220, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9109, PPL=7412.21, Parent_W_NPMI=0.0102, Sub_NPMI=0.0233, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1096, PPL=9042.12, Parent_W_NPMI=-0.0047, Sub_NPMI=0.0244, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9858, PPL=7988.58, Parent_W_NPMI=0.0565, Sub_NPMI=0.0251, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9306, PPL=7559.52, Parent_W_NPMI=-0.0034, Sub_NPMI=0.0238, Converged=No
#
# --- 组合 44/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0544, PPL=23256.94, Parent_W_NPMI=0.0549, Sub_NPMI=0.0360, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9443, PPL=20832.88, Parent_W_NPMI=0.0719, Sub_NPMI=0.0452, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.0192, PPL=22453.94, Parent_W_NPMI=0.0530, Sub_NPMI=0.0307, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0856, PPL=23995.10, Parent_W_NPMI=-0.0031, Sub_NPMI=0.0320, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9294, PPL=20524.37, Parent_W_NPMI=0.0171, Sub_NPMI=0.0292, Converged=Yes
#
# --- 组合 45/54: 测试 K1=10, K2=80, Alpha=0.5, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.1564, PPL=3485.45, Parent_W_NPMI=-0.3798, Sub_NPMI=0.0356, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.4934, PPL=4882.20, Parent_W_NPMI=-0.4074, Sub_NPMI=0.0515, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.5282, PPL=5055.32, Parent_W_NPMI=-0.3936, Sub_NPMI=0.0207, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.3876, PPL=4392.13, Parent_W_NPMI=-0.4779, Sub_NPMI=0.0734, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4529, PPL=4688.86, Parent_W_NPMI=-0.2825, Sub_NPMI=0.0510, Converged=No
#
# --- 组合 46/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2089, PPL=9985.73, Parent_W_NPMI=0.0266, Sub_NPMI=0.0293, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.6002, PPL=14767.59, Parent_W_NPMI=0.0093, Sub_NPMI=0.0272, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4884, PPL=13205.83, Parent_W_NPMI=0.0521, Sub_NPMI=0.0228, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4145, PPL=12265.04, Parent_W_NPMI=0.0252, Sub_NPMI=0.0274, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3477, PPL=11472.12, Parent_W_NPMI=0.0737, Sub_NPMI=0.0214, Converged=Yes
#
# --- 组合 47/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.9551, PPL=21060.03, Parent_W_NPMI=0.0135, Sub_NPMI=0.0427, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.4527, PPL=34638.75, Parent_W_NPMI=-0.0004, Sub_NPMI=0.0351, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8590, PPL=19130.38, Parent_W_NPMI=0.0527, Sub_NPMI=0.0411, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.7907, PPL=17867.32, Parent_W_NPMI=-0.0009, Sub_NPMI=0.0438, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.6546, PPL=15593.32, Parent_W_NPMI=0.0439, Sub_NPMI=0.0384, Converged=No
#
# --- 组合 48/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.0679, PPL=8672.49, Parent_W_NPMI=-0.4373, Sub_NPMI=0.0480, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3819, PPL=11871.62, Parent_W_NPMI=-0.4618, Sub_NPMI=0.0743, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3861, PPL=11921.31, Parent_W_NPMI=-0.2861, Sub_NPMI=0.0247, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0816, PPL=8791.62, Parent_W_NPMI=-0.3992, Sub_NPMI=0.0336, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4656, PPL=12907.82, Parent_W_NPMI=-0.3754, Sub_NPMI=0.0358, Converged=Yes
#
# --- 组合 49/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.6044, PPL=14830.46, Parent_W_NPMI=0.0287, Sub_NPMI=0.0251, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5736, PPL=14380.77, Parent_W_NPMI=0.0353, Sub_NPMI=0.0258, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0529, PPL=8543.63, Parent_W_NPMI=0.0497, Sub_NPMI=0.0292, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4632, PPL=12876.49, Parent_W_NPMI=0.0156, Sub_NPMI=0.0234, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.7574, PPL=17282.11, Parent_W_NPMI=0.0471, Sub_NPMI=0.0169, Converged=Yes
#
# --- 组合 50/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.8500, PPL=18958.15, Parent_W_NPMI=0.0140, Sub_NPMI=0.0396, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9669, PPL=21309.87, Parent_W_NPMI=0.0365, Sub_NPMI=0.0366, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.0884, PPL=24063.25, Parent_W_NPMI=-0.0141, Sub_NPMI=0.0329, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.6762, PPL=15933.21, Parent_W_NPMI=-0.0058, Sub_NPMI=0.0307, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.0805, PPL=23874.08, Parent_W_NPMI=0.0575, Sub_NPMI=0.0388, Converged=Yes
#
# --- 组合 51/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.1850, PPL=3586.65, Parent_W_NPMI=-0.4762, Sub_NPMI=0.0407, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.5144, PPL=4985.95, Parent_W_NPMI=-0.3900, Sub_NPMI=0.0449, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1309, PPL=9236.20, Parent_W_NPMI=-0.3043, Sub_NPMI=0.0454, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9126, PPL=7424.62, Parent_W_NPMI=-0.3015, Sub_NPMI=0.0460, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0674, PPL=8668.09, Parent_W_NPMI=-0.4034, Sub_NPMI=0.0383, Converged=Yes
#
# --- 组合 52/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.1878, PPL=9776.91, Parent_W_NPMI=0.0514, Sub_NPMI=0.0250, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3109, PPL=11057.48, Parent_W_NPMI=-0.0178, Sub_NPMI=0.0239, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.6401, PPL=15368.46, Parent_W_NPMI=0.0073, Sub_NPMI=0.0245, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.6796, PPL=15988.50, Parent_W_NPMI=0.0512, Sub_NPMI=0.0204, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1767, PPL=9669.51, Parent_W_NPMI=0.0172, Sub_NPMI=0.0244, Converged=No
#
# --- 组合 53/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.7556, PPL=17251.27, Parent_W_NPMI=0.0169, Sub_NPMI=0.0441, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.3017, PPL=29782.80, Parent_W_NPMI=-0.0555, Sub_NPMI=0.0329, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.6171, PPL=15018.93, Parent_W_NPMI=0.0374, Sub_NPMI=0.0356, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.7856, PPL=17775.53, Parent_W_NPMI=0.0774, Sub_NPMI=0.0352, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.7126, PPL=16524.69, Parent_W_NPMI=0.0179, Sub_NPMI=0.0465, Converged=No
#
# --- 组合 54/54: 测试 K1=10, K2=80, Alpha=1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7385, PPL=6238.24, Parent_W_NPMI=-0.3934, Sub_NPMI=0.0150, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8554, PPL=7012.35, Parent_W_NPMI=-0.3658, Sub_NPMI=0.0456, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.7233, PPL=6144.24, Parent_W_NPMI=-0.3946, Sub_NPMI=0.0330, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.8369, PPL=6883.83, Parent_W_NPMI=-0.4411, Sub_NPMI=0.0446, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1227, PPL=9161.19, Parent_W_NPMI=-0.3836, Sub_NPMI=0.0668, Converged=No
#
#
# ✅ PAM 全面网格搜索完成!
#
# 🏆 所有运行中 Parent_Weighted_NPMI 最高的一次参数: K=[10, 80], Alpha=0.1, Subalpha=0.1, Eta=0.01 (NPMI: 0.1069)
#
#
# 🎉 PAM 网格搜索完成！
# 🏆 找到的最佳超参数 (基于全局单次运行最高 Parent_Weighted_NPMI): K=[10, 80], Alpha=0.1, Subalpha=0.1, Eta=0.01
#
# 🔍 对最佳PAM模型的【父主题】进行分析:
#
# 🔍 Best PAM (Super-Topics) Topic Analysis (showing top 10 words):
# ================================================================================
# Topic   0 (weight:0.061): linear(0.061), constraint(0.058), set(0.052), energy(0.051), equation(0.050)
# Topic   1 (weight:0.110): process(0.110), manufacturing(0.048), simulation(0.047), additive(0.039), part(0.038)
# Topic   2 (weight:0.180): tire(0.180), contact(0.069), road(0.054), geometry(0.045), sttc(0.045)
# Topic   3 (weight:0.064): finite(0.064), formulation(0.061), framework(0.059), element(0.051), numerical(0.046)
# Topic   4 (weight:0.109): method(0.109), al(0.105), mech(0.100), et(0.100), comput(0.086)
# Topic   5 (weight:0.231): fiber(0.231), orientation(0.110), reinforce(0.062), composite(0.062), volume(0.050)
# Topic   6 (weight:0.127): thermal(0.127), heat(0.113), temperature(0.097), thermomechanical(0.089), couple(0.048)
# Topic   7 (weight:0.055): number(0.055), covid(0.046), spread(0.046), new(0.039), droplet(0.036)
# Topic   8 (weight:0.075): grain(0.075), crystal(0.065), growth(0.059), void(0.044), formation(0.043)
# Topic   9 (weight:0.113): network(0.113), data(0.074), neural(0.063), learn(0.057), deep(0.051)
#
# 📊 Best PAM (Super-Topics) Topic Statistics:
#    - Active topics: 10/10
#    - Topic activity rate: 100.0%
#
# 🔬 对最佳PAM模型的【子主题】进行评估:
#
# --- PAM 最终全部运行调优结果 ---
#      K1  K2  Alpha  Subalpha   Eta  Run_Index  Parent_Weighted_NPMI  Sub_NPMI    Perplexity  Parent_Weighted_Cv    Sub_Cv  Parent_Renyi_Entropy  Sub_Renyi_Entropy  Parent_JSD_Diversity  Sub_JSD_Diversity  LL_per_word Converged  Iterations    Time_sec
# 0    10  60    0.1       0.1  0.01          1              0.092554  0.024327   5076.991352            0.568174  0.517627              3.380176           5.512381              0.962528           0.432136    -8.532474       Yes         710  104.780163
# 1    10  60    0.1       0.1  0.01          2              0.036445  0.023997   3956.735444            0.578404  0.514209              3.495251           5.508099              0.974856           0.439551    -8.283175       Yes        1100  172.354809
# 2    10  60    0.1       0.1  0.01          3              0.011678  0.020836   4484.523034            0.494799  0.513597              3.110110           5.516598              0.978382           0.420856    -8.408387        No        1200  193.528746
# 3    10  60    0.1       0.1  0.01          4              0.032077  0.023516   4278.447819            0.473673  0.512542              3.201835           5.526008              0.961326           0.424354    -8.361346       Yes        1070  168.703664
# 4    10  60    0.1       0.1  0.01          5              0.060441  0.024149   4806.792190            0.541358  0.517119              2.875442           5.517463              0.980464           0.430666    -8.477785       Yes         860  131.986405
# 5    10  60    0.1       0.1  0.10          1              0.036114  0.027517  12712.175063            0.543758  0.521345              4.322128           5.334088              0.958143           0.572846    -9.450315       Yes         570   59.401314
# 6    10  60    0.1       0.1  0.10          2              0.063277  0.029485  12078.508240            0.564258  0.523232              4.108858           5.340887              0.972285           0.554597    -9.399183       Yes         870  133.769257
# 7    10  60    0.1       0.1  0.10          3              0.068249  0.035287  11262.209277            0.545770  0.537188              4.127807           5.325787              0.947498           0.570815    -9.329208        No        1200  194.980111
# 8    10  60    0.1       0.1  0.10          4              0.049785  0.030428  11360.615412            0.559442  0.522416              4.074665           5.334915              0.932854           0.573128    -9.337908       Yes        1170  188.227706
# 9    10  60    0.1       0.1  0.10          5              0.101551  0.043191  12153.317601            0.593867  0.541124              4.134314           5.328292              0.955033           0.557197    -9.405357       Yes        1080  170.977313
# 10   10  60    0.1       0.1  1.00          1             -0.430449  0.036561   9149.439407            0.518318  0.530571              7.214332           4.917566              0.452442           0.709680    -9.121448       Yes         550   72.291675
# 11   10  60    0.1       0.1  1.00          2             -0.376155  0.032787   8213.235235            0.524242  0.527590              6.943122           5.014419              0.633066           0.679770    -9.013502        No        1200  193.356511
# 12   10  60    0.1       0.1  1.00          3             -0.256807  0.039478   8293.944631            0.488219  0.523186              6.534460           4.945726              0.830670           0.694947    -9.023281       Yes         650   92.420168
# 13   10  60    0.1       0.1  1.00          4             -0.445507  0.031717   9157.819957            0.515428  0.516415              7.240715           4.947650              0.538459           0.719466    -9.122363       Yes         480   61.353259
# 14   10  60    0.1       0.1  1.00          5             -0.465313  0.048339   8529.004915            0.540473  0.516040              7.070972           4.982496              0.373286           0.720431    -9.051228       Yes         480   61.822297
# 15   10  60    0.1       0.5  0.01          1              0.050648  0.018023   4310.924125            0.559624  0.503525              2.971250           5.528484              0.983133           0.414498    -8.368908       Yes         990  154.786299
# 16   10  60    0.1       0.5  0.01          2              0.025650  0.018763   4022.004998            0.509506  0.507662              2.977726           5.521939              0.979777           0.421920    -8.299536        No        1200  195.578959
# 17   10  60    0.1       0.5  0.01          3              0.050970  0.021497   5322.547804            0.515312  0.512929              3.147616           5.517855              0.957658           0.427247    -8.579707       Yes         630   91.175168
# 18   10  60    0.1       0.5  0.01          4             -0.007898  0.024497   3958.208654            0.498233  0.518578              3.230037           5.508406              0.978447           0.434417    -8.283547        No        1200  189.912524
# 19   10  60    0.1       0.5  0.01          5              0.080695  0.018798   3847.607149            0.616795  0.515932              3.167109           5.495899              0.980105           0.439097    -8.255207        No        1200  192.984668
# 20   10  60    0.1       0.5  0.10          1              0.039299  0.038255  11275.901378            0.526143  0.541499              4.318886           5.332742              0.959906           0.569342    -9.330423       Yes        1040  165.643419
# 21   10  60    0.1       0.5  0.10          2              0.045764  0.029064  13118.061755            0.533846  0.524969              4.255859           5.334590              0.921491           0.563960    -9.481745       Yes         380   44.576372
# 22   10  60    0.1       0.5  0.10          3              0.069875  0.029153  13520.089695            0.564687  0.523734              4.309458           5.345779              0.975149           0.559750    -9.511932       Yes         460   59.347210
# 23   10  60    0.1       0.5  0.10          4              0.032118  0.034582  11576.267329            0.527517  0.532505              4.136395           5.313707              0.978544           0.582128    -9.356712       Yes         910  127.302127
# 24   10  60    0.1       0.5  0.10          5              0.016642  0.036255  13164.146398            0.506541  0.533403              4.244350           5.346027              0.945627           0.562607    -9.485252       Yes         500   64.647035
# 25   10  60    0.1       0.5  1.00          1             -0.266536  0.070700   6587.889649            0.586788  0.558018              6.733203           4.789675              0.771536           0.768873    -8.792988        No        1200  174.948302
# 26   10  60    0.1       0.5  1.00          2             -0.364052  0.050521   7563.576687            0.498806  0.533463              6.871694           4.913704              0.655787           0.729082    -8.931099       Yes         680   99.557944
# 27   10  60    0.1       0.5  1.00          3             -0.462482  0.040926   6220.517842            0.473165  0.524738              7.294136           4.949821              0.615251           0.694758    -8.735608        No        1200  194.603919
# 28   10  60    0.1       0.5  1.00          4             -0.444012  0.038102   7588.827757            0.483270  0.523571              7.134337           4.836536              0.567187           0.738080    -8.934432       Yes         510   68.626440
# 29   10  60    0.1       0.5  1.00          5             -0.351806  0.065980   5132.178027            0.500883  0.552523              6.877635           4.823662              0.625767           0.758599    -8.543285        No        1200  192.632126
# 30   10  60    0.1       1.0  0.01          1              0.013655  0.018235   4763.484555            0.440566  0.509006              3.140356           5.536858              0.974276           0.406226    -8.468735       Yes         640   92.226381
# 31   10  60    0.1       1.0  0.01          2              0.103382  0.031729   4254.330110            0.707453  0.524881              3.306097           5.502956              0.981490           0.445364    -8.355693       Yes         970  153.844309
# 32   10  60    0.1       1.0  0.01          3              0.044886  0.013757   5441.727258            0.566566  0.511197              3.323102           5.509548              0.934821           0.415116    -8.601852       Yes         590   82.988171
# 33   10  60    0.1       1.0  0.01          4              0.018733  0.025966   4053.106030            0.546635  0.521905              3.367151           5.484319              0.956758           0.439031    -8.307239       Yes        1150  185.852204
# 34   10  60    0.1       1.0  0.01          5              0.049185  0.027054   4167.321228            0.546335  0.519130              3.211167           5.497614              0.967092           0.430690    -8.335029       Yes        1150  182.203151
# 35   10  60    0.1       1.0  0.10          1              0.029298  0.025774  12610.976639            0.537862  0.518827              4.342354           5.343951              0.963638           0.566270    -9.442323       Yes         520   69.508092
# 36   10  60    0.1       1.0  0.10          2              0.033073  0.030976  12964.627695            0.524431  0.529491              4.321022           5.359990              0.969169           0.543299    -9.469980       Yes         430   54.463920
# 37   10  60    0.1       1.0  0.10          3              0.054099  0.041049  11723.971257            0.488948  0.529030              4.221758           5.327668              0.965410           0.564460    -9.369391       Yes         810  123.525914
# 38   10  60    0.1       1.0  0.10          4              0.075654  0.026869  13163.529321            0.539466  0.518801              3.963423           5.345482              0.956188           0.543514    -9.485205       Yes         350   38.704071
# 39   10  60    0.1       1.0  0.10          5              0.073944  0.035455  13002.284533            0.552494  0.528227              4.106104           5.357122              0.947685           0.551938    -9.472880       Yes         560   76.975512
# ...
# 207  10  80    0.5       0.5  1.00          3             -0.418001  0.035980   8335.673629            0.468277  0.525988              7.042468           5.019851              0.771162           0.704064    -9.028300        No        1200  224.459334
# 208  10  80    0.5       0.5  1.00          4             -0.372925  0.032990   5501.376482            0.415411  0.523988              7.040707           4.895155              0.884235           0.748673    -8.612754       Yes         630  104.042332
# 209  10  80    0.5       0.5  1.00          5             -0.427949  0.031750   6686.830852            0.434563  0.528949              7.279581           4.827135              0.776288           0.769335    -8.807895       Yes         610   97.773180
# 210  10  80    0.5       1.0  0.01          1              0.098368  0.021972   7844.716786            0.609413  0.515558              2.936228           5.474729              0.991629           0.456791    -8.967596        No        1200  198.734212
# 211  10  80    0.5       1.0  0.01          2              0.010159  0.023314   7412.206803            0.472413  0.520447              2.884049           5.476564              0.978031           0.454832    -8.910883        No        1200  223.742563
# 212  10  80    0.5       1.0  0.01          3             -0.004736  0.024382   9042.119626            0.445956  0.511813              2.922989           5.491612              0.972394           0.439439    -9.109649        No        1200  226.580926
# 213  10  80    0.5       1.0  0.01          4              0.056521  0.025080   7988.577044            0.590428  0.514727              3.086667           5.483888              0.983059           0.443133    -8.985768       Yes        1030  188.042082
# 214  10  80    0.5       1.0  0.01          5             -0.003367  0.023804   7559.515624            0.485497  0.518574              2.872128           5.483514              0.987454           0.447709    -8.930562        No        1200  207.274858
# 215  10  80    0.5       1.0  0.10          1              0.054884  0.036040  23256.936110            0.549610  0.528150              4.253399           5.299154              0.967727           0.582939   -10.054359       Yes         630  103.436917
# 216  10  80    0.5       1.0  0.10          2              0.071857  0.045156  20832.879957            0.570257  0.532582              4.062485           5.276595              0.982905           0.590401    -9.944288        No        1200  224.409138
# 217  10  80    0.5       1.0  0.10          3              0.052955  0.030665  22453.943142            0.551268  0.514817              4.147245           5.321389              0.969478           0.559639   -10.019222       Yes         830  147.641171
# 218  10  80    0.5       1.0  0.10          4             -0.003129  0.032044  23995.104386            0.436365  0.521509              4.205285           5.299431              0.968613           0.576085   -10.085605       Yes        1150  214.688212
# 219  10  80    0.5       1.0  0.10          5              0.017081  0.029174  20524.370411            0.508985  0.524894              4.355302           5.306475              0.958108           0.581525    -9.929368       Yes         810  142.797271
# 220  10  80    0.5       1.0  1.00          1             -0.379840  0.035551   3485.452529            0.480645  0.519538              7.226122           4.736967              0.847934           0.815759    -8.156353       Yes         380   50.614019
# 221  10  80    0.5       1.0  1.00          2             -0.407443  0.051476   4882.196683            0.512235  0.514121              7.091275           4.835395              0.607825           0.770456    -8.493351        No        1200  219.807699
# 222  10  80    0.5       1.0  1.00          3             -0.393554  0.020714   5055.317984            0.547558  0.531160              7.016708           5.164851              0.525302           0.705729    -8.528196       Yes         380   50.525088
# 223  10  80    0.5       1.0  1.00          4             -0.477949  0.073444   4392.129004            0.531692  0.527651              7.163826           4.733744              0.368558           0.798105    -8.387569       Yes         950  171.656176
# 224  10  80    0.5       1.0  1.00          5             -0.282479  0.050959   4688.861676            0.472923  0.524121              7.033786           4.745032              0.930183           0.791905    -8.452945        No        1200  224.153125
# 225  10  80    1.0       0.1  0.01          1              0.026638  0.029342   9985.728270            0.500664  0.523108              2.968322           5.453918              0.985744           0.467000    -9.208912        No        1200  223.395974
# 226  10  80    1.0       0.1  0.01          2              0.009259  0.027248  14767.593314            0.521297  0.520700              2.739038           5.470953              0.967497           0.449211    -9.600190       Yes         710  119.961624
# 227  10  80    1.0       0.1  0.01          3              0.052084  0.022818  13205.829431            0.554346  0.517746              3.092898           5.488910              0.974823           0.444499    -9.488414       Yes         890  130.685157
# 228  10  80    1.0       0.1  0.01          4              0.025244  0.027447  12265.044826            0.545643  0.522476              2.790544           5.460562              0.976648           0.460503    -9.414509        No        1200  225.961471
# 229  10  80    1.0       0.1  0.01          5              0.073690  0.021372  11472.123894            0.576715  0.515327              2.992634           5.476040              0.975004           0.458988    -9.347675       Yes         880  157.879628
# 230  10  80    1.0       0.1  0.10          1              0.013451  0.042671  21060.033230            0.524414  0.531768              3.963016           5.264819              0.966065           0.600082    -9.955132        No        1200  224.879735
# 231  10  80    1.0       0.1  0.10          2             -0.000448  0.035091  34638.745150            0.507494  0.528665              3.801391           5.371739              0.972468           0.527083   -10.452728       Yes         380   52.553972
# 232  10  80    1.0       0.1  0.10          3              0.052741  0.041102  19130.379037            0.532516  0.534701              4.039464           5.277892              0.972854           0.590811    -9.859033       Yes         960  173.907776
# 233  10  80    1.0       0.1  0.10          4             -0.000895  0.043767  17867.321023            0.473372  0.541557              4.093781           5.251262              0.962410           0.606437    -9.790729        No        1200  222.575200
# 234  10  80    1.0       0.1  0.10          5              0.043916  0.038355  15593.321660            0.633865  0.538879              3.848918           5.216005              0.970317           0.612316    -9.654598        No        1200  221.776123
# 235  10  80    1.0       0.1  1.00          1             -0.437309  0.047970   8672.487861            0.556072  0.535347              6.898329           5.049107              0.372929           0.700721    -9.067911        No        1200  225.202590
# 236  10  80    1.0       0.1  1.00          2             -0.461831  0.074306  11871.619041            0.511954  0.530120              7.254554           4.858779              0.552318           0.733463    -9.381906        No        1200  202.406626
# 237  10  80    1.0       0.1  1.00          3             -0.286115  0.024731  11921.307816            0.430034  0.508259              7.059156           5.049742              0.968050           0.678381    -9.386083       Yes         280   30.755911
# 238  10  80    1.0       0.1  1.00          4             -0.399216  0.033580   8791.615045            0.474255  0.512896              7.264641           4.999069              0.613260           0.710250    -9.081554        No        1200  219.399106
# 239  10  80    1.0       0.1  1.00          5             -0.375434  0.035796  12907.816482            0.427989  0.521971              7.025719           4.937845              0.852671           0.711221    -9.465588       Yes         590   96.797788
# 240  10  80    1.0       0.5  0.01          1              0.028684  0.025140  14830.462875            0.555673  0.514345              3.213854           5.513893              0.974091           0.421172    -9.604439       Yes         740  123.968963
# 241  10  80    1.0       0.5  0.01          2              0.035346  0.025788  14380.767608            0.530027  0.517777              2.783475           5.479158              0.958453           0.448064    -9.573647       Yes         550   88.674936
# 242  10  80    1.0       0.5  0.01          3              0.049746  0.029216   8543.630110            0.540823  0.525980              3.035556           5.446297              0.979579           0.476685    -9.052941        No        1200  224.566181
# 243  10  80    1.0       0.5  0.01          4              0.015576  0.023369  12876.487580            0.508472  0.513925              3.162938           5.468423              0.977069           0.449732    -9.463158       Yes         890  157.691419
# 244  10  80    1.0       0.5  0.01          5              0.047056  0.016895  17282.109073            0.569624  0.510243              2.926771           5.511292              0.972447           0.426871    -9.757427       Yes         430   62.416776
# 245  10  80    1.0       0.5  0.10          1              0.014007  0.039592  18958.149443            0.507165  0.530339              3.936293           5.267925              0.961676           0.598692    -9.849989        No        1200  225.703571
# 246  10  80    1.0       0.5  0.10          2              0.036523  0.036650  21309.872254            0.563911  0.527871              4.172489           5.294454              0.979537           0.584734    -9.966926       Yes         680  116.652702
# 247  10  80    1.0       0.5  0.10          3             -0.014054  0.032866  24063.247843            0.528603  0.530738              4.099842           5.306282              0.981357           0.576969   -10.088441       Yes         810  143.549654
# 248  10  80    1.0       0.5  0.10          4             -0.005809  0.030657  15933.208194            0.528499  0.522258              3.918125           5.274841              0.978578           0.586581    -9.676161        No        1200  223.875043
# 249  10  80    1.0       0.5  0.10          5              0.057543  0.038800  23874.081933            0.519530  0.533167              4.182647           5.288957              0.965741           0.577873   -10.080549       Yes         730  126.108786
# 250  10  80    1.0       0.5  1.00          1             -0.476180  0.040657   3586.650384            0.492948  0.493601              7.287253           4.644276              0.534821           0.747934    -8.184974       Yes         350   44.679214
# 251  10  80    1.0       0.5  1.00          2             -0.389960  0.044947   4985.953876            0.509931  0.524565              7.216334           4.965904              0.571117           0.749353    -8.514380        No        1200  218.303496
# 252  10  80    1.0       0.5  1.00          3             -0.304339  0.045439   9236.197884            0.469016  0.534926              6.933402           4.760662              0.921847           0.778296    -9.130886       Yes         690  116.774799
# 253  10  80    1.0       0.5  1.00          4             -0.301531  0.046017   7424.615720            0.524246  0.545152              6.844937           5.012285              0.791996           0.734682    -8.912556       Yes         880  139.792135
# 254  10  80    1.0       0.5  1.00          5             -0.403417  0.038294   8668.092299            0.455825  0.521172              7.214324           4.846434              0.854138           0.759400    -9.067404       Yes         560   89.961335
# 255  10  80    1.0       1.0  0.01          1              0.051381  0.024980   9776.909327            0.527685  0.512683              3.048296           5.487778              0.969734           0.441552    -9.187779       Yes         870  156.086768
# 256  10  80    1.0       1.0  0.01          2             -0.017771  0.023860  11057.483533            0.459893  0.511354              2.793425           5.478401              0.975681           0.443153    -9.310863       Yes         770  136.152939
# 257  10  80    1.0       1.0  0.01          3              0.007272  0.024484  15368.455862            0.515728  0.515437              2.966876           5.491963              0.979165           0.436894    -9.640072       Yes         570   91.049171
# 258  10  80    1.0       1.0  0.01          4              0.051244  0.020446  15988.502433            0.529910  0.514401              2.933536           5.531934              0.974159           0.405488    -9.679625       Yes         370   48.145961
# 259  10  80    1.0       1.0  0.01          5              0.017151  0.024415   9669.506490            0.527953  0.512103              2.852856           5.454150              0.988591           0.467201    -9.176733        No        1200  182.109309
# 260  10  80    1.0       1.0  0.10          1              0.016904  0.044110  17251.269181            0.561261  0.543843              4.209983           5.216658              0.970759           0.621526    -9.755641        No        1200  227.176965
# 261  10  80    1.0       1.0  0.10          2             -0.055523  0.032873  29782.800202            0.424006  0.525711              4.081010           5.353160              0.967437           0.537064   -10.301686       Yes         350   46.584205
# 262  10  80    1.0       1.0  0.10          3              0.037367  0.035610  15018.930235            0.500702  0.527637              3.779388           5.252320              0.962601           0.596287    -9.617067        No        1200  224.446422
# 263  10  80    1.0       1.0  0.10          4              0.077439  0.035221  17775.533854            0.617096  0.531478              3.937654           5.296545              0.984324           0.573738    -9.785578       Yes        1030  188.241714
# 264  10  80    1.0       1.0  0.10          5              0.017874  0.046489  16524.691798            0.543370  0.540126              4.184959           5.241865              0.967220           0.606134    -9.712611        No        1200  223.961975
# 265  10  80    1.0       1.0  1.00          1             -0.393372  0.014981   6238.243066            0.488205  0.492555              7.070181           4.934351              0.784674           0.761343    -8.738454       Yes         480   72.727880
# 266  10  80    1.0       1.0  1.00          2             -0.365750  0.045591   7012.349081            0.583124  0.511471              7.034757           4.810296              0.528756           0.775569    -8.855428       Yes         510   77.164405
# 267  10  80    1.0       1.0  1.00          3             -0.394649  0.033031   6144.235121            0.534094  0.532589              7.037683           4.992181              0.533333           0.756918    -8.723270       Yes         670  109.961305
# 268  10  80    1.0       1.0  1.00          4             -0.441070  0.044575   6883.827572            0.556907  0.547897              7.096889           5.120762              0.377778           0.674239    -8.836930       Yes        1020  184.004875
# 269  10  80    1.0       1.0  1.00          5             -0.383574  0.066849   9161.187210            0.554524  0.570742              6.989730           4.971173              0.527727           0.742055    -9.122731        No        1200  220.052879
#
# ✅ 结果已保存到: ./data/model_result/pam_full_grid_search_results.csv
