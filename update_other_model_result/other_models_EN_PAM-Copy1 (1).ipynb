# %%
""" 0. set-up part:  import necessary libraries and set up environment """

import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from collections import Counter, defaultdict
import numpy as np
import math
import copy
import itertools
import matplotlib.pyplot as plt
import matplotlib as mpl

import joblib
from joblib import Parallel, delayed
from threading import Thread

import os
import pickle
import time

import operator
from functools import reduce
import json
import cProfile

import gensim
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary

import tomotopy as tp

# download nltk data once time
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('omw-1.4')
# nltk.download('punkt_tab')
# nltk.download('averaged_perceptron_tagger_eng')

#  chinese character support in matplotlib
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS' 'SimHei' 'DejaVu Sans']  
plt.rcParams['axes.unicode_minus'] = False

# %%
""" 1.1 Data Preprocessing: load data, clean text, lemmatization, remove low-frequency words"""

# Map POS tags to WordNet format， Penn Treebank annotation: fine-grained (45 tags), WordNet annotation: coarse-grained (4 tags: a, v, n, r)
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return 'a'  # 形容词
    elif treebank_tag.startswith('V'):
        return 'v'  # 动词
    elif treebank_tag.startswith('N'):
        return 'n'  # 名词
    elif treebank_tag.startswith('R'):
        return 'r'  # 副词
    else:
        return 'n'  # 默认名词

# Text cleaning and lemmatization preprocessing function
def clean_and_lemmatize(text):
    if pd.isnull(text):
        return []
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # Remove non-alphabetic characters using regex
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    pos_tags = pos_tag(tokens)
    lemmatized = [lemmatizer.lemmatize(w, get_wordnet_pos(pos)) for w, pos in pos_tags]
    return lemmatized  

#-----------------Load data----------------
data = pd.read_excel('./data/raw/papers_CM.xlsx', usecols=['PaperID', 'Abstract', 'Keywords', 'Year'])

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# clean and lemmatize the abstracts
data['Lemmatized_Tokens'] = data['Abstract'].apply(clean_and_lemmatize)

# count word frequencies
all_tokens = [word for tokens in data['Lemmatized_Tokens'] for word in tokens]
word_counts = Counter(all_tokens)

# set a minimum frequency threshold for valid words
min_freq = 10
valid_words = set([word for word, freq in word_counts.items() if freq >= min_freq])

# remove rare words based on frequency threshold
def remove_rare_words(tokens):
    return [word for word in tokens if word in valid_words]

data['Filtered_Tokens'] = data['Lemmatized_Tokens'].apply(remove_rare_words)

# join tokens back into cleaned abstracts
data['Cleaned_Abstract'] = data['Filtered_Tokens'].apply(lambda x: " ".join(x))

# create a cleaned DataFrame with relevant columns
cleaned_data = data[['PaperID', 'Year', 'Cleaned_Abstract']]
cleaned_data = cleaned_data[~(cleaned_data['PaperID'] == 57188)] # this paper has no abstract
cleaned_data = cleaned_data.reset_index(drop=True) 
cleaned_data.insert(0, 'Document_ID', range(len(cleaned_data))) 
abstract_list = cleaned_data['Cleaned_Abstract'].apply(lambda x: x.split()).tolist()

corpus = {doc_id: abstract_list for doc_id, abstract_list in enumerate(abstract_list)}
# cleaned_data.to_csv('./data/processed/cleaned_data.xlsx', index=False, encoding='utf-8-sig')

# %%
# ===== Enhanced Coherence Calculation Function (Supports Multiple Metrics Including NPMI) =====
def calculate_multiple_coherence_metrics(mdl, corpus_docs, metrics=['c_v', 'c_npmi'], fast_mode=True, top_n=5):
    """
    Enhanced coherence calculation function - supports multiple coherence metrics including NPMI
    
    Supported coherence metrics:
    - c_v: Vector space-based coherence (default)
    - c_npmi: Normalized Pointwise Mutual Information (NPMI)
    
    Supported model types:
    - Single-layer models: LDA, CTM
    - Hierarchical models: hLDA, PAM, hPAM
    - Non-parametric models: HDP
    
    Returns: dict containing various coherence metrics
    """
    try:
        docs = list(corpus_docs)
        dictionary = Dictionary(docs)
        
        # Check if it is a hierarchical model
        model_type_str = str(type(mdl))
        is_hierarchical = hasattr(mdl, 'depth') or 'HLDA' in model_type_str or 'PAM' in model_type_str
        
        if is_hierarchical:
            # Hierarchical model: calculate coherence by level, weighted average
            metrics_results = {metric: [] for metric in metrics}
            layer_weights = []
            
            try:
                for level in range(getattr(mdl, 'depth', 3)):
                    level_topics = []
                    level_doc_count = 0
                    
                    # Iterate through all nodes of this level
                    for k in range(getattr(mdl, 'k', 100)):
                        try:
                            topic_words = mdl.get_topic_words(k, top_n=top_n)
                            if topic_words:
                                words = [word for word, prob in topic_words]
                                level_topics.append(words)
                                level_doc_count += 1
                        except:
                            continue
                    
                    if level_topics:
                        # Calculate coherence for each metric
                        for metric in metrics:
                            try:
                                cm = CoherenceModel(
                                    topics=level_topics,
                                    texts=docs,
                                    dictionary=dictionary,
                                    coherence=metric,
                                    processes=1
                                )
                                score = cm.get_coherence()
                                if score and not math.isnan(score):
                                    metrics_results[metric].append(score)
                                else:
                                    metrics_results[metric].append(0.1)
                            except Exception as e:
                                print(f"Hierarchical model {metric} calculation warning: {e}")
                                metrics_results[metric].append(0.1)
                        
                        layer_weights.append(level_doc_count)
            except:
                pass
            
            # Calculate weighted average
            final_results = {}
            for metric in metrics:
                if metrics_results[metric] and layer_weights:
                    total_weight = sum(layer_weights)
                    if total_weight > 0:
                        weighted_avg = sum(score * w for score, w in zip(metrics_results[metric], layer_weights)) / total_weight
                        final_results[metric] = weighted_avg
                    else:
                        final_results[metric] = 0.1
                else:
                    final_results[metric] = 0.1
            
            return final_results
        
        # Single-layer model: calculate coherence for all topics
        num_topics = getattr(mdl, 'k', None) or getattr(mdl, 'num_topics', None) or 100
        topics = []
        
        for k in range(num_topics):
            try:
                topic_words = mdl.get_topic_words(k, top_n=top_n)
                if topic_words:
                    words = [word for word, prob in topic_words]
                    topics.append(words)
            except:
                continue
        
        if not topics:
            return {metric: 0.1 for metric in metrics}
        
        # Calculate coherence for each metric
        final_results = {}
        for metric in metrics:
            try:
                cm = CoherenceModel(
                    topics=topics,
                    texts=docs,
                    dictionary=dictionary,
                    coherence=metric,
                    processes=1
                )
                score = cm.get_coherence()
                final_results[metric] = score if score and not math.isnan(score) else 0.1
            except Exception as e:
                print(f"Single-layer model {metric} calculation warning: {e}")
                final_results[metric] = 0.1
        
        return final_results
        
    except Exception as e:
        print(f"Coherence calculation error: {e}")
        return {metric: 0.1 for metric in metrics}

# %%
def calculate_renyi_entropy_unweighted(model, alpha=2):
    """
    Calculate the Renyi entropy for all topics (unweighted version, direct average)
    - model: topic model object (e.g., tomotopy LDA/CTM/PAM/hLDA)
    - alpha: order of Renyi entropy (commonly 2)
    Returns: the average of Renyi entropies for all topics
    """
    # ...existing code...
    import numpy as np
    entropies = []
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    for k in range(num_topics):
        try:
            topic_probs = np.array([prob for word, prob in model.get_topic_words(k, top_n=-1)])
            topic_probs = topic_probs / topic_probs.sum()
            if len(topic_probs) > 0:
                renyi = (1/(1-alpha)) * np.log(np.sum(topic_probs**alpha))
                entropies.append(renyi)
            else:
                entropies.append(0)
        except:
            entropies.append(0)
    if entropies:
        return float(np.mean(entropies))
    else:
        return 0.0
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
# ===== 加权Renyi熵计算函数 (Weighted Renyi Entropy) =====
def get_topic_doc_counts(model, threshold=0.01):
    """
    获取每个主题覆盖的文档数（即每个主题出现在了多少个文档中）
    """
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    topic_doc_counts = [0] * num_topics
    for doc in model.docs:
        try:
            topic_dist = doc.get_topic_dist()
        except:
            continue
        for k, prob in enumerate(topic_dist):
            if prob > threshold:
                topic_doc_counts[k] += 1
    return topic_doc_counts

def calculate_weighted_renyi_entropy(model, alpha=2):
    """
    按主题覆盖的文档数加权的Renyi熵
    """
    entropies = []
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    for k in range(num_topics):
        try:
            topic_probs = np.array([prob for word, prob in model.get_topic_words(k, top_n=-1)])
            if topic_probs.sum() > 0:
                topic_probs = topic_probs / topic_probs.sum()
                renyi = (1/(1-alpha)) * np.log(np.sum(topic_probs**alpha))
                entropies.append(renyi)
            else:
                entropies.append(0)
        except:
            entropies.append(0)
    
    # 按主题的文档覆盖数进行加权
    topic_doc_counts = get_topic_doc_counts(model)
    total_docs_covered = sum(topic_doc_counts)
    
    if total_docs_covered > 0 and len(entropies) == len(topic_doc_counts):
        return np.average(entropies, weights=topic_doc_counts)
    elif entropies:
        return np.mean(entropies) # 如果加权失败，则返回普通平均值
    else:
        return 0.0

# %%
from scipy.spatial.distance import jensenshannon
import numpy as np

def calculate_topic_diversity_jsd(model, top_n=25):
    """
    计算所有主题对之间的平均JSD（Jensen-Shannon Divergence），以衡量主题多样性。
    JSD值域为[0, 1]，值越高代表主题间差异越大，多样性越好。

    - model: 训练好的tomotopy模型。
    - top_n: 用于计算JSD的每个主题的top N个词。
    """
    try:
        num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
        if num_topics < 2:
            return 0.0

        # 1. 收集所有主题的top N词和概率，并建立一个共享词汇表
        topic_word_probs = []
        vocab = set()
        for k in range(num_topics):
            try:
                words = model.get_topic_words(k, top_n=top_n)
                if not words: continue
                topic_word_probs.append(dict(words))
                vocab.update([word for word, prob in words])
            except:
                continue
        
        if len(topic_word_probs) < 2:
            return 0.0

        vocab_list = sorted(list(vocab))
        vocab_map = {word: i for i, word in enumerate(vocab_list)}
        
        # 2. 将每个主题的词分布转换为对齐的概率向量
        aligned_probs = []
        for topic_dict in topic_word_probs:
            prob_vector = np.zeros(len(vocab_list))
            for word, prob in topic_dict.items():
                if word in vocab_map:
                    prob_vector[vocab_map[word]] = prob
            
            # 归一化，使其成为有效的概率分布
            if prob_vector.sum() > 1e-9:
                prob_vector /= prob_vector.sum()
            else:
                continue # 跳过无效的空主题
            aligned_probs.append(prob_vector)

        if len(aligned_probs) < 2:
            return 0.0

        # 3. 计算所有主题对之间的JSD
        jsd_values = []
        for i in range(len(aligned_probs)):
            for j in range(i + 1, len(aligned_probs)):
                p = aligned_probs[i]
                q = aligned_probs[j]
                jsd = jensenshannon(p, q, base=2)
                if not np.isnan(jsd):
                    jsd_values.append(jsd**2) # JSD距离通常使用JSD值的平方

        if not jsd_values:
            return 0.0
        
        return float(np.mean(jsd_values))

    except Exception as e:
        # print(f"Error calculating JSD: {e}")
        return 0.0

# %%
# ===== General Topic Analysis Function =====
def analyze_model_topics(model, model_name="Model", top_words=5, min_prob=0.01, max_display=10):
    """
    General topic analysis function - applicable to all topic models
    
    Functionality:
    - Extracts active topics
    - Displays topic words and weights
    - Calculates topic activity rate
    """
    print(f"\n🔍 {model_name} Topic Analysis (showing top {top_words} words):")
    print("=" * 80)
    
    active_topics = 0
    topic_info = []
    
    num_topics = getattr(model, 'k', None) or getattr(model, 'num_topics', None) or 0
    
    for k in range(num_topics):
        try:
            topic_words = model.get_topic_words(k, top_n=top_words)
            if topic_words and topic_words[0][1] > min_prob:
                active_topics += 1
                words_str = ", ".join([f"{word}({prob:.3f})" for word, prob in topic_words[:5]])
                topic_info.append((k, topic_words[0][1], words_str))
                
                if active_topics <= max_display:
                    print(f"Topic {k:3d} (weight:{topic_words[0][1]:.3f}): {words_str}")
        except:
            continue
    
    if active_topics > max_display:
        print(f"... (and {active_topics - max_display} more active topics)")
    
    print(f"\n📊 {model_name} Topic Statistics:")
    print(f"   - Active topics: {active_topics}/{num_topics}")
    print(f"   - Topic activity rate: {active_topics/num_topics*100:.1f}%")
    
    return topic_info

# %%
def calculate_r_hat(chains_history):
    """
    根据多个MCMC链的后半部分历史记录计算R-hat（Gelman-Rubin诊断）值。
    
    参数:
    - chains_history (np.ndarray): 一个2D numpy数组，形状为 (M, N)，
      其中 M 是链的数量（运行次数），N 是每个链记录的迭代次数。
      数组中的值是对数似然（log-likelihood）。

    返回:
    - float: R-hat值。如果无法计算，则返回 np.nan。
    """
    # 仅使用后半部分的样本进行计算，这是标准做法
    num_iterations = chains_history.shape[1]
    start_index = num_iterations // 2
    
    if chains_history.shape[0] < 2 or (num_iterations - start_index) < 2:
        return np.nan

    chains_history = chains_history[:, start_index:]
    num_chains, num_used_iterations = chains_history.shape
    
    # 1. 计算每个链的均值
    chain_means = np.mean(chains_history, axis=1)
    
    # 2. 计算每个链的方差
    chain_variances = np.var(chains_history, axis=1, ddof=1)
    
    # 3. 计算链内方差的均值 (W)
    W = np.mean(chain_variances)
    
    # 4. 计算链间方差 (B)
    overall_mean = np.mean(chain_means)
    B = num_used_iterations / (num_chains - 1) * np.sum((chain_means - overall_mean)**2)
    
    # 5. 估计目标分布的方差 (Var_hat)
    var_hat = (1 - 1 / num_used_iterations) * W + (1 / num_used_iterations) * B
    
    if W == 0:
        return np.nan
        
    # 6. 计算R-hat
    r_hat = np.sqrt(var_hat / W)
    
    return r_hat

# %%
def calculate_weighted_coherence(model, corpus_docs, metrics=['c_v', 'c_npmi'], top_n=10, threshold=0.01):
    """
    计算按主题的文档覆盖率加权的 coherence 分数 (NPMI, C_v)。
    
    Args:
        model: 训练好的 tomotopy 模型。
        corpus_docs: 用于计算 coherence 的原始文档列表。
        metrics: 要计算的指标列表。
        top_n: 用于定义主题的 top N 个词。
        threshold: 判断一个主题在文档中是否“显著”的概率阈值。

    Returns:
        一个包含加权和未加权 coherence 分数的字典。
    """
    try:
        docs = list(corpus_docs)
        dictionary = Dictionary(docs)
        num_topics = getattr(model, 'k', 0) or getattr(model, 'num_topics', 0)
        
        if num_topics == 0:
            return {}

        # 1. 提取所有主题的 top words
        topics = []
        for k in range(num_topics):
            topic_words = [word for word, prob in model.get_topic_words(k, top_n=top_n)]
            if topic_words:
                topics.append(topic_words)
        
        if not topics:
            return {}

        # 2. 获取每个主题的权重 (文档覆盖数)
        topic_doc_counts = np.zeros(num_topics)
        for doc in model.docs:
            topic_dist = doc.get_topic_dist()
            for k, prob in enumerate(topic_dist):
                if prob > threshold:
                    topic_doc_counts[k] += 1
        
        total_docs_covered = np.sum(topic_doc_counts)
        
        results = {}
        for metric in metrics:
            cm = CoherenceModel(
                topics=topics,
                texts=docs,
                dictionary=dictionary,
                coherence=metric,
                processes=1
            )
            
            # 获取每个主题的分数
            per_topic_scores = cm.get_coherence_per_topic()
            
            # 计算简单平均值 (未加权)
            unweighted_avg = np.mean(per_topic_scores)
            results[f'unweighted_{metric}'] = unweighted_avg
            
            # 计算加权平均值
            if total_docs_covered > 0:
                weighted_avg = np.average(per_topic_scores, weights=topic_doc_counts)
                results[f'weighted_{metric}'] = weighted_avg
            else:
                results[f'weighted_{metric}'] = unweighted_avg # 如果没有权重，则退回到简单平均

        return results

    except Exception as e:
        print(f"计算加权Coherence时出错: {e}")
        return {}

# --- 如何使用 ---
# 假设 best_lda_model 是你训练好的模型
# weighted_scores = calculate_weighted_coherence(best_lda_model, abstract_list)
# print(weighted_scores)
# 输出可能像这样:
# {'unweighted_c_v': 0.45, 'weighted_c_v': 0.48, 'unweighted_c_npmi': 0.05, 'weighted_c_npmi': 0.06}

# %%
def evaluate_pam_sub_topics(model, corpus_docs, top_n=10):
    """
    修复并优化的PAM子主题评估函数。
    它通过分析所有文档的子主题分布来推断子主题词汇，而不是调用不存在的方法。
    """
    if not isinstance(model, tp.PAModel):
        print("❌错误: 此函数仅适用于 tomotopy.PAModel。")
        return {}

    # print(f"\n🔬 开始评估 {model.k2} 个子主题 (修复版)...")
    
    sub_topics = []
    sub_topic_word_probs = [] # 用于计算Renyi和JSD

    try:
        # 1. 为每个子主题初始化一个词汇计数器
        sub_topic_word_counts = [defaultdict(float) for _ in range(model.k2)]
        
        # 2. 遍历所有文档，根据子主题分布累加词汇权重
        num_valid_docs = 0
        for doc_idx, doc in enumerate(model.docs):
            if hasattr(doc, 'get_sub_topic_dist'):
                sub_dist = doc.get_sub_topic_dist()
                if sum(sub_dist) < 0.1: continue # 跳过无效分布的文档
                
                num_valid_docs += 1
                original_doc_words = corpus_docs[doc_idx]
                
                for k in range(model.k2):
                    weight = sub_dist[k]
                    if weight > 0.01: # 只考虑有一定权重的
                        for word in original_doc_words:
                            sub_topic_word_counts[k][word] += weight
        
        # print(f"   分析了 {num_valid_docs} 个文档的子主题分布。")

        # 3. 从累加的权重中提取每个子主题的 Top N 词汇
        for k in range(model.k2):
            if not sub_topic_word_counts[k]:
                continue

            # 归一化得到概率分布，用于计算Renyi和JSD
            total_weight = sum(sub_topic_word_counts[k].values())
            if total_weight > 0:
                word_probs = {word: count / total_weight for word, count in sub_topic_word_counts[k].items()}
                sub_topic_word_probs.append(word_probs)

            # 提取top N词用于计算Coherence
            sorted_words = sorted(sub_topic_word_counts[k].items(), key=lambda item: item[1], reverse=True)
            top_words = [word for word, weight in sorted_words[:top_n]]
            
            if len(top_words) >= 2: # 至少需要2个词才能计算coherence
                sub_topics.append(top_words)

    except Exception as e:
        # print(f"   ❌ 推断子主题时发生严重错误: {e}")
        pass

    # --- 后续计算部分 ---
    if not sub_topics:
        # print("❌ 未能提取任何有效子主题！")
        return {
            'sub_topics_npmi': 0.0, 'sub_topics_c_v': 0.0, 
            'sub_topics_renyi_entropy': 0.0, 'sub_topics_jsd_diversity': 0.0
        }
    
    results = {}
    # 1. 计算Coherence
    try:
        dictionary = Dictionary(corpus_docs)
        cm_npmi = CoherenceModel(topics=sub_topics, texts=corpus_docs, dictionary=dictionary, coherence='c_npmi', processes=1)
        npmi_score = cm_npmi.get_coherence()
        results['sub_topics_npmi'] = npmi_score if not np.isnan(npmi_score) else 0.0
        
        cm_cv = CoherenceModel(topics=sub_topics, texts=corpus_docs, dictionary=dictionary, coherence='c_v', processes=1)
        cv_score = cm_cv.get_coherence()
        results['sub_topics_c_v'] = cv_score if not np.isnan(cv_score) else 0.0
    except Exception:
        results['sub_topics_npmi'] = 0.0
        results['sub_topics_c_v'] = 0.0

    # 2. 计算Renyi熵和JSD多样性
    try:
        # 模拟一个模型对象，使其能被现有函数使用
        class SubTopicProvider:
            def __init__(self, inferred_topics):
                self.inferred_topics = inferred_topics
                self.k = len(inferred_topics)
            def get_topic_words(self, k, top_n=-1):
                # 将字典转换为 (word, prob) 格式
                topic_dist = self.inferred_topics[k]
                sorted_words = sorted(topic_dist.items(), key=lambda item: item[1], reverse=True)
                if top_n == -1:
                    return sorted_words
                return sorted_words[:top_n]

        if sub_topic_word_probs:
            sub_topic_provider = SubTopicProvider(sub_topic_word_probs)
            # Renyi熵 (这里用父主题的函数，因为它只依赖get_topic_words)
            # 注意：calculate_weighted_renyi_entropy无法使用，因为它依赖doc.get_topic_dist()
            # 我们用一个简化的非加权版本
            entropies = []
            for k in range(sub_topic_provider.k):
                topic_probs = np.array([prob for word, prob in sub_topic_provider.get_topic_words(k, top_n=-1)])
                if len(topic_probs) > 0:
                    renyi = (1/(1-2)) * np.log(np.sum(topic_probs**2))
                    entropies.append(renyi)
            results['sub_topics_renyi_entropy'] = np.mean(entropies) if entropies else 0.0
            
            # JSD多样性
            results['sub_topics_jsd_diversity'] = calculate_topic_diversity_jsd(sub_topic_provider, top_n=25)
        else:
            results['sub_topics_renyi_entropy'] = 0.0
            results['sub_topics_jsd_diversity'] = 0.0
    except Exception:
        results['sub_topics_renyi_entropy'] = 0.0
        results['sub_topics_jsd_diversity'] = 0.0

    return results

# %%
def tune_pam_model(
    docs, 
    k_combinations, 
    alpha_range, 
    sub_alpha_range,
    eta_range, 
    num_runs=3, 
    seed=42, 
    max_iters=1000,
    burn_in=100,
    convergence_patience=5,
    convergence_tolerance=1e-2,
    parent_top_n=10,  # <--- 新增：父主题的 top_n
    sub_top_n=5      # <--- 新增：子主题的 top_n
):
    """
    对PAM模型执行全面的网格搜索（最终版）。

    - 遍历所有 k1, k2, alpha, sub_alpha, eta 的组合。
    - 包含一个独立的 burn-in 阶段。
    - 使用对数似然（LL）的变化判断收敛。
    - 为每个组合运行多次以获得稳健的结果。
    - 收集父主题和子主题的详细指标：LL/word, PPL, Coherence, Renyi熵, JSD多样性。
    """
    all_run_results = []
    best_single_run_npmi = -1
    best_params = {}
    best_model = None

    param_grid = list(itertools.product(k_combinations, alpha_range, sub_alpha_range, eta_range))
    total_combinations = len(param_grid)
    
    print(f"🚀 开始 PAM 模型全面网格搜索，共 {total_combinations} 种组合，每种运行 {num_runs} 次...")
    print(f"   (收敛判断: LL 在 {convergence_patience} 次连续检查中的波动 < {convergence_tolerance})")

    for i, (k_list, alpha, subalpha_val, eta) in enumerate(param_grid, 1):
        if len(k_list) != 2:
            print(f"\n--- 跳过组合 {i}/{total_combinations}: K={k_list} 不是有效的PAM模型两层结构。 ---")
            continue
        
        k1, k2 = k_list[0], k_list[1]
        print(f"\n--- 组合 {i}/{total_combinations}: 测试 K1={k1}, K2={k2}, Alpha={alpha}, Subalpha={subalpha_val}, Eta={eta} ---")
        
        for run_idx in range(num_runs):
            start_time = time.time()
            current_seed = seed + run_idx
            print(f"  - 运行 {run_idx + 1}/{num_runs} (seed={current_seed})...")
            
            try:
                model = tp.PAModel(k1=k1, k2=k2, alpha=alpha, subalpha=subalpha_val, eta=eta, seed=current_seed)
                for doc in docs:
                    model.add_doc(doc)
                
                if burn_in > 0:
                    model.train(burn_in)

                ll_history = []
                converged = False
                final_iter = max_iters
                for step in range(0, max_iters, 10):
                    model.train(10, 1)
                    ll_history.append(model.ll_per_word)
                    if len(ll_history) > convergence_patience:
                        recent_ll = ll_history[-convergence_patience:]
                        if (np.max(recent_ll) - np.min(recent_ll)) < convergence_tolerance:
                            final_iter = step + 10
                            converged = True
                            break
                if not converged: final_iter = max_iters

                # --- 评估指标 ---
                ll_per_word = model.ll_per_word
                perplexity = math.exp(-ll_per_word) if ll_per_word is not None else float('inf')
                
                # [修改] 使用 parent_top_n
                parent_coherence = calculate_weighted_coherence(model, docs, metrics=['c_v', 'c_npmi'], top_n=parent_top_n)
                parent_renyi = calculate_weighted_renyi_entropy(model)
                parent_jsd = calculate_topic_diversity_jsd(model)
                
                # [修改] 使用 sub_top_n
                sub_topic_metrics = evaluate_pam_sub_topics(model, docs, top_n=sub_top_n)

                w_npmi = parent_coherence.get('weighted_c_npmi', 0)
                converged_str = "Yes" if converged else "No"
                print(f"    => 结果: LL/word={ll_per_word:.4f}, PPL={perplexity:.2f}, Parent_W_NPMI={w_npmi:.4f}, Sub_NPMI={sub_topic_metrics.get('sub_topics_npmi', 0):.4f}, Converged={converged_str}")

                run_result = {
                    'K1': k1, 'K2': k2, 'Alpha': alpha, 'Subalpha': subalpha_val, 'Eta': eta,
                    'Run_Index': run_idx + 1,
                    'LL_per_word': ll_per_word,
                    'Perplexity': perplexity,
                    
                    'Parent_Weighted_NPMI': parent_coherence.get('weighted_c_npmi', 0),
                    'Parent_Weighted_Cv': parent_coherence.get('weighted_c_v', 0),
                    'Parent_Unweighted_NPMI': parent_coherence.get('unweighted_c_npmi', 0),
                    'Parent_Unweighted_Cv': parent_coherence.get('unweighted_c_v', 0),
                    'Parent_Renyi_Entropy': parent_renyi,
                    'Parent_JSD_Diversity': parent_jsd,

                    'Sub_NPMI': sub_topic_metrics.get('sub_topics_npmi', 0),
                    'Sub_Cv': sub_topic_metrics.get('sub_topics_c_v', 0),
                    'Sub_Renyi_Entropy': sub_topic_metrics.get('sub_topics_renyi_entropy', 0),
                    'Sub_JSD_Diversity': sub_topic_metrics.get('sub_topics_jsd_diversity', 0),

                    'Iterations': final_iter + burn_in,
                    'Converged': converged_str,
                    'Time_sec': time.time() - start_time
                }
                all_run_results.append(run_result)
                
                if w_npmi > best_single_run_npmi:
                    best_single_run_npmi = w_npmi
                    best_params = {'K': k_list, 'Alpha': alpha, 'Subalpha': subalpha_val, 'Eta': eta}
                    best_model = model

            except Exception as e:
                print(f"    ❌ 运行 {run_idx + 1} 失败: {e}")

    results_df = pd.DataFrame(all_run_results)
    print("\n\n✅ PAM 全面网格搜索完成!")
    
    if best_params:
        print(f"\n🏆 所有运行中 Parent_Weighted_NPMI 最高的一次参数: K={best_params.get('K')}, Alpha={best_params.get('Alpha')}, Subalpha={best_params.get('Subalpha')}, Eta={best_params.get('Eta')} (NPMI: {best_single_run_npmi:.4f})")
    else:
        print("\n❌ 未能成功完成任何运行。")

    return results_df, best_model, best_params

# %%
print("\n🎯 开始为 PAM 模型进行全面网格搜索...")
print("=" * 60)

# 1. 定义需要测试的超参数范围
k_combinations_to_test = [
    [10,100],
    [20, 80],
]
alpha_range_to_test = [0.1, 0.5, 1]
sub_alpha_range_to_test = [0.1, 0.5,1]
eta_range_to_test = [0.01, 0.1, 1]

# [新增] 定义父主题和子主题的 top_n
PARENT_TOP_N = 10
SUB_TOP_N = 5

# 2. 确保您的预处理文档已准备就绪
pam_docs = abstract_list

# 3. 运行网格搜索函数
pam_results_df, best_pam_model, best_pam_params = tune_pam_model(
    docs=pam_docs,
    k_combinations=k_combinations_to_test,
    alpha_range=alpha_range_to_test,
    sub_alpha_range=sub_alpha_range_to_test,
    eta_range=eta_range_to_test,
    num_runs=5, # 为了演示，减少运行次数
    max_iters=1000, # 为了演示，减少迭代次数
    burn_in=200,
    parent_top_n=PARENT_TOP_N, # <--- 传入父主题 top_n
    sub_top_n=SUB_TOP_N       # <--- 传入子主题 top_n
)

# 4. 打印找到的最佳模型信息
print("\n\n🎉 PAM 网格搜索完成！")
if best_pam_params:
    print(f"🏆 找到的最佳超参数 (基于全局单次运行最高 Parent_Weighted_NPMI): "
          f"K={best_pam_params.get('K')}, "
          f"Alpha={best_pam_params.get('Alpha')}, "
          f"Subalpha={best_pam_params.get('Subalpha')}, "
          f"Eta={best_pam_params.get('Eta')}")
    
    # 分别分析父主题和子主题
    print("\n🔍 对最佳PAM模型的【父主题】进行分析:")
    analyze_model_topics(best_pam_model, model_name="Best PAM (Super-Topics)", top_words=PARENT_TOP_N)
    
    print("\n🔬 对最佳PAM模型的【子主题】进行评估:")
    # [修改] 在最终评估时也使用 SUB_TOP_N 保持一致
    evaluate_pam_sub_topics(best_pam_model, pam_docs, top_n=SUB_TOP_N)

else:
    print("❌ 未能找到最佳模型。")

# 5. 显示并保存详细的、每一次运行的调优结果表格
if pam_results_df is not None and not pam_results_df.empty:
    print("\n--- PAM 最终全部运行调优结果 ---")
    # 调整列顺序以获得更好的可读性
    cols = [
        'K1', 'K2', 'Alpha', 'Subalpha', 'Eta', 'Run_Index',
        'Parent_Weighted_NPMI', 'Sub_NPMI', 'Perplexity',
        'Parent_Weighted_Cv', 'Sub_Cv',
        'Parent_Renyi_Entropy', 'Sub_Renyi_Entropy',
        'Parent_JSD_Diversity', 'Sub_JSD_Diversity',
        'LL_per_word', 'Converged', 'Iterations', 'Time_sec'
    ]
    display_df = pam_results_df.reindex(columns=[c for c in cols if c in pam_results_df.columns])
    print(display_df.to_string())
    
    # 保存结果
    output_path = './data/model_result/pam_full_grid_search_results_02.csv'
    pam_results_df.to_csv(output_path, index=False, encoding='utf-8-sig')
    print(f"\n✅ 结果已保存到: {output_path}")
# Out:
# 🎯 开始为 PAM 模型进行全面网格搜索...
# ============================================================
# 🚀 开始 PAM 模型全面网格搜索，共 54 种组合，每种运行 5 次...
#    (收敛判断: LL 在 5 次连续检查中的波动 < 0.01)
#
# --- 组合 1/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
# /tmp/ipykernel_1761/1911189480.py:55: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   model.train(burn_in)
#     => 结果: LL/word=-8.5538, PPL=5186.19, Parent_W_NPMI=0.0218, Sub_NPMI=0.0275, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.7084, PPL=6053.49, Parent_W_NPMI=0.0318, Sub_NPMI=0.0289, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.5601, PPL=5219.11, Parent_W_NPMI=0.0169, Sub_NPMI=0.0252, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.7868, PPL=6547.00, Parent_W_NPMI=0.0272, Sub_NPMI=0.0328, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.6950, PPL=5972.88, Parent_W_NPMI=0.0786, Sub_NPMI=0.0272, Converged=Yes
#
# --- 组合 2/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.4211, PPL=12346.62, Parent_W_NPMI=0.0476, Sub_NPMI=0.0414, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5277, PPL=13735.47, Parent_W_NPMI=0.0226, Sub_NPMI=0.0518, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4793, PPL=13086.50, Parent_W_NPMI=0.0536, Sub_NPMI=0.0521, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4136, PPL=12253.51, Parent_W_NPMI=0.0399, Sub_NPMI=0.0448, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.5062, PPL=13442.57, Parent_W_NPMI=0.0898, Sub_NPMI=0.0519, Converged=Yes
#
# --- 组合 3/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.9572, PPL=7763.53, Parent_W_NPMI=-0.4893, Sub_NPMI=0.0521, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.9603, PPL=7787.96, Parent_W_NPMI=-0.4837, Sub_NPMI=0.0436, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.8618, PPL=7057.43, Parent_W_NPMI=-0.4867, Sub_NPMI=0.0395, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9949, PPL=8062.22, Parent_W_NPMI=-0.4153, Sub_NPMI=0.0097, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9347, PPL=7591.11, Parent_W_NPMI=-0.3268, Sub_NPMI=0.0279, Converged=Yes
#
# --- 组合 4/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4604, PPL=4723.91, Parent_W_NPMI=0.0489, Sub_NPMI=0.0249, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.5842, PPL=5346.55, Parent_W_NPMI=0.0225, Sub_NPMI=0.0199, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.5385, PPL=5107.71, Parent_W_NPMI=0.0622, Sub_NPMI=0.0343, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.6644, PPL=5792.82, Parent_W_NPMI=0.0170, Sub_NPMI=0.0302, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4603, PPL=4723.51, Parent_W_NPMI=0.0203, Sub_NPMI=0.0283, Converged=No
#
# --- 组合 5/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.5610, PPL=14199.60, Parent_W_NPMI=0.0139, Sub_NPMI=0.0483, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5139, PPL=13547.18, Parent_W_NPMI=-0.0593, Sub_NPMI=0.0362, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4248, PPL=12392.12, Parent_W_NPMI=0.0469, Sub_NPMI=0.0559, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3994, PPL=12081.09, Parent_W_NPMI=-0.0225, Sub_NPMI=0.0458, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4106, PPL=12217.41, Parent_W_NPMI=0.0351, Sub_NPMI=0.0458, Converged=No
#
# --- 组合 6/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.6036, PPL=5451.42, Parent_W_NPMI=-0.3887, Sub_NPMI=0.0237, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.6319, PPL=5607.68, Parent_W_NPMI=-0.4726, Sub_NPMI=0.0512, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.2660, PPL=3889.55, Parent_W_NPMI=-0.3469, Sub_NPMI=0.0476, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.3197, PPL=4103.95, Parent_W_NPMI=-0.3292, Sub_NPMI=0.0267, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4924, PPL=4877.77, Parent_W_NPMI=-0.4432, Sub_NPMI=0.0295, Converged=No
#
# --- 组合 7/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.6857, PPL=5917.76, Parent_W_NPMI=0.0424, Sub_NPMI=0.0215, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.4659, PPL=4749.83, Parent_W_NPMI=0.1248, Sub_NPMI=0.0256, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.7706, PPL=6442.28, Parent_W_NPMI=0.0669, Sub_NPMI=0.0316, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.4444, PPL=4649.02, Parent_W_NPMI=0.0508, Sub_NPMI=0.0290, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4663, PPL=4752.09, Parent_W_NPMI=0.0312, Sub_NPMI=0.0260, Converged=No
#
# --- 组合 8/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.5429, PPL=13945.22, Parent_W_NPMI=0.0113, Sub_NPMI=0.0484, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4967, PPL=13315.39, Parent_W_NPMI=0.0134, Sub_NPMI=0.0438, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3732, PPL=11768.18, Parent_W_NPMI=-0.0227, Sub_NPMI=0.0522, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4849, PPL=13159.89, Parent_W_NPMI=0.0397, Sub_NPMI=0.0436, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.5000, PPL=13359.47, Parent_W_NPMI=-0.0018, Sub_NPMI=0.0517, Converged=Yes
#
# --- 组合 9/54: 测试 K1=10, K2=100, Alpha=0.1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.0041, PPL=2993.21, Parent_W_NPMI=-0.2970, Sub_NPMI=0.0387, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-7.7979, PPL=2435.40, Parent_W_NPMI=-0.3388, Sub_NPMI=0.0367, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-7.9995, PPL=2979.59, Parent_W_NPMI=-0.4314, Sub_NPMI=0.0711, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-7.6380, PPL=2075.49, Parent_W_NPMI=-0.3683, Sub_NPMI=0.0938, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.0926, PPL=3270.30, Parent_W_NPMI=-0.3972, Sub_NPMI=0.0478, Converged=Yes
#
# --- 组合 10/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2632, PPL=10542.93, Parent_W_NPMI=-0.0039, Sub_NPMI=0.0210, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5051, PPL=13428.12, Parent_W_NPMI=0.0250, Sub_NPMI=0.0225, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1553, PPL=9464.33, Parent_W_NPMI=0.0447, Sub_NPMI=0.0287, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1105, PPL=9049.74, Parent_W_NPMI=0.0192, Sub_NPMI=0.0277, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.1337, PPL=9262.61, Parent_W_NPMI=-0.0050, Sub_NPMI=0.0241, Converged=No
#
# --- 组合 11/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.1765, PPL=26278.73, Parent_W_NPMI=0.0478, Sub_NPMI=0.0459, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9946, PPL=21907.52, Parent_W_NPMI=0.0698, Sub_NPMI=0.0446, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.1614, PPL=25883.97, Parent_W_NPMI=0.0251, Sub_NPMI=0.0370, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0918, PPL=24144.83, Parent_W_NPMI=-0.0111, Sub_NPMI=0.0347, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.0789, PPL=23834.07, Parent_W_NPMI=-0.0071, Sub_NPMI=0.0417, Converged=Yes
#
# --- 组合 12/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7700, PPL=6438.22, Parent_W_NPMI=-0.4959, Sub_NPMI=0.0330, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0267, PPL=8322.51, Parent_W_NPMI=-0.5028, Sub_NPMI=0.0427, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1092, PPL=9037.84, Parent_W_NPMI=-0.4152, Sub_NPMI=0.0570, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1940, PPL=9837.44, Parent_W_NPMI=-0.3178, Sub_NPMI=0.0280, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2170, PPL=10066.80, Parent_W_NPMI=-0.4399, Sub_NPMI=0.0407, Converged=Yes
#
# --- 组合 13/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.0551, PPL=8562.47, Parent_W_NPMI=0.0034, Sub_NPMI=0.0273, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2114, PPL=10010.54, Parent_W_NPMI=0.0509, Sub_NPMI=0.0242, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4748, PPL=13027.87, Parent_W_NPMI=0.0263, Sub_NPMI=0.0219, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0124, PPL=8203.80, Parent_W_NPMI=0.0030, Sub_NPMI=0.0287, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2009, PPL=9906.17, Parent_W_NPMI=0.0180, Sub_NPMI=0.0277, Converged=Yes
#
# --- 组合 14/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0807, PPL=23877.96, Parent_W_NPMI=0.0061, Sub_NPMI=0.0436, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0940, PPL=24196.77, Parent_W_NPMI=0.0426, Sub_NPMI=0.0341, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.1673, PPL=26037.01, Parent_W_NPMI=-0.0280, Sub_NPMI=0.0387, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.8346, PPL=18669.16, Parent_W_NPMI=-0.0097, Sub_NPMI=0.0457, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9171, PPL=20274.36, Parent_W_NPMI=0.0251, Sub_NPMI=0.0409, Converged=No
#
# --- 组合 15/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.6845, PPL=5910.29, Parent_W_NPMI=-0.3060, Sub_NPMI=0.0420, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.5056, PPL=4942.45, Parent_W_NPMI=-0.4716, Sub_NPMI=0.0485, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.3340, PPL=4163.23, Parent_W_NPMI=-0.4034, Sub_NPMI=0.0742, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0902, PPL=8867.96, Parent_W_NPMI=-0.4615, Sub_NPMI=0.0285, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.7073, PPL=6047.00, Parent_W_NPMI=-0.3937, Sub_NPMI=0.0316, Converged=Yes
#
# --- 组合 16/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.1159, PPL=9098.99, Parent_W_NPMI=0.0300, Sub_NPMI=0.0207, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0550, PPL=8561.24, Parent_W_NPMI=-0.0282, Sub_NPMI=0.0297, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1387, PPL=9308.95, Parent_W_NPMI=-0.0244, Sub_NPMI=0.0253, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.0339, PPL=8382.68, Parent_W_NPMI=0.0452, Sub_NPMI=0.0279, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9542, PPL=7740.24, Parent_W_NPMI=0.0573, Sub_NPMI=0.0273, Converged=No
#
# --- 组合 17/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.1430, PPL=25411.54, Parent_W_NPMI=0.0551, Sub_NPMI=0.0313, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.8776, PPL=19489.33, Parent_W_NPMI=-0.0127, Sub_NPMI=0.0565, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8341, PPL=18658.38, Parent_W_NPMI=-0.0039, Sub_NPMI=0.0409, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9291, PPL=20519.80, Parent_W_NPMI=0.0538, Sub_NPMI=0.0511, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9194, PPL=20321.26, Parent_W_NPMI=-0.0368, Sub_NPMI=0.0514, Converged=Yes
#
# --- 组合 18/54: 测试 K1=10, K2=100, Alpha=0.5, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.3512, PPL=4235.42, Parent_W_NPMI=-0.4204, Sub_NPMI=0.0614, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.2812, PPL=3948.76, Parent_W_NPMI=-0.4008, Sub_NPMI=0.0589, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.6665, PPL=5804.93, Parent_W_NPMI=-0.3818, Sub_NPMI=0.0687, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.8575, PPL=7026.66, Parent_W_NPMI=-0.3460, Sub_NPMI=0.0484, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.1012, PPL=3298.55, Parent_W_NPMI=-0.4311, Sub_NPMI=0.0717, Converged=Yes
#
# --- 组合 19/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.0227, PPL=22531.12, Parent_W_NPMI=0.0288, Sub_NPMI=0.0196, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9679, PPL=21331.23, Parent_W_NPMI=0.0385, Sub_NPMI=0.0236, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3817, PPL=11869.69, Parent_W_NPMI=0.0645, Sub_NPMI=0.0250, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5416, PPL=13926.61, Parent_W_NPMI=0.0136, Sub_NPMI=0.0312, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4468, PPL=12667.07, Parent_W_NPMI=0.0803, Sub_NPMI=0.0305, Converged=No
#
# --- 组合 20/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.1420, PPL=25387.38, Parent_W_NPMI=0.0260, Sub_NPMI=0.0422, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0150, PPL=22358.53, Parent_W_NPMI=0.0808, Sub_NPMI=0.0483, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8241, PPL=18474.02, Parent_W_NPMI=0.0095, Sub_NPMI=0.0500, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0702, PPL=23628.05, Parent_W_NPMI=0.0355, Sub_NPMI=0.0455, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.7490, PPL=17136.79, Parent_W_NPMI=0.0929, Sub_NPMI=0.0488, Converged=No
#
# --- 组合 21/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2399, PPL=10300.05, Parent_W_NPMI=-0.4450, Sub_NPMI=0.0277, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0022, PPL=8121.18, Parent_W_NPMI=-0.3698, Sub_NPMI=0.0419, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.8636, PPL=7069.75, Parent_W_NPMI=-0.4034, Sub_NPMI=0.0538, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.2863, PPL=10789.30, Parent_W_NPMI=-0.3919, Sub_NPMI=0.0251, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2374, PPL=10274.63, Parent_W_NPMI=-0.4713, Sub_NPMI=0.0386, Converged=Yes
#
# --- 组合 22/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.4336, PPL=12501.21, Parent_W_NPMI=0.0631, Sub_NPMI=0.0285, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4843, PPL=13151.01, Parent_W_NPMI=0.0551, Sub_NPMI=0.0239, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3238, PPL=11202.02, Parent_W_NPMI=0.0269, Sub_NPMI=0.0268, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1782, PPL=9683.53, Parent_W_NPMI=-0.0185, Sub_NPMI=0.0339, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3011, PPL=10950.59, Parent_W_NPMI=0.0536, Sub_NPMI=0.0324, Converged=No
#
# --- 组合 23/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.5439, PPL=37945.09, Parent_W_NPMI=0.0129, Sub_NPMI=0.0289, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.1826, PPL=26438.73, Parent_W_NPMI=0.0794, Sub_NPMI=0.0451, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8818, PPL=19571.57, Parent_W_NPMI=-0.0258, Sub_NPMI=0.0372, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9725, PPL=21429.53, Parent_W_NPMI=0.0004, Sub_NPMI=0.0433, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.8953, PPL=19835.99, Parent_W_NPMI=-0.0574, Sub_NPMI=0.0461, Converged=Yes
#
# --- 组合 24/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.9688, PPL=7853.90, Parent_W_NPMI=-0.4708, Sub_NPMI=0.0602, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8440, PPL=6932.83, Parent_W_NPMI=-0.2982, Sub_NPMI=0.0430, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.8566, PPL=7020.31, Parent_W_NPMI=-0.4554, Sub_NPMI=0.0456, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.8300, PPL=6836.48, Parent_W_NPMI=-0.4815, Sub_NPMI=0.0498, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.7335, PPL=6207.67, Parent_W_NPMI=-0.4120, Sub_NPMI=0.0326, Converged=Yes
#
# --- 组合 25/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3009, PPL=10948.00, Parent_W_NPMI=0.0211, Sub_NPMI=0.0277, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4205, PPL=12339.35, Parent_W_NPMI=0.0355, Sub_NPMI=0.0257, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3418, PPL=11404.66, Parent_W_NPMI=0.0497, Sub_NPMI=0.0258, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3625, PPL=11643.24, Parent_W_NPMI=0.0490, Sub_NPMI=0.0282, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.6983, PPL=16290.48, Parent_W_NPMI=0.0351, Sub_NPMI=0.0267, Converged=Yes
#
# --- 组合 26/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.9791, PPL=21570.03, Parent_W_NPMI=-0.0638, Sub_NPMI=0.0403, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0941, PPL=24199.32, Parent_W_NPMI=-0.0450, Sub_NPMI=0.0467, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8643, PPL=19230.79, Parent_W_NPMI=0.0018, Sub_NPMI=0.0491, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.6597, PPL=15673.09, Parent_W_NPMI=-0.0426, Sub_NPMI=0.0443, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.8145, PPL=18297.83, Parent_W_NPMI=-0.0138, Sub_NPMI=0.0552, Converged=No
#
# --- 组合 27/54: 测试 K1=10, K2=100, Alpha=1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.1771, PPL=3558.42, Parent_W_NPMI=-0.5502, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.1690, PPL=3529.82, Parent_W_NPMI=-0.5502, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.7409, PPL=6253.32, Parent_W_NPMI=-0.4136, Sub_NPMI=0.0419, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.1879, PPL=3597.16, Parent_W_NPMI=-0.5502, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4866, PPL=4849.35, Parent_W_NPMI=-0.5443, Sub_NPMI=0.0118, Converged=Yes
#
# --- 组合 28/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4912, PPL=4871.64, Parent_W_NPMI=-0.0015, Sub_NPMI=0.0145, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.3732, PPL=4329.28, Parent_W_NPMI=0.0347, Sub_NPMI=0.0279, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.4202, PPL=4537.77, Parent_W_NPMI=0.0130, Sub_NPMI=0.0271, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.5748, PPL=5296.65, Parent_W_NPMI=0.0315, Sub_NPMI=0.0267, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4964, PPL=4897.07, Parent_W_NPMI=0.0310, Sub_NPMI=0.0312, Converged=Yes
#
# --- 组合 29/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.6579, PPL=15645.52, Parent_W_NPMI=0.0133, Sub_NPMI=0.0336, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3786, PPL=11832.34, Parent_W_NPMI=0.0257, Sub_NPMI=0.0393, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.6214, PPL=15084.70, Parent_W_NPMI=0.0282, Sub_NPMI=0.0345, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3759, PPL=11800.33, Parent_W_NPMI=0.0262, Sub_NPMI=0.0381, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.5396, PPL=13900.05, Parent_W_NPMI=0.0157, Sub_NPMI=0.0318, Converged=Yes
#
# --- 组合 30/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.7941, PPL=6595.00, Parent_W_NPMI=-0.3237, Sub_NPMI=0.0302, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8001, PPL=6635.03, Parent_W_NPMI=-0.3183, Sub_NPMI=0.0481, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.2831, PPL=10755.17, Parent_W_NPMI=-0.3514, Sub_NPMI=0.0199, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3017, PPL=10956.82, Parent_W_NPMI=-0.3308, Sub_NPMI=0.0303, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9806, PPL=7947.39, Parent_W_NPMI=-0.2894, Sub_NPMI=0.0191, Converged=Yes
#
# --- 组合 31/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4174, PPL=4525.20, Parent_W_NPMI=0.0486, Sub_NPMI=0.0209, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.5312, PPL=5070.62, Parent_W_NPMI=0.0441, Sub_NPMI=0.0243, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.4826, PPL=4830.22, Parent_W_NPMI=0.0298, Sub_NPMI=0.0317, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.4494, PPL=4672.28, Parent_W_NPMI=0.0125, Sub_NPMI=0.0266, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.4623, PPL=4732.85, Parent_W_NPMI=0.0285, Sub_NPMI=0.0260, Converged=Yes
#
# --- 组合 32/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3558, PPL=11566.12, Parent_W_NPMI=0.0638, Sub_NPMI=0.0338, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5814, PPL=14492.44, Parent_W_NPMI=0.0328, Sub_NPMI=0.0482, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4416, PPL=12602.31, Parent_W_NPMI=0.0086, Sub_NPMI=0.0409, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.6390, PPL=15352.67, Parent_W_NPMI=0.0490, Sub_NPMI=0.0377, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.5208, PPL=13641.05, Parent_W_NPMI=0.0344, Sub_NPMI=0.0422, Converged=Yes
#
# --- 组合 33/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.0696, PPL=3195.75, Parent_W_NPMI=-0.3886, Sub_NPMI=0.0698, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.1359, PPL=3414.91, Parent_W_NPMI=-0.4164, Sub_NPMI=0.0546, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.3490, PPL=4226.05, Parent_W_NPMI=-0.3624, Sub_NPMI=0.0354, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.4698, PPL=4768.73, Parent_W_NPMI=-0.3667, Sub_NPMI=0.0446, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.3670, PPL=4302.89, Parent_W_NPMI=-0.3069, Sub_NPMI=0.0239, Converged=Yes
#
# --- 组合 34/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.4161, PPL=4519.30, Parent_W_NPMI=0.0288, Sub_NPMI=0.0282, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.4171, PPL=4523.56, Parent_W_NPMI=0.0445, Sub_NPMI=0.0290, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.4988, PPL=4908.70, Parent_W_NPMI=0.0319, Sub_NPMI=0.0155, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.4834, PPL=4833.91, Parent_W_NPMI=0.0722, Sub_NPMI=0.0252, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.2983, PPL=4016.89, Parent_W_NPMI=0.0424, Sub_NPMI=0.0215, Converged=No
#
# --- 组合 35/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.5655, PPL=14264.79, Parent_W_NPMI=-0.0072, Sub_NPMI=0.0307, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4426, PPL=12614.28, Parent_W_NPMI=0.0569, Sub_NPMI=0.0435, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3074, PPL=11019.15, Parent_W_NPMI=0.0428, Sub_NPMI=0.0412, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5713, PPL=14346.45, Parent_W_NPMI=0.0629, Sub_NPMI=0.0436, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4737, PPL=13012.50, Parent_W_NPMI=0.0288, Sub_NPMI=0.0402, Converged=Yes
#
# --- 组合 36/54: 测试 K1=20, K2=80, Alpha=0.1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.0278, PPL=3065.03, Parent_W_NPMI=-0.3156, Sub_NPMI=0.0820, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.1800, PPL=3568.99, Parent_W_NPMI=-0.3633, Sub_NPMI=0.0889, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.0669, PPL=3187.16, Parent_W_NPMI=-0.3749, Sub_NPMI=0.0638, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-7.7583, PPL=2340.95, Parent_W_NPMI=-0.4705, Sub_NPMI=0.0437, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-7.7196, PPL=2252.09, Parent_W_NPMI=-0.4686, Sub_NPMI=0.0794, Converged=Yes
#
# --- 组合 37/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3244, PPL=11208.32, Parent_W_NPMI=0.0510, Sub_NPMI=0.0305, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2868, PPL=10794.32, Parent_W_NPMI=0.0360, Sub_NPMI=0.0286, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5112, PPL=13510.67, Parent_W_NPMI=0.0308, Sub_NPMI=0.0221, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3529, PPL=11531.85, Parent_W_NPMI=0.0449, Sub_NPMI=0.0340, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3074, PPL=11019.58, Parent_W_NPMI=0.0376, Sub_NPMI=0.0328, Converged=No
#
# --- 组合 38/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.8568, PPL=19087.99, Parent_W_NPMI=0.0340, Sub_NPMI=0.0522, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.2177, PPL=27383.54, Parent_W_NPMI=0.0294, Sub_NPMI=0.0385, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9245, PPL=20424.20, Parent_W_NPMI=0.0277, Sub_NPMI=0.0363, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9363, PPL=20667.77, Parent_W_NPMI=-0.0025, Sub_NPMI=0.0276, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9708, PPL=21393.34, Parent_W_NPMI=0.0300, Sub_NPMI=0.0415, Converged=No
#
# --- 组合 39/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3241, PPL=11204.42, Parent_W_NPMI=-0.2789, Sub_NPMI=0.0355, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.4184, PPL=12312.36, Parent_W_NPMI=-0.3291, Sub_NPMI=0.0285, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.9891, PPL=8015.62, Parent_W_NPMI=-0.3496, Sub_NPMI=0.0512, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9874, PPL=8001.49, Parent_W_NPMI=-0.4139, Sub_NPMI=0.0696, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.7918, PPL=6580.25, Parent_W_NPMI=-0.3553, Sub_NPMI=0.0755, Converged=Yes
#
# --- 组合 40/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3339, PPL=11315.00, Parent_W_NPMI=0.0319, Sub_NPMI=0.0220, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2607, PPL=10516.23, Parent_W_NPMI=0.0069, Sub_NPMI=0.0230, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.3872, PPL=11934.46, Parent_W_NPMI=-0.0031, Sub_NPMI=0.0272, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5625, PPL=14221.38, Parent_W_NPMI=0.0246, Sub_NPMI=0.0205, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.6457, PPL=15455.32, Parent_W_NPMI=0.0388, Sub_NPMI=0.0232, Converged=Yes
#
# --- 组合 41/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.9179, PPL=20290.34, Parent_W_NPMI=0.0391, Sub_NPMI=0.0424, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.8801, PPL=19537.22, Parent_W_NPMI=0.0162, Sub_NPMI=0.0493, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.9435, PPL=20815.78, Parent_W_NPMI=0.0576, Sub_NPMI=0.0465, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9474, PPL=20898.02, Parent_W_NPMI=0.0015, Sub_NPMI=0.0426, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.3277, PPL=30568.04, Parent_W_NPMI=0.0271, Sub_NPMI=0.0333, Converged=Yes
#
# --- 组合 42/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2013, PPL=9909.99, Parent_W_NPMI=-0.3492, Sub_NPMI=0.0908, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.3476, PPL=11471.03, Parent_W_NPMI=-0.3499, Sub_NPMI=0.0427, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-8.9556, PPL=7750.83, Parent_W_NPMI=-0.3287, Sub_NPMI=0.0636, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.5402, PPL=5116.19, Parent_W_NPMI=-0.5457, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2747, PPL=10664.95, Parent_W_NPMI=-0.2939, Sub_NPMI=0.0587, Converged=Yes
#
# --- 组合 43/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.3212, PPL=11172.62, Parent_W_NPMI=0.0581, Sub_NPMI=0.0316, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.1815, PPL=9715.76, Parent_W_NPMI=0.0544, Sub_NPMI=0.0391, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.2469, PPL=10371.87, Parent_W_NPMI=0.0123, Sub_NPMI=0.0251, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.1832, PPL=9731.84, Parent_W_NPMI=0.0403, Sub_NPMI=0.0272, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.2642, PPL=10553.59, Parent_W_NPMI=0.0372, Sub_NPMI=0.0217, Converged=No
#
# --- 组合 44/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.8657, PPL=19257.76, Parent_W_NPMI=0.0188, Sub_NPMI=0.0464, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.8684, PPL=19309.70, Parent_W_NPMI=0.0625, Sub_NPMI=0.0455, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.0268, PPL=22625.45, Parent_W_NPMI=0.0423, Sub_NPMI=0.0330, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0340, PPL=22788.07, Parent_W_NPMI=0.0335, Sub_NPMI=0.0452, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9467, PPL=20882.21, Parent_W_NPMI=0.0476, Sub_NPMI=0.0481, Converged=No
#
# --- 组合 45/54: 测试 K1=20, K2=80, Alpha=0.5, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.9499, PPL=7706.77, Parent_W_NPMI=-0.3540, Sub_NPMI=0.0962, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.0246, PPL=8304.97, Parent_W_NPMI=-0.4688, Sub_NPMI=0.0716, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1571, PPL=9481.68, Parent_W_NPMI=-0.2544, Sub_NPMI=0.1043, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.6911, PPL=5949.50, Parent_W_NPMI=-0.5454, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.0296, PPL=8346.49, Parent_W_NPMI=-0.2869, Sub_NPMI=0.0912, Converged=Yes
#
# --- 组合 46/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.7170, PPL=16597.43, Parent_W_NPMI=0.0361, Sub_NPMI=0.0231, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.7273, PPL=16769.74, Parent_W_NPMI=0.0401, Sub_NPMI=0.0163, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5416, PPL=13926.86, Parent_W_NPMI=0.0189, Sub_NPMI=0.0294, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4458, PPL=12655.42, Parent_W_NPMI=0.0038, Sub_NPMI=0.0248, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4899, PPL=13226.06, Parent_W_NPMI=0.0460, Sub_NPMI=0.0359, Converged=No
#
# --- 组合 47/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.1155, PPL=24723.92, Parent_W_NPMI=0.0349, Sub_NPMI=0.0406, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-10.0145, PPL=22348.83, Parent_W_NPMI=0.0109, Sub_NPMI=0.0548, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-10.1719, PPL=26157.42, Parent_W_NPMI=0.0314, Sub_NPMI=0.0411, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.0679, PPL=23573.79, Parent_W_NPMI=-0.0065, Sub_NPMI=0.0503, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-10.2598, PPL=28561.11, Parent_W_NPMI=0.0377, Sub_NPMI=0.0426, Converged=Yes
#
# --- 组合 48/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.2358, PPL=10257.82, Parent_W_NPMI=-0.3964, Sub_NPMI=0.0664, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.2895, PPL=10824.29, Parent_W_NPMI=-0.3354, Sub_NPMI=0.0541, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.5296, PPL=13761.10, Parent_W_NPMI=-0.2970, Sub_NPMI=0.0318, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.3813, PPL=11864.07, Parent_W_NPMI=-0.3614, Sub_NPMI=0.0611, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4792, PPL=13084.35, Parent_W_NPMI=-0.3674, Sub_NPMI=0.0533, Converged=Yes
#
# --- 组合 49/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.5, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.7016, PPL=16343.40, Parent_W_NPMI=0.0243, Sub_NPMI=0.0296, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.7313, PPL=16836.27, Parent_W_NPMI=0.0320, Sub_NPMI=0.0270, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.6389, PPL=15351.10, Parent_W_NPMI=0.0315, Sub_NPMI=0.0250, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5497, PPL=14040.13, Parent_W_NPMI=0.0416, Sub_NPMI=0.0294, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3901, PPL=11969.17, Parent_W_NPMI=0.0254, Sub_NPMI=0.0353, Converged=No
#
# --- 组合 50/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.5, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-10.1374, PPL=25271.66, Parent_W_NPMI=0.0062, Sub_NPMI=0.0475, Converged=No
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.9815, PPL=21622.53, Parent_W_NPMI=0.0411, Sub_NPMI=0.0430, Converged=No
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.8714, PPL=19369.28, Parent_W_NPMI=0.0220, Sub_NPMI=0.0467, Converged=No
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-10.1256, PPL=24973.27, Parent_W_NPMI=-0.0101, Sub_NPMI=0.0443, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9995, PPL=22015.34, Parent_W_NPMI=-0.0217, Sub_NPMI=0.0461, Converged=Yes
#
# --- 组合 51/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=0.5, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.1397, PPL=9317.79, Parent_W_NPMI=-0.3816, Sub_NPMI=0.0774, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.6295, PPL=15207.05, Parent_W_NPMI=-0.4001, Sub_NPMI=0.0887, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.0940, PPL=8902.04, Parent_W_NPMI=-0.4795, Sub_NPMI=0.0772, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.5641, PPL=14244.11, Parent_W_NPMI=-0.3837, Sub_NPMI=0.0657, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.4942, PPL=13282.62, Parent_W_NPMI=-0.4057, Sub_NPMI=0.0751, Converged=No
#
# --- 组合 52/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=1, Eta=0.01 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.6249, PPL=15137.42, Parent_W_NPMI=-0.0156, Sub_NPMI=0.0283, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.5307, PPL=13776.03, Parent_W_NPMI=0.0138, Sub_NPMI=0.0214, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.4439, PPL=12631.27, Parent_W_NPMI=0.0572, Sub_NPMI=0.0289, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.4444, PPL=12637.44, Parent_W_NPMI=0.0308, Sub_NPMI=0.0305, Converged=No
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.3587, PPL=11599.73, Parent_W_NPMI=0.0531, Sub_NPMI=0.0331, Converged=Yes
#
# --- 组合 53/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=1, Eta=0.1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-9.7523, PPL=17193.59, Parent_W_NPMI=0.0047, Sub_NPMI=0.0614, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-9.6416, PPL=15392.44, Parent_W_NPMI=0.0531, Sub_NPMI=0.0643, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.7868, PPL=17796.47, Parent_W_NPMI=0.0001, Sub_NPMI=0.0541, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-9.9359, PPL=20658.14, Parent_W_NPMI=0.0152, Sub_NPMI=0.0504, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-9.9739, PPL=21458.51, Parent_W_NPMI=0.0372, Sub_NPMI=0.0551, Converged=Yes
#
# --- 组合 54/54: 测试 K1=20, K2=80, Alpha=1, Subalpha=1, Eta=1 ---
#   - 运行 1/5 (seed=42)...
#     => 结果: LL/word=-8.8235, PPL=6792.33, Parent_W_NPMI=-0.5448, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 2/5 (seed=43)...
#     => 结果: LL/word=-8.8707, PPL=7119.97, Parent_W_NPMI=-0.5502, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 3/5 (seed=44)...
#     => 结果: LL/word=-9.1025, PPL=8977.44, Parent_W_NPMI=-0.5502, Sub_NPMI=0.0139, Converged=Yes
#   - 运行 4/5 (seed=45)...
#     => 结果: LL/word=-8.9973, PPL=8081.02, Parent_W_NPMI=-0.5174, Sub_NPMI=0.0510, Converged=Yes
#   - 运行 5/5 (seed=46)...
#     => 结果: LL/word=-8.9477, PPL=7690.20, Parent_W_NPMI=-0.5210, Sub_NPMI=0.0139, Converged=Yes
#
#
# ✅ PAM 全面网格搜索完成!
#
# 🏆 所有运行中 Parent_Weighted_NPMI 最高的一次参数: K=[10, 100], Alpha=0.1, Subalpha=1, Eta=0.01 (NPMI: 0.1248)
#
#
# 🎉 PAM 网格搜索完成！
# 🏆 找到的最佳超参数 (基于全局单次运行最高 Parent_Weighted_NPMI): K=[10, 100], Alpha=0.1, Subalpha=1, Eta=0.01
#
# 🔍 对最佳PAM模型的【父主题】进行分析:
#
# 🔍 Best PAM (Super-Topics) Topic Analysis (showing top 10 words):
# ================================================================================
# Topic   0 (weight:0.237): crack(0.237), fracture(0.173), phasefield(0.077), propagation(0.058), ductile(0.027)
# Topic   1 (weight:0.378): contact(0.378), surface(0.066), problem(0.054), algorithm(0.047), friction(0.039)
# Topic   2 (weight:0.064): st(0.064), flow(0.059), method(0.058), computational(0.048), mesh(0.040)
# Topic   3 (weight:0.095): heart(0.095), concentration(0.082), tissue(0.078), cardiac(0.073), stress(0.056)
# Topic   4 (weight:0.169): nonlocal(0.169), peridynamic(0.086), theory(0.066), operator(0.061), continuum(0.050)
# Topic   5 (weight:0.111): network(0.111), data(0.093), neural(0.060), learn(0.057), deep(0.047)
# Topic   6 (weight:0.113): multiscale(0.113), scale(0.097), macroscopic(0.058), macroscale(0.056), microscale(0.055)
# Topic   7 (weight:0.057): two(0.057), first(0.049), show(0.048), three(0.043), example(0.040)
# Topic   8 (weight:0.113): al(0.113), et(0.110), mech(0.108), comput(0.096), eng(0.093)
# Topic   9 (weight:0.184): strain(0.184), deformation(0.084), stress(0.063), constitutive(0.043), plasticity(0.041)
#
# 📊 Best PAM (Super-Topics) Topic Statistics:
#    - Active topics: 10/10
#    - Topic activity rate: 100.0%
#
# 🔬 对最佳PAM模型的【子主题】进行评估:
#
# --- PAM 最终全部运行调优结果 ---
#      K1   K2  Alpha  Subalpha   Eta  Run_Index  Parent_Weighted_NPMI  Sub_NPMI    Perplexity  Parent_Weighted_Cv    Sub_Cv  Parent_Renyi_Entropy  Sub_Renyi_Entropy  Parent_JSD_Diversity  Sub_JSD_Diversity  LL_per_word Converged  Iterations    Time_sec
# 0    10  100    0.1       0.1  0.01          1              0.021833  0.027469   5186.188186            0.497940  0.522762              3.272341           5.419183              0.964461           0.495164    -8.553754       Yes        1070  231.161374
# 1    10  100    0.1       0.1  0.01          2              0.031784  0.028896   6053.492292            0.545583  0.520392              2.876775           5.420508              0.984987           0.481405    -8.708391       Yes         940  195.422477
# 2    10  100    0.1       0.1  0.01          3              0.016944  0.025242   5219.106931            0.494726  0.517580              3.035724           5.420351              0.983951           0.491257    -8.560082       Yes        1040  220.346909
# 3    10  100    0.1       0.1  0.01          4              0.027228  0.032788   6546.997663            0.498190  0.525391              3.004707           5.424973              0.978947           0.473298    -8.786762       Yes         720  144.765708
# 4    10  100    0.1       0.1  0.01          5              0.078643  0.027235   5972.881156            0.532136  0.512575              3.096238           5.411257              0.960494           0.487955    -8.694985       Yes         800  159.542918
# 5    10  100    0.1       0.1  0.10          1              0.047589  0.041377  12346.623029            0.552582  0.535655              4.508549           5.119537              0.966812           0.658983    -9.421138        No        1200  258.866448
# 6    10  100    0.1       0.1  0.10          2              0.022586  0.051826  13735.466652            0.499814  0.537124              4.460706           5.126662              0.962933           0.654963    -9.527737       Yes         670  126.099828
# 7    10  100    0.1       0.1  0.10          3              0.053633  0.052101  13086.496414            0.497492  0.539274              4.419262           5.108770              0.957819           0.664604    -9.479336       Yes         950  184.554219
# 8    10  100    0.1       0.1  0.10          4              0.039874  0.044767  12253.507722            0.552132  0.534604              4.148060           5.113271              0.969592           0.661651    -9.413568       Yes         940  178.585333
# 9    10  100    0.1       0.1  0.10          5              0.089816  0.051872  13442.568448            0.563583  0.543428              4.167447           5.141711              0.966272           0.653578    -9.506182       Yes         750  149.206696
# 10   10  100    0.1       0.1  1.00          1             -0.489328  0.052050   7763.529090            0.490996  0.522562              7.298153           4.740447              0.487801           0.742627    -8.957192       Yes         830  160.624721
# 11   10  100    0.1       0.1  1.00          2             -0.483670  0.043578   7787.958333            0.502256  0.517081              7.286489           4.851828              0.447452           0.737947    -8.960334       Yes         410   68.297115
# 12   10  100    0.1       0.1  1.00          3             -0.486698  0.039455   7057.427475            0.509676  0.526449              7.294568           4.819667              0.352552           0.738150    -8.861836       Yes        1150  243.976338
# 13   10  100    0.1       0.1  1.00          4             -0.415330  0.009750   8062.222784            0.500039  0.508140              7.179473           4.873433              0.632683           0.709303    -8.994945       Yes        1200  256.408510
# 14   10  100    0.1       0.1  1.00          5             -0.326761  0.027945   7591.114342            0.461407  0.515416              7.111619           4.843994              0.893511           0.737872    -8.934734       Yes         520   93.056571
# 15   10  100    0.1       0.5  0.01          1              0.048893  0.024901   4723.909128            0.521279  0.515511              2.771128           5.403322              0.970951           0.497756    -8.460392        No        1200  260.893413
# 16   10  100    0.1       0.5  0.01          2              0.022504  0.019931   5346.549784            0.502770  0.516131              2.799112           5.446804              0.980521           0.472576    -8.584207       Yes         720  124.518163
# 17   10  100    0.1       0.5  0.01          3              0.062182  0.034259   5107.709730            0.548205  0.527749              2.778674           5.412497              0.985147           0.495129    -8.538506       Yes        1140  247.050149
# 18   10  100    0.1       0.5  0.01          4              0.017036  0.030165   5792.820097            0.585087  0.517097              3.060938           5.426765              0.969069           0.479164    -8.664375       Yes         720  144.892156
# 19   10  100    0.1       0.5  0.01          5              0.020255  0.028301   4723.509757            0.496970  0.521420              2.876945           5.421546              0.980139           0.485863    -8.460307        No        1200  255.131621
# 20   10  100    0.1       0.5  0.10          1              0.013938  0.048289  14199.595174            0.537161  0.539130              4.307363           5.139716              0.970782           0.650851    -9.560969       Yes         610  118.017720
# 21   10  100    0.1       0.5  0.10          2             -0.059311  0.036237  13547.182852            0.428855  0.536559              4.491985           5.162978              0.979114           0.640680    -9.513934       Yes         410   69.642597
# 22   10  100    0.1       0.5  0.10          3              0.046871  0.055931  12392.121632            0.505061  0.544803              4.342095           5.106261              0.973280           0.665154    -9.424816        No        1200  259.267442
# 23   10  100    0.1       0.5  0.10          4             -0.022500  0.045840  12081.086915            0.544736  0.536762              4.553051           5.142151              0.971204           0.645157    -9.399396        No        1200  260.240141
# 24   10  100    0.1       0.5  0.10          5              0.035059  0.045815  12217.405909            0.527141  0.537361              4.357350           5.132124              0.971686           0.649843    -9.410617        No        1200  257.577175
# 25   10  100    0.1       0.5  1.00          1             -0.388655  0.023715   5451.419580            0.510086  0.514956              7.104980           4.828271              0.620265           0.767329    -8.603631        No        1200  260.271190
# 26   10  100    0.1       0.5  1.00          2             -0.472599  0.051237   5607.677320            0.507519  0.518504              7.295233           4.755933              0.538219           0.752469    -8.631892        No        1200  249.228834
# 27   10  100    0.1       0.5  1.00          3             -0.346905  0.047629   3889.545894            0.454439  0.514981              7.007344           4.810714              0.812211           0.771582    -8.266048       Yes         810  157.905790
# 28   10  100    0.1       0.5  1.00          4             -0.329165  0.026688   4103.945217            0.428865  0.502223              7.146253           4.794144              0.946089           0.790222    -8.319704       Yes         490   88.179652
# 29   10  100    0.1       0.5  1.00          5             -0.443214  0.029468   4877.769324            0.461703  0.500449              7.272008           4.743841              0.779515           0.782420    -8.492443        No        1200  260.726768
# 30   10  100    0.1       1.0  0.01          1              0.042357  0.021467   5917.764984            0.469785  0.514316              3.190870           5.438249              0.983918           0.480856    -8.685714       Yes         590  112.331253
# 31   10  100    0.1       1.0  0.01          2              0.124770  0.025565   4749.825034            0.646618  0.518450              2.934615           5.416563              0.985062           0.503360    -8.465863        No        1200  246.524243
# 32   10  100    0.1       1.0  0.01          3              0.066930  0.031640   6442.280931            0.578861  0.526905              3.179482           5.445368              0.972628           0.469641    -8.770638       Yes         560  105.359323
# 33   10  100    0.1       1.0  0.01          4              0.050799  0.028984   4649.016812            0.518091  0.518693              2.876425           5.418998              0.969923           0.490304    -8.444411        No        1200  257.357476
# 34   10  100    0.1       1.0  0.01          5              0.031196  0.025981   4752.093139            0.520518  0.517149              3.101490           5.413171              0.965967           0.492217    -8.466340        No        1200  259.017733
# 35   10  100    0.1       1.0  0.10          1              0.011280  0.048398  13945.221942            0.473528  0.537870              4.062320           5.143752              0.963696           0.643869    -9.542892       Yes         460   80.961565
# 36   10  100    0.1       1.0  0.10          2              0.013359  0.043758  13315.387881            0.488052  0.536446              4.475291           5.149914              0.977136           0.651925    -9.496676       Yes         710  141.030865
# 37   10  100    0.1       1.0  0.10          3             -0.022745  0.052227  11768.176713            0.545383  0.541868              4.582176           5.121123              0.976112           0.660824    -9.373154       Yes         970  202.771034
# 38   10  100    0.1       1.0  0.10          4              0.039738  0.043577  13159.887641            0.554428  0.536851              3.803048           5.112012              0.957647           0.650165    -9.484929       Yes         680  131.073318
# 39   10  100    0.1       1.0  0.10          5             -0.001837  0.051702  13359.470506            0.453933  0.542551              4.221721           5.129983              0.962064           0.662171    -9.499981       Yes         620  118.131896
# ...
# 207  20   80    0.5       0.5  1.00          3             -0.328748  0.063605   7750.832115            0.457789  0.525202              7.087114           4.465640              0.910028           0.842048    -8.955555       Yes         270   43.567999
# 208  20   80    0.5       0.5  1.00          4             -0.545717  0.013899   5116.190664            0.548747  0.480785              7.305533           5.807704              0.100000           0.058864    -8.540165       Yes         340   68.601500
# 209  20   80    0.5       0.5  1.00          5             -0.293941  0.058702  10664.951826            0.451959  0.541425              6.982271           4.421436              0.962650           0.844224    -9.274718       Yes         390   89.076687
# 210  20   80    0.5       1.0  0.01          1              0.058090  0.031646  11172.622485            0.552312  0.521840              2.867505           5.443276              0.983549           0.466453    -9.321222       Yes         850  262.892696
# 211  20   80    0.5       1.0  0.01          2              0.054363  0.039073   9715.757734            0.560668  0.530496              2.786691           5.394357              0.980257           0.510420    -9.181504        No        1200  399.072375
# 212  20   80    0.5       1.0  0.01          3              0.012336  0.025066  10371.865240            0.502122  0.517265              2.930181           5.458372              0.980197           0.465641    -9.246852        No        1200  396.495261
# 213  20   80    0.5       1.0  0.01          4              0.040303  0.027203   9731.840611            0.495418  0.525763              2.869573           5.423725              0.975187           0.492124    -9.183158       Yes        1030  331.108077
# 214  20   80    0.5       1.0  0.01          5              0.037199  0.021654  10553.588058            0.503032  0.513122              2.959496           5.482358              0.979383           0.443097    -9.264221        No        1200  394.584501
# 215  20   80    0.5       1.0  0.10          1              0.018753  0.046360  19257.763113            0.513544  0.541804              3.958526           5.177865              0.975740           0.641991    -9.865670        No        1200  397.183680
# 216  20   80    0.5       1.0  0.10          2              0.062488  0.045529  19309.701277            0.534291  0.540559              3.968564           5.214482              0.972734           0.617906    -9.868363        No        1200  391.540522
# 217  20   80    0.5       1.0  0.10          3              0.042261  0.032967  22625.452300            0.559460  0.531243              3.936447           5.258079              0.964484           0.606455   -10.026831       Yes         320   62.282292
# 218  20   80    0.5       1.0  0.10          4              0.033514  0.045245  22788.070110            0.519198  0.543388              4.108278           5.248218              0.963604           0.616964   -10.033992       Yes         520  136.930798
# 219  20   80    0.5       1.0  0.10          5              0.047591  0.048081  20882.208387            0.575372  0.542985              3.940875           5.150183              0.977979           0.644027    -9.946653        No        1200  396.236192
# 220  20   80    0.5       1.0  1.00          1             -0.354001  0.096161   7706.774975            0.462201  0.548963              7.080179           4.535980              0.830130           0.843383    -8.949855       Yes         710  208.108375
# 221  20   80    0.5       1.0  1.00          2             -0.468760  0.071553   8304.965734            0.512311  0.555063              7.170383           4.661261              0.415727           0.849201    -9.024609       Yes         300   54.249906
# 222  20   80    0.5       1.0  1.00          3             -0.254428  0.104338   9481.682681            0.459880  0.565466              6.953760           4.474478              0.970673           0.854221    -9.157117       Yes         670  195.647714
# 223  20   80    0.5       1.0  1.00          4             -0.545386  0.013899   5949.497460            0.548650  0.480785              7.306364           5.804443              0.031803           0.000097    -8.691062       Yes         280   46.233716
# 224  20   80    0.5       1.0  1.00          5             -0.286914  0.091247   8346.490785            0.432101  0.548694              7.000354           4.377558              0.965309           0.855593    -9.029596       Yes         310   58.522831
# 225  20   80    1.0       0.1  0.01          1              0.036113  0.023113  16597.429024            0.511364  0.516915              2.771853           5.458426              0.988861           0.479721    -9.717003       Yes        1040  329.676837
# 226  20   80    1.0       0.1  0.01          2              0.040101  0.016340  16769.743419            0.540763  0.506720              2.811175           5.506392              0.983714           0.426648    -9.727332       Yes         700  204.100783
# 227  20   80    1.0       0.1  0.01          3              0.018939  0.029364  13926.861497            0.525113  0.519620              2.725509           5.452252              0.983208           0.476502    -9.541575       Yes        1010  320.355572
# 228  20   80    1.0       0.1  0.01          4              0.003752  0.024834  12655.420237            0.512342  0.518463              2.607206           5.477251              0.981678           0.457499    -9.445841        No        1200  397.366342
# 229  20   80    1.0       0.1  0.01          5              0.045969  0.035907  13226.062435            0.562013  0.531090              2.765619           5.403288              0.986034           0.510048    -9.489945        No        1200  394.665872
# 230  20   80    1.0       0.1  0.10          1              0.034895  0.040594  24723.923339            0.565104  0.536451              3.957951           5.286531              0.977348           0.592605   -10.115527       Yes         730  219.450328
# 231  20   80    1.0       0.1  0.10          2              0.010885  0.054753  22348.827179            0.509047  0.554510              3.831144           5.217703              0.971862           0.624611   -10.014529        No        1200  392.142509
# 232  20   80    1.0       0.1  0.10          3              0.031364  0.041063  26157.423707            0.541920  0.541156              3.834878           5.281978              0.978479           0.582175   -10.171888       Yes         980  313.387913
# 233  20   80    1.0       0.1  0.10          4             -0.006469  0.050272  23573.790693            0.502157  0.541775              3.844047           5.217897              0.982877           0.621062   -10.067891        No        1200  396.569469
# 234  20   80    1.0       0.1  0.10          5              0.037724  0.042578  28561.113490            0.553680  0.548959              3.808561           5.302840              0.977279           0.569402   -10.259801       Yes         810  249.758575
# 235  20   80    1.0       0.1  1.00          1             -0.396437  0.066443  10257.815024            0.442679  0.529895              7.209960           4.540182              0.884330           0.837716    -9.235795       Yes        1190  389.217754
# 236  20   80    1.0       0.1  1.00          2             -0.335445  0.054081  10824.286692            0.432928  0.530500              7.162961           4.584969              0.973824           0.840485    -9.289548       Yes         260   40.733704
# 237  20   80    1.0       0.1  1.00          3             -0.296966  0.031796  13761.096697            0.440139  0.510586              6.942898           4.656085              0.980281           0.803371    -9.529601       Yes         520  138.543715
# 238  20   80    1.0       0.1  1.00          4             -0.361442  0.061110  11864.065534            0.428413  0.545773              7.076789           4.510481              0.905959           0.839691    -9.381269       Yes         620  173.324798
# 239  20   80    1.0       0.1  1.00          5             -0.367370  0.053317  13084.354889            0.440576  0.508754              7.137554           4.459341              0.931065           0.849900    -9.479173       Yes         900  258.481264
# 240  20   80    1.0       0.5  0.01          1              0.024304  0.029630  16343.404049            0.524618  0.519938              2.774908           5.459033              0.976841           0.460451    -9.701580       Yes         620  178.200505
# 241  20   80    1.0       0.5  0.01          2              0.031968  0.026990  16836.269968            0.512300  0.521394              2.968783           5.459998              0.974846           0.460248    -9.731291       Yes        1010  326.158840
# 242  20   80    1.0       0.5  0.01          3              0.031513  0.025007  15351.100781            0.526949  0.519749              2.987381           5.473041              0.975421           0.456781    -9.638942        No        1200  396.735844
# 243  20   80    1.0       0.5  0.01          4              0.041630  0.029388  14040.133769            0.534450  0.521697              2.763112           5.461596              0.983700           0.461377    -9.549675       Yes        1150  376.160857
# 244  20   80    1.0       0.5  0.01          5              0.025414  0.035293  11969.168643            0.529149  0.526577              2.831901           5.424126              0.981640           0.492469    -9.390089        No        1200  401.353581
# 245  20   80    1.0       0.5  0.10          1              0.006169  0.047492  25271.656217            0.543585  0.544953              3.737573           5.204612              0.982141           0.616680   -10.137439        No        1200  394.808788
# 246  20   80    1.0       0.5  0.10          2              0.041120  0.043036  21622.530595            0.567646  0.532666              3.989145           5.226044              0.976991           0.619491    -9.981491        No        1200  390.371907
# 247  20   80    1.0       0.5  0.10          3              0.022017  0.046692  19369.282821            0.542590  0.536796              3.929343           5.211507              0.978846           0.622835    -9.871444        No        1200  396.959875
# 248  20   80    1.0       0.5  0.10          4             -0.010122  0.044314  24973.271841            0.527547  0.539900              3.810704           5.260267              0.977862           0.593066   -10.125561       Yes        1020  326.863222
# 249  20   80    1.0       0.5  0.10          5             -0.021727  0.046056  22015.336672            0.471535  0.544977              3.987061           5.238509              0.980181           0.612237    -9.999495       Yes         730  215.862441
# 250  20   80    1.0       0.5  1.00          1             -0.381625  0.077433   9317.790044            0.476055  0.527223              7.061243           4.425926              0.791848           0.851068    -9.139681       Yes         300   54.860341
# 251  20   80    1.0       0.5  1.00          2             -0.400052  0.088687  15207.050626            0.440664  0.577595              7.193477           4.462151              0.863095           0.845033    -9.629514       Yes         780  231.547267
# 252  20   80    1.0       0.5  1.00          3             -0.479529  0.077210   8902.036898            0.520169  0.568241              7.194785           4.853523              0.414502           0.811039    -9.094035       Yes         260   39.110833
# 253  20   80    1.0       0.5  1.00          4             -0.383705  0.065664  14244.113365            0.513182  0.548467              7.165453           4.741982              0.713732           0.808879    -9.564099       Yes         430  103.441212
# 254  20   80    1.0       0.5  1.00          5             -0.405670  0.075090  13282.618794            0.478188  0.544047              7.061630           4.517491              0.779150           0.838784    -9.494212        No        1200  382.134776
# 255  20   80    1.0       1.0  0.01          1             -0.015598  0.028284  15137.415608            0.468811  0.520152              2.779827           5.479374              0.980425           0.463426    -9.624925       Yes         580  160.854251
# 256  20   80    1.0       1.0  0.01          2              0.013791  0.021419  13776.030605            0.534813  0.516434              2.952218           5.487167              0.984461           0.445325    -9.530685       Yes         650  189.581765
# 257  20   80    1.0       1.0  0.01          3              0.057227  0.028939  12631.273056            0.554814  0.523775              2.711978           5.436316              0.984558           0.480871    -9.443931       Yes        1140  373.962768
# 258  20   80    1.0       1.0  0.01          4              0.030752  0.030463  12637.436548            0.507180  0.516946              2.778496           5.454431              0.979130           0.476468    -9.444419        No        1200  395.359540
# 259  20   80    1.0       1.0  0.01          5              0.053084  0.033145  11599.727558            0.555191  0.529262              2.900135           5.402595              0.983459           0.513012    -9.358737       Yes        1080  350.731752
# 260  20   80    1.0       1.0  0.10          1              0.004696  0.061364  17193.593484            0.531703  0.550955              4.016761           5.012618              0.975220           0.706269    -9.752292       Yes         530  143.902767
# 261  20   80    1.0       1.0  0.10          2              0.053141  0.064251  15392.441909            0.552777  0.560268              3.848185           5.129872              0.978133           0.659023    -9.641632       Yes         860  264.962024
# 262  20   80    1.0       1.0  0.10          3              0.000119  0.054122  17796.466065            0.520053  0.553210              3.881304           5.135344              0.979640           0.656786    -9.786755       Yes         640  183.769090
# 263  20   80    1.0       1.0  0.10          4              0.015236  0.050411  20658.137155            0.542207  0.543509              3.822118           5.183510              0.977278           0.635398    -9.935865       Yes         790  238.945830
# 264  20   80    1.0       1.0  0.10          5              0.037222  0.055123  21458.509576            0.556764  0.547185              3.965147           5.161348              0.978177           0.653064    -9.973877       Yes         370   81.882889
# 265  20   80    1.0       1.0  1.00          1             -0.544790  0.013899   6792.326707            0.549938  0.480785              7.306333           5.805628              0.031924           0.033309    -8.823549       Yes         590  157.124286
# 266  20   80    1.0       1.0  1.00          2             -0.550182  0.013899   7119.968539            0.554059  0.480785              7.306531           5.804690              0.000000           0.060568    -8.870659       Yes         380   79.407412
# 267  20   80    1.0       1.0  1.00          3             -0.550182  0.013899   8977.444547            0.554059  0.480785              7.306531           5.802499              0.000000           0.000028    -9.102471       Yes         260   38.247445
# 268  20   80    1.0       1.0  1.00          4             -0.517422  0.051001   8081.021543            0.559046  0.563092              7.211653           5.660420              0.100000           0.343895    -8.997274       Yes         290   51.017486
# 269  20   80    1.0       1.0  1.00          5             -0.520992  0.013899   7690.202366            0.551035  0.480785              7.217903           5.807280              0.112994           0.061081    -8.947702       Yes         260   38.744841
#
# ✅ 结果已保存到: ./data/model_result/pam_full_grid_search_results_02.csv
